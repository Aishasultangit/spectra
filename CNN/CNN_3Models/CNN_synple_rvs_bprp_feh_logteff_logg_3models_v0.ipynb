# %% [markdown]
# # Train the StarNet Model
#
# This notebook takes you through the steps of how to train a StarNet Model
# - Required Python packages: `numpy h5py keras`
# - Required data files: training_data.h5, mean_and_std.npy
#
# Note: We use tensorflow for the keras backend.

# %%
import numpy as np
import h5py
import random
import keras
from keras.models import Model
from keras.layers import Input, Dense, InputLayer, Flatten, Reshape, Concatenate, concatenate
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.optimizers import Adam
import tensorflow as tf
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.utils import HDF5Matrix
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc


#Loading the data

#RVSFlux normalized for fehmm
pathrvs0 = '/Users/aishasultan/work/synple-gaia/run/list_of_fluxes/fehmm08/norm_rvsflux.h5'
pathrvs1 = '/Users/aishasultan/work/synple-gaia/run/list_of_fluxes/fehmp05/norm_rvsflux.h5'
pathrvs2 = '/Users/aishasultan/work/synple-gaia/run/list_of_fluxes/fehmp10/norm_rvsflux.h5'


readrvs0 = h5py.File(pathrvs0, 'r')
readrvs1 = h5py.File(pathrvs1, 'r')
readrvs2 = h5py.File(pathrvs2, 'r')


rvs0 = readrvs0.get('normrvs')
rvs1 = readrvs1.get('normrvs')
rvs2 = readrvs2.get('normrvs')

norm_rvsflux0 = np.array(rvs0)
norm_rvsflux1 = np.array(rvs1)
norm_rvsflux2 = np.array(rvs2)



readrvs0.close()
readrvs1.close()
readrvs2.close()

print('shape of rvsflux:', np.shape(norm_rvsflux0))
norm_rvsflux = np.vstack((norm_rvsflux0, norm_rvsflux1, norm_rvsflux2))

print('shape of normalized rvsflux:', np.shape(norm_rvsflux))
# Out:
# Using TensorFlow backend.
# shape of rvsflux: (415, 1134)
# shape of normalized rvsflux: (1245, 1134)

# %%
#BPFlux
pathbp0 = '/Users/aishasultan/work/synple-gaia/run/list_of_fluxes/fehmm08/bpflux.h5'
pathbp1 = '/Users/aishasultan/work/synple-gaia/run/list_of_fluxes/fehmp05/bpflux.h5'
pathbp2 = '/Users/aishasultan/work/synple-gaia/run/list_of_fluxes/fehmp10/bpflux.h5'

readbp0 = h5py.File(pathbp0, 'r')
readbp1 = h5py.File(pathbp1, 'r')
readbp2 = h5py.File(pathbp2, 'r')



norm_bpflux0= []

for ii in range(np.shape(norm_rvsflux0)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star #',ii)
        fluxlabel = 'bpflux'+str(ii)
        wavelabel = 'bpwave' +str(ii)
        flux = readbp0.get(fluxlabel)
        wave= readbp0.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_bpflux0.append(normflux)


        
norm_bpflux0= np.array(norm_bpflux0)

print('shape of norm bpflux0:', np.shape(norm_bpflux0))

#####################################

norm_bpflux1= []

for ii in range(np.shape(norm_rvsflux1)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star #',ii)
        fluxlabel = 'bpflux'+str(ii)
        wavelabel = 'bpwave' +str(ii)
        flux = readbp1.get(fluxlabel)
        wave= readbp1.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_bpflux1.append(normflux)


        
norm_bpflux1= np.array(norm_bpflux1)

print('shape of norm bpflux1:', np.shape(norm_bpflux1))

#####################################

norm_bpflux2= []

for ii in range(np.shape(norm_rvsflux2)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star #',ii)
        fluxlabel = 'bpflux'+str(ii)
        wavelabel = 'bpwave' +str(ii)
        flux = readbp2.get(fluxlabel)
        wave= readbp2.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_bpflux2.append(normflux)


        
norm_bpflux2= np.array(norm_bpflux2)

print('shape of norm bpflux2:', np.shape(norm_bpflux2))

norm_bpflux = np.vstack((norm_bpflux0, norm_bpflux1, norm_bpflux2))
# Out:
# shape of norm bpflux0: (415, 40)
# shape of norm bpflux1: (415, 40)
# shape of norm bpflux2: (415, 40)

# %%
#RPFlux

#BPFlux
pathrp0 = '/Users/aishasultan/work/synple-gaia/run/list_of_fluxes/fehmm08/rpflux.h5'
pathrp1 = '/Users/aishasultan/work/synple-gaia/run/list_of_fluxes/fehmp05/rpflux.h5'
pathrp2 = '/Users/aishasultan/work/synple-gaia/run/list_of_fluxes/fehmp10/rpflux.h5'

readrp0 = h5py.File(pathrp0, 'r')
readrp1 = h5py.File(pathrp1, 'r')
readrp2 = h5py.File(pathrp2, 'r')




norm_rpflux0= []

for ii in range(np.shape(norm_rvsflux0)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star:',ii)
        fluxlabel = 'rpflux'+str(ii)
        wavelabel = 'rpwave' +str(ii)
        
        flux = readrp0.get(fluxlabel)
        wave= readrp0.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_rpflux0.append(normflux)


        
norm_rpflux0= np.array(norm_rpflux0)
print('shape of norm_rpflux0:', np.shape(norm_rpflux0))

##########################################


norm_rpflux1= []

for ii in range(np.shape(norm_rvsflux1)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star:',ii)
        fluxlabel = 'rpflux'+str(ii)
        wavelabel = 'rpwave' +str(ii)
        
        flux = readrp1.get(fluxlabel)
        wave= readrp1.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_rpflux1.append(normflux)


        
norm_rpflux1= np.array(norm_rpflux1)

print('shape of norm_rpflux1:', np.shape(norm_rpflux1))

#############################################

norm_rpflux2= []

for ii in range(np.shape(norm_rvsflux2)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star:',ii)
        fluxlabel = 'rpflux'+str(ii)
        wavelabel = 'rpwave' +str(ii)
        
        flux = readrp2.get(fluxlabel)
        wave= readrp2.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_rpflux2.append(normflux)


        
norm_rpflux2= np.array(norm_rpflux2)

print('shape of norm_rpflux2:', np.shape(norm_rpflux2))

norm_rpflux = np.vstack((norm_rpflux0, norm_rpflux1, norm_rpflux2))

print('norm_rpflux:', np.shape(norm_rpflux))


#print('The shapes of features and labels:', np.shape(norm_flux), np.shape(logteff))
# Out:
# shape of norm_rpflux0: (415, 40)
# shape of norm_rpflux1: (415, 40)
# shape of norm_rpflux2: (415, 40)
# norm_rpflux: (1245, 40)

# %%
#model parameters includes log g, teff, and [Fe/H] 

modparam0 = '/Users/aishasultan/work/synple-gaia/run/list_of_fluxes/fehmm08/modparam.h5'
modparam1 = '/Users/aishasultan/work/synple-gaia/run/list_of_fluxes/fehmp05/modparam.h5'
modparam2 = '/Users/aishasultan/work/synple-gaia/run/list_of_fluxes/fehmp10/modparam.h5'



readfile0 = h5py.File(modparam0, 'r')
readfile1 = h5py.File(modparam1, 'r')
readfile2 = h5py.File(modparam2, 'r')
print(readfile0.keys())


teff0 = readfile0.get('teff')
teff0 = np.array(teff0)
teff1 = readfile1.get('teff')
teff1 = np.array(teff1)
teff2 = readfile2.get('teff')
teff2 = np.array(teff2)

logg0 = readfile0.get('logg')
logg0 = np.array(logg0)
logg1 = readfile1.get('logg')
logg1 = np.array(logg1)
logg2 = readfile2.get('logg')
logg2 = np.array(logg2)

feh0 = readfile0.get('[FeH]')
feh0 = np.array(feh0)
feh1 = readfile1.get('[FeH]')
feh1 = np.array(feh1)
feh2 = readfile2.get('[FeH]')
feh2 = np.array(feh2)

readfile0.close()
readfile1.close()
readfile2.close()

teff= np.hstack ((teff0, teff1, teff2))
logg= np.hstack ((logg0, logg1, logg2))
feh= np.hstack ((feh0, feh1, feh2))

print('teff',np.shape(teff))

print('logg', np.shape(logg))

print('feh',np.shape(feh))


print(teff[20:25])
# Out:
# <KeysViewHDF5 ['[FeH]', 'logg', 'teff']>
# teff (1245,)
# logg (1245,)
# feh (1245,)
# [3750. 3750. 4000. 4000. 4000.]

# %%
#features
num_tot = len(teff)
print('total number of input stars =', num_tot)
plim = 0.8
ran_frac = np.random.uniform(0,1,num_tot)
#print('ranfrac=' , ran_frac)




#Input flux data of RVS, BP, RP
x_RVStrain = norm_rvsflux[ran_frac < plim, :]
print('number of RVS training data=', len(x_RVStrain[:,0]))
x_RVScv = norm_rvsflux[ran_frac >= plim, :] #test set we left for the application

x_BPtrain = norm_bpflux[ran_frac < plim, :]
print('number of BP training data=', len(x_BPtrain[:,0]))
x_BPcv = norm_bpflux[ran_frac >= plim, :]

x_RPtrain =norm_rpflux[ran_frac < plim, :]
print('number of RP training data=', len(x_RPtrain[:,0]))
x_RPcv = norm_rpflux[ran_frac >= plim, :]


#print('x_BPtrain', x_BPtrain)

#x_train_combined = np.vstack (x_RVStrain[0,:],x_RPtrain[0,:]) 

#output label which is the logteff and log g
y_teff_train = teff[ran_frac< plim]
y_teff_cv = teff[ran_frac >= plim] #test set

y_logg_train = logg[ran_frac< plim]
y_logg_cv = logg[ran_frac >= plim] #test set

y_feh_train = feh[ran_frac< plim]
y_feh_cv = feh[ran_frac >= plim] #test set





print('The size of CVS for the input flux data')
print('RVS cvs=', np.shape(x_RVScv))
print('BP cvs=', np.shape(x_BPcv))
print('RP cvs=', np.shape(x_RPcv))

print('the size of output label=', np.shape(y_teff_train) )

id = np.linspace(0, len(x_RVStrain[:, 0])-1, len(x_RVStrain[:, 0]))
plt.plot(id, y_teff_train)
plt.show()
# Out:
# total number of input stars = 1245
# number of RVS training data= 978
# number of BP training data= 978
# number of RP training data= 978
# The size of CVS for the input flux data
# RVS cvs= (267, 1134)
# BP cvs= (267, 40)
# RP cvs= (267, 40)
# the size of output label= (978,)

# %% [markdown]
# ** Normalization **
#
# Write a function to normalize the output labels. Each label will be normalized to have approximately have a mean of zero and unit variance.
#
# NOTE: This is necessary to put output labels on a similar scale in order for the model to train properly, this process is reversed in the test stage to give the output labels their proper units

# %%
#mean_labels=np.mean(logteff)
#std_labels=np.std(logteff)
#print('mean and std teff=', mean_labels, std_labels)
def normalize(labels):
    # Normalize labels
    mean_labels=np.mean(labels)
    std_labels=np.std(labels)
    norm_labels = (labels-mean_labels) / std_labels
    return (norm_labels, mean_labels, std_labels)

# %%
#normalize the y labels, the log teff and log g 

#output label which is the logteff and log g
y_teff_train = normalize(y_teff_train)
y_teff_cv = normalize(y_teff_cv)

y_logg_train = normalize(y_logg_train)
y_logg_cv = normalize(y_logg_cv)

y_feh_train = normalize(y_feh_train)
y_feh_cv = normalize(y_feh_cv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-8a972c36fbc3> in <module>
#       2
#       3 #output label which is the logteff and log g
# ----> 4 y_teff_train = normalize(y_teff_train)
#       5 y_teff_cv = normalize(y_teff_cv)
#       6
#
# <ipython-input-10-0cf7cc4e5f83> in normalize(labels)
#       6     mean_labels=np.mean(labels)
#       7     std_labels=np.std(labels)
# ----> 8     norm_labels = (labels-mean_labels) / std_labels
#       9     return (norm_labels, mean_labels, std_labels)
#      10
#
# ValueError: operands could not be broadcast together with shapes (3,) (978,)

# %%
print('type of data ', type(y_teff_train[0]),type(y_teff_cv[0]), type(y_logg_train[0]),type(y_logg_cv[0]) )

print(y_teff_train)
# Out:
# type of data  <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (array([-1.12579456, -1.12579456, -1.12579456, -1.12579456, -1.12579456,
#        -1.12579456, -1.12579456, -1.12579456, -1.12579456, -1.08448022,
#        -1.08448022, -1.08448022, -1.08448022, -1.08448022, -1.08448022,
#        -1.08448022, -1.08448022, -1.04316588, -1.04316588, -1.04316588,
#        -1.04316588, -1.04316588, -1.04316588, -1.04316588, -1.04316588,
#        -1.00185155, -1.00185155, -1.00185155, -1.00185155, -1.00185155,
#        -1.00185155, -1.00185155, -1.00185155, -1.00185155, -1.00185155,
#        -0.96053721, -0.96053721, -0.96053721, -0.96053721, -0.96053721,
#        -0.96053721, -0.96053721, -0.91922287, -0.91922287, -0.91922287,
#        -0.91922287, -0.91922287, -0.91922287, -0.91922287, -0.91922287,
#        -0.87790853, -0.87790853, -0.87790853, -0.87790853, -0.87790853,
#        -0.87790853, -0.87790853, -0.87790853, -0.87790853, -0.87790853,
#        -0.87790853, -0.8365942 , -0.8365942 , -0.8365942 , -0.8365942 ,
#        -0.8365942 , -0.8365942 , -0.8365942 , -0.8365942 , -0.8365942 ,
#        -0.79527986, -0.79527986, -0.79527986, -0.79527986, -0.79527986,
#        -0.79527986, -0.79527986, -0.79527986, -0.75396552, -0.75396552,
#        -0.75396552, -0.75396552, -0.75396552, -0.75396552, -0.75396552,
#        -0.75396552, -0.75396552, -0.75396552, -0.71265119, -0.71265119,
#        -0.71265119, -0.71265119, -0.71265119, -0.71265119, -0.71265119,
#        -0.71265119, -0.71265119, -0.71265119, -0.67133685, -0.67133685,
#        -0.67133685, -0.67133685, -0.67133685, -0.67133685, -0.63002251,
#        -0.63002251, -0.63002251, -0.63002251, -0.63002251, -0.63002251,
#        -0.63002251, -0.58870818, -0.58870818, -0.58870818, -0.58870818,
#        -0.58870818, -0.58870818, -0.54739384, -0.54739384, -0.54739384,
#        -0.54739384, -0.54739384, -0.54739384, -0.54739384, -0.54739384,
#        -0.54739384, -0.5060795 , -0.5060795 , -0.5060795 , -0.5060795 ,
#        -0.5060795 , -0.5060795 , -0.5060795 , -0.5060795 , -0.5060795 ,
#        -0.46476517, -0.46476517, -0.46476517, -0.46476517, -0.46476517,
#        -0.46476517, -0.46476517, -0.46476517, -0.42345083, -0.42345083,
#        -0.42345083, -0.42345083, -0.42345083, -0.42345083, -0.42345083,
#        -0.42345083, -0.42345083, -0.38213649, -0.38213649, -0.38213649,
#        -0.38213649, -0.38213649, -0.38213649, -0.38213649, -0.34082216,
#        -0.34082216, -0.34082216, -0.34082216, -0.34082216, -0.34082216,
#        -0.29950782, -0.29950782, -0.29950782, -0.29950782, -0.29950782,
#        -0.29950782, -0.25819348, -0.25819348, -0.25819348, -0.25819348,
#        -0.25819348, -0.25819348, -0.21687915, -0.21687915, -0.17556481,
#        -0.17556481, -0.17556481, -0.17556481, -0.17556481, -0.17556481,
#        -0.13425047, -0.13425047, -0.13425047, -0.13425047, -0.13425047,
#        -0.09293614, -0.09293614, -0.09293614, -0.09293614, -0.09293614,
#        -0.0516218 , -0.0516218 , -0.0516218 , -0.0516218 , -0.0516218 ,
#        -0.01030746, -0.01030746, -0.01030746, -0.01030746, -0.01030746,
#         0.03100687,  0.03100687,  0.03100687,  0.03100687,  0.03100687,
#         0.03100687,  0.07232121,  0.07232121,  0.07232121,  0.07232121,
#         0.07232121,  0.07232121,  0.07232121,  0.11363555,  0.11363555,
#         0.11363555,  0.11363555,  0.11363555,  0.11363555,  0.15494988,
#         0.15494988,  0.15494988,  0.15494988,  0.15494988,  0.15494988,
#         0.19626422,  0.19626422,  0.19626422,  0.19626422,  0.19626422,
#         0.19626422,  0.23757856,  0.23757856,  0.23757856,  0.23757856,
#         0.2788929 ,  0.2788929 ,  0.2788929 ,  0.2788929 ,  0.2788929 ,
#         0.36152157,  0.36152157,  0.36152157,  0.36152157,  0.36152157,
#         0.44415024,  0.44415024,  0.44415024,  0.44415024,  0.44415024,
#         0.52677892,  0.52677892,  0.52677892,  0.52677892,  0.60940759,
#         0.60940759,  0.69203626,  0.69203626,  0.69203626,  0.69203626,
#         0.77466494,  0.77466494,  0.77466494,  0.85729361,  0.85729361,
#         0.85729361,  0.85729361,  0.93992228,  0.93992228,  0.93992228,
#         0.93992228,  0.93992228,  1.02255096,  1.02255096,  1.02255096,
#         1.02255096,  1.02255096,  1.10517963,  1.10517963,  1.10517963,
#         1.1878083 ,  1.1878083 ,  1.1878083 ,  1.1878083 ,  1.1878083 ,
#         1.27043698,  1.27043698,  1.27043698,  1.27043698,  1.35306565,
#         1.35306565,  1.35306565,  1.43569433,  1.43569433,  1.43569433,
#         1.518323  ,  1.518323  ,  1.518323  ,  1.518323  ,  1.518323  ,
#         1.60095167,  1.60095167,  1.60095167,  1.60095167,  1.60095167,
#         1.76620902,  1.76620902,  1.76620902,  1.93146637,  1.93146637,
#         1.93146637,  2.09672371,  2.09672371,  2.26198106,  2.26198106,
#         2.26198106,  2.42723841,  2.59249576,  2.59249576,  2.59249576,
#         2.7577531 ,  2.7577531 ,  2.7577531 ,  2.92301045,  2.92301045,
#         2.92301045,  3.0882678 ,  3.0882678 ,  3.0882678 ,  3.25352514,
#         3.25352514, -1.12579456, -1.12579456, -1.12579456, -1.12579456,
#        -1.12579456, -1.12579456, -1.12579456, -1.12579456, -1.12579456,
#        -1.08448022, -1.08448022, -1.08448022, -1.08448022, -1.08448022,
#        -1.08448022, -1.08448022, -1.08448022, -1.08448022, -1.08448022,
#        -1.04316588, -1.04316588, -1.04316588, -1.04316588, -1.04316588,
#        -1.04316588, -1.04316588, -1.04316588, -1.04316588, -1.00185155,
#        -1.00185155, -1.00185155, -1.00185155, -1.00185155, -1.00185155,
#        -1.00185155, -1.00185155, -1.00185155, -1.00185155, -0.96053721,
#        -0.96053721, -0.96053721, -0.96053721, -0.96053721, -0.96053721,
#        -0.96053721, -0.96053721, -0.96053721, -0.96053721, -0.91922287,
#        -0.91922287, -0.91922287, -0.91922287, -0.91922287, -0.91922287,
#        -0.91922287, -0.91922287, -0.91922287, -0.87790853, -0.87790853,
#        -0.87790853, -0.87790853, -0.87790853, -0.87790853, -0.87790853,
#        -0.87790853, -0.87790853, -0.8365942 , -0.8365942 , -0.8365942 ,
#        -0.8365942 , -0.8365942 , -0.8365942 , -0.8365942 , -0.8365942 ,
#        -0.79527986, -0.79527986, -0.79527986, -0.79527986, -0.79527986,
#        -0.79527986, -0.79527986, -0.79527986, -0.75396552, -0.75396552,
#        -0.75396552, -0.75396552, -0.75396552, -0.75396552, -0.75396552,
#        -0.75396552, -0.71265119, -0.71265119, -0.71265119, -0.71265119,
#        -0.71265119, -0.71265119, -0.71265119, -0.71265119, -0.71265119,
#        -0.67133685, -0.67133685, -0.67133685, -0.67133685, -0.67133685,
#        -0.67133685, -0.67133685, -0.63002251, -0.63002251, -0.63002251,
#        -0.63002251, -0.63002251, -0.63002251, -0.63002251, -0.63002251,
#        -0.58870818, -0.58870818, -0.58870818, -0.58870818, -0.58870818,
#        -0.58870818, -0.58870818, -0.54739384, -0.54739384, -0.54739384,
#        -0.54739384, -0.54739384, -0.54739384, -0.54739384, -0.5060795 ,
#        -0.5060795 , -0.5060795 , -0.5060795 , -0.5060795 , -0.5060795 ,
#        -0.46476517, -0.46476517, -0.46476517, -0.46476517, -0.46476517,
#        -0.46476517, -0.46476517, -0.42345083, -0.42345083, -0.42345083,
#        -0.42345083, -0.42345083, -0.42345083, -0.42345083, -0.38213649,
#        -0.38213649, -0.38213649, -0.38213649, -0.38213649, -0.34082216,
#        -0.34082216, -0.34082216, -0.34082216, -0.34082216, -0.34082216,
#        -0.34082216, -0.29950782, -0.29950782, -0.29950782, -0.29950782,
#        -0.25819348, -0.25819348, -0.25819348, -0.21687915, -0.21687915,
#        -0.21687915, -0.21687915, -0.21687915, -0.17556481, -0.17556481,
#        -0.17556481, -0.17556481, -0.17556481, -0.17556481, -0.13425047,
#        -0.13425047, -0.13425047, -0.13425047, -0.13425047, -0.13425047,
#        -0.09293614, -0.09293614, -0.09293614, -0.09293614, -0.09293614,
#        -0.09293614, -0.09293614, -0.0516218 , -0.0516218 , -0.0516218 ,
#        -0.0516218 , -0.0516218 , -0.01030746, -0.01030746, -0.01030746,
#        -0.01030746, -0.01030746,  0.03100687,  0.03100687,  0.03100687,
#         0.03100687,  0.03100687,  0.03100687,  0.07232121,  0.07232121,
#         0.07232121,  0.07232121,  0.07232121,  0.07232121,  0.11363555,
#         0.11363555,  0.11363555,  0.11363555,  0.15494988,  0.15494988,
#         0.15494988,  0.15494988,  0.15494988,  0.19626422,  0.19626422,
#         0.19626422,  0.19626422,  0.19626422,  0.19626422,  0.23757856,
#         0.23757856,  0.23757856,  0.23757856,  0.23757856,  0.2788929 ,
#         0.2788929 ,  0.2788929 ,  0.2788929 ,  0.2788929 ,  0.2788929 ,
#         0.36152157,  0.36152157,  0.36152157,  0.36152157,  0.44415024,
#         0.44415024,  0.44415024,  0.44415024,  0.52677892,  0.52677892,
#         0.60940759,  0.60940759,  0.60940759,  0.60940759,  0.69203626,
#         0.69203626,  0.69203626,  0.69203626,  0.77466494,  0.77466494,
#         0.77466494,  0.77466494,  0.85729361,  0.85729361,  0.85729361,
#         0.85729361,  0.85729361,  0.93992228,  0.93992228,  0.93992228,
#         0.93992228,  0.93992228,  1.02255096,  1.02255096,  1.02255096,
#         1.02255096,  1.10517963,  1.10517963,  1.10517963,  1.10517963,
#         1.1878083 ,  1.1878083 ,  1.1878083 ,  1.1878083 ,  1.1878083 ,
#         1.27043698,  1.27043698,  1.35306565,  1.35306565,  1.35306565,
#         1.35306565,  1.35306565,  1.43569433,  1.43569433,  1.43569433,
#         1.43569433,  1.43569433,  1.518323  ,  1.518323  ,  1.518323  ,
#         1.60095167,  1.60095167,  1.60095167,  1.60095167,  1.76620902,
#         1.76620902,  1.93146637,  2.09672371,  2.09672371,  2.26198106,
#         2.26198106,  2.42723841,  2.42723841,  2.42723841,  2.59249576,
#         2.59249576,  2.7577531 ,  2.7577531 ,  2.92301045,  2.92301045,
#         3.0882678 ,  3.0882678 ,  3.25352514,  3.25352514, -1.12579456,
#        -1.12579456, -1.12579456, -1.12579456, -1.12579456, -1.12579456,
#        -1.12579456, -1.12579456, -1.12579456, -1.12579456, -1.12579456,
#        -1.08448022, -1.08448022, -1.08448022, -1.08448022, -1.08448022,
#        -1.08448022, -1.08448022, -1.04316588, -1.04316588, -1.04316588,
#        -1.04316588, -1.04316588, -1.04316588, -1.04316588, -1.04316588,
#        -1.04316588, -1.00185155, -1.00185155, -1.00185155, -1.00185155,
#        -1.00185155, -1.00185155, -1.00185155, -1.00185155, -1.00185155,
#        -1.00185155, -0.96053721, -0.96053721, -0.96053721, -0.96053721,
#        -0.96053721, -0.96053721, -0.96053721, -0.96053721, -0.96053721,
#        -0.96053721, -0.96053721, -0.91922287, -0.91922287, -0.91922287,
#        -0.91922287, -0.91922287, -0.91922287, -0.87790853, -0.87790853,
#        -0.87790853, -0.87790853, -0.87790853, -0.87790853, -0.87790853,
#        -0.87790853, -0.87790853, -0.8365942 , -0.8365942 , -0.8365942 ,
#        -0.8365942 , -0.8365942 , -0.8365942 , -0.8365942 , -0.8365942 ,
#        -0.79527986, -0.79527986, -0.79527986, -0.79527986, -0.79527986,
#        -0.79527986, -0.79527986, -0.79527986, -0.75396552, -0.75396552,
#        -0.75396552, -0.75396552, -0.75396552, -0.75396552, -0.75396552,
#        -0.75396552, -0.71265119, -0.71265119, -0.71265119, -0.71265119,
#        -0.71265119, -0.67133685, -0.67133685, -0.67133685, -0.67133685,
#        -0.67133685, -0.63002251, -0.63002251, -0.63002251, -0.63002251,
#        -0.63002251, -0.63002251, -0.63002251, -0.58870818, -0.58870818,
#        -0.58870818, -0.58870818, -0.58870818, -0.58870818, -0.58870818,
#        -0.58870818, -0.54739384, -0.54739384, -0.54739384, -0.54739384,
#        -0.54739384, -0.54739384, -0.5060795 , -0.5060795 , -0.5060795 ,
#        -0.5060795 , -0.5060795 , -0.5060795 , -0.5060795 , -0.46476517,
#        -0.46476517, -0.46476517, -0.46476517, -0.46476517, -0.46476517,
#        -0.46476517, -0.42345083, -0.42345083, -0.42345083, -0.42345083,
#        -0.42345083, -0.42345083, -0.42345083, -0.42345083, -0.42345083,
#        -0.38213649, -0.38213649, -0.38213649, -0.38213649, -0.38213649,
#        -0.38213649, -0.38213649, -0.34082216, -0.34082216, -0.34082216,
#        -0.34082216, -0.34082216, -0.34082216, -0.29950782, -0.29950782,
#        -0.29950782, -0.29950782, -0.29950782, -0.29950782, -0.25819348,
#        -0.25819348, -0.25819348, -0.25819348, -0.25819348, -0.25819348,
#        -0.21687915, -0.21687915, -0.21687915, -0.21687915, -0.17556481,
#        -0.17556481, -0.17556481, -0.17556481, -0.17556481, -0.13425047,
#        -0.13425047, -0.09293614, -0.09293614, -0.09293614, -0.09293614,
#        -0.09293614, -0.09293614, -0.0516218 , -0.0516218 , -0.0516218 ,
#        -0.0516218 , -0.0516218 , -0.01030746, -0.01030746, -0.01030746,
#        -0.01030746,  0.03100687,  0.03100687,  0.03100687,  0.03100687,
#         0.03100687,  0.03100687,  0.07232121,  0.07232121,  0.07232121,
#         0.07232121,  0.07232121,  0.07232121,  0.11363555,  0.11363555,
#         0.11363555,  0.11363555,  0.11363555,  0.11363555,  0.11363555,
#         0.15494988,  0.15494988,  0.15494988,  0.15494988,  0.15494988,
#         0.15494988,  0.19626422,  0.19626422,  0.19626422,  0.19626422,
#         0.19626422,  0.19626422,  0.23757856,  0.23757856,  0.23757856,
#         0.23757856,  0.23757856,  0.2788929 ,  0.2788929 ,  0.2788929 ,
#         0.2788929 ,  0.2788929 ,  0.2788929 ,  0.36152157,  0.36152157,
#         0.44415024,  0.44415024,  0.44415024,  0.52677892,  0.52677892,
#         0.52677892,  0.52677892,  0.60940759,  0.60940759,  0.60940759,
#         0.69203626,  0.69203626,  0.69203626,  0.77466494,  0.77466494,
#         0.77466494,  0.77466494,  0.85729361,  0.85729361,  0.85729361,
#         0.85729361,  0.85729361,  0.93992228,  0.93992228,  0.93992228,
#         0.93992228,  0.93992228,  1.02255096,  1.02255096,  1.02255096,
#         1.02255096,  1.10517963,  1.10517963,  1.10517963,  1.10517963,
#         1.10517963,  1.1878083 ,  1.1878083 ,  1.1878083 ,  1.1878083 ,
#         1.27043698,  1.27043698,  1.27043698,  1.27043698,  1.35306565,
#         1.35306565,  1.35306565,  1.35306565,  1.35306565,  1.43569433,
#         1.43569433,  1.43569433,  1.43569433,  1.43569433,  1.518323  ,
#         1.518323  ,  1.518323  ,  1.518323  ,  1.518323  ,  1.60095167,
#         1.60095167,  1.60095167,  1.76620902,  1.76620902,  1.76620902,
#         1.93146637,  2.09672371,  2.09672371,  2.26198106,  2.42723841,
#         2.59249576,  2.59249576,  2.59249576,  2.7577531 ,  2.7577531 ,
#         2.92301045,  2.92301045,  3.0882678 ,  3.0882678 ,  3.0882678 ,
#         3.25352514,  3.25352514,  3.25352514]), 10312.37218813906, 6051.168176064339)

# %% [markdown]
# **Build the StarNet model architecture**
#
# The StarNet architecture is built with:
# - input layer
# - 2 convolutional layers
# - 1 maxpooling layer followed by flattening for the fully connected layer
# - 2 fully connected layers
# - output layer
#
# First, let's define some model variables.

# %%
# activation function used following every layer except for the output layers
activation = 'relu'
#activation = 'sigmoid'

# model weight initializer
initializer = 'he_normal'

# number of filters used in the convolutional layers
#num_filters = [4,16]
num_filters = [8,32]
#num_filters = [8,16]

# length of the filters in the convolutional layers
#filter_length = 8
#filter_length = 16
filter_length = 8

# length of the maxpooling window 
pool_length = 4

# number of nodes in each of the hidden fully connected layers
num_hidden = [256,128]
#num_hidden = [24,12]

# number of spectra fed into model at once during training
batch_size = 64

# maximum number of interations for model training
#max_epochs = 200
#max_epochs = 100
#max_epochs = 150 
#max_epochs = 350
#max_epochs = 225
#max_epochs = 180
#max_epochs = 450
#max_epochs = 300
max_epochs = 300


# initial learning rate for optimization algorithm
lr = 0.000003 #handled by Adam
    
# exponential decay rate for the 1st moment estimates for optimization algorithm
beta_1 = 0.9

# exponential decay rate for the 2nd moment estimates for optimization algorithm
beta_2 = 0.999

# a small constant for numerical stability for optimization algorithm
optimizer_epsilon = 1e-08

# %%
num_RVSfluxes=len(x_RVStrain[0,:]) 
print('number of RVS fluxes=', num_RVSfluxes)

num_BPfluxes=len(x_BPtrain[0,:]) 
print('number of BP fluxes=', num_BPfluxes)

num_RPfluxes=len(x_RPtrain[0,:]) 
print('number of RP fluxes=', num_RPfluxes)

#num_labels= 1
num_labels= 3
print('number of training labels=', num_labels)

#ilam = np.linspace(0, num_fluxes-1, num_fluxes)
#plt.plot(ilam, x_train[329, :])
#plt.plot()

#iy = np.linspace(0, len(y_train)-1, len(y_train))
#plt.plot(iy, y_train)
#plt.plot()
# Out:
# number of RVS fluxes= 1134
# number of BP fluxes= 40
# number of RP fluxes= 40
# number of training labels= 3

# %%
# Input RVS spectra
# print(' num_RVSfluxes=', num_RVSfluxes)
input_RVSspec = Input(shape=(num_RVSfluxes,), name='rvs_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for RVS layers
cur_rvs = Reshape((num_RVSfluxes, 1))(input_RVSspec)

# CNN layers
cur_rvs = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_rvs) #first CNN layer
cur_rvs = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_rvs) #2nd CNN layer

# Max pooling layer
cur_rvs = MaxPooling1D(pool_size=pool_length)(cur_rvs)

# Flatten the current input for the fully-connected layers
cur_rvs = Flatten()(cur_rvs)


##############################################################################################


# Input BP spectra
# print(' num_BPfluxes=', num_BPfluxes)
input_BPspec = Input(shape=(num_BPfluxes,), name='bp_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for BP layers
cur_bp = Reshape((num_BPfluxes, 1))(input_BPspec)

# CNN layers
cur_bp = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_bp) #first CNN layer
cur_bp = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_bp) #2nd CNN layer

# Max pooling layer
cur_bp = MaxPooling1D(pool_size=pool_length)(cur_bp)


# Flatten the current input for the fully-connected layers
cur_bp = Flatten()(cur_bp)


################################################################################################

# Input RP spectra
input_RPspec = Input(shape=(num_RPfluxes,), name='rp_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for CNN layers
cur_rp = Reshape((num_RPfluxes, 1))(input_RPspec)

# CNN layers
cur_rp = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_rp) #first CNN layer
cur_rp = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_rp) #2nd CNN layer

# Max pooling layer
cur_rp = MaxPooling1D(pool_size=pool_length)(cur_rp)

# Flatten the current input for the fully-connected layers
cur_rp = Flatten()(cur_rp)

###############################################################################################

#concatenate RVS/BP/RP and then insert it to dense layer 

cur_comb = concatenate([cur_rvs, cur_bp, cur_rp])

# Fully-connected layers
cur_final = Dense(units=num_hidden[0], kernel_initializer=initializer, 
               activation=activation)(cur_comb)
cur_final = Dense(units=num_hidden[1], kernel_initializer=initializer, 
               activation=activation)(cur_final)

# Output nodes
output_final = Dense(units=num_labels, activation="linear", 
                    input_dim=num_hidden[1], name='output_y')(cur_final)


model = Model(inputs = [input_RVSspec, input_BPspec, input_RPspec], outputs=output_final)
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# **More model techniques**
# * The `Adam` optimizer is the gradient descent algorithm used for minimizing the loss function
# * `EarlyStopping` uses the cross-validation set to test the model following every iteration and stops the training if the cv loss does not decrease by `min_delta` after `patience` iterations
# * `ReduceLROnPlateau` is a form of learning rate decay where the learning rate is decreased by a factor of `factor` if the training loss does not decrease by `epsilon` after `patience` iterations unless the learning rate has reached `min_lr`

# %%
# Default loss function parameters
early_stopping_min_delta = 0.0007
early_stopping_patience = 4
reduce_lr_factor = 0.5
reuce_lr_epsilon = 0.0000009
reduce_lr_patience = 2
reduce_lr_min = 0.00008

# loss function to minimize
loss_function = 'mean_squared_error'

# compute mean absolute deviation
metrics = ['mae', 'mse']
#metrics = ['mae']

# %%
#optimizer = Adam(lr=lr, beta_1=beta_1, beta_2=beta_2, epsilon=optimizer_epsilon, decay=0.0)
optimizer = Adam(lr=0.0005 )

early_stopping = EarlyStopping(monitor='val_loss', min_delta=early_stopping_min_delta, 
                                       patience=early_stopping_patience, verbose=2, mode='min')

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, epsilon=reuce_lr_epsilon, 
                                  patience=reduce_lr_patience, min_lr=reduce_lr_min, mode='min', verbose=2)
# Out:
# /anaconda3/lib/python3.6/site-packages/keras/callbacks.py:1065: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '

# %% [markdown]
# **Compile model**

# %%
model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# rvs_input_x (InputLayer)        (None, 1134)         0
# __________________________________________________________________________________________________
# bp_input_x (InputLayer)         (None, 40)           0
# __________________________________________________________________________________________________
# rp_input_x (InputLayer)         (None, 40)           0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1134, 1)      0           rvs_input_x[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 40, 1)        0           bp_input_x[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 40, 1)        0           rp_input_x[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 1134, 8)      72          reshape_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 40, 8)        72          reshape_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 40, 8)        72          reshape_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 1134, 32)     2080        conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 40, 32)       2080        conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 40, 32)       2080        conv1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 283, 32)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 10, 32)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 10, 32)       0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 9056)         0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 320)          0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 320)          0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 9696)         0           flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          2482432     concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          32896       dense_1[0][0]
# __________________________________________________________________________________________________
# output_y (Dense)                (None, 3)            387         dense_2[0][0]
# ==================================================================================================
# Total params: 2,522,171
# Trainable params: 2,522,171
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Train model**

# %%
#history = model.fit(x_train, y_train, validation_data=(x_cv, y_cv),
          #epochs=max_epochs, verbose=1, shuffle='batch',
         #callbacks=[early_stopping, reduce_lr])
        

y_train_stack = np.column_stack((y_teff_train[0], y_logg_train[0], y_feh_train[0]))
y_cv_stack = np.column_stack ((y_teff_cv[0], y_logg_cv[0], y_feh_cv[0]))

print('shape of the cv logteff and logg=', np.shape(y_cv_stack))
print(' shape of y teff and logg=', np.shape(y_train_stack))
#history = model.fit(x=[x_RVStrain, x_BPtrain, x_RPtrain], y=y_train_stack,
          #validation_split=0.2, epochs=max_epochs, verbose=1, shuffle='batch')
        
history = model.fit(x=[x_RVStrain, x_BPtrain, x_RPtrain], y= y_train_stack, 
                    validation_data=([x_RVScv, x_BPcv, x_RPcv], y_cv_stack),
          epochs=max_epochs, verbose=1, shuffle='batch')
# Out:
# shape of the cv logteff and logg= (267, 3)
#  shape of y teff and logg= (978, 3)
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 978 samples, validate on 267 samples
# Epoch 1/300
# 978/978 [==============================] - 3s 3ms/step - loss: 3.9946 - mean_absolute_error: 1.3448 - mean_squared_error: 3.9946 - val_loss: 1.6392 - val_mean_absolute_error: 0.9574 - val_mean_squared_error: 1.6392
# Epoch 2/300
# 978/978 [==============================] - 1s 1ms/step - loss: 1.2730 - mean_absolute_error: 0.9084 - mean_squared_error: 1.2730 - val_loss: 3.4209 - val_mean_absolute_error: 1.6001 - val_mean_squared_error: 3.4209
# Epoch 3/300
# 978/978 [==============================] - 1s 1ms/step - loss: 2.1226 - mean_absolute_error: 1.2070 - mean_squared_error: 2.1226 - val_loss: 2.7287 - val_mean_absolute_error: 1.2637 - val_mean_squared_error: 2.7287
# Epoch 4/300
# 978/978 [==============================] - 1s 1ms/step - loss: 1.2884 - mean_absolute_error: 0.8766 - mean_squared_error: 1.2884 - val_loss: 1.0738 - val_mean_absolute_error: 0.8357 - val_mean_squared_error: 1.0738
# Epoch 5/300
# 978/978 [==============================] - 1s 1ms/step - loss: 1.3326 - mean_absolute_error: 0.8877 - mean_squared_error: 1.3326 - val_loss: 0.7233 - val_mean_absolute_error: 0.7147 - val_mean_squared_error: 0.7233
# Epoch 6/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.9606 - mean_absolute_error: 0.7882 - mean_squared_error: 0.9606 - val_loss: 1.3633 - val_mean_absolute_error: 0.9737 - val_mean_squared_error: 1.3633
# Epoch 7/300
# 978/978 [==============================] - 1s 1ms/step - loss: 1.0877 - mean_absolute_error: 0.8503 - mean_squared_error: 1.0877 - val_loss: 0.7585 - val_mean_absolute_error: 0.7462 - val_mean_squared_error: 0.7585
# Epoch 8/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.8194 - mean_absolute_error: 0.7029 - mean_squared_error: 0.8194 - val_loss: 0.7450 - val_mean_absolute_error: 0.6851 - val_mean_squared_error: 0.7450
# Epoch 9/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.8233 - mean_absolute_error: 0.7429 - mean_squared_error: 0.8233 - val_loss: 0.6025 - val_mean_absolute_error: 0.6020 - val_mean_squared_error: 0.6025
# Epoch 10/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.6954 - mean_absolute_error: 0.6567 - mean_squared_error: 0.6954 - val_loss: 0.6837 - val_mean_absolute_error: 0.6041 - val_mean_squared_error: 0.6837
# Epoch 11/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.6708 - mean_absolute_error: 0.6434 - mean_squared_error: 0.6708 - val_loss: 0.7952 - val_mean_absolute_error: 0.7851 - val_mean_squared_error: 0.7952
# Epoch 12/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.7230 - mean_absolute_error: 0.6779 - mean_squared_error: 0.7230 - val_loss: 0.5886 - val_mean_absolute_error: 0.6269 - val_mean_squared_error: 0.5886
# Epoch 13/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.5972 - mean_absolute_error: 0.6041 - mean_squared_error: 0.5972 - val_loss: 0.5354 - val_mean_absolute_error: 0.5726 - val_mean_squared_error: 0.5354
# Epoch 14/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.5722 - mean_absolute_error: 0.5936 - mean_squared_error: 0.5722 - val_loss: 0.4827 - val_mean_absolute_error: 0.5425 - val_mean_squared_error: 0.4827
# Epoch 15/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.5005 - mean_absolute_error: 0.5600 - mean_squared_error: 0.5005 - val_loss: 0.5446 - val_mean_absolute_error: 0.5196 - val_mean_squared_error: 0.5446
# Epoch 16/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.5196 - mean_absolute_error: 0.5531 - mean_squared_error: 0.5196 - val_loss: 0.5005 - val_mean_absolute_error: 0.5058 - val_mean_squared_error: 0.5005
# Epoch 17/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.5296 - mean_absolute_error: 0.5549 - mean_squared_error: 0.5296 - val_loss: 0.4928 - val_mean_absolute_error: 0.4973 - val_mean_squared_error: 0.4928
# Epoch 18/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.5086 - mean_absolute_error: 0.5430 - mean_squared_error: 0.5086 - val_loss: 0.4299 - val_mean_absolute_error: 0.4906 - val_mean_squared_error: 0.4299
# Epoch 19/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.4884 - mean_absolute_error: 0.5322 - mean_squared_error: 0.4884 - val_loss: 0.4245 - val_mean_absolute_error: 0.5012 - val_mean_squared_error: 0.4245
# Epoch 20/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.4285 - mean_absolute_error: 0.5017 - mean_squared_error: 0.4285 - val_loss: 0.3773 - val_mean_absolute_error: 0.4545 - val_mean_squared_error: 0.3773
# Epoch 21/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.4170 - mean_absolute_error: 0.4927 - mean_squared_error: 0.4170 - val_loss: 0.3703 - val_mean_absolute_error: 0.4572 - val_mean_squared_error: 0.3703
# Epoch 22/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.4435 - mean_absolute_error: 0.5141 - mean_squared_error: 0.4435 - val_loss: 0.3771 - val_mean_absolute_error: 0.4664 - val_mean_squared_error: 0.3771
# Epoch 23/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.3968 - mean_absolute_error: 0.4778 - mean_squared_error: 0.3968 - val_loss: 0.3628 - val_mean_absolute_error: 0.4505 - val_mean_squared_error: 0.3628
# Epoch 24/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.3977 - mean_absolute_error: 0.4817 - mean_squared_error: 0.3977 - val_loss: 0.3770 - val_mean_absolute_error: 0.4706 - val_mean_squared_error: 0.3770
# Epoch 25/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.4331 - mean_absolute_error: 0.5067 - mean_squared_error: 0.4331 - val_loss: 0.3797 - val_mean_absolute_error: 0.4779 - val_mean_squared_error: 0.3797
# Epoch 26/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.4065 - mean_absolute_error: 0.4923 - mean_squared_error: 0.4065 - val_loss: 0.3821 - val_mean_absolute_error: 0.4809 - val_mean_squared_error: 0.3821
# Epoch 27/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.3697 - mean_absolute_error: 0.4728 - mean_squared_error: 0.3697 - val_loss: 0.3229 - val_mean_absolute_error: 0.4170 - val_mean_squared_error: 0.3229
# Epoch 28/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.3325 - mean_absolute_error: 0.4375 - mean_squared_error: 0.3325 - val_loss: 0.4663 - val_mean_absolute_error: 0.4699 - val_mean_squared_error: 0.4663
# Epoch 29/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.4168 - mean_absolute_error: 0.4783 - mean_squared_error: 0.4168 - val_loss: 0.6927 - val_mean_absolute_error: 0.6782 - val_mean_squared_error: 0.6927
# Epoch 30/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.4365 - mean_absolute_error: 0.5133 - mean_squared_error: 0.4365 - val_loss: 0.3986 - val_mean_absolute_error: 0.4426 - val_mean_squared_error: 0.3986
# Epoch 31/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.3601 - mean_absolute_error: 0.4441 - mean_squared_error: 0.3601 - val_loss: 0.7377 - val_mean_absolute_error: 0.5787 - val_mean_squared_error: 0.7377
# Epoch 32/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.3473 - mean_absolute_error: 0.4245 - mean_squared_error: 0.3473 - val_loss: 0.3269 - val_mean_absolute_error: 0.4129 - val_mean_squared_error: 0.3269
# Epoch 33/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.3430 - mean_absolute_error: 0.4269 - mean_squared_error: 0.3430 - val_loss: 0.2852 - val_mean_absolute_error: 0.3867 - val_mean_squared_error: 0.2852
# Epoch 34/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.2924 - mean_absolute_error: 0.3934 - mean_squared_error: 0.2924 - val_loss: 0.2864 - val_mean_absolute_error: 0.3888 - val_mean_squared_error: 0.2864
# Epoch 35/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.3146 - mean_absolute_error: 0.4103 - mean_squared_error: 0.3146 - val_loss: 0.2793 - val_mean_absolute_error: 0.3774 - val_mean_squared_error: 0.2793
# Epoch 36/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.2650 - mean_absolute_error: 0.3760 - mean_squared_error: 0.2650 - val_loss: 0.2449 - val_mean_absolute_error: 0.3708 - val_mean_squared_error: 0.2449
# Epoch 37/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.2558 - mean_absolute_error: 0.3777 - mean_squared_error: 0.2558 - val_loss: 0.2487 - val_mean_absolute_error: 0.3842 - val_mean_squared_error: 0.2487
# Epoch 38/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.2720 - mean_absolute_error: 0.3713 - mean_squared_error: 0.2720 - val_loss: 0.3445 - val_mean_absolute_error: 0.4298 - val_mean_squared_error: 0.3445
# Epoch 39/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.3344 - mean_absolute_error: 0.4368 - mean_squared_error: 0.3344 - val_loss: 0.2818 - val_mean_absolute_error: 0.4027 - val_mean_squared_error: 0.2818
# Epoch 40/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.2747 - mean_absolute_error: 0.4077 - mean_squared_error: 0.2747 - val_loss: 0.2426 - val_mean_absolute_error: 0.3553 - val_mean_squared_error: 0.2426
# Epoch 41/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.2339 - mean_absolute_error: 0.3512 - mean_squared_error: 0.2339 - val_loss: 0.2476 - val_mean_absolute_error: 0.3693 - val_mean_squared_error: 0.2476
# Epoch 42/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.2365 - mean_absolute_error: 0.3428 - mean_squared_error: 0.2365 - val_loss: 0.2516 - val_mean_absolute_error: 0.3738 - val_mean_squared_error: 0.2516
# Epoch 43/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.2328 - mean_absolute_error: 0.3559 - mean_squared_error: 0.2328 - val_loss: 0.2515 - val_mean_absolute_error: 0.3672 - val_mean_squared_error: 0.2515
# Epoch 44/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.2599 - mean_absolute_error: 0.3779 - mean_squared_error: 0.2599 - val_loss: 0.2009 - val_mean_absolute_error: 0.3271 - val_mean_squared_error: 0.2009
# Epoch 45/300
# 978/978 [==============================] - 1s 996us/step - loss: 0.2163 - mean_absolute_error: 0.3334 - mean_squared_error: 0.2163 - val_loss: 0.2264 - val_mean_absolute_error: 0.3459 - val_mean_squared_error: 0.2264
# Epoch 46/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.2143 - mean_absolute_error: 0.3377 - mean_squared_error: 0.2143 - val_loss: 0.1972 - val_mean_absolute_error: 0.3086 - val_mean_squared_error: 0.1972
# Epoch 47/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1902 - mean_absolute_error: 0.3044 - mean_squared_error: 0.1902 - val_loss: 0.1614 - val_mean_absolute_error: 0.2828 - val_mean_squared_error: 0.1614
# Epoch 48/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1892 - mean_absolute_error: 0.3139 - mean_squared_error: 0.1892 - val_loss: 0.1858 - val_mean_absolute_error: 0.3130 - val_mean_squared_error: 0.1858
# Epoch 49/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.2004 - mean_absolute_error: 0.3248 - mean_squared_error: 0.2004 - val_loss: 0.1859 - val_mean_absolute_error: 0.2996 - val_mean_squared_error: 0.1859
# Epoch 50/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1893 - mean_absolute_error: 0.3157 - mean_squared_error: 0.1893 - val_loss: 0.3165 - val_mean_absolute_error: 0.4531 - val_mean_squared_error: 0.3165
# Epoch 51/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1935 - mean_absolute_error: 0.3042 - mean_squared_error: 0.1935 - val_loss: 0.1445 - val_mean_absolute_error: 0.2809 - val_mean_squared_error: 0.1445
# Epoch 52/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1678 - mean_absolute_error: 0.2986 - mean_squared_error: 0.1678 - val_loss: 0.2427 - val_mean_absolute_error: 0.3764 - val_mean_squared_error: 0.2427
# Epoch 53/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1752 - mean_absolute_error: 0.2933 - mean_squared_error: 0.1752 - val_loss: 0.1482 - val_mean_absolute_error: 0.2736 - val_mean_squared_error: 0.1482
# Epoch 54/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1615 - mean_absolute_error: 0.2906 - mean_squared_error: 0.1615 - val_loss: 0.1871 - val_mean_absolute_error: 0.3238 - val_mean_squared_error: 0.1871
# Epoch 55/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.2083 - mean_absolute_error: 0.3439 - mean_squared_error: 0.2083 - val_loss: 0.1411 - val_mean_absolute_error: 0.2786 - val_mean_squared_error: 0.1411
# Epoch 56/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1456 - mean_absolute_error: 0.2772 - mean_squared_error: 0.1456 - val_loss: 0.1441 - val_mean_absolute_error: 0.2612 - val_mean_squared_error: 0.1441
# Epoch 57/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1357 - mean_absolute_error: 0.2510 - mean_squared_error: 0.1357 - val_loss: 0.1167 - val_mean_absolute_error: 0.2340 - val_mean_squared_error: 0.1167
# Epoch 58/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1497 - mean_absolute_error: 0.2751 - mean_squared_error: 0.1497 - val_loss: 0.1858 - val_mean_absolute_error: 0.3278 - val_mean_squared_error: 0.1858
# Epoch 59/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.2110 - mean_absolute_error: 0.3301 - mean_squared_error: 0.2110 - val_loss: 0.1208 - val_mean_absolute_error: 0.2514 - val_mean_squared_error: 0.1208
# Epoch 60/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1419 - mean_absolute_error: 0.2743 - mean_squared_error: 0.1419 - val_loss: 0.1141 - val_mean_absolute_error: 0.2421 - val_mean_squared_error: 0.1141
# Epoch 61/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1224 - mean_absolute_error: 0.2501 - mean_squared_error: 0.1224 - val_loss: 0.1178 - val_mean_absolute_error: 0.2317 - val_mean_squared_error: 0.1178
# Epoch 62/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1058 - mean_absolute_error: 0.2140 - mean_squared_error: 0.1058 - val_loss: 0.1047 - val_mean_absolute_error: 0.2217 - val_mean_squared_error: 0.1047
# Epoch 63/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1170 - mean_absolute_error: 0.2408 - mean_squared_error: 0.1170 - val_loss: 0.1598 - val_mean_absolute_error: 0.2933 - val_mean_squared_error: 0.1598
# Epoch 64/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1418 - mean_absolute_error: 0.2576 - mean_squared_error: 0.1418 - val_loss: 0.1032 - val_mean_absolute_error: 0.2183 - val_mean_squared_error: 0.1032
# Epoch 65/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1393 - mean_absolute_error: 0.2659 - mean_squared_error: 0.1393 - val_loss: 0.1185 - val_mean_absolute_error: 0.2454 - val_mean_squared_error: 0.1185
# Epoch 66/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1085 - mean_absolute_error: 0.2276 - mean_squared_error: 0.1085 - val_loss: 0.1384 - val_mean_absolute_error: 0.2776 - val_mean_squared_error: 0.1384
# Epoch 67/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1092 - mean_absolute_error: 0.2297 - mean_squared_error: 0.1092 - val_loss: 0.1067 - val_mean_absolute_error: 0.2352 - val_mean_squared_error: 0.1067
# Epoch 68/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1141 - mean_absolute_error: 0.2384 - mean_squared_error: 0.1141 - val_loss: 0.1148 - val_mean_absolute_error: 0.2333 - val_mean_squared_error: 0.1148
# Epoch 69/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1107 - mean_absolute_error: 0.2316 - mean_squared_error: 0.1107 - val_loss: 0.0903 - val_mean_absolute_error: 0.2122 - val_mean_squared_error: 0.0903
# Epoch 70/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1121 - mean_absolute_error: 0.2280 - mean_squared_error: 0.1121 - val_loss: 0.1008 - val_mean_absolute_error: 0.2347 - val_mean_squared_error: 0.1008
# Epoch 71/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1082 - mean_absolute_error: 0.2301 - mean_squared_error: 0.1082 - val_loss: 0.1796 - val_mean_absolute_error: 0.2953 - val_mean_squared_error: 0.1796
# Epoch 72/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1129 - mean_absolute_error: 0.2327 - mean_squared_error: 0.1129 - val_loss: 0.1265 - val_mean_absolute_error: 0.2598 - val_mean_squared_error: 0.1265
# Epoch 73/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0946 - mean_absolute_error: 0.2174 - mean_squared_error: 0.0946 - val_loss: 0.1254 - val_mean_absolute_error: 0.2710 - val_mean_squared_error: 0.1254
# Epoch 74/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0980 - mean_absolute_error: 0.2090 - mean_squared_error: 0.0980 - val_loss: 0.0923 - val_mean_absolute_error: 0.2164 - val_mean_squared_error: 0.0923
# Epoch 75/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0945 - mean_absolute_error: 0.2100 - mean_squared_error: 0.0945 - val_loss: 0.0923 - val_mean_absolute_error: 0.2125 - val_mean_squared_error: 0.0923
# Epoch 76/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0861 - mean_absolute_error: 0.1986 - mean_squared_error: 0.0861 - val_loss: 0.0749 - val_mean_absolute_error: 0.1988 - val_mean_squared_error: 0.0749
# Epoch 77/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1047 - mean_absolute_error: 0.2368 - mean_squared_error: 0.1047 - val_loss: 0.0796 - val_mean_absolute_error: 0.1991 - val_mean_squared_error: 0.0796
# Epoch 78/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1038 - mean_absolute_error: 0.2275 - mean_squared_error: 0.1038 - val_loss: 0.1264 - val_mean_absolute_error: 0.2433 - val_mean_squared_error: 0.1264
# Epoch 79/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1211 - mean_absolute_error: 0.2348 - mean_squared_error: 0.1211 - val_loss: 0.0912 - val_mean_absolute_error: 0.2170 - val_mean_squared_error: 0.0912
# Epoch 80/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0896 - mean_absolute_error: 0.2153 - mean_squared_error: 0.0896 - val_loss: 0.1789 - val_mean_absolute_error: 0.3268 - val_mean_squared_error: 0.1789
# Epoch 81/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0927 - mean_absolute_error: 0.2160 - mean_squared_error: 0.0927 - val_loss: 0.0883 - val_mean_absolute_error: 0.2074 - val_mean_squared_error: 0.0883
# Epoch 82/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0880 - mean_absolute_error: 0.2023 - mean_squared_error: 0.0880 - val_loss: 0.0686 - val_mean_absolute_error: 0.1812 - val_mean_squared_error: 0.0686
# Epoch 83/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0974 - mean_absolute_error: 0.2095 - mean_squared_error: 0.0974 - val_loss: 0.0661 - val_mean_absolute_error: 0.1737 - val_mean_squared_error: 0.0661
# Epoch 84/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1078 - mean_absolute_error: 0.2269 - mean_squared_error: 0.1078 - val_loss: 0.0644 - val_mean_absolute_error: 0.1680 - val_mean_squared_error: 0.0644
# Epoch 85/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0996 - mean_absolute_error: 0.2126 - mean_squared_error: 0.0996 - val_loss: 0.0693 - val_mean_absolute_error: 0.1763 - val_mean_squared_error: 0.0693
# Epoch 86/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0800 - mean_absolute_error: 0.1857 - mean_squared_error: 0.0800 - val_loss: 0.0721 - val_mean_absolute_error: 0.1759 - val_mean_squared_error: 0.0721
# Epoch 87/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0732 - mean_absolute_error: 0.1716 - mean_squared_error: 0.0732 - val_loss: 0.0829 - val_mean_absolute_error: 0.2038 - val_mean_squared_error: 0.0829
# Epoch 88/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0961 - mean_absolute_error: 0.2166 - mean_squared_error: 0.0961 - val_loss: 0.0917 - val_mean_absolute_error: 0.2107 - val_mean_squared_error: 0.0917
# Epoch 89/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0853 - mean_absolute_error: 0.1978 - mean_squared_error: 0.0853 - val_loss: 0.0575 - val_mean_absolute_error: 0.1516 - val_mean_squared_error: 0.0575
# Epoch 90/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0875 - mean_absolute_error: 0.2071 - mean_squared_error: 0.0875 - val_loss: 0.0696 - val_mean_absolute_error: 0.1839 - val_mean_squared_error: 0.0696
# Epoch 91/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0772 - mean_absolute_error: 0.1868 - mean_squared_error: 0.0772 - val_loss: 0.0819 - val_mean_absolute_error: 0.1788 - val_mean_squared_error: 0.0819
# Epoch 92/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0990 - mean_absolute_error: 0.2175 - mean_squared_error: 0.0990 - val_loss: 0.0700 - val_mean_absolute_error: 0.1945 - val_mean_squared_error: 0.0700
# Epoch 93/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0667 - mean_absolute_error: 0.1782 - mean_squared_error: 0.0667 - val_loss: 0.0594 - val_mean_absolute_error: 0.1605 - val_mean_squared_error: 0.0594
# Epoch 94/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0706 - mean_absolute_error: 0.1772 - mean_squared_error: 0.0706 - val_loss: 0.0848 - val_mean_absolute_error: 0.2056 - val_mean_squared_error: 0.0848
# Epoch 95/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0878 - mean_absolute_error: 0.2046 - mean_squared_error: 0.0878 - val_loss: 0.0745 - val_mean_absolute_error: 0.1890 - val_mean_squared_error: 0.0745
# Epoch 96/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0672 - mean_absolute_error: 0.1805 - mean_squared_error: 0.0672 - val_loss: 0.0585 - val_mean_absolute_error: 0.1652 - val_mean_squared_error: 0.0585
# Epoch 97/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1501 - mean_squared_error: 0.0547 - val_loss: 0.0519 - val_mean_absolute_error: 0.1526 - val_mean_squared_error: 0.0519
# Epoch 98/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0814 - mean_absolute_error: 0.1888 - mean_squared_error: 0.0814 - val_loss: 0.0623 - val_mean_absolute_error: 0.1721 - val_mean_squared_error: 0.0623
# Epoch 99/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0459 - mean_absolute_error: 0.1454 - mean_squared_error: 0.0459 - val_loss: 0.0838 - val_mean_absolute_error: 0.2029 - val_mean_squared_error: 0.0838
# Epoch 100/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0563 - mean_absolute_error: 0.1479 - mean_squared_error: 0.0563 - val_loss: 0.0523 - val_mean_absolute_error: 0.1441 - val_mean_squared_error: 0.0523
# Epoch 101/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0602 - mean_absolute_error: 0.1558 - mean_squared_error: 0.0602 - val_loss: 0.1111 - val_mean_absolute_error: 0.2544 - val_mean_squared_error: 0.1111
# Epoch 102/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0631 - mean_absolute_error: 0.1646 - mean_squared_error: 0.0631 - val_loss: 0.0424 - val_mean_absolute_error: 0.1291 - val_mean_squared_error: 0.0424
# Epoch 103/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0666 - mean_absolute_error: 0.1635 - mean_squared_error: 0.0666 - val_loss: 0.0765 - val_mean_absolute_error: 0.1905 - val_mean_squared_error: 0.0765
# Epoch 104/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0691 - mean_absolute_error: 0.1741 - mean_squared_error: 0.0691 - val_loss: 0.0978 - val_mean_absolute_error: 0.2097 - val_mean_squared_error: 0.0978
# Epoch 105/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0929 - mean_absolute_error: 0.2052 - mean_squared_error: 0.0929 - val_loss: 0.1428 - val_mean_absolute_error: 0.2933 - val_mean_squared_error: 0.1428
# Epoch 106/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1113 - mean_absolute_error: 0.2424 - mean_squared_error: 0.1113 - val_loss: 0.1319 - val_mean_absolute_error: 0.2502 - val_mean_squared_error: 0.1319
# Epoch 107/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0967 - mean_absolute_error: 0.2104 - mean_squared_error: 0.0967 - val_loss: 0.0527 - val_mean_absolute_error: 0.1518 - val_mean_squared_error: 0.0527
# Epoch 108/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0805 - mean_absolute_error: 0.1934 - mean_squared_error: 0.0805 - val_loss: 0.0827 - val_mean_absolute_error: 0.2304 - val_mean_squared_error: 0.0827
# Epoch 109/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0630 - mean_absolute_error: 0.1764 - mean_squared_error: 0.0630 - val_loss: 0.0764 - val_mean_absolute_error: 0.1988 - val_mean_squared_error: 0.0764
# Epoch 110/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0584 - mean_absolute_error: 0.1706 - mean_squared_error: 0.0584 - val_loss: 0.0725 - val_mean_absolute_error: 0.1824 - val_mean_squared_error: 0.0725
# Epoch 111/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0693 - mean_absolute_error: 0.1678 - mean_squared_error: 0.0693 - val_loss: 0.0467 - val_mean_absolute_error: 0.1401 - val_mean_squared_error: 0.0467
# Epoch 112/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0431 - mean_absolute_error: 0.1333 - mean_squared_error: 0.0431 - val_loss: 0.0491 - val_mean_absolute_error: 0.1467 - val_mean_squared_error: 0.0491
# Epoch 113/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0451 - mean_absolute_error: 0.1438 - mean_squared_error: 0.0451 - val_loss: 0.0443 - val_mean_absolute_error: 0.1371 - val_mean_squared_error: 0.0443
# Epoch 114/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0556 - mean_absolute_error: 0.1540 - mean_squared_error: 0.0556 - val_loss: 0.0465 - val_mean_absolute_error: 0.1407 - val_mean_squared_error: 0.0465
# Epoch 115/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0450 - mean_absolute_error: 0.1424 - mean_squared_error: 0.0450 - val_loss: 0.0411 - val_mean_absolute_error: 0.1284 - val_mean_squared_error: 0.0411
# Epoch 116/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0438 - mean_absolute_error: 0.1282 - mean_squared_error: 0.0438 - val_loss: 0.0479 - val_mean_absolute_error: 0.1515 - val_mean_squared_error: 0.0479
# Epoch 117/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0461 - mean_absolute_error: 0.1454 - mean_squared_error: 0.0461 - val_loss: 0.0395 - val_mean_absolute_error: 0.1314 - val_mean_squared_error: 0.0395
# Epoch 118/300
# 978/978 [==============================] - 1s 998us/step - loss: 0.0423 - mean_absolute_error: 0.1367 - mean_squared_error: 0.0423 - val_loss: 0.0583 - val_mean_absolute_error: 0.1617 - val_mean_squared_error: 0.0583
# Epoch 119/300
# 978/978 [==============================] - 1s 975us/step - loss: 0.0497 - mean_absolute_error: 0.1452 - mean_squared_error: 0.0497 - val_loss: 0.0528 - val_mean_absolute_error: 0.1687 - val_mean_squared_error: 0.0528
# Epoch 120/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0605 - mean_absolute_error: 0.1651 - mean_squared_error: 0.0605 - val_loss: 0.0542 - val_mean_absolute_error: 0.1585 - val_mean_squared_error: 0.0542
# Epoch 121/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0435 - mean_absolute_error: 0.1404 - mean_squared_error: 0.0435 - val_loss: 0.0950 - val_mean_absolute_error: 0.2040 - val_mean_squared_error: 0.0950
# Epoch 122/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0522 - mean_absolute_error: 0.1601 - mean_squared_error: 0.0522 - val_loss: 0.1022 - val_mean_absolute_error: 0.2073 - val_mean_squared_error: 0.1022
# Epoch 123/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0468 - mean_absolute_error: 0.1479 - mean_squared_error: 0.0468 - val_loss: 0.0526 - val_mean_absolute_error: 0.1456 - val_mean_squared_error: 0.0526
# Epoch 124/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0458 - mean_absolute_error: 0.1429 - mean_squared_error: 0.0458 - val_loss: 0.0402 - val_mean_absolute_error: 0.1307 - val_mean_squared_error: 0.0402
# Epoch 125/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0383 - mean_absolute_error: 0.1288 - mean_squared_error: 0.0383 - val_loss: 0.0417 - val_mean_absolute_error: 0.1471 - val_mean_squared_error: 0.0417
# Epoch 126/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0362 - mean_absolute_error: 0.1245 - mean_squared_error: 0.0362 - val_loss: 0.0677 - val_mean_absolute_error: 0.1803 - val_mean_squared_error: 0.0677
# Epoch 127/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0542 - mean_absolute_error: 0.1573 - mean_squared_error: 0.0542 - val_loss: 0.0499 - val_mean_absolute_error: 0.1551 - val_mean_squared_error: 0.0499
# Epoch 128/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0530 - mean_absolute_error: 0.1529 - mean_squared_error: 0.0530 - val_loss: 0.0974 - val_mean_absolute_error: 0.2338 - val_mean_squared_error: 0.0974
# Epoch 129/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0961 - mean_absolute_error: 0.2328 - mean_squared_error: 0.0961 - val_loss: 0.0973 - val_mean_absolute_error: 0.2360 - val_mean_squared_error: 0.0973
# Epoch 130/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0713 - mean_absolute_error: 0.1845 - mean_squared_error: 0.0713 - val_loss: 0.0540 - val_mean_absolute_error: 0.1677 - val_mean_squared_error: 0.0540
# Epoch 131/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0556 - mean_absolute_error: 0.1685 - mean_squared_error: 0.0556 - val_loss: 0.0759 - val_mean_absolute_error: 0.2144 - val_mean_squared_error: 0.0759
# Epoch 132/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0380 - mean_absolute_error: 0.1284 - mean_squared_error: 0.0380 - val_loss: 0.0325 - val_mean_absolute_error: 0.1176 - val_mean_squared_error: 0.0325
# Epoch 133/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0342 - mean_absolute_error: 0.1252 - mean_squared_error: 0.0342 - val_loss: 0.0527 - val_mean_absolute_error: 0.1705 - val_mean_squared_error: 0.0527
# Epoch 134/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0481 - mean_absolute_error: 0.1490 - mean_squared_error: 0.0481 - val_loss: 0.0540 - val_mean_absolute_error: 0.1657 - val_mean_squared_error: 0.0540
# Epoch 135/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0355 - mean_absolute_error: 0.1261 - mean_squared_error: 0.0355 - val_loss: 0.0354 - val_mean_absolute_error: 0.1242 - val_mean_squared_error: 0.0354
# Epoch 136/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0352 - mean_absolute_error: 0.1267 - mean_squared_error: 0.0352 - val_loss: 0.0474 - val_mean_absolute_error: 0.1582 - val_mean_squared_error: 0.0474
# Epoch 137/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0427 - mean_absolute_error: 0.1386 - mean_squared_error: 0.0427 - val_loss: 0.0442 - val_mean_absolute_error: 0.1366 - val_mean_squared_error: 0.0442
# Epoch 138/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0433 - mean_absolute_error: 0.1412 - mean_squared_error: 0.0433 - val_loss: 0.0518 - val_mean_absolute_error: 0.1672 - val_mean_squared_error: 0.0518
# Epoch 139/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0397 - mean_absolute_error: 0.1373 - mean_squared_error: 0.0397 - val_loss: 0.0451 - val_mean_absolute_error: 0.1471 - val_mean_squared_error: 0.0451
# Epoch 140/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0380 - mean_absolute_error: 0.1218 - mean_squared_error: 0.0380 - val_loss: 0.0459 - val_mean_absolute_error: 0.1530 - val_mean_squared_error: 0.0459
# Epoch 141/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0430 - mean_absolute_error: 0.1345 - mean_squared_error: 0.0430 - val_loss: 0.0307 - val_mean_absolute_error: 0.1111 - val_mean_squared_error: 0.0307
# Epoch 142/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0535 - mean_absolute_error: 0.1613 - mean_squared_error: 0.0535 - val_loss: 0.0472 - val_mean_absolute_error: 0.1494 - val_mean_squared_error: 0.0472
# Epoch 143/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0511 - mean_absolute_error: 0.1509 - mean_squared_error: 0.0511 - val_loss: 0.0574 - val_mean_absolute_error: 0.1608 - val_mean_squared_error: 0.0574
# Epoch 144/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0476 - mean_absolute_error: 0.1449 - mean_squared_error: 0.0476 - val_loss: 0.0704 - val_mean_absolute_error: 0.1899 - val_mean_squared_error: 0.0704
# Epoch 145/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0374 - mean_absolute_error: 0.1321 - mean_squared_error: 0.0374 - val_loss: 0.0424 - val_mean_absolute_error: 0.1399 - val_mean_squared_error: 0.0424
# Epoch 146/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0282 - mean_absolute_error: 0.1107 - mean_squared_error: 0.0282 - val_loss: 0.0426 - val_mean_absolute_error: 0.1547 - val_mean_squared_error: 0.0426
# Epoch 147/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0344 - mean_absolute_error: 0.1258 - mean_squared_error: 0.0344 - val_loss: 0.0654 - val_mean_absolute_error: 0.1692 - val_mean_squared_error: 0.0654
# Epoch 148/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0569 - mean_absolute_error: 0.1616 - mean_squared_error: 0.0569 - val_loss: 0.0297 - val_mean_absolute_error: 0.1104 - val_mean_squared_error: 0.0297
# Epoch 149/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0834 - mean_absolute_error: 0.2146 - mean_squared_error: 0.0834 - val_loss: 0.0945 - val_mean_absolute_error: 0.2457 - val_mean_squared_error: 0.0945
# Epoch 150/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0578 - mean_absolute_error: 0.1610 - mean_squared_error: 0.0578 - val_loss: 0.0341 - val_mean_absolute_error: 0.1268 - val_mean_squared_error: 0.0341
# Epoch 151/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0381 - mean_absolute_error: 0.1311 - mean_squared_error: 0.0381 - val_loss: 0.0423 - val_mean_absolute_error: 0.1422 - val_mean_squared_error: 0.0423
# Epoch 152/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0320 - mean_absolute_error: 0.1169 - mean_squared_error: 0.0320 - val_loss: 0.0556 - val_mean_absolute_error: 0.1842 - val_mean_squared_error: 0.0556
# Epoch 153/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0360 - mean_absolute_error: 0.1271 - mean_squared_error: 0.0360 - val_loss: 0.0413 - val_mean_absolute_error: 0.1364 - val_mean_squared_error: 0.0413
# Epoch 154/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0284 - mean_absolute_error: 0.1116 - mean_squared_error: 0.0284 - val_loss: 0.0387 - val_mean_absolute_error: 0.1378 - val_mean_squared_error: 0.0387
# Epoch 155/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0289 - mean_absolute_error: 0.1158 - mean_squared_error: 0.0289 - val_loss: 0.0510 - val_mean_absolute_error: 0.1576 - val_mean_squared_error: 0.0510
# Epoch 156/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0267 - mean_absolute_error: 0.1053 - mean_squared_error: 0.0267 - val_loss: 0.0370 - val_mean_absolute_error: 0.1412 - val_mean_squared_error: 0.0370
# Epoch 157/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0365 - mean_absolute_error: 0.1353 - mean_squared_error: 0.0365 - val_loss: 0.0685 - val_mean_absolute_error: 0.1942 - val_mean_squared_error: 0.0685
# Epoch 158/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0512 - mean_absolute_error: 0.1597 - mean_squared_error: 0.0512 - val_loss: 0.0836 - val_mean_absolute_error: 0.2153 - val_mean_squared_error: 0.0836
# Epoch 159/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0776 - mean_absolute_error: 0.1958 - mean_squared_error: 0.0776 - val_loss: 0.0809 - val_mean_absolute_error: 0.2269 - val_mean_squared_error: 0.0809
# Epoch 160/300
# 978/978 [==============================] - 1s 995us/step - loss: 0.0809 - mean_absolute_error: 0.1813 - mean_squared_error: 0.0809 - val_loss: 0.0787 - val_mean_absolute_error: 0.2062 - val_mean_squared_error: 0.0787
# Epoch 161/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0844 - mean_absolute_error: 0.2013 - mean_squared_error: 0.0844 - val_loss: 0.0621 - val_mean_absolute_error: 0.1730 - val_mean_squared_error: 0.0621
# Epoch 162/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0297 - mean_absolute_error: 0.1199 - mean_squared_error: 0.0297 - val_loss: 0.0385 - val_mean_absolute_error: 0.1335 - val_mean_squared_error: 0.0385
# Epoch 163/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0323 - mean_absolute_error: 0.1192 - mean_squared_error: 0.0323 - val_loss: 0.0403 - val_mean_absolute_error: 0.1452 - val_mean_squared_error: 0.0403
# Epoch 164/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0361 - mean_absolute_error: 0.1388 - mean_squared_error: 0.0361 - val_loss: 0.0403 - val_mean_absolute_error: 0.1470 - val_mean_squared_error: 0.0403
# Epoch 165/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0300 - mean_absolute_error: 0.1147 - mean_squared_error: 0.0300 - val_loss: 0.0514 - val_mean_absolute_error: 0.1654 - val_mean_squared_error: 0.0514
# Epoch 166/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0471 - mean_absolute_error: 0.1465 - mean_squared_error: 0.0471 - val_loss: 0.0369 - val_mean_absolute_error: 0.1433 - val_mean_squared_error: 0.0369
# Epoch 167/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0282 - mean_absolute_error: 0.1177 - mean_squared_error: 0.0282 - val_loss: 0.0293 - val_mean_absolute_error: 0.1121 - val_mean_squared_error: 0.0293
# Epoch 168/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0278 - mean_absolute_error: 0.1073 - mean_squared_error: 0.0278 - val_loss: 0.0291 - val_mean_absolute_error: 0.1171 - val_mean_squared_error: 0.0291
# Epoch 169/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0267 - mean_absolute_error: 0.1097 - mean_squared_error: 0.0267 - val_loss: 0.0345 - val_mean_absolute_error: 0.1278 - val_mean_squared_error: 0.0345
# Epoch 170/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0364 - mean_absolute_error: 0.1406 - mean_squared_error: 0.0364 - val_loss: 0.0372 - val_mean_absolute_error: 0.1369 - val_mean_squared_error: 0.0372
# Epoch 171/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0274 - mean_absolute_error: 0.1135 - mean_squared_error: 0.0274 - val_loss: 0.0501 - val_mean_absolute_error: 0.1628 - val_mean_squared_error: 0.0501
# Epoch 172/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0278 - mean_absolute_error: 0.1130 - mean_squared_error: 0.0278 - val_loss: 0.0359 - val_mean_absolute_error: 0.1326 - val_mean_squared_error: 0.0359
# Epoch 173/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0369 - mean_absolute_error: 0.1225 - mean_squared_error: 0.0369 - val_loss: 0.0697 - val_mean_absolute_error: 0.2132 - val_mean_squared_error: 0.0697
# Epoch 174/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0371 - mean_absolute_error: 0.1334 - mean_squared_error: 0.0371 - val_loss: 0.0317 - val_mean_absolute_error: 0.1213 - val_mean_squared_error: 0.0317
# Epoch 175/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0244 - mean_absolute_error: 0.1023 - mean_squared_error: 0.0244 - val_loss: 0.0305 - val_mean_absolute_error: 0.1253 - val_mean_squared_error: 0.0305
# Epoch 176/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0226 - mean_absolute_error: 0.1009 - mean_squared_error: 0.0226 - val_loss: 0.0263 - val_mean_absolute_error: 0.1068 - val_mean_squared_error: 0.0263
# Epoch 177/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0229 - mean_absolute_error: 0.1032 - mean_squared_error: 0.0229 - val_loss: 0.0237 - val_mean_absolute_error: 0.1034 - val_mean_squared_error: 0.0237
# Epoch 178/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0211 - mean_absolute_error: 0.0956 - mean_squared_error: 0.0211 - val_loss: 0.0268 - val_mean_absolute_error: 0.1121 - val_mean_squared_error: 0.0268
# Epoch 179/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0204 - mean_absolute_error: 0.0940 - mean_squared_error: 0.0204 - val_loss: 0.0370 - val_mean_absolute_error: 0.1399 - val_mean_squared_error: 0.0370
# Epoch 180/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0213 - mean_absolute_error: 0.0980 - mean_squared_error: 0.0213 - val_loss: 0.0287 - val_mean_absolute_error: 0.1201 - val_mean_squared_error: 0.0287
# Epoch 181/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0198 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0198 - val_loss: 0.0265 - val_mean_absolute_error: 0.1147 - val_mean_squared_error: 0.0265
# Epoch 182/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0185 - mean_absolute_error: 0.0924 - mean_squared_error: 0.0185 - val_loss: 0.0346 - val_mean_absolute_error: 0.1308 - val_mean_squared_error: 0.0346
# Epoch 183/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0243 - mean_absolute_error: 0.0987 - mean_squared_error: 0.0243 - val_loss: 0.0248 - val_mean_absolute_error: 0.1005 - val_mean_squared_error: 0.0248
# Epoch 184/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0204 - mean_absolute_error: 0.0937 - mean_squared_error: 0.0204 - val_loss: 0.0249 - val_mean_absolute_error: 0.1077 - val_mean_squared_error: 0.0249
# Epoch 185/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0310 - mean_absolute_error: 0.1226 - mean_squared_error: 0.0310 - val_loss: 0.0370 - val_mean_absolute_error: 0.1441 - val_mean_squared_error: 0.0370
# Epoch 186/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0248 - mean_absolute_error: 0.1039 - mean_squared_error: 0.0248 - val_loss: 0.0297 - val_mean_absolute_error: 0.1206 - val_mean_squared_error: 0.0297
# Epoch 187/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0252 - mean_absolute_error: 0.1092 - mean_squared_error: 0.0252 - val_loss: 0.0275 - val_mean_absolute_error: 0.1132 - val_mean_squared_error: 0.0275
# Epoch 188/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0315 - mean_absolute_error: 0.1196 - mean_squared_error: 0.0315 - val_loss: 0.0262 - val_mean_absolute_error: 0.1078 - val_mean_squared_error: 0.0262
# Epoch 189/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0997 - mean_absolute_error: 0.2190 - mean_squared_error: 0.0997 - val_loss: 0.0752 - val_mean_absolute_error: 0.1994 - val_mean_squared_error: 0.0752
# Epoch 190/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.1515 - mean_absolute_error: 0.2785 - mean_squared_error: 0.1515 - val_loss: 0.0858 - val_mean_absolute_error: 0.2154 - val_mean_squared_error: 0.0858
# Epoch 191/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0772 - mean_absolute_error: 0.1929 - mean_squared_error: 0.0772 - val_loss: 0.0525 - val_mean_absolute_error: 0.1807 - val_mean_squared_error: 0.0525
# Epoch 192/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0677 - mean_absolute_error: 0.1868 - mean_squared_error: 0.0677 - val_loss: 0.0496 - val_mean_absolute_error: 0.1764 - val_mean_squared_error: 0.0496
# Epoch 193/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0769 - mean_absolute_error: 0.1978 - mean_squared_error: 0.0769 - val_loss: 0.0678 - val_mean_absolute_error: 0.1927 - val_mean_squared_error: 0.0678
# Epoch 194/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0445 - mean_absolute_error: 0.1471 - mean_squared_error: 0.0445 - val_loss: 0.0540 - val_mean_absolute_error: 0.1698 - val_mean_squared_error: 0.0540
# Epoch 195/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0690 - mean_absolute_error: 0.1787 - mean_squared_error: 0.0690 - val_loss: 0.0478 - val_mean_absolute_error: 0.1612 - val_mean_squared_error: 0.0478
# Epoch 196/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0395 - mean_absolute_error: 0.1422 - mean_squared_error: 0.0395 - val_loss: 0.0501 - val_mean_absolute_error: 0.1678 - val_mean_squared_error: 0.0501
# Epoch 197/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0435 - mean_absolute_error: 0.1390 - mean_squared_error: 0.0435 - val_loss: 0.0444 - val_mean_absolute_error: 0.1423 - val_mean_squared_error: 0.0444
# Epoch 198/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0408 - mean_absolute_error: 0.1303 - mean_squared_error: 0.0408 - val_loss: 0.0434 - val_mean_absolute_error: 0.1632 - val_mean_squared_error: 0.0434
# Epoch 199/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0438 - mean_absolute_error: 0.1390 - mean_squared_error: 0.0438 - val_loss: 0.0393 - val_mean_absolute_error: 0.1349 - val_mean_squared_error: 0.0393
# Epoch 200/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0352 - mean_absolute_error: 0.1301 - mean_squared_error: 0.0352 - val_loss: 0.0269 - val_mean_absolute_error: 0.1098 - val_mean_squared_error: 0.0269
# Epoch 201/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0229 - mean_absolute_error: 0.0994 - mean_squared_error: 0.0229 - val_loss: 0.0351 - val_mean_absolute_error: 0.1298 - val_mean_squared_error: 0.0351
# Epoch 202/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0214 - mean_absolute_error: 0.0948 - mean_squared_error: 0.0214 - val_loss: 0.0230 - val_mean_absolute_error: 0.0998 - val_mean_squared_error: 0.0230
# Epoch 203/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0216 - mean_absolute_error: 0.0939 - mean_squared_error: 0.0216 - val_loss: 0.0313 - val_mean_absolute_error: 0.1291 - val_mean_squared_error: 0.0313
# Epoch 204/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0238 - mean_absolute_error: 0.0995 - mean_squared_error: 0.0238 - val_loss: 0.0307 - val_mean_absolute_error: 0.1226 - val_mean_squared_error: 0.0307
# Epoch 205/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0206 - mean_absolute_error: 0.0992 - mean_squared_error: 0.0206 - val_loss: 0.0293 - val_mean_absolute_error: 0.1158 - val_mean_squared_error: 0.0293
# Epoch 206/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0265 - mean_absolute_error: 0.1088 - mean_squared_error: 0.0265 - val_loss: 0.0347 - val_mean_absolute_error: 0.1284 - val_mean_squared_error: 0.0347
# Epoch 207/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0227 - mean_absolute_error: 0.0998 - mean_squared_error: 0.0227 - val_loss: 0.0335 - val_mean_absolute_error: 0.1287 - val_mean_squared_error: 0.0335
# Epoch 208/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0293 - mean_absolute_error: 0.1176 - mean_squared_error: 0.0293 - val_loss: 0.0315 - val_mean_absolute_error: 0.1198 - val_mean_squared_error: 0.0315
# Epoch 209/300
# ...
# Epoch 232/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0579 - mean_absolute_error: 0.1590 - mean_squared_error: 0.0579 - val_loss: 0.0519 - val_mean_absolute_error: 0.1676 - val_mean_squared_error: 0.0519
# Epoch 233/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0769 - mean_absolute_error: 0.1948 - mean_squared_error: 0.0769 - val_loss: 0.0893 - val_mean_absolute_error: 0.2292 - val_mean_squared_error: 0.0893
# Epoch 234/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0480 - mean_absolute_error: 0.1656 - mean_squared_error: 0.0480 - val_loss: 0.0586 - val_mean_absolute_error: 0.1697 - val_mean_squared_error: 0.0586
# Epoch 235/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0278 - mean_absolute_error: 0.1206 - mean_squared_error: 0.0278 - val_loss: 0.0254 - val_mean_absolute_error: 0.1146 - val_mean_squared_error: 0.0254
# Epoch 236/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0200 - mean_absolute_error: 0.0967 - mean_squared_error: 0.0200 - val_loss: 0.0361 - val_mean_absolute_error: 0.1338 - val_mean_squared_error: 0.0361
# Epoch 237/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0226 - mean_absolute_error: 0.1034 - mean_squared_error: 0.0226 - val_loss: 0.0431 - val_mean_absolute_error: 0.1613 - val_mean_squared_error: 0.0431
# Epoch 238/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0172 - mean_absolute_error: 0.0917 - mean_squared_error: 0.0172 - val_loss: 0.0298 - val_mean_absolute_error: 0.1335 - val_mean_squared_error: 0.0298
# Epoch 239/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0201 - mean_absolute_error: 0.0969 - mean_squared_error: 0.0201 - val_loss: 0.0274 - val_mean_absolute_error: 0.1145 - val_mean_squared_error: 0.0274
# Epoch 240/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0195 - mean_absolute_error: 0.0979 - mean_squared_error: 0.0195 - val_loss: 0.0264 - val_mean_absolute_error: 0.1109 - val_mean_squared_error: 0.0264
# Epoch 241/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0230 - mean_absolute_error: 0.1035 - mean_squared_error: 0.0230 - val_loss: 0.0228 - val_mean_absolute_error: 0.1065 - val_mean_squared_error: 0.0228
# Epoch 242/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0171 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0171 - val_loss: 0.0229 - val_mean_absolute_error: 0.1007 - val_mean_squared_error: 0.0229
# Epoch 243/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0171 - mean_absolute_error: 0.0879 - mean_squared_error: 0.0171 - val_loss: 0.0258 - val_mean_absolute_error: 0.1172 - val_mean_squared_error: 0.0258
# Epoch 244/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0140 - mean_absolute_error: 0.0807 - mean_squared_error: 0.0140 - val_loss: 0.0256 - val_mean_absolute_error: 0.1117 - val_mean_squared_error: 0.0256
# Epoch 245/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0152 - mean_absolute_error: 0.0818 - mean_squared_error: 0.0152 - val_loss: 0.0331 - val_mean_absolute_error: 0.1271 - val_mean_squared_error: 0.0331
# Epoch 246/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0176 - mean_absolute_error: 0.0899 - mean_squared_error: 0.0176 - val_loss: 0.0295 - val_mean_absolute_error: 0.1201 - val_mean_squared_error: 0.0295
# Epoch 247/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0166 - mean_absolute_error: 0.0881 - mean_squared_error: 0.0166 - val_loss: 0.0211 - val_mean_absolute_error: 0.0999 - val_mean_squared_error: 0.0211
# Epoch 248/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0143 - mean_absolute_error: 0.0791 - mean_squared_error: 0.0143 - val_loss: 0.0275 - val_mean_absolute_error: 0.1154 - val_mean_squared_error: 0.0275
# Epoch 249/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0158 - mean_absolute_error: 0.0851 - mean_squared_error: 0.0158 - val_loss: 0.0275 - val_mean_absolute_error: 0.1197 - val_mean_squared_error: 0.0275
# Epoch 250/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0145 - mean_absolute_error: 0.0822 - mean_squared_error: 0.0145 - val_loss: 0.0205 - val_mean_absolute_error: 0.1001 - val_mean_squared_error: 0.0205
# Epoch 251/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0179 - mean_absolute_error: 0.0898 - mean_squared_error: 0.0179 - val_loss: 0.0238 - val_mean_absolute_error: 0.1092 - val_mean_squared_error: 0.0238
# Epoch 252/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0151 - mean_absolute_error: 0.0847 - mean_squared_error: 0.0151 - val_loss: 0.0185 - val_mean_absolute_error: 0.0952 - val_mean_squared_error: 0.0185
# Epoch 253/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0132 - mean_absolute_error: 0.0784 - mean_squared_error: 0.0132 - val_loss: 0.0219 - val_mean_absolute_error: 0.1055 - val_mean_squared_error: 0.0219
# Epoch 254/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0132 - mean_absolute_error: 0.0798 - mean_squared_error: 0.0132 - val_loss: 0.0197 - val_mean_absolute_error: 0.0947 - val_mean_squared_error: 0.0197
# Epoch 255/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0164 - mean_absolute_error: 0.0905 - mean_squared_error: 0.0164 - val_loss: 0.0233 - val_mean_absolute_error: 0.1045 - val_mean_squared_error: 0.0233
# Epoch 256/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0169 - mean_absolute_error: 0.0906 - mean_squared_error: 0.0169 - val_loss: 0.0198 - val_mean_absolute_error: 0.0988 - val_mean_squared_error: 0.0198
# Epoch 257/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0154 - mean_absolute_error: 0.0858 - mean_squared_error: 0.0154 - val_loss: 0.0187 - val_mean_absolute_error: 0.0920 - val_mean_squared_error: 0.0187
# Epoch 258/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0125 - mean_absolute_error: 0.0770 - mean_squared_error: 0.0125 - val_loss: 0.0260 - val_mean_absolute_error: 0.1126 - val_mean_squared_error: 0.0260
# Epoch 259/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0147 - mean_absolute_error: 0.0833 - mean_squared_error: 0.0147 - val_loss: 0.0234 - val_mean_absolute_error: 0.1112 - val_mean_squared_error: 0.0234
# Epoch 260/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0141 - mean_absolute_error: 0.0831 - mean_squared_error: 0.0141 - val_loss: 0.0296 - val_mean_absolute_error: 0.1271 - val_mean_squared_error: 0.0296
# Epoch 261/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0195 - mean_absolute_error: 0.0947 - mean_squared_error: 0.0195 - val_loss: 0.0167 - val_mean_absolute_error: 0.0848 - val_mean_squared_error: 0.0167
# Epoch 262/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0169 - mean_absolute_error: 0.0865 - mean_squared_error: 0.0169 - val_loss: 0.0322 - val_mean_absolute_error: 0.1281 - val_mean_squared_error: 0.0322
# Epoch 263/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0176 - mean_absolute_error: 0.0900 - mean_squared_error: 0.0176 - val_loss: 0.0282 - val_mean_absolute_error: 0.1259 - val_mean_squared_error: 0.0282
# Epoch 264/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0138 - mean_absolute_error: 0.0798 - mean_squared_error: 0.0138 - val_loss: 0.0178 - val_mean_absolute_error: 0.0914 - val_mean_squared_error: 0.0178
# Epoch 265/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0131 - mean_absolute_error: 0.0795 - mean_squared_error: 0.0131 - val_loss: 0.0179 - val_mean_absolute_error: 0.0842 - val_mean_squared_error: 0.0179
# Epoch 266/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0127 - mean_absolute_error: 0.0778 - mean_squared_error: 0.0127 - val_loss: 0.0224 - val_mean_absolute_error: 0.1053 - val_mean_squared_error: 0.0224
# Epoch 267/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0144 - mean_absolute_error: 0.0809 - mean_squared_error: 0.0144 - val_loss: 0.0207 - val_mean_absolute_error: 0.0988 - val_mean_squared_error: 0.0207
# Epoch 268/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0150 - mean_absolute_error: 0.0850 - mean_squared_error: 0.0150 - val_loss: 0.0292 - val_mean_absolute_error: 0.1198 - val_mean_squared_error: 0.0292
# Epoch 269/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0200 - mean_absolute_error: 0.0978 - mean_squared_error: 0.0200 - val_loss: 0.0196 - val_mean_absolute_error: 0.0890 - val_mean_squared_error: 0.0196
# Epoch 270/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0162 - mean_absolute_error: 0.0913 - mean_squared_error: 0.0162 - val_loss: 0.0222 - val_mean_absolute_error: 0.1065 - val_mean_squared_error: 0.0222
# Epoch 271/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0153 - mean_absolute_error: 0.0830 - mean_squared_error: 0.0153 - val_loss: 0.0192 - val_mean_absolute_error: 0.0951 - val_mean_squared_error: 0.0192
# Epoch 272/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0137 - mean_absolute_error: 0.0824 - mean_squared_error: 0.0137 - val_loss: 0.0323 - val_mean_absolute_error: 0.1304 - val_mean_squared_error: 0.0323
# Epoch 273/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0185 - mean_absolute_error: 0.0922 - mean_squared_error: 0.0185 - val_loss: 0.0261 - val_mean_absolute_error: 0.1102 - val_mean_squared_error: 0.0261
# Epoch 274/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0219 - mean_absolute_error: 0.1002 - mean_squared_error: 0.0219 - val_loss: 0.0327 - val_mean_absolute_error: 0.1294 - val_mean_squared_error: 0.0327
# Epoch 275/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0194 - mean_absolute_error: 0.0956 - mean_squared_error: 0.0194 - val_loss: 0.0253 - val_mean_absolute_error: 0.1155 - val_mean_squared_error: 0.0253
# Epoch 276/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0228 - mean_absolute_error: 0.1111 - mean_squared_error: 0.0228 - val_loss: 0.0276 - val_mean_absolute_error: 0.1150 - val_mean_squared_error: 0.0276
# Epoch 277/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0339 - mean_absolute_error: 0.1283 - mean_squared_error: 0.0339 - val_loss: 0.0502 - val_mean_absolute_error: 0.1534 - val_mean_squared_error: 0.0502
# Epoch 278/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0225 - mean_absolute_error: 0.1052 - mean_squared_error: 0.0225 - val_loss: 0.0224 - val_mean_absolute_error: 0.1039 - val_mean_squared_error: 0.0224
# Epoch 279/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0168 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0168 - val_loss: 0.0253 - val_mean_absolute_error: 0.1125 - val_mean_squared_error: 0.0253
# Epoch 280/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0335 - mean_absolute_error: 0.1275 - mean_squared_error: 0.0335 - val_loss: 0.0544 - val_mean_absolute_error: 0.1669 - val_mean_squared_error: 0.0544
# Epoch 281/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0294 - mean_absolute_error: 0.1246 - mean_squared_error: 0.0294 - val_loss: 0.0579 - val_mean_absolute_error: 0.1847 - val_mean_squared_error: 0.0579
# Epoch 282/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0305 - mean_absolute_error: 0.1256 - mean_squared_error: 0.0305 - val_loss: 0.0287 - val_mean_absolute_error: 0.1133 - val_mean_squared_error: 0.0287
# Epoch 283/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0389 - mean_absolute_error: 0.1327 - mean_squared_error: 0.0389 - val_loss: 0.0271 - val_mean_absolute_error: 0.1187 - val_mean_squared_error: 0.0271
# Epoch 284/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0218 - mean_absolute_error: 0.1036 - mean_squared_error: 0.0218 - val_loss: 0.0221 - val_mean_absolute_error: 0.0991 - val_mean_squared_error: 0.0221
# Epoch 285/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0277 - mean_absolute_error: 0.1172 - mean_squared_error: 0.0277 - val_loss: 0.0289 - val_mean_absolute_error: 0.1201 - val_mean_squared_error: 0.0289
# Epoch 286/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0337 - mean_absolute_error: 0.1329 - mean_squared_error: 0.0337 - val_loss: 0.0386 - val_mean_absolute_error: 0.1371 - val_mean_squared_error: 0.0386
# Epoch 287/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0255 - mean_absolute_error: 0.1118 - mean_squared_error: 0.0255 - val_loss: 0.0323 - val_mean_absolute_error: 0.1349 - val_mean_squared_error: 0.0323
# Epoch 288/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0218 - mean_absolute_error: 0.1106 - mean_squared_error: 0.0218 - val_loss: 0.0206 - val_mean_absolute_error: 0.1006 - val_mean_squared_error: 0.0206
# Epoch 289/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0149 - mean_absolute_error: 0.0847 - mean_squared_error: 0.0149 - val_loss: 0.0214 - val_mean_absolute_error: 0.0987 - val_mean_squared_error: 0.0214
# Epoch 290/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0169 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0169 - val_loss: 0.0228 - val_mean_absolute_error: 0.1070 - val_mean_squared_error: 0.0228
# Epoch 291/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0158 - mean_absolute_error: 0.0872 - mean_squared_error: 0.0158 - val_loss: 0.0299 - val_mean_absolute_error: 0.1262 - val_mean_squared_error: 0.0299
# Epoch 292/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0122 - mean_absolute_error: 0.0758 - mean_squared_error: 0.0122 - val_loss: 0.0189 - val_mean_absolute_error: 0.1007 - val_mean_squared_error: 0.0189
# Epoch 293/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0119 - mean_absolute_error: 0.0776 - mean_squared_error: 0.0119 - val_loss: 0.0205 - val_mean_absolute_error: 0.1067 - val_mean_squared_error: 0.0205
# Epoch 294/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0125 - mean_absolute_error: 0.0804 - mean_squared_error: 0.0125 - val_loss: 0.0162 - val_mean_absolute_error: 0.0858 - val_mean_squared_error: 0.0162
# Epoch 295/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0157 - mean_absolute_error: 0.0847 - mean_squared_error: 0.0157 - val_loss: 0.0298 - val_mean_absolute_error: 0.1200 - val_mean_squared_error: 0.0298
# Epoch 296/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0288 - mean_absolute_error: 0.1180 - mean_squared_error: 0.0288 - val_loss: 0.0230 - val_mean_absolute_error: 0.1082 - val_mean_squared_error: 0.0230
# Epoch 297/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0205 - mean_absolute_error: 0.1004 - mean_squared_error: 0.0205 - val_loss: 0.0219 - val_mean_absolute_error: 0.1038 - val_mean_squared_error: 0.0219
# Epoch 298/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0194 - mean_absolute_error: 0.1031 - mean_squared_error: 0.0194 - val_loss: 0.0238 - val_mean_absolute_error: 0.0963 - val_mean_squared_error: 0.0238
# Epoch 299/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0170 - mean_absolute_error: 0.0907 - mean_squared_error: 0.0170 - val_loss: 0.0281 - val_mean_absolute_error: 0.1204 - val_mean_squared_error: 0.0281
# Epoch 300/300
# 978/978 [==============================] - 1s 1ms/step - loss: 0.0135 - mean_absolute_error: 0.0812 - mean_squared_error: 0.0135 - val_loss: 0.0197 - val_mean_absolute_error: 0.0996 - val_mean_squared_error: 0.0197

# %%
hist = pd.DataFrame(history.history)
hist['epoch']= history.epoch
hist.tail()
# Out:
#      val_loss  val_mean_absolute_error  val_mean_squared_error      loss  \
# 295  0.023003                 0.108241                0.023003  0.028831
# 296  0.021882                 0.103835                0.021882  0.020463
# 297  0.023822                 0.096305                0.023822  0.019418
# 298  0.028059                 0.120421                0.028059  0.017010
# 299  0.019742                 0.099574                0.019742  0.013479
#
#      mean_absolute_error  mean_squared_error  epoch
# 295             0.117998            0.028831    295
# 296             0.100400            0.020463    296
# 297             0.103053            0.019418    297
# 298             0.090729            0.017010    298
# 299             0.081174            0.013479    299

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
    
  plt.figure(figsize=(13,9))
  #plt.figure()
  plt.xlabel('Epoch', fontsize= 18)
  plt.ylabel('Mean Abs Error', fontsize= 18)
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  plt.ylim([0,1.2])
  plt.tick_params(labelsize=20)
  plt.legend()
  

  plt.figure(figsize=(13,9))
  #plt.figure()
  plt.xlabel('Epoch', fontsize = 20)
  plt.ylabel('Mean Square Error', fontsize= 20)
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  plt.ylim([0,10])
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# **Save model**

# %%
test_predictions = model.predict([x_RVStrain, x_BPtrain, x_RPtrain])
print(np.shape(test_predictions))
print('shape of teff',np.shape(y_train_stack[:,0]))
print('shape of logg',np.shape(y_train_stack[:,1]))
print('shape of [Fe/H]',np.shape(y_train_stack[:,2]))
plt.scatter((y_train_stack[:,0]), test_predictions[:,0], label= 'Teff')
plt.scatter((y_train_stack[:,1]), test_predictions[:,1], label= 'Log(g)')
plt.scatter((y_train_stack[:,2]), test_predictions[:,2], label= '[Fe/H]')
plt.xlabel('True Values [Teff]')
plt.ylabel('Predictions [Teff]')
plt.axis('equal')
plt.axis('square')
plt.legend()
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
#_ = plt.plot([1.4, 1.4], [1.4, 1.4])
#print('test predictions=', test_predictions)
# Out:
# (978, 3)
# shape of teff (978,)
# shape of logg (978,)
# shape of [Fe/H] (978,)

# %%
def denormalize(labels, mean_labels, std_labels):
    return (labels*std_labels)+mean_labels



k=denormalise(y_train_stack[:,0], y_teff_train[1], y_teff_train[2])

# %%
#Unnormalizing the labels (teff)

#print(np.shape(y_train_stack[:,0]))
#print(np.shape(y_train_stack[:,1]))
#print(np.shape(y_train_stack[:,2]))




test_predictions = model.predict([x_RVStrain, x_BPtrain, x_RPtrain])
#print('shape of test_predictions:',np.shape(test_predictions))

#teff
plt.figure(figsize=(13,9))
plt.scatter(denormalize(y_train_stack[:,0], y_teff_train[1], y_teff_train[2]), denormalize(test_predictions[:,0], y_teff_train[1], y_teff_train[2]), s= 4.0, c= 'r', label='LogTeff' )
plt.xlabel(r"True", fontsize=25)
plt.ylabel(r"Prediction", fontsize=25)
plt.axis('equal')
plt.axis('square')
# increase the x,y tick label size
plt.tick_params(labelsize= 25) 
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([0, 30000], [0, 30000], color='red')
plt.legend(fontsize=20)
plt.show()


#logg
plt.figure(figsize=(13,9))
plt.scatter(denormalize(y_train_stack[:,1],  y_logg_train[1], y_logg_train[2]), denormalize(test_predictions[:,1], y_logg_train[1], y_logg_train[2] ), s= 4.0, c= 'b', label='Log(g)' )
plt.xlabel(r"True", fontsize=25)
plt.ylabel(r"Prediction", fontsize=25)
plt.axis('equal')
plt.axis('square')
# increase the x,y tick label size
plt.tick_params(labelsize= 25) 
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([0, 5], [0, 5], color='blue')
plt.legend(fontsize=20)
plt.show()


#feh
plt.scatter(denormalize(y_train_stack[:,2], y_feh_train[1], y_feh_train[2] ), denormalize(test_predictions[:,2], y_feh_train[1], y_feh_train[2]), s= 4.0, c= 'y', label='[Fe/H]' )
plt.xlabel(r"True", fontsize=25)
plt.ylabel(r"Prediction", fontsize=25)
plt.axis('equal')
plt.axis('square')
# increase the x,y tick label size
plt.tick_params(labelsize= 25) 
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([0, 1], [0, 1], color='green')
plt.legend(fontsize=20)
plt.show()

# %%
#Making the histogram of denormalized training set 

plt.figure(figsize=(10,9))
data_teff=np.subtract(denormalize(y_train_stack[:,0], y_teff_train[1], y_teff_train[2]), denormalize(test_predictions[:,0], y_teff_train[1], y_teff_train[2])) 
data_logg=np.subtract(denormalize(y_train_stack[:,1],  y_logg_train[1], y_logg_train[2]), denormalize(test_predictions[:,1], y_logg_train[1], y_logg_train[2]))
data_feh=np.subtract(denormalize(y_train_stack[:,2], y_feh_train[1], y_feh_train[2] ), denormalize(test_predictions[:,2], y_feh_train[1], y_feh_train[2])) 

counts_teff, bins_teff = np.histogram(data_teff)
counts_logg, bins_logg = np.histogram(data_logg)
counts_feh, bins_feh = np.histogram(data_feh)

#histogram for LogTeff
plt.hist(bins_teff[:-1], bins_teff, weights=counts_teff, label= r'$\rm log(\rm T_{\rm eff})$')
plt.tick_params(labelsize=18) 
plt.xlabel(r'[Prediction-True]', fontsize=18)
plt.ylabel('Counts', fontsize=18)
plt.legend(fontsize=20)
plt.show()

#histogram for Log(g)
plt.figure(figsize=(10,9))
plt.hist(bins_logg[:-1], bins_logg, weights=counts_logg, label= 'log(g)', color='red')
plt.tick_params(labelsize=18) 
plt.xlabel(r'[Prediction-True]', fontsize=18)
plt.ylabel('Counts', fontsize=18)
plt.legend(fontsize=20)
plt.show()

#histogram for feh
plt.figure(figsize=(10,9))
plt.hist(bins_feh[:-1], bins_feh, weights=counts_feh, label= '[Fe/H]', color='magenta')
plt.tick_params(labelsize=18) 
plt.xlabel(r'[Prediction-True]', fontsize=18)
plt.ylabel('Counts', fontsize=18)
plt.legend(fontsize=20)
plt.show()




#print('standard deviation', len(z))
#print(len(z[teff<5000]))
#print(len(z))

# %% [markdown]
# # Training Data Set

# %%
# getting deviation in Teff bins
teffbin_edges=np.array([ 0, 5000, 10000, 15000, 20000, 25000, 30000])
nbin = len(teffbin_edges)

# pred vs. true
# unnormalised values
teff_pred = denormalize(test_predictions[:,0], y_teff_train[1], y_teff_train[2])
teff_true = denormalize(y_train_stack[:,0], y_teff_train[1], y_teff_train[2]) 
teff_diff = teff_pred-teff_true

# compute mean and std in Teff bins
teff_diff_mean = np.zeros(nbin) 
teff_diff_std = np.zeros(nbin)
teffbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(teff_true<teffbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(teff_true>teffbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((teff_true>teffbin_edges[i-1]) & (teff_true<teffbin_edges[i]))
        #if i=1, teff_true>(teffbin_edges[1-1=0]= 5000) & teff_true<teffbin_edges[1]= 10000, so 5000<teff<10000
        #if i=2, teff_true>(teffbin_edges[2-1=1]=10000) & teff_true<teffbin_edges[2]= 15000, so 10000<teff<15000
        #if i=3, teff_true> (teffbin_edges[3-1=2]= 15000) & teff_true<teffbin_edges[3]= 20000 so 15000<teff<20000
    teffbin_mean[i] = np.mean(teff_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    teff_diff_mean[i] = np.mean(teff_diff[indx]) #calculating the mean values of teff_diff from its index 
    teff_diff_std[i] = np.std(teff_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin teff_true=', teffbin_mean)
print('mean of teff_diff=', teff_diff_mean)
print('std of teff_diff=', teff_diff_std)
print('length of teff_diff=', len(teff_diff))

####################################################################################################################
print('==========================================================================================================')
# getting deviation in Teff bins
nbin = 6
loggbin_edges=np.array([-1.5, -0.5, 0., 0.5, 1.0, 1.5, 2.0])

# pred vs. true
# unnormalised values
logg_pred = denormalize(test_predictions[:,1], y_logg_train[1], y_logg_train[2])
logg_true = denormalize(y_train_stack[:,1], y_logg_train[1], y_logg_train[2]) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
logg_diff = logg_pred-logg_true

# compute mean and std in Teff bins
logg_diff_mean = np.zeros(nbin) 
logg_diff_std = np.zeros(nbin)
loggbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(logg_true<loggbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(logg_true>loggbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((logg_true>loggbin_edges[i-1]) & (logg_true<loggbin_edges[i]))

    loggbin_mean[i] = np.mean(logg_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    logg_diff_mean[i] = np.mean(logg_diff[indx]) #calculating the mean values of teff_diff from its index 
    logg_diff_std[i] = np.std(logg_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin logg_true=', loggbin_mean)
print('mean of logg_diff=', logg_diff_mean)
print('std of logg_diff=', logg_diff_std)
print('length of logg_diff=', len(logg_diff))

#################################################################################################################

print('==========================================================================================================')
nbin = 6
fehbin_edges=np.array([-1.5, -0.5, 0., 0.5, 1.0, 1.5, 2.0])

# pred vs. true
# unnormalised values
feh_pred = denormalize(test_predictions[:,2],  y_feh_train[1], y_feh_train[2])
feh_true = denormalize(y_train_stack[:,2],  y_feh_train[1], y_feh_train[2]) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
feh_diff = feh_pred-feh_true

# compute mean and std in Teff bins
feh_diff_mean = np.zeros(nbin) 
feh_diff_std = np.zeros(nbin)
fehbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(feh_true<fehbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(feh_true>fehbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((feh_true>fehbin_edges[i-1]) & (feh_true<fehbin_edges[i]))

    fehbin_mean[i] = np.mean(feh_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    feh_diff_mean[i] = np.mean(feh_diff[indx]) #calculating the mean values of teff_diff from its index 
    feh_diff_std[i] = np.std(feh_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin feh_true=', fehbin_mean)
print('mean of feh_diff=', feh_diff_mean)
print('std of feh_diff=', feh_diff_std)
print('length of feh_diff=', len(feh_diff))
# Out:
# mean of bin teff_true= [           nan  4111.80124224  7275.72559367 11788.77005348
#  17448.71794872 22400.         27972.97297297]
# mean of teff_diff= [          nan -195.87744444 -256.85823739 -203.30859897 -233.87696982
#   495.105      -642.95956503]
# std of teff_diff= [          nan  234.6422929   212.09092339  314.36314832  392.78465986
#   623.94623493 1021.62137675]
# length of teff_diff= 978
# ==========================================================================================================
# mean of bin logg_true= [       nan        nan        nan        nan        nan 3.58437856]
# mean of logg_diff= [       nan        nan        nan        nan        nan 0.06655433]
# std of logg_diff= [       nan        nan        nan        nan        nan 0.13074782]
# length of logg_diff= 978
# ==========================================================================================================
# mean of bin feh_true= [        nan -0.74999497         nan         nan  0.50000032         nan]
# mean of feh_diff= [        nan -0.01431082         nan         nan -0.03073581         nan]
# std of feh_diff= [       nan 0.0844609         nan        nan 0.09470682        nan]
# length of feh_diff= 978

# %%
# plot of teff
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(teff_true, teff_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(teffbin_mean,teff_diff_mean, yerr=teff_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
plt.xlabel(r"$\rm T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$\rm T_{\rm eff,pred}-\rm T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([0, 30000])
ylim=np.array([-3500, 1500])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# set x, y label. 
#plt.xlabel(r"$\rm logT_{\rm eff,true}$ (K)", fontsize=18)
#plt.ylabel(r"$\rm logT_{\rm eff,pred}-\rm logT_{\rm eff,true}$ (K)", fontsize=18)

# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %%
#Plot log 
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(logg_true, logg_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(loggbin_mean,logg_diff_mean, yerr=logg_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
#plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=18)
#plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([-2.8,1.8])
ylim=np.array([-0.5,0.5])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])


# set x, y label. 
plt.xlabel(r"$\rm log(g)_{\rm true}$", fontsize=18)
plt.ylabel(r"$\rm log(g)_{\rm pred}-\rm log(g)_{\rm true}$", fontsize=18)



# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %%
#Plot feh 
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(feh_true, feh_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(fehbin_mean,feh_diff_mean, yerr=feh_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
#plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=18)
#plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([-2.5,2.5])
ylim=np.array([-0.3,0.3])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])


# set x, y label. 
plt.xlabel(r"$\rm [Fe/H]_{\rm true}$", fontsize=18)
plt.ylabel(r"$\rm [Fe/H]_{\rm pred}-\rm [Fe/H]_{\rm true}$", fontsize=18)



# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %% [markdown]
# # Cross Validation Set

# %%
#Test set (x_cv)

print(np.shape(y_cv_stack[:,0]))
print(np.shape(y_cv_stack[:,1]))
print(np.shape(y_cv_stack[:,2]))



def denormalize (labels):
    mean_labels=np.mean(labels)
    std_labels=np.std(labels)
    return (((labels)*(std_labels)) + mean_labels)

plt.figure(figsize=(13,9))
test_predictions = model.predict([x_RVScv, x_BPcv, x_RPcv])
print('shape of test_predictions:',np.shape(test_predictions))
print('print 10 elements of test_predictions:', test_predictions[0:10])
plt.scatter(denormalize(y_cv_stack[:,0]), denormalize(test_predictions[:,0]), s= 4.0, c= 'r', label='LogTeff' )
plt.scatter(denormalize(y_cv_stack[:,1]), denormalize(test_predictions[:,1]), s= 4.0, c= 'b', label='Log(g)' )
plt.scatter(denormalize(y_cv_stack[:,2]), denormalize(test_predictions[:,2]), s= 4.0, c= 'y', label='[Fe/H]' )
plt.xlabel(r"True", fontsize=25)
plt.ylabel(r"Prediction", fontsize=25)
plt.axis('equal')
plt.axis('square')
# increase the x,y tick label size
plt.tick_params(labelsize= 25) 
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-2, 3], [-2, 3], color='green')
plt.legend(fontsize=20)
# Out:
# (240,)
# (240,)
# (240,)
# shape of test_predictions: (240, 3)
# print 10 elements of test_predictions: [[-1.1057812   0.41088572 -1.4603622 ]
#  [-1.0842968  -0.29974443 -1.2198856 ]
#  [-1.0189385  -0.31152436 -1.3500407 ]
#  [-1.0228441  -0.02247522 -1.258637  ]
#  [-1.0356679   0.4020311  -1.3161513 ]
#  [-1.0798621   0.85600704 -1.4739966 ]
#  [-1.0149057  -1.2859225  -1.3776956 ]
#  [-1.0204592  -1.3891165  -1.4858513 ]
#  [-0.9176756  -1.3467926  -1.3853017 ]
#  [-0.88107765  0.5478607  -1.3021855 ]]

# %%
# getting deviation in Teff bins
nbin = 6
teffbin_edges=np.array([-2, -1.5, -0.5, 1, 2.5, 3.5])


# pred vs. true
# unnormalised values
teff_pred = denormalize(test_predictions[:,0])
teff_true = denormalize(y_cv_stack[:,0]) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
teff_diff = teff_pred-teff_true

# compute mean and std in Teff bins
teff_diff_mean = np.zeros(nbin) 
teff_diff_std = np.zeros(nbin)
teffbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(teff_true<teffbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(teff_true>teffbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((teff_true>teffbin_edges[i-1]) & (teff_true<teffbin_edges[i]))
        #if i=1, teff_true>(teffbin_edges[1-1=0]= 5000) & teff_true<teffbin_edges[1]= 10000, so 5000<teff<10000
        #if i=2, teff_true>(teffbin_edges[2-1=1]=10000) & teff_true<teffbin_edges[2]= 15000, so 10000<teff<15000
        #if i=3, teff_true> (teffbin_edges[3-1=2]= 15000) & teff_true<teffbin_edges[3]= 20000 so 15000<teff<20000
    teffbin_mean[i] = np.mean(teff_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    teff_diff_mean[i] = np.mean(teff_diff[indx]) #calculating the mean values of teff_diff from its index 
    teff_diff_std[i] = np.std(teff_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin teff_true=', teffbin_mean)
print('mean of teff_diff=', teff_diff_mean)
print('std of teff_diff=', teff_diff_std)
print('len of teff_diff=', len(teff_diff))

####################################################################################################################
print('==========================================================================================================')
# getting deviation in Teff bins
nbin = 6
loggbin_edges=np.array([-1.5, -0.5, 0., 0.5, 1.0, 1.5, 2.0])

# pred vs. true
# unnormalised values
logg_pred = denormalize(test_predictions[:,1])
logg_true = denormalize(y_cv_stack[:,1]) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
logg_diff = logg_pred-logg_true

# compute mean and std in Teff bins
logg_diff_mean = np.zeros(nbin) 
logg_diff_std = np.zeros(nbin)
loggbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(logg_true<loggbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(logg_true>loggbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((logg_true>loggbin_edges[i-1]) & (logg_true<loggbin_edges[i]))

    loggbin_mean[i] = np.mean(logg_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    logg_diff_mean[i] = np.mean(logg_diff[indx]) #calculating the mean values of teff_diff from its index 
    logg_diff_std[i] = np.std(logg_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin logg_true=', loggbin_mean)
print('mean of logg_diff=', logg_diff_mean)
print('std of logg_diff=', logg_diff_std)
print('length of logg_diff=', len(logg_diff))

#################################################################################################################

print('==========================================================================================================')
nbin = 6
fehbin_edges=np.array([-1.5, -0.5, 0., 0.5, 1.0, 1.5, 2.0])

# pred vs. true
# unnormalised values
feh_pred = denormalize(test_predictions[:,2])
feh_true = denormalize(y_cv_stack[:,2]) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
feh_diff = feh_pred-feh_true

# compute mean and std in Teff bins
feh_diff_mean = np.zeros(nbin) 
feh_diff_std = np.zeros(nbin)
fehbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(feh_true<fehbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(feh_true>fehbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((feh_true>fehbin_edges[i-1]) & (feh_true<fehbin_edges[i]))

    fehbin_mean[i] = np.mean(feh_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    feh_diff_mean[i] = np.mean(feh_diff[indx]) #calculating the mean values of teff_diff from its index 
    feh_diff_std[i] = np.std(feh_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin feh_true=', fehbin_mean)
print('mean of feh_diff=', feh_diff_mean)
print('std of feh_diff=', feh_diff_std)
print('length of feh_diff=', len(feh_diff))
# Out:
# mean of bin teff_true= [        nan         nan -0.83910625  0.07811242  1.58210853  2.88183583]
# mean of teff_diff= [        nan         nan  0.16693033  0.16848693  0.25817335 -0.00230981]
# std of teff_diff= [       nan        nan 0.02483909 0.05183712 0.11787325 0.24812883]
# len of teff_diff= 240
# ==========================================================================================================
# mean of bin logg_true= [-1.99271009 -0.96352887 -0.228976    0.14233643  0.66796054  1.25627375]
# mean of logg_diff= [-0.08108264 -0.06969587 -0.06886777 -0.03001234 -0.02709573 -0.18861542]
# std of logg_diff= [0.09926668 0.10161952 0.06249774 0.0898252  0.12700576 0.14159505]
# length of logg_diff= 240
# ==========================================================================================================
# mean of bin feh_true= [        nan -1.38373027         nan  0.31757654  0.99810138         nan]
# mean of feh_diff= [       nan 0.12243459        nan 0.09341534 0.08225004        nan]
# std of feh_diff= [       nan 0.14382741        nan 0.17298483 0.07345282        nan]
# length of feh_diff= 240
# teff_pred [-1.02245450e+00 -1.00093770e+00 -9.35480952e-01 -9.39392328e-01
#  -9.52235460e-01 -9.96496320e-01 -9.31442022e-01 -9.37003851e-01
#  -8.34065318e-01 -7.97412157e-01 -6.84860528e-01 -7.08378017e-01
#  -6.37260973e-01 -6.23869121e-01 -6.16282403e-01 -5.88265598e-01
#  -5.43616235e-01 -5.35594821e-01 -5.33658385e-01 -5.33711135e-01
#  -5.52778244e-01 -4.84272480e-01 -3.90221953e-01 -3.79941434e-01
#  -3.65331799e-01 -3.58692557e-01 -3.06935579e-01 -3.30551237e-01
#  -2.55200177e-01 -2.88494110e-01 -2.45566458e-01 -1.83870167e-01
#  -2.01934993e-01 -1.42499119e-01 -7.49288872e-02 -9.88005176e-02
#  -1.08666189e-01 -2.76431218e-02  2.51063704e-03  1.53762549e-02
#   1.21184438e-02  6.97342604e-02  3.98660302e-02  1.07418165e-01
#   1.06331512e-01  1.43811241e-01  2.05044597e-01  1.26944005e-01
#   2.22236842e-01  2.71806538e-01  1.77281767e-01  2.35483646e-01
#   2.50434369e-01  3.50795597e-01  4.58189487e-01  4.71300960e-01
#   5.28288245e-01  6.11357868e-01  7.49051452e-01  8.85609031e-01
#   7.18906581e-01  9.28493619e-01  9.35984194e-01  8.51333916e-01
#   1.03984630e+00  1.09018779e+00  9.28465009e-01  1.09578443e+00
#   1.04003859e+00  1.14959300e+00  1.22403502e+00  1.66326416e+00
#   1.79248118e+00  2.49289012e+00  2.53118157e+00  2.56234789e+00
#   2.84403539e+00  2.80735254e+00 -1.00500751e+00 -1.02420926e+00
#  -9.33339238e-01 -8.98635030e-01 -8.64041388e-01 -8.88254404e-01
#  -8.52968514e-01 -8.38796198e-01 -7.59728014e-01 -7.78510809e-01
#  -7.57893443e-01 -7.38262951e-01 -6.98368490e-01 -7.08955646e-01
#  -7.35496998e-01 -6.55660212e-01 -6.84789896e-01 -6.84205353e-01
#  -6.36027157e-01 -5.58207154e-01 -5.46131492e-01 -4.88112867e-01
#  -4.77591097e-01 -4.31091011e-01 -3.80858332e-01 -4.15280104e-01
#  -4.38129127e-01 -4.07412112e-01 -3.73376638e-01 -3.73827100e-01
#  -3.21347624e-01 -3.31572592e-01 -2.82952368e-01 -3.31137687e-01
#  -2.33004630e-01 -2.46483177e-01 -2.38822073e-01 -2.49551535e-01
#  -1.66419387e-01 -2.07802862e-01 -2.38407344e-01 -5.69692329e-02
#  -1.14139266e-01 -1.23816676e-01 -1.35022625e-02  2.23704159e-01
#   1.53393999e-01  1.61552370e-01  2.50361174e-01  2.75058746e-01
#   2.81198591e-01  3.38701069e-01  3.19861561e-01  3.27846169e-01
#   4.74280387e-01  5.44650972e-01  5.56790888e-01  8.13548446e-01
#   8.91205132e-01  8.96046102e-01  1.24512982e+00  1.22053587e+00
#   1.36699998e+00  1.34982491e+00  1.42481816e+00  1.55227244e+00
#   1.65556884e+00  1.62469554e+00  2.02741814e+00  2.34516692e+00
#   2.30360889e+00  2.55953884e+00  2.63933158e+00  3.11117172e+00
#   2.77691817e+00  2.76415920e+00  2.61513066e+00  2.98935032e+00
#   2.97939587e+00 -1.04180348e+00 -1.04170144e+00 -1.07893467e+00
#  -9.98725057e-01 -9.77008820e-01 -9.53734279e-01 -8.65656734e-01
#  -8.34618151e-01 -8.70047927e-01 -7.71828711e-01 -7.48293579e-01
#  -7.93026507e-01 -7.54859269e-01 -7.09502220e-01 -6.75489902e-01
#  -6.78713799e-01 -6.55538917e-01 -6.84838295e-01 -6.94876313e-01
#  -6.43502116e-01 -6.42313004e-01 -6.35554850e-01 -6.30204439e-01
#  -5.51347792e-01 -5.25960505e-01 -5.30472934e-01 -4.62833226e-01
#  -4.37953472e-01 -4.28857505e-01 -4.39938545e-01 -3.59598875e-01
#  -3.81297439e-01 -4.14660513e-01 -3.56747687e-01 -2.80038416e-01
#  -2.78175473e-01 -2.91399986e-01 -3.22053909e-01 -2.72020996e-01
#  -2.18501866e-01 -2.46418178e-01 -1.88585341e-01 -1.80854678e-01
#  -1.30824268e-01 -1.52092099e-01 -9.93745252e-02 -1.21449403e-01
#  -3.97350043e-02 -5.91898933e-02 -1.36044323e-02 -2.00086683e-02
#   6.52895421e-02  9.60231945e-02  1.49614006e-01  1.13994837e-01
#   1.26587346e-01  1.92072198e-01  2.44310230e-01  3.47349256e-01
#   3.09580475e-01  3.48059088e-01  3.60998869e-01  5.06347120e-01
#   5.26255667e-01  6.57155395e-01  5.16252279e-01  7.35991538e-01
#   7.82023907e-01  8.36236119e-01  9.13084030e-01  9.07348394e-01
#   1.01911676e+00  1.11792493e+00  1.10358369e+00  1.36321473e+00
#   1.30802429e+00  1.28518784e+00  1.46064639e+00  1.62250662e+00
#   2.29541874e+00  2.30464458e+00  2.67075539e+00  3.26841474e+00]

# %%
# plot of teff
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(teff_true, teff_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(teffbin_mean,teff_diff_mean, yerr=teff_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
#plt.xlabel(r"$\rm T_{\rm eff,true}$ (K)", fontsize=18)
#plt.ylabel(r"$\rm T_{\rm eff,pred}-\rm T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([-2.2,3.6])
ylim=np.array([-0.15,0.3])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# set x, y label. 
plt.xlabel(r"$\rm logT_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$\rm logT_{\rm eff,pred}-\rm logT_{\rm eff,true}$ (K)", fontsize=18)

# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %%
#Plot log 
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(logg_true, logg_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(loggbin_mean,logg_diff_mean, yerr=logg_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
#plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=18)
#plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([-2.8,1.8])
ylim=np.array([-0.5,0.5])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])


# set x, y label. 
plt.xlabel(r"$\rm log(g)_{\rm true}$", fontsize=18)
plt.ylabel(r"$\rm log(g)_{\rm pred}-\rm log(g)_{\rm true}$", fontsize=18)



# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %%
#Plot feh 
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(feh_true, feh_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(fehbin_mean,feh_diff_mean, yerr=feh_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 


# set x, y lim plot range
xlim=np.array([-2.5,2.5])
ylim=np.array([-0.3,0.4])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])


# set x, y label. 
plt.xlabel(r"$\rm [Fe/H]_{\rm true}$", fontsize=18)
plt.ylabel(r"$\rm [Fe/H]_{\rm pred}-\rm [Fe/H]_{\rm true}$", fontsize=18)


# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %%
#Making the histogram of the CV set 

plt.figure(figsize=(13,9))
z=np.subtract(denormalize(y_cv), denormalize(cv_predictions)) #difference between the true and predicted values
counts, bins = np.histogram(z)
plt.hist(bins[:-1], bins, weights=counts)


# increase the x,y tick label size
plt.tick_params(labelsize=18) 

plt.title(r'Histogram of $T_{eff}$', fontsize=18)
plt.xlabel(r"$\rm logT_{\rm eff,pred}-\rm logT_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel('Counts', fontsize=18)
#z[teff<5000].std()
print('standard deviation', len(z))
#print(len(z[teff<5000]))
#print(len(z))
# Out:
# standard deviation 83

# %% [raw]
# # Another model
# From TheCNNon, https://github.com/adrn/TheCNNon/blob/master/notebooks/ThisIsCNNON.ipynb

# %%
# Input spectra
input_spec = Input(shape=(num_fluxes,), name='starnet_input_x')

# Reshape spectra for CNN layers
cur_in = Reshape((num_fluxes, 1))(input_spec)

# CNN layers
# First
cur_in = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=128, kernel_size=32)(cur_in) #first CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=32)(cur_in)
# Second CNN layer
cur_in = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=128, kernel_size=16)(cur_in) #2nd CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=16)(cur_in)
# Third CNN layer
cur_in = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=128, kernel_size=8)(cur_in) #2nd CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=8)(cur_in)

# Flatten the current input for the fully-connected layers
cur_in = Flatten()(cur_in)

# Fully-connected layers
cur_in = Dense(units=258, kernel_initializer=initializer, 
               activation=activation)(cur_in)
cur_in = Dense(units=128, kernel_initializer=initializer, 
               activation=activation)(cur_in)

# Output nodes
output_label = Dense(units=num_labels, kernel_regularizer=keras.regularizers.l2(0.01), activation="linear", 
                     input_dim=num_hidden[1])(cur_in)

model = Model(input_spec, output_label)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1658   try:
# -> 1659     c_op = c_api.TF_FinishOperation(op_desc)
#    1660   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Negative dimension size caused by subtracting 8 from 1 for 'max_pooling1d_12/MaxPool' (op: 'MaxPool') with input shapes: [?,1,1,128].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-07ed572f0f80> in <module>
#      20                 padding="same", filters=128, kernel_size=8)(cur_in) #2nd CNN layer
#      21 # Max pooling layer
# ---> 22 cur_in = MaxPooling1D(pool_size=8)(cur_in)
#      23
#      24 # Flatten the current input for the fully-connected layers
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     455             # Actually call the layer,
#     456             # collecting output(s), mask(s), and shape(s).
# --> 457             output = self.call(inputs, **kwargs)
#     458             output_mask = self.compute_mask(inputs, previous_mask)
#     459
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/pooling.py in call(self, inputs)
#      55                                         strides=self.strides + (1,),
#      56                                         padding=self.padding,
# ---> 57                                         data_format=self.data_format)
#      58         return K.squeeze(output, dummy_axis)  # remove dummy last dimension
#      59
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/pooling.py in _pooling_function(self, inputs, pool_size, strides, padding, data_format)
#     111                           padding, data_format):
#     112         output = K.pool2d(inputs, pool_size, strides,
# --> 113                           padding, data_format, pool_mode='max')
#     114         return output
#     115
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in pool2d(x, pool_size, strides, padding, data_format, pool_mode)
#    3976         x = tf.nn.max_pool(x, pool_size, strides,
#    3977                            padding=padding,
# -> 3978                            data_format=tf_data_format)
#    3979     elif pool_mode == 'avg':
#    3980         x = tf.nn.avg_pool(x, pool_size, strides,
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in max_pool(value, ksize, strides, padding, data_format, name)
#    2746         padding=padding,
#    2747         data_format=data_format,
# -> 2748         name=name)
#    2749
#    2750
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in max_pool(input, ksize, strides, padding, data_format, name)
#    5135   _, _, _op = _op_def_lib._apply_op_helper(
#    5136         "MaxPool", input=input, ksize=ksize, strides=strides, padding=padding,
# -> 5137                    data_format=data_format, name=name)
#    5138   _result = _op.outputs[:]
#    5139   _inputs_flat = _op.inputs
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     787                          input_types=input_types, attrs=attr_protos,
# --> 788                          op_def=op_def)
#     789       return output_structure, op_def.is_stateful, op
#     790
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(***failed resolving arguments***)
#    3298           input_types=input_types,
#    3299           original_op=self._default_original_op,
# -> 3300           op_def=op_def)
#    3301       self._create_op_helper(ret, compute_device=compute_device)
#    3302     return ret
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1821           op_def, inputs, node_def.attr)
#    1822       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1823                                 control_input_ops)
#    1824
#    1825     # Initialize self._outputs.
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1660   except errors.InvalidArgumentError as e:
#    1661     # Convert to ValueError for backwards compatibility.
# -> 1662     raise ValueError(str(e))
#    1663
#    1664   return c_op
#
# ValueError: Negative dimension size caused by subtracting 8 from 1 for 'max_pooling1d_12/MaxPool' (op: 'MaxPool') with input shapes: [?,1,1,128].

# %%
optimizer = Adam(lr=0.0005)

# %%
# loss function to minimize
loss_function = 'mean_squared_error'
optimizer = 'adadelta'
# compute mean absolute deviation
metrics = ['mae', 'mse']
#metrics = ['mae']
model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# starnet_input_x (InputLayer) (None, 6758)              0
# _________________________________________________________________
# reshape_10 (Reshape)         (None, 6758, 1)           0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 6758, 128)         4224
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 211, 128)          0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 211, 128)          262272
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 13, 128)           0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 13, 128)           131200
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 1, 128)            0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 258)               33282
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               33152
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 464,259
# Trainable params: 464,259
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, 
          epochs=max_epochs, validation_split = 0.2, verbose=1, shuffle='batch')
# Out:
# Train on 875 samples, validate on 219 samples
# Epoch 1/200
# 875/875 [==============================] - 13s 15ms/step - loss: 5.2174 - mean_absolute_error: 1.4147 - mean_squared_error: 5.1988 - val_loss: 1.5482 - val_mean_absolute_error: 0.9417 - val_mean_squared_error: 1.5305
# Epoch 2/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3955 - mean_absolute_error: 0.5094 - mean_squared_error: 0.3783 - val_loss: 1.8217 - val_mean_absolute_error: 1.0313 - val_mean_squared_error: 1.8050
# Epoch 3/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3606 - mean_absolute_error: 0.4579 - mean_squared_error: 0.3443 - val_loss: 1.9750 - val_mean_absolute_error: 1.0742 - val_mean_squared_error: 1.9589
# Epoch 4/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3806 - mean_absolute_error: 0.4960 - mean_squared_error: 0.3648 - val_loss: 2.0388 - val_mean_absolute_error: 1.0894 - val_mean_squared_error: 2.0232
# Epoch 5/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.4077 - mean_absolute_error: 0.4772 - mean_squared_error: 0.3923 - val_loss: 3.4660 - val_mean_absolute_error: 1.5366 - val_mean_squared_error: 3.4508
# Epoch 6/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.3888 - mean_absolute_error: 0.5023 - mean_squared_error: 0.3738 - val_loss: 3.0916 - val_mean_absolute_error: 1.4193 - val_mean_squared_error: 3.0766
# Epoch 7/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3001 - mean_absolute_error: 0.4360 - mean_squared_error: 0.2852 - val_loss: 3.7524 - val_mean_absolute_error: 1.6397 - val_mean_squared_error: 3.7377
# Epoch 8/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.2883 - mean_absolute_error: 0.4420 - mean_squared_error: 0.2736 - val_loss: 3.6873 - val_mean_absolute_error: 1.6205 - val_mean_squared_error: 3.6728
# Epoch 9/200
# 875/875 [==============================] - 22s 25ms/step - loss: 0.2976 - mean_absolute_error: 0.4493 - mean_squared_error: 0.2833 - val_loss: 3.8704 - val_mean_absolute_error: 1.6722 - val_mean_squared_error: 3.8562
# Epoch 10/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.2398 - mean_absolute_error: 0.3987 - mean_squared_error: 0.2256 - val_loss: 3.9370 - val_mean_absolute_error: 1.6926 - val_mean_squared_error: 3.9230
# Epoch 11/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.2136 - mean_absolute_error: 0.3585 - mean_squared_error: 0.1997 - val_loss: 3.5978 - val_mean_absolute_error: 1.5898 - val_mean_squared_error: 3.5840
# Epoch 12/200
# 875/875 [==============================] - 27s 31ms/step - loss: 0.2410 - mean_absolute_error: 0.3820 - mean_squared_error: 0.2274 - val_loss: 4.0983 - val_mean_absolute_error: 1.7393 - val_mean_squared_error: 4.0850
# Epoch 13/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.1661 - mean_absolute_error: 0.3015 - mean_squared_error: 0.1530 - val_loss: 2.8094 - val_mean_absolute_error: 1.3314 - val_mean_squared_error: 2.7965
# Epoch 14/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1630 - mean_absolute_error: 0.2858 - mean_squared_error: 0.1503 - val_loss: 3.9325 - val_mean_absolute_error: 1.6919 - val_mean_squared_error: 3.9201
# Epoch 15/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.1432 - mean_absolute_error: 0.2689 - mean_squared_error: 0.1311 - val_loss: 3.6180 - val_mean_absolute_error: 1.5971 - val_mean_squared_error: 3.6062
# Epoch 16/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1220 - mean_absolute_error: 0.2405 - mean_squared_error: 0.1106 - val_loss: 3.5919 - val_mean_absolute_error: 1.5885 - val_mean_squared_error: 3.5809
# Epoch 17/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1122 - mean_absolute_error: 0.2418 - mean_squared_error: 0.1015 - val_loss: 3.4441 - val_mean_absolute_error: 1.5411 - val_mean_squared_error: 3.4337
# Epoch 18/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1125 - mean_absolute_error: 0.2457 - mean_squared_error: 0.1025 - val_loss: 3.6328 - val_mean_absolute_error: 1.6010 - val_mean_squared_error: 3.6232
# Epoch 19/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1287 - mean_absolute_error: 0.2610 - mean_squared_error: 0.1194 - val_loss: 3.5788 - val_mean_absolute_error: 1.5843 - val_mean_squared_error: 3.5699
# Epoch 20/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0884 - mean_absolute_error: 0.2150 - mean_squared_error: 0.0797 - val_loss: 2.2024 - val_mean_absolute_error: 1.1457 - val_mean_squared_error: 2.1939
# Epoch 21/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1126 - mean_absolute_error: 0.2483 - mean_squared_error: 0.1043 - val_loss: 3.1658 - val_mean_absolute_error: 1.4498 - val_mean_squared_error: 3.1579
# Epoch 22/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0973 - mean_absolute_error: 0.2238 - mean_squared_error: 0.0895 - val_loss: 3.2924 - val_mean_absolute_error: 1.4950 - val_mean_squared_error: 3.2848
# Epoch 23/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0928 - mean_absolute_error: 0.2209 - mean_squared_error: 0.0853 - val_loss: 2.5891 - val_mean_absolute_error: 1.2693 - val_mean_squared_error: 2.5818
# Epoch 24/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1052 - mean_absolute_error: 0.2388 - mean_squared_error: 0.0981 - val_loss: 2.9058 - val_mean_absolute_error: 1.3614 - val_mean_squared_error: 2.8988
# Epoch 25/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1014 - mean_absolute_error: 0.2394 - mean_squared_error: 0.0945 - val_loss: 2.1955 - val_mean_absolute_error: 1.1433 - val_mean_squared_error: 2.1887
# Epoch 26/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1404 - mean_absolute_error: 0.2719 - mean_squared_error: 0.1338 - val_loss: 3.4146 - val_mean_absolute_error: 1.5348 - val_mean_squared_error: 3.4081
# Epoch 27/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0821 - mean_absolute_error: 0.2071 - mean_squared_error: 0.0757 - val_loss: 2.4974 - val_mean_absolute_error: 1.2405 - val_mean_squared_error: 2.4909
# Epoch 28/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0923 - mean_absolute_error: 0.2196 - mean_squared_error: 0.0859 - val_loss: 2.6382 - val_mean_absolute_error: 1.2849 - val_mean_squared_error: 2.6318
# Epoch 29/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0897 - mean_absolute_error: 0.2259 - mean_squared_error: 0.0834 - val_loss: 2.8831 - val_mean_absolute_error: 1.3586 - val_mean_squared_error: 2.8769
# Epoch 30/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0744 - mean_absolute_error: 0.1986 - mean_squared_error: 0.0682 - val_loss: 1.7850 - val_mean_absolute_error: 1.0208 - val_mean_squared_error: 1.7788
# Epoch 31/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1151 - mean_absolute_error: 0.2334 - mean_squared_error: 0.1090 - val_loss: 2.8941 - val_mean_absolute_error: 1.3617 - val_mean_squared_error: 2.8881
# Epoch 32/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0832 - mean_absolute_error: 0.2128 - mean_squared_error: 0.0773 - val_loss: 2.6767 - val_mean_absolute_error: 1.2974 - val_mean_squared_error: 2.6707
# Epoch 33/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0797 - mean_absolute_error: 0.2058 - mean_squared_error: 0.0738 - val_loss: 3.1776 - val_mean_absolute_error: 1.4555 - val_mean_squared_error: 3.1718
# Epoch 34/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0814 - mean_absolute_error: 0.2059 - mean_squared_error: 0.0757 - val_loss: 2.6626 - val_mean_absolute_error: 1.2925 - val_mean_squared_error: 2.6568
# Epoch 35/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0876 - mean_absolute_error: 0.2151 - mean_squared_error: 0.0819 - val_loss: 2.5699 - val_mean_absolute_error: 1.2623 - val_mean_squared_error: 2.5643
# Epoch 36/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1182 - mean_absolute_error: 0.2553 - mean_squared_error: 0.1126 - val_loss: 2.7674 - val_mean_absolute_error: 1.3285 - val_mean_squared_error: 2.7619
# Epoch 37/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0652 - mean_absolute_error: 0.1795 - mean_squared_error: 0.0597 - val_loss: 3.1619 - val_mean_absolute_error: 1.4543 - val_mean_squared_error: 3.1564
# Epoch 38/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0757 - mean_absolute_error: 0.2025 - mean_squared_error: 0.0703 - val_loss: 2.8025 - val_mean_absolute_error: 1.3408 - val_mean_squared_error: 2.7970
# Epoch 39/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0759 - mean_absolute_error: 0.2020 - mean_squared_error: 0.0705 - val_loss: 2.1523 - val_mean_absolute_error: 1.1254 - val_mean_squared_error: 2.1470
# Epoch 40/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0722 - mean_absolute_error: 0.1941 - mean_squared_error: 0.0669 - val_loss: 2.2233 - val_mean_absolute_error: 1.1493 - val_mean_squared_error: 2.2180
# Epoch 41/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0718 - mean_absolute_error: 0.1899 - mean_squared_error: 0.0666 - val_loss: 2.5742 - val_mean_absolute_error: 1.2647 - val_mean_squared_error: 2.5689
# Epoch 42/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0649 - mean_absolute_error: 0.1807 - mean_squared_error: 0.0597 - val_loss: 2.5939 - val_mean_absolute_error: 1.2684 - val_mean_squared_error: 2.5887
# Epoch 43/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0669 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0618 - val_loss: 2.8934 - val_mean_absolute_error: 1.3602 - val_mean_squared_error: 2.8883
# Epoch 44/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0709 - mean_absolute_error: 0.1983 - mean_squared_error: 0.0659 - val_loss: 2.5505 - val_mean_absolute_error: 1.2618 - val_mean_squared_error: 2.5456
# Epoch 45/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0694 - mean_absolute_error: 0.1891 - mean_squared_error: 0.0645 - val_loss: 2.9804 - val_mean_absolute_error: 1.3956 - val_mean_squared_error: 2.9755
# Epoch 46/200
# 875/875 [==============================] - 24s 28ms/step - loss: 0.0719 - mean_absolute_error: 0.1961 - mean_squared_error: 0.0670 - val_loss: 2.4074 - val_mean_absolute_error: 1.2118 - val_mean_squared_error: 2.4026
# Epoch 47/200
# 875/875 [==============================] - 24s 28ms/step - loss: 0.0618 - mean_absolute_error: 0.1743 - mean_squared_error: 0.0571 - val_loss: 2.2830 - val_mean_absolute_error: 1.1690 - val_mean_squared_error: 2.2782
# Epoch 48/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0676 - mean_absolute_error: 0.1821 - mean_squared_error: 0.0629 - val_loss: 2.6052 - val_mean_absolute_error: 1.2808 - val_mean_squared_error: 2.6005
# Epoch 49/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0630 - mean_absolute_error: 0.1787 - mean_squared_error: 0.0583 - val_loss: 2.4626 - val_mean_absolute_error: 1.2316 - val_mean_squared_error: 2.4579
# Epoch 50/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0601 - mean_absolute_error: 0.1661 - mean_squared_error: 0.0555 - val_loss: 2.7647 - val_mean_absolute_error: 1.3206 - val_mean_squared_error: 2.7601
# Epoch 51/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0643 - mean_absolute_error: 0.1779 - mean_squared_error: 0.0597 - val_loss: 2.5744 - val_mean_absolute_error: 1.2720 - val_mean_squared_error: 2.5698
# Epoch 52/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0919 - mean_absolute_error: 0.2229 - mean_squared_error: 0.0873 - val_loss: 2.5535 - val_mean_absolute_error: 1.2609 - val_mean_squared_error: 2.5490
# Epoch 53/200
# 875/875 [==============================] - 436s 498ms/step - loss: 0.0650 - mean_absolute_error: 0.1887 - mean_squared_error: 0.0605 - val_loss: 2.1651 - val_mean_absolute_error: 1.1289 - val_mean_squared_error: 2.1606
# Epoch 54/200
# 875/875 [==============================] - 116s 133ms/step - loss: 0.1022 - mean_absolute_error: 0.2107 - mean_squared_error: 0.0977 - val_loss: 2.2922 - val_mean_absolute_error: 1.1691 - val_mean_squared_error: 2.2878
# Epoch 55/200
# 875/875 [==============================] - 1980s 2s/step - loss: 0.0704 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0661 - val_loss: 2.6339 - val_mean_absolute_error: 1.2914 - val_mean_squared_error: 2.6296
# Epoch 56/200
# 875/875 [==============================] - 16s 18ms/step - loss: 0.0528 - mean_absolute_error: 0.1586 - mean_squared_error: 0.0485 - val_loss: 1.9749 - val_mean_absolute_error: 1.0711 - val_mean_squared_error: 1.9706
# Epoch 57/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0525 - mean_absolute_error: 0.1568 - mean_squared_error: 0.0482 - val_loss: 2.0850 - val_mean_absolute_error: 1.1014 - val_mean_squared_error: 2.0807
# Epoch 58/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0607 - mean_absolute_error: 0.1662 - mean_squared_error: 0.0565 - val_loss: 2.4774 - val_mean_absolute_error: 1.2292 - val_mean_squared_error: 2.4732
# Epoch 59/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0578 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0536 - val_loss: 2.1773 - val_mean_absolute_error: 1.1350 - val_mean_squared_error: 2.1730
# Epoch 60/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0521 - mean_absolute_error: 0.1542 - mean_squared_error: 0.0479 - val_loss: 2.2251 - val_mean_absolute_error: 1.1478 - val_mean_squared_error: 2.2209
# Epoch 61/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0482 - mean_absolute_error: 0.1538 - mean_squared_error: 0.0441 - val_loss: 2.4825 - val_mean_absolute_error: 1.2420 - val_mean_squared_error: 2.4783
# Epoch 62/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0498 - mean_absolute_error: 0.1520 - mean_squared_error: 0.0457 - val_loss: 2.2666 - val_mean_absolute_error: 1.1597 - val_mean_squared_error: 2.2624
# Epoch 63/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0545 - mean_absolute_error: 0.1639 - mean_squared_error: 0.0504 - val_loss: 2.0965 - val_mean_absolute_error: 1.1046 - val_mean_squared_error: 2.0924
# Epoch 64/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0453 - mean_absolute_error: 0.1479 - mean_squared_error: 0.0412 - val_loss: 2.0962 - val_mean_absolute_error: 1.1012 - val_mean_squared_error: 2.0921
# Epoch 65/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0569 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0528 - val_loss: 2.6018 - val_mean_absolute_error: 1.2822 - val_mean_squared_error: 2.5977
# Epoch 66/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0521 - mean_absolute_error: 0.1593 - mean_squared_error: 0.0481 - val_loss: 2.1614 - val_mean_absolute_error: 1.1230 - val_mean_squared_error: 2.1573
# Epoch 67/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0468 - mean_absolute_error: 0.1503 - mean_squared_error: 0.0427 - val_loss: 1.9528 - val_mean_absolute_error: 1.0605 - val_mean_squared_error: 1.9488
# Epoch 68/200
# 875/875 [==============================] - 14s 15ms/step - loss: 0.0550 - mean_absolute_error: 0.1625 - mean_squared_error: 0.0510 - val_loss: 1.6402 - val_mean_absolute_error: 0.9684 - val_mean_squared_error: 1.6361
# Epoch 69/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0675 - mean_absolute_error: 0.1783 - mean_squared_error: 0.0636 - val_loss: 1.6937 - val_mean_absolute_error: 0.9808 - val_mean_squared_error: 1.6898
# Epoch 70/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0504 - mean_absolute_error: 0.1465 - mean_squared_error: 0.0465 - val_loss: 1.8599 - val_mean_absolute_error: 1.0318 - val_mean_squared_error: 1.8560
# Epoch 71/200
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0540 - mean_absolute_error: 0.1642 - mean_squared_error: 0.0501 - val_loss: 1.9639 - val_mean_absolute_error: 1.0634 - val_mean_squared_error: 1.9600
# Epoch 72/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0399 - mean_absolute_error: 0.1346 - mean_squared_error: 0.0361 - val_loss: 1.6221 - val_mean_absolute_error: 0.9613 - val_mean_squared_error: 1.6183
# Epoch 73/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0413 - mean_absolute_error: 0.1380 - mean_squared_error: 0.0375 - val_loss: 1.5695 - val_mean_absolute_error: 0.9410 - val_mean_squared_error: 1.5657
# Epoch 74/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0508 - mean_absolute_error: 0.1554 - mean_squared_error: 0.0470 - val_loss: 1.6579 - val_mean_absolute_error: 0.9698 - val_mean_squared_error: 1.6541
# Epoch 75/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0419 - mean_absolute_error: 0.1415 - mean_squared_error: 0.0381 - val_loss: 1.9499 - val_mean_absolute_error: 1.0596 - val_mean_squared_error: 1.9461
# Epoch 76/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0503 - mean_absolute_error: 0.1572 - mean_squared_error: 0.0465 - val_loss: 1.8577 - val_mean_absolute_error: 1.0327 - val_mean_squared_error: 1.8540
# Epoch 77/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0476 - mean_absolute_error: 0.1527 - mean_squared_error: 0.0439 - val_loss: 1.7745 - val_mean_absolute_error: 1.0009 - val_mean_squared_error: 1.7708
# Epoch 78/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0451 - mean_absolute_error: 0.1489 - mean_squared_error: 0.0415 - val_loss: 2.0050 - val_mean_absolute_error: 1.0651 - val_mean_squared_error: 2.0014
# Epoch 79/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0440 - mean_absolute_error: 0.1435 - mean_squared_error: 0.0404 - val_loss: 2.0267 - val_mean_absolute_error: 1.0795 - val_mean_squared_error: 2.0231
# Epoch 80/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0364 - mean_absolute_error: 0.1310 - mean_squared_error: 0.0327 - val_loss: 1.8544 - val_mean_absolute_error: 1.0227 - val_mean_squared_error: 1.8507
# Epoch 81/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0374 - mean_absolute_error: 0.1308 - mean_squared_error: 0.0337 - val_loss: 2.1050 - val_mean_absolute_error: 1.0957 - val_mean_squared_error: 2.1014
# Epoch 82/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0405 - mean_absolute_error: 0.1369 - mean_squared_error: 0.0369 - val_loss: 2.0692 - val_mean_absolute_error: 1.0950 - val_mean_squared_error: 2.0656
# Epoch 83/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0377 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0341 - val_loss: 2.1537 - val_mean_absolute_error: 1.1251 - val_mean_squared_error: 2.1501
# Epoch 84/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0437 - mean_absolute_error: 0.1535 - mean_squared_error: 0.0401 - val_loss: 1.9010 - val_mean_absolute_error: 1.0358 - val_mean_squared_error: 1.8974
# Epoch 85/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0372 - mean_absolute_error: 0.1277 - mean_squared_error: 0.0336 - val_loss: 2.2669 - val_mean_absolute_error: 1.1700 - val_mean_squared_error: 2.2633
# Epoch 86/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0398 - mean_absolute_error: 0.1395 - mean_squared_error: 0.0363 - val_loss: 2.4500 - val_mean_absolute_error: 1.2285 - val_mean_squared_error: 2.4464
# Epoch 87/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0461 - mean_absolute_error: 0.1518 - mean_squared_error: 0.0426 - val_loss: 1.7367 - val_mean_absolute_error: 0.9874 - val_mean_squared_error: 1.7331
# Epoch 88/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0332 - mean_absolute_error: 0.1268 - mean_squared_error: 0.0296 - val_loss: 1.9588 - val_mean_absolute_error: 1.0607 - val_mean_squared_error: 1.9552
# Epoch 89/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0321 - mean_absolute_error: 0.1208 - mean_squared_error: 0.0286 - val_loss: 1.7206 - val_mean_absolute_error: 0.9780 - val_mean_squared_error: 1.7171
# Epoch 90/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0419 - mean_absolute_error: 0.1408 - mean_squared_error: 0.0384 - val_loss: 1.8123 - val_mean_absolute_error: 1.0004 - val_mean_squared_error: 1.8087
# Epoch 91/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0369 - mean_absolute_error: 0.1327 - mean_squared_error: 0.0334 - val_loss: 1.9241 - val_mean_absolute_error: 1.0326 - val_mean_squared_error: 1.9206
# Epoch 92/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0409 - mean_absolute_error: 0.1397 - mean_squared_error: 0.0374 - val_loss: 1.9379 - val_mean_absolute_error: 1.0506 - val_mean_squared_error: 1.9345
# Epoch 93/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0382 - mean_absolute_error: 0.1378 - mean_squared_error: 0.0347 - val_loss: 1.7358 - val_mean_absolute_error: 0.9827 - val_mean_squared_error: 1.7323
# Epoch 94/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0326 - mean_absolute_error: 0.1196 - mean_squared_error: 0.0292 - val_loss: 2.3345 - val_mean_absolute_error: 1.1833 - val_mean_squared_error: 2.3311
# Epoch 95/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0323 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0290 - val_loss: 1.7382 - val_mean_absolute_error: 0.9739 - val_mean_squared_error: 1.7348
# Epoch 96/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0350 - mean_absolute_error: 0.1280 - mean_squared_error: 0.0316 - val_loss: 2.1179 - val_mean_absolute_error: 1.1150 - val_mean_squared_error: 2.1145
# Epoch 97/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0421 - mean_absolute_error: 0.1314 - mean_squared_error: 0.0388 - val_loss: 1.6972 - val_mean_absolute_error: 0.9665 - val_mean_squared_error: 1.6939
# Epoch 98/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0352 - mean_absolute_error: 0.1298 - mean_squared_error: 0.0319 - val_loss: 1.6073 - val_mean_absolute_error: 0.9383 - val_mean_squared_error: 1.6039
# Epoch 99/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0366 - mean_absolute_error: 0.1250 - mean_squared_error: 0.0333 - val_loss: 1.6065 - val_mean_absolute_error: 0.9305 - val_mean_squared_error: 1.6031
# Epoch 100/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0383 - mean_absolute_error: 0.1360 - mean_squared_error: 0.0350 - val_loss: 1.5558 - val_mean_absolute_error: 0.9232 - val_mean_squared_error: 1.5524
# Epoch 101/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0360 - mean_absolute_error: 0.1306 - mean_squared_error: 0.0327 - val_loss: 1.7025 - val_mean_absolute_error: 0.9734 - val_mean_squared_error: 1.6992
# Epoch 102/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0343 - mean_absolute_error: 0.1262 - mean_squared_error: 0.0310 - val_loss: 1.6342 - val_mean_absolute_error: 0.9522 - val_mean_squared_error: 1.6309
# Epoch 103/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0292 - mean_absolute_error: 0.1137 - mean_squared_error: 0.0259 - val_loss: 1.6105 - val_mean_absolute_error: 0.9344 - val_mean_squared_error: 1.6073
# Epoch 104/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0303 - mean_absolute_error: 0.1176 - mean_squared_error: 0.0271 - val_loss: 1.7194 - val_mean_absolute_error: 0.9676 - val_mean_squared_error: 1.7162
# Epoch 105/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0335 - mean_absolute_error: 0.1217 - mean_squared_error: 0.0303 - val_loss: 1.9535 - val_mean_absolute_error: 1.0296 - val_mean_squared_error: 1.9503
# Epoch 106/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0304 - mean_absolute_error: 0.1168 - mean_squared_error: 0.0272 - val_loss: 1.7627 - val_mean_absolute_error: 0.9748 - val_mean_squared_error: 1.7595
# Epoch 107/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0285 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0254 - val_loss: 1.5525 - val_mean_absolute_error: 0.9117 - val_mean_squared_error: 1.5493
# Epoch 108/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0284 - mean_absolute_error: 0.1064 - mean_squared_error: 0.0253 - val_loss: 1.9490 - val_mean_absolute_error: 1.0553 - val_mean_squared_error: 1.9458
# Epoch 109/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0288 - mean_absolute_error: 0.1140 - mean_squared_error: 0.0257 - val_loss: 1.6905 - val_mean_absolute_error: 0.9528 - val_mean_squared_error: 1.6874
# Epoch 110/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0305 - mean_absolute_error: 0.1127 - mean_squared_error: 0.0274 - val_loss: 1.9716 - val_mean_absolute_error: 1.0641 - val_mean_squared_error: 1.9685
# Epoch 111/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0478 - mean_absolute_error: 0.1412 - mean_squared_error: 0.0447 - val_loss: 2.3680 - val_mean_absolute_error: 1.1940 - val_mean_squared_error: 2.3649
# Epoch 112/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0319 - mean_absolute_error: 0.1190 - mean_squared_error: 0.0288 - val_loss: 1.5907 - val_mean_absolute_error: 0.9276 - val_mean_squared_error: 1.5876
# Epoch 113/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0406 - mean_absolute_error: 0.1436 - mean_squared_error: 0.0376 - val_loss: 1.6303 - val_mean_absolute_error: 0.9397 - val_mean_squared_error: 1.6273
# Epoch 114/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0279 - mean_absolute_error: 0.1070 - mean_squared_error: 0.0248 - val_loss: 1.6271 - val_mean_absolute_error: 0.9349 - val_mean_squared_error: 1.6241
# Epoch 115/200
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0367 - mean_absolute_error: 0.1284 - mean_squared_error: 0.0337 - val_loss: 1.4954 - val_mean_absolute_error: 0.8941 - val_mean_squared_error: 1.4924
# Epoch 116/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0296 - mean_absolute_error: 0.1059 - mean_squared_error: 0.0267 - val_loss: 1.6060 - val_mean_absolute_error: 0.9296 - val_mean_squared_error: 1.6030
# Epoch 117/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0242 - mean_absolute_error: 0.1044 - mean_squared_error: 0.0212 - val_loss: 1.5665 - val_mean_absolute_error: 0.9125 - val_mean_squared_error: 1.5635
# Epoch 118/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0294 - mean_absolute_error: 0.1080 - mean_squared_error: 0.0264 - val_loss: 1.9528 - val_mean_absolute_error: 1.0536 - val_mean_squared_error: 1.9499
# Epoch 119/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0268 - mean_absolute_error: 0.1112 - mean_squared_error: 0.0238 - val_loss: 1.7776 - val_mean_absolute_error: 0.9920 - val_mean_squared_error: 1.7747
# Epoch 120/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0234 - mean_absolute_error: 0.0991 - mean_squared_error: 0.0204 - val_loss: 1.6669 - val_mean_absolute_error: 0.9537 - val_mean_squared_error: 1.6640
# Epoch 121/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0395 - mean_absolute_error: 0.1368 - mean_squared_error: 0.0366 - val_loss: 1.4784 - val_mean_absolute_error: 0.8891 - val_mean_squared_error: 1.4755
# Epoch 122/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0292 - mean_absolute_error: 0.1148 - mean_squared_error: 0.0263 - val_loss: 1.8647 - val_mean_absolute_error: 1.0212 - val_mean_squared_error: 1.8618
# Epoch 123/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0408 - mean_absolute_error: 0.1294 - mean_squared_error: 0.0379 - val_loss: 1.5569 - val_mean_absolute_error: 0.9142 - val_mean_squared_error: 1.5541
# Epoch 124/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0249 - mean_absolute_error: 0.1057 - mean_squared_error: 0.0221 - val_loss: 1.5006 - val_mean_absolute_error: 0.8936 - val_mean_squared_error: 1.4978
# Epoch 125/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0252 - mean_absolute_error: 0.1017 - mean_squared_error: 0.0223 - val_loss: 1.3502 - val_mean_absolute_error: 0.8432 - val_mean_squared_error: 1.3474
# Epoch 126/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0328 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0300 - val_loss: 1.4099 - val_mean_absolute_error: 0.8643 - val_mean_squared_error: 1.4071
# Epoch 127/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0238 - mean_absolute_error: 0.1068 - mean_squared_error: 0.0210 - val_loss: 1.4231 - val_mean_absolute_error: 0.8624 - val_mean_squared_error: 1.4203
# Epoch 128/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0268 - mean_absolute_error: 0.1065 - mean_squared_error: 0.0240 - val_loss: 1.4367 - val_mean_absolute_error: 0.8706 - val_mean_squared_error: 1.4338
# Epoch 129/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0227 - mean_absolute_error: 0.0965 - mean_squared_error: 0.0199 - val_loss: 1.5391 - val_mean_absolute_error: 0.8931 - val_mean_squared_error: 1.5364
# Epoch 130/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0343 - mean_absolute_error: 0.1239 - mean_squared_error: 0.0315 - val_loss: 1.4705 - val_mean_absolute_error: 0.8828 - val_mean_squared_error: 1.4677
# Epoch 131/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0280 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0253 - val_loss: 1.5932 - val_mean_absolute_error: 0.9133 - val_mean_squared_error: 1.5905
# Epoch 132/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0277 - mean_absolute_error: 0.1139 - mean_squared_error: 0.0250 - val_loss: 1.7935 - val_mean_absolute_error: 0.9983 - val_mean_squared_error: 1.7908
# Epoch 133/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0322 - mean_absolute_error: 0.1160 - mean_squared_error: 0.0295 - val_loss: 1.4766 - val_mean_absolute_error: 0.8801 - val_mean_squared_error: 1.4739
# Epoch 134/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0253 - mean_absolute_error: 0.1060 - mean_squared_error: 0.0226 - val_loss: 1.5339 - val_mean_absolute_error: 0.9065 - val_mean_squared_error: 1.5312
# Epoch 135/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0261 - mean_absolute_error: 0.1125 - mean_squared_error: 0.0234 - val_loss: 1.4380 - val_mean_absolute_error: 0.8710 - val_mean_squared_error: 1.4353
# Epoch 136/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0576 - mean_absolute_error: 0.1493 - mean_squared_error: 0.0549 - val_loss: 1.3447 - val_mean_absolute_error: 0.8465 - val_mean_squared_error: 1.3421
# Epoch 137/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0333 - mean_absolute_error: 0.1154 - mean_squared_error: 0.0307 - val_loss: 1.3273 - val_mean_absolute_error: 0.8353 - val_mean_squared_error: 1.3247
# Epoch 138/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0271 - mean_absolute_error: 0.1111 - mean_squared_error: 0.0245 - val_loss: 1.2775 - val_mean_absolute_error: 0.8230 - val_mean_squared_error: 1.2748
# Epoch 139/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0230 - mean_absolute_error: 0.0956 - mean_squared_error: 0.0204 - val_loss: 1.3633 - val_mean_absolute_error: 0.8381 - val_mean_squared_error: 1.3607
# Epoch 140/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0225 - mean_absolute_error: 0.1048 - mean_squared_error: 0.0199 - val_loss: 1.3127 - val_mean_absolute_error: 0.8349 - val_mean_squared_error: 1.3100
# Epoch 141/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0185 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0159 - val_loss: 1.3691 - val_mean_absolute_error: 0.8287 - val_mean_squared_error: 1.3664
# Epoch 142/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0267 - mean_absolute_error: 0.1066 - mean_squared_error: 0.0241 - val_loss: 1.3541 - val_mean_absolute_error: 0.8321 - val_mean_squared_error: 1.3514
# Epoch 143/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0540 - mean_absolute_error: 0.1430 - mean_squared_error: 0.0514 - val_loss: 1.8749 - val_mean_absolute_error: 1.0292 - val_mean_squared_error: 1.8723
# Epoch 144/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0324 - mean_absolute_error: 0.1221 - mean_squared_error: 0.0298 - val_loss: 1.3159 - val_mean_absolute_error: 0.8185 - val_mean_squared_error: 1.3133
# Epoch 145/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0255 - mean_absolute_error: 0.0968 - mean_squared_error: 0.0230 - val_loss: 1.3150 - val_mean_absolute_error: 0.8193 - val_mean_squared_error: 1.3124
# Epoch 146/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0254 - mean_absolute_error: 0.1047 - mean_squared_error: 0.0229 - val_loss: 1.2388 - val_mean_absolute_error: 0.8109 - val_mean_squared_error: 1.2363
# Epoch 147/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0228 - mean_absolute_error: 0.0953 - mean_squared_error: 0.0203 - val_loss: 1.3844 - val_mean_absolute_error: 0.8388 - val_mean_squared_error: 1.3819
# Epoch 148/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0183 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0158 - val_loss: 1.4506 - val_mean_absolute_error: 0.8512 - val_mean_squared_error: 1.4481
# Epoch 149/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0226 - mean_absolute_error: 0.1001 - mean_squared_error: 0.0201 - val_loss: 1.2548 - val_mean_absolute_error: 0.8096 - val_mean_squared_error: 1.2523
# Epoch 150/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0166 - mean_absolute_error: 0.0821 - mean_squared_error: 0.0141 - val_loss: 1.3095 - val_mean_absolute_error: 0.8080 - val_mean_squared_error: 1.3069
# Epoch 151/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0236 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0211 - val_loss: 1.2904 - val_mean_absolute_error: 0.8212 - val_mean_squared_error: 1.2879
# Epoch 152/200
# 736/875 [========================>.....] - ETA: 1s - loss: 0.0236 - mean_absolute_error: 0.0999 - mean_squared_error: 0.0210

# %%
hist = pd.DataFrame(history.history)
hist['epoch']= history.epoch
hist.tail()
# Out:
#          val_loss  val_mean_absolute_error  val_mean_squared_error  \
# 195  6.650632e+07              6355.818481            6.650632e+07
# 196  6.275853e+07              6161.197162            6.275853e+07
# 197  5.944006e+07              5997.135702            5.944006e+07
# 198  6.229281e+07              6138.579988            6.229281e+07
# 199  6.106594e+07              6076.085226            6.106594e+07
#
#              loss  mean_absolute_error  mean_squared_error  epoch
# 195  1.702399e+06           881.769361        1.702399e+06    195
# 196  1.711892e+06           930.596856        1.711892e+06    196
# 197  1.580298e+06           893.164042        1.580298e+06    197
# 198  1.912179e+06           979.157146        1.912179e+06    198
# 199  1.614590e+06           912.569914        1.614590e+06    199

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  #plt.ylim([0,5])
  plt.legend()
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  #plt.ylim([0,20])
  plt.legend()
  plt.show()


plot_history(history)

# %%
test_predictions = model.predict(norm_flux).flatten()

plt.scatter(normalize(teff), test_predictions)
plt.xlabel('True Values [Teff]')
plt.ylabel('Predictions [Teff]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

print('test predictions=', test_predictions)
# Out:
# test predictions= [ 6836.807   6837.5747  6836.7603 ... 10159.98   12968.633  12631.623 ]
