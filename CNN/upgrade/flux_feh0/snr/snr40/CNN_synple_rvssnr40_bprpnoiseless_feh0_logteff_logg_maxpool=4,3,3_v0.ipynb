# %% [markdown]
# # Train the StarNet Model
#
# This notebook takes you through the steps of how to train a StarNet Model
# - Required Python packages: `numpy h5py keras`
# - Required data files: training_data.h5, mean_and_std.npy
#
# Note: We use tensorflow for the keras backend.

# %%
import numpy as np
import h5py
import random
import keras
from keras.models import Model
from keras.layers import Input, Dense, InputLayer, Flatten, Reshape, Concatenate, concatenate
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.optimizers import Adam
import tensorflow as tf
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.utils import HDF5Matrix
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc


#Loading the data

#RVSFlux normalized
pathrvs = 'norm_rvsflux.h5'
readrvs = h5py.File(pathrvs, 'r')
print(readrvs.keys())
rvs = readrvs.get('normrvs')
norm_rvsflux = np.array(rvs)
readrvs.close()

type(rvs)
print('shape of rvsflux:', np.shape(norm_rvsflux))
# Out:
# <KeysViewHDF5 ['normrvs']>
# shape of rvsflux: (415, 1134)

# %%
#BPFlux noiseless
pathbp = '/Users/aishasultan/work/synple-gaia/run/flux_feh0/bpflux.h5'
readbp = h5py.File(pathbp, 'r')
#print('total number of wave and flux in the folder:'len(readbp.keys()))
bpflux = readbp.get('bpflux0')
bpflux = np.array(bpflux)


norm_bpflux= []

for ii in range(np.shape(norm_rvsflux)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star #',ii)
        fluxlabel = 'bpflux'+str(ii)
        wavelabel = 'bpwave' +str(ii)
        flux = readbp.get(fluxlabel)
        wave= readbp.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_bpflux.append(normflux)


        
norm_bpflux= np.array(norm_bpflux)

print('shape of norm bpflux:', np.shape(norm_bpflux))
#print('shape of norm bpflux:', print(norm_bpflux[0:10]))
# Out:
# shape of norm bpflux: (415, 53)

# %%
#RPFlux
pathrp = '/Users/aishasultan/work/synple-gaia/run/flux_feh0/rpflux.h5'
readrp = h5py.File(pathrp, 'r')
#print('total number of wave and flux in the folder:'len(readbp.keys()))
rpflux = readrp.get('rpflux0')
rpflux = np.array(rpflux)


norm_rpflux= []

for ii in range(np.shape(norm_rvsflux)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star:',ii)
        fluxlabel = 'rpflux'+str(ii)
        wavelabel = 'rpwave' +str(ii)
        
        flux = readrp.get(fluxlabel)
        wave= readrp.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_rpflux.append(normflux)


        
norm_rpflux= np.array(norm_rpflux)

print('shape of norm_rpflux:', np.shape(norm_rpflux))
#print('output of norm_flux:', print(norm_rpflux[0:10]))

#print('The shapes of features and labels:', np.shape(norm_flux), np.shape(logteff))
# Out:
# shape of norm_rpflux: (415, 49)

# %%
#LogTeff
modparam = 'modparam_feh0.h5' #model parameters includes log g and teff
readfile = h5py.File(modparam, 'r')
print(readfile.keys())
teff = readfile.get('teff')
teff = np.array(teff)
logg = readfile.get('logg')
logg = np.array(logg)
print(teff)
readfile.close()
# Out:
# <KeysViewHDF5 ['logg', 'teff']>
# [ 3500.  3500.  3500.  3500.  3500.  3500.  3500.  3500.  3500.  3500.
#   3500.  3750.  3750.  3750.  3750.  3750.  3750.  3750.  3750.  3750.
#   3750.  3750.  4000.  4000.  4000.  4000.  4000.  4000.  4000.  4000.
#   4000.  4000.  4000.  4250.  4250.  4250.  4250.  4250.  4250.  4250.
#   4250.  4250.  4250.  4250.  4500.  4500.  4500.  4500.  4500.  4500.
#   4500.  4500.  4500.  4500.  4500.  4750.  4750.  4750.  4750.  4750.
#   4750.  4750.  4750.  4750.  4750.  4750.  5000.  5000.  5000.  5000.
#   5000.  5000.  5000.  5000.  5000.  5000.  5000.  5250.  5250.  5250.
#   5250.  5250.  5250.  5250.  5250.  5250.  5250.  5250.  5500.  5500.
#   5500.  5500.  5500.  5500.  5500.  5500.  5500.  5500.  5500.  5750.
#   5750.  5750.  5750.  5750.  5750.  5750.  5750.  5750.  5750.  5750.
#   6000.  6000.  6000.  6000.  6000.  6000.  6000.  6000.  6000.  6000.
#   6000.  6250.  6250.  6250.  6250.  6250.  6250.  6250.  6250.  6250.
#   6500.  6500.  6500.  6500.  6500.  6500.  6500.  6500.  6500.  6750.
#   6750.  6750.  6750.  6750.  6750.  6750.  6750.  6750.  7000.  7000.
#   7000.  7000.  7000.  7000.  7000.  7000.  7000.  7250.  7250.  7250.
#   7250.  7250.  7250.  7250.  7250.  7250.  7500.  7500.  7500.  7500.
#   7500.  7500.  7500.  7500.  7500.  7750.  7750.  7750.  7750.  7750.
#   7750.  7750.  7750.  7750.  8000.  8000.  8000.  8000.  8000.  8000.
#   8000.  8000.  8000.  8250.  8250.  8250.  8250.  8250.  8250.  8250.
#   8500.  8500.  8500.  8500.  8500.  8500.  8500.  8750.  8750.  8750.
#   8750.  8750.  8750.  8750.  9000.  9000.  9000.  9000.  9000.  9000.
#   9000.  9250.  9250.  9250.  9250.  9250.  9250.  9250.  9500.  9500.
#   9500.  9500.  9500.  9500.  9500.  9750.  9750.  9750.  9750.  9750.
#   9750.  9750. 10000. 10000. 10000. 10000. 10000. 10000. 10000. 10250.
#  10250. 10250. 10250. 10250. 10250. 10250. 10500. 10500. 10500. 10500.
#  10500. 10500. 10500. 10750. 10750. 10750. 10750. 10750. 10750. 10750.
#  11000. 11000. 11000. 11000. 11000. 11000. 11000. 11250. 11250. 11250.
#  11250. 11250. 11250. 11250. 11500. 11500. 11500. 11500. 11500. 11500.
#  11500. 11750. 11750. 11750. 11750. 11750. 11750. 11750. 12000. 12000.
#  12000. 12000. 12000. 12000. 12000. 12500. 12500. 12500. 12500. 12500.
#  13000. 13000. 13000. 13000. 13000. 13500. 13500. 13500. 13500. 13500.
#  14000. 14000. 14000. 14000. 14000. 14500. 14500. 14500. 14500. 14500.
#  15000. 15000. 15000. 15000. 15000. 15500. 15500. 15500. 15500. 15500.
#  16000. 16000. 16000. 16000. 16000. 16500. 16500. 16500. 16500. 16500.
#  17000. 17000. 17000. 17000. 17000. 17500. 17500. 17500. 17500. 17500.
#  18000. 18000. 18000. 18000. 18000. 18500. 18500. 18500. 18500. 18500.
#  19000. 19000. 19000. 19000. 19000. 19500. 19500. 19500. 19500. 19500.
#  20000. 20000. 20000. 20000. 20000. 21000. 21000. 21000. 22000. 22000.
#  22000. 23000. 23000. 23000. 24000. 24000. 24000. 25000. 25000. 25000.
#  26000. 26000. 26000. 27000. 27000. 27000. 28000. 28000. 28000. 29000.
#  29000. 29000. 30000. 30000. 30000.]

# %%
#features
num_tot = len(teff)
print('total number of input stars =', num_tot)
plim = 0.8
ran_frac = np.random.uniform(0,1,num_tot)
#print('ranfrac=' , ran_frac)




#Input flux data of RVS, BP, RP
x_RVStrain = norm_rvsflux[ran_frac < plim, :]
print('number of RVS training data=', len(x_RVStrain[:,0]))
x_RVScv = norm_rvsflux[ran_frac >= plim, :] #test set we left for the application

x_BPtrain = norm_bpflux[ran_frac < plim, :]
print('number of BP training data=', len(x_BPtrain[:,0]))
x_BPcv = norm_bpflux[ran_frac >= plim, :]

x_RPtrain =norm_rpflux[ran_frac < plim, :]
print('number of RP training data=', len(x_RPtrain[:,0]))
x_RPcv = norm_rpflux[ran_frac >= plim, :]


#print('x_BPtrain', x_BPtrain)

#x_train_combined = np.vstack (x_RVStrain[0,:],x_RPtrain[0,:]) 

#output label which is the logteff and log g
y_teff_train = teff[ran_frac< plim]
y_teff_cv = teff[ran_frac >= plim] #test set

y_logg_train = logg[ran_frac< plim]
y_logg_cv = logg[ran_frac >= plim] #test set



print('The size of CVS for the input flux data')
print('RVS cvs=', np.shape(x_RVScv))
print('BP cvs=', np.shape(x_BPcv))
print('RP cvs=', np.shape(x_RPcv))

print('the size of output label=', np.shape(y_teff_train) )

id = np.linspace(0, len(x_RVStrain[:, 0])-1, len(x_RVStrain[:, 0]))
plt.plot(id, y_teff_train)
plt.show()
# Out:
# total number of input stars = 415
# number of RVS training data= 343
# number of BP training data= 343
# number of RP training data= 343
# The size of CVS for the input flux data
# RVS cvs= (72, 1134)
# BP cvs= (72, 53)
# RP cvs= (72, 49)
# the size of output label= (343,)

# %% [markdown]
# ** Normalization **
#
# Write a function to normalize the output labels. Each label will be normalized to have approximately have a mean of zero and unit variance.
#
# NOTE: This is necessary to put output labels on a similar scale in order for the model to train properly, this process is reversed in the test stage to give the output labels their proper units

# %%
#mean_labels=np.mean(logteff)
#std_labels=np.std(logteff)
#print('mean and std teff=', mean_labels, std_labels)
def normalize(labels, mean_label, std_label):
    # Normalize labels
    return (labels-mean_label) / std_label

def denormalize(labels, mean_label, std_label):
    return (((labels)*(std_label)) + mean_label)

# %%
#normalize the y labels, the log teff and log g 

#labels trained
mean_teff_train = np.mean(y_teff_train)
std_teff_train = np.std(y_teff_train)

mean_logg_train = np.mean(y_logg_train)
std_logg_train = np.std(y_logg_train)

#labels cv
#mean_teff_cv = np.mean(y_teff_cv)
#std_teff_cv = np.std(y_teff_cv)

#mean_logg_cv = np.mean(y_logg_cv)
#std_logg_cv = np.std(y_logg_cv)

#output label which is the logteff and log g
y_teff_train = normalize(y_teff_train, mean_teff_train, std_teff_train)
y_teff_cv = normalize(y_teff_cv, mean_teff_train, std_teff_train)

y_logg_train = normalize(y_logg_train, mean_logg_train, std_logg_train)
y_logg_cv = normalize(y_logg_cv, mean_logg_train, std_logg_train)


print('type of data ', type(y_teff_train),type(y_teff_cv), type(y_logg_train), type(y_logg_cv) )
# Out:
# type of data  <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %% [markdown]
# **Build the StarNet model architecture**
#
# The StarNet architecture is built with:
# - input layer
# - 2 convolutional layers
# - 1 maxpooling layer followed by flattening for the fully connected layer
# - 2 fully connected layers
# - output layer
#
# First, let's define some model variables.

# %%
# activation function used following every layer except for the output layers
activation = 'relu'
#activation = 'sigmoid'

# model weight initializer
initializer = 'he_normal'

# number of filters used in the convolutional layers
#num_filters = [4,16]
num_filters = [8,32]
#num_filters = [8,16]

# length of the filters in the convolutional layers
#filter_length = 8
#filter_length = 16
filter_length = 8

# length of the maxpooling window 
pool_length_rvs = 4

pool_length_bp = 3

pool_length_rp = 3

# number of nodes in each of the hidden fully connected layers
num_hidden = [256,128]
#num_hidden = [24,12]

# number of spectra fed into model at once during training
batch_size = 64

# maximum number of interations for model training
#max_epochs = 200
#max_epochs = 100
#max_epochs = 150 
#max_epochs = 350
#max_epochs = 225
#max_epochs = 180
#max_epochs = 450
#max_epochs = 300
max_epochs = 300


# initial learning rate for optimization algorithm
lr = 0.000003 #handled by Adam
    
# exponential decay rate for the 1st moment estimates for optimization algorithm
beta_1 = 0.9

# exponential decay rate for the 2nd moment estimates for optimization algorithm
beta_2 = 0.999

# a small constant for numerical stability for optimization algorithm
optimizer_epsilon = 1e-08

# %%
num_RVSfluxes=len(x_RVStrain[0,:]) 
print('number of RVS fluxes=', num_RVSfluxes)

num_BPfluxes=len(x_BPtrain[0,:]) 
print('number of BP fluxes=', num_BPfluxes)

num_RPfluxes=len(x_RPtrain[0,:]) 
print('number of RP fluxes=', num_RPfluxes)

#num_labels= 1
num_labels= 2
print('number of training labels=', num_labels)

#ilam = np.linspace(0, num_fluxes-1, num_fluxes)
#plt.plot(ilam, x_train[329, :])
#plt.plot()

#iy = np.linspace(0, len(y_train)-1, len(y_train))
#plt.plot(iy, y_train)
#plt.plot()
# Out:
# number of RVS fluxes= 1134
# number of BP fluxes= 53
# number of RP fluxes= 49
# number of training labels= 2

# %%
# Input RVS spectra
# print(' num_RVSfluxes=', num_RVSfluxes)
input_RVSspec = Input(shape=(num_RVSfluxes,), name='rvs_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for RVS layers
cur_rvs = Reshape((num_RVSfluxes, 1))(input_RVSspec)

# CNN layers
cur_rvs = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_rvs) #first CNN layer
cur_rvs = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_rvs) #2nd CNN layer

# Max pooling layer
cur_rvs = MaxPooling1D(pool_size=pool_length_rvs)(cur_rvs)

# Flatten the current input for the fully-connected layers
cur_rvs = Flatten()(cur_rvs)


##############################################################################################


# Input BP spectra
# print(' num_BPfluxes=', num_BPfluxes)
input_BPspec = Input(shape=(num_BPfluxes,), name='bp_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for BP layers
cur_bp = Reshape((num_BPfluxes, 1))(input_BPspec)

# CNN layers
cur_bp = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_bp) #first CNN layer
cur_bp = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_bp) #2nd CNN layer

# Max pooling layer
cur_bp = MaxPooling1D(pool_size=pool_length_bp)(cur_bp)


# Flatten the current input for the fully-connected layers
cur_bp = Flatten()(cur_bp)


################################################################################################

# Input RP spectra
input_RPspec = Input(shape=(num_RPfluxes,), name='rp_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for CNN layers
cur_rp = Reshape((num_RPfluxes, 1))(input_RPspec)

# CNN layers
cur_rp = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_rp) #first CNN layer
cur_rp = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_rp) #2nd CNN layer

# Max pooling layer
cur_rp = MaxPooling1D(pool_size=pool_length_rp)(cur_rp)

# Flatten the current input for the fully-connected layers
cur_rp = Flatten()(cur_rp)

###############################################################################################

#concatenate RVS/BP/RP and then insert it to dense layer 

cur_comb = concatenate([cur_rvs, cur_bp, cur_rp])

# Fully-connected layers
cur_final = Dense(units=num_hidden[0], kernel_initializer=initializer, 
               activation=activation)(cur_comb)
cur_final = Dense(units=num_hidden[1], kernel_initializer=initializer, 
               activation=activation)(cur_final)

# Output nodes
output_final = Dense(units=num_labels, activation="linear", 
                    input_dim=num_hidden[1], name='output_y')(cur_final)


model = Model(inputs = [input_RVSspec, input_BPspec, input_RPspec], outputs=output_final)

# %% [markdown]
# **More model techniques**
# * The `Adam` optimizer is the gradient descent algorithm used for minimizing the loss function
# * `EarlyStopping` uses the cross-validation set to test the model following every iteration and stops the training if the cv loss does not decrease by `min_delta` after `patience` iterations
# * `ReduceLROnPlateau` is a form of learning rate decay where the learning rate is decreased by a factor of `factor` if the training loss does not decrease by `epsilon` after `patience` iterations unless the learning rate has reached `min_lr`

# %%
# Default loss function parameters
early_stopping_min_delta = 0.0007
early_stopping_patience = 4
reduce_lr_factor = 0.5
reuce_lr_epsilon = 0.0000009
reduce_lr_patience = 2
reduce_lr_min = 0.00008

# loss function to minimize
loss_function = 'mean_squared_error'

# compute mean absolute deviation
metrics = ['mae', 'mse']
#metrics = ['mae']

# %%
#optimizer = Adam(lr=lr, beta_1=beta_1, beta_2=beta_2, epsilon=optimizer_epsilon, decay=0.0)
optimizer = Adam(lr=0.005 )

early_stopping = EarlyStopping(monitor='val_loss', min_delta=early_stopping_min_delta, 
                                       patience=early_stopping_patience, verbose=2, mode='min')

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, epsilon=reuce_lr_epsilon, 
                                  patience=reduce_lr_patience, min_lr=reduce_lr_min, mode='min', verbose=2)

# %% [markdown]
# **Compile model**

# %%
model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# rvs_input_x (InputLayer)        (None, 1134)         0
# __________________________________________________________________________________________________
# bp_input_x (InputLayer)         (None, 53)           0
# __________________________________________________________________________________________________
# rp_input_x (InputLayer)         (None, 49)           0
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1134, 1)      0           rvs_input_x[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 53, 1)        0           bp_input_x[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 49, 1)        0           rp_input_x[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 1134, 8)      72          reshape_4[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 53, 8)        72          reshape_5[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 49, 8)        72          reshape_6[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 1134, 32)     2080        conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 53, 32)       2080        conv1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 49, 32)       2080        conv1d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 283, 32)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 17, 32)       0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 16, 32)       0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 9056)         0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 544)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 512)          0           max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 10112)        0           flatten_4[0][0]
#                                                                  flatten_5[0][0]
#                                                                  flatten_6[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          2588928     concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          32896       dense_3[0][0]
# __________________________________________________________________________________________________
# output_y (Dense)                (None, 2)            258         dense_4[0][0]
# ==================================================================================================
# Total params: 2,628,538
# Trainable params: 2,628,538
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Train model**

# %%
#history = model.fit(x_train, y_train, validation_data=(x_cv, y_cv),
          #epochs=max_epochs, verbose=1, shuffle='batch',
         #callbacks=[early_stopping, reduce_lr])
        

y_train_stack = np.column_stack((y_teff_train, y_logg_train))
y_cv_stack = np.column_stack ((y_teff_cv, y_logg_cv))

print('shape of the cv teff and logg=', np.shape(y_cv_stack))
print(' shape of y teff and logg=', np.shape(y_train_stack))
#history = model.fit(x=[x_RVStrain, x_BPtrain, x_RPtrain], y=y_train_stack,
          #validation_split=0.2, epochs=max_epochs, verbose=1, shuffle='batch')
        
history = model.fit(x=[x_RVStrain, x_BPtrain, x_RPtrain], y= y_train_stack, 
                    validation_data=([x_RVScv, x_BPcv, x_RPcv], y_cv_stack),
          epochs=max_epochs, verbose=1, shuffle='batch')
# Out:
# shape of the cv teff and logg= (72, 2)
#  shape of y teff and logg= (343, 2)
# Train on 343 samples, validate on 72 samples
# Epoch 1/300
# 343/343 [==============================] - 2s 5ms/step - loss: 1840.7963 - mean_absolute_error: 17.3438 - mean_squared_error: 1840.7963 - val_loss: 3.7139 - val_mean_absolute_error: 1.6120 - val_mean_squared_error: 3.7139
# Epoch 2/300
# 343/343 [==============================] - 0s 1ms/step - loss: 2.8766 - mean_absolute_error: 1.3173 - mean_squared_error: 2.8766 - val_loss: 1.6160 - val_mean_absolute_error: 1.0857 - val_mean_squared_error: 1.6160
# Epoch 3/300
# 343/343 [==============================] - 0s 1ms/step - loss: 1.8705 - mean_absolute_error: 1.1647 - mean_squared_error: 1.8705 - val_loss: 3.1117 - val_mean_absolute_error: 1.5189 - val_mean_squared_error: 3.1117
# Epoch 4/300
# 343/343 [==============================] - 1s 2ms/step - loss: 1.9602 - mean_absolute_error: 1.1637 - mean_squared_error: 1.9602 - val_loss: 0.8948 - val_mean_absolute_error: 0.7006 - val_mean_squared_error: 0.8948
# Epoch 5/300
# 343/343 [==============================] - 0s 1ms/step - loss: 1.4272 - mean_absolute_error: 0.9269 - mean_squared_error: 1.4272 - val_loss: 0.8095 - val_mean_absolute_error: 0.6572 - val_mean_squared_error: 0.8095
# Epoch 6/300
# 343/343 [==============================] - 0s 1ms/step - loss: 1.0487 - mean_absolute_error: 0.8491 - mean_squared_error: 1.0487 - val_loss: 0.5939 - val_mean_absolute_error: 0.5491 - val_mean_squared_error: 0.5939
# Epoch 7/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.6473 - mean_absolute_error: 0.6188 - mean_squared_error: 0.6473 - val_loss: 0.5525 - val_mean_absolute_error: 0.6367 - val_mean_squared_error: 0.5525
# Epoch 8/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.7568 - mean_absolute_error: 0.6800 - mean_squared_error: 0.7568 - val_loss: 0.5617 - val_mean_absolute_error: 0.5665 - val_mean_squared_error: 0.5617
# Epoch 9/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.6117 - mean_absolute_error: 0.6138 - mean_squared_error: 0.6117 - val_loss: 0.3700 - val_mean_absolute_error: 0.4720 - val_mean_squared_error: 0.3700
# Epoch 10/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.5059 - mean_absolute_error: 0.5577 - mean_squared_error: 0.5059 - val_loss: 0.3627 - val_mean_absolute_error: 0.4649 - val_mean_squared_error: 0.3627
# Epoch 11/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.4334 - mean_absolute_error: 0.5285 - mean_squared_error: 0.4334 - val_loss: 0.3126 - val_mean_absolute_error: 0.4581 - val_mean_squared_error: 0.3126
# Epoch 12/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.3982 - mean_absolute_error: 0.4817 - mean_squared_error: 0.3982 - val_loss: 0.3356 - val_mean_absolute_error: 0.4492 - val_mean_squared_error: 0.3356
# Epoch 13/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.5054 - mean_absolute_error: 0.5621 - mean_squared_error: 0.5054 - val_loss: 0.4493 - val_mean_absolute_error: 0.5553 - val_mean_squared_error: 0.4493
# Epoch 14/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.5071 - mean_absolute_error: 0.5927 - mean_squared_error: 0.5071 - val_loss: 0.5144 - val_mean_absolute_error: 0.6149 - val_mean_squared_error: 0.5144
# Epoch 15/300
# 343/343 [==============================] - 1s 1ms/step - loss: 0.6174 - mean_absolute_error: 0.6433 - mean_squared_error: 0.6174 - val_loss: 0.2877 - val_mean_absolute_error: 0.3878 - val_mean_squared_error: 0.2877
# Epoch 16/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.4044 - mean_absolute_error: 0.5242 - mean_squared_error: 0.4044 - val_loss: 0.3780 - val_mean_absolute_error: 0.5219 - val_mean_squared_error: 0.3780
# Epoch 17/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.3687 - mean_absolute_error: 0.4455 - mean_squared_error: 0.3687 - val_loss: 0.2172 - val_mean_absolute_error: 0.3282 - val_mean_squared_error: 0.2172
# Epoch 18/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.2801 - mean_absolute_error: 0.4121 - mean_squared_error: 0.2801 - val_loss: 0.2000 - val_mean_absolute_error: 0.3491 - val_mean_squared_error: 0.2000
# Epoch 19/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.2362 - mean_absolute_error: 0.3680 - mean_squared_error: 0.2362 - val_loss: 0.1339 - val_mean_absolute_error: 0.2911 - val_mean_squared_error: 0.1339
# Epoch 20/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.2544 - mean_absolute_error: 0.3649 - mean_squared_error: 0.2544 - val_loss: 0.2229 - val_mean_absolute_error: 0.3535 - val_mean_squared_error: 0.2229
# Epoch 21/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.2445 - mean_absolute_error: 0.4184 - mean_squared_error: 0.2445 - val_loss: 0.2219 - val_mean_absolute_error: 0.4056 - val_mean_squared_error: 0.2219
# Epoch 22/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1521 - mean_absolute_error: 0.3063 - mean_squared_error: 0.1521 - val_loss: 0.2700 - val_mean_absolute_error: 0.4297 - val_mean_squared_error: 0.2700
# Epoch 23/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.2160 - mean_absolute_error: 0.3870 - mean_squared_error: 0.2160 - val_loss: 0.2029 - val_mean_absolute_error: 0.3830 - val_mean_squared_error: 0.2029
# Epoch 24/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.2068 - mean_absolute_error: 0.3758 - mean_squared_error: 0.2068 - val_loss: 0.1685 - val_mean_absolute_error: 0.3351 - val_mean_squared_error: 0.1685
# Epoch 25/300
# 343/343 [==============================] - 1s 1ms/step - loss: 0.2622 - mean_absolute_error: 0.4047 - mean_squared_error: 0.2622 - val_loss: 0.0827 - val_mean_absolute_error: 0.2141 - val_mean_squared_error: 0.0827
# Epoch 26/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.2640 - mean_absolute_error: 0.4087 - mean_squared_error: 0.2640 - val_loss: 0.0957 - val_mean_absolute_error: 0.2520 - val_mean_squared_error: 0.0957
# Epoch 27/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.2804 - mean_absolute_error: 0.4400 - mean_squared_error: 0.2804 - val_loss: 0.4443 - val_mean_absolute_error: 0.5703 - val_mean_squared_error: 0.4443
# Epoch 28/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.4636 - mean_absolute_error: 0.5872 - mean_squared_error: 0.4636 - val_loss: 0.1947 - val_mean_absolute_error: 0.3230 - val_mean_squared_error: 0.1947
# Epoch 29/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.3162 - mean_absolute_error: 0.4656 - mean_squared_error: 0.3162 - val_loss: 0.2921 - val_mean_absolute_error: 0.4538 - val_mean_squared_error: 0.2921
# Epoch 30/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.2553 - mean_absolute_error: 0.3949 - mean_squared_error: 0.2553 - val_loss: 0.2552 - val_mean_absolute_error: 0.3837 - val_mean_squared_error: 0.2552
# Epoch 31/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.2436 - mean_absolute_error: 0.3920 - mean_squared_error: 0.2436 - val_loss: 0.0836 - val_mean_absolute_error: 0.2207 - val_mean_squared_error: 0.0836
# Epoch 32/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1398 - mean_absolute_error: 0.2883 - mean_squared_error: 0.1398 - val_loss: 0.1752 - val_mean_absolute_error: 0.3024 - val_mean_squared_error: 0.1752
# Epoch 33/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1340 - mean_absolute_error: 0.2825 - mean_squared_error: 0.1340 - val_loss: 0.0848 - val_mean_absolute_error: 0.2547 - val_mean_squared_error: 0.0848
# Epoch 34/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1129 - mean_absolute_error: 0.2691 - mean_squared_error: 0.1129 - val_loss: 0.0652 - val_mean_absolute_error: 0.2055 - val_mean_squared_error: 0.0652
# Epoch 35/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1329 - mean_absolute_error: 0.2965 - mean_squared_error: 0.1329 - val_loss: 0.0563 - val_mean_absolute_error: 0.1715 - val_mean_squared_error: 0.0563
# Epoch 36/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.1285 - mean_absolute_error: 0.2815 - mean_squared_error: 0.1285 - val_loss: 0.0838 - val_mean_absolute_error: 0.2278 - val_mean_squared_error: 0.0838
# Epoch 37/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1663 - mean_absolute_error: 0.3426 - mean_squared_error: 0.1663 - val_loss: 0.1235 - val_mean_absolute_error: 0.2880 - val_mean_squared_error: 0.1235
# Epoch 38/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.2673 - mean_absolute_error: 0.4350 - mean_squared_error: 0.2673 - val_loss: 0.4186 - val_mean_absolute_error: 0.4833 - val_mean_squared_error: 0.4186
# Epoch 39/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.3965 - mean_absolute_error: 0.4960 - mean_squared_error: 0.3965 - val_loss: 0.8726 - val_mean_absolute_error: 0.8758 - val_mean_squared_error: 0.8726
# Epoch 40/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.6977 - mean_absolute_error: 0.6612 - mean_squared_error: 0.6977 - val_loss: 1.0749 - val_mean_absolute_error: 0.7907 - val_mean_squared_error: 1.0749
# Epoch 41/300
# 343/343 [==============================] - 1s 1ms/step - loss: 0.4744 - mean_absolute_error: 0.5409 - mean_squared_error: 0.4744 - val_loss: 0.2721 - val_mean_absolute_error: 0.4576 - val_mean_squared_error: 0.2721
# Epoch 42/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.2840 - mean_absolute_error: 0.4364 - mean_squared_error: 0.2840 - val_loss: 0.2098 - val_mean_absolute_error: 0.3156 - val_mean_squared_error: 0.2098
# Epoch 43/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.2068 - mean_absolute_error: 0.3627 - mean_squared_error: 0.2068 - val_loss: 0.1763 - val_mean_absolute_error: 0.3172 - val_mean_squared_error: 0.1763
# Epoch 44/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1780 - mean_absolute_error: 0.3106 - mean_squared_error: 0.1780 - val_loss: 0.3545 - val_mean_absolute_error: 0.4477 - val_mean_squared_error: 0.3545
# Epoch 45/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1973 - mean_absolute_error: 0.3320 - mean_squared_error: 0.1973 - val_loss: 0.1621 - val_mean_absolute_error: 0.3286 - val_mean_squared_error: 0.1621
# Epoch 46/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.1262 - mean_absolute_error: 0.2749 - mean_squared_error: 0.1262 - val_loss: 0.0514 - val_mean_absolute_error: 0.1710 - val_mean_squared_error: 0.0514
# Epoch 47/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1081 - mean_absolute_error: 0.2704 - mean_squared_error: 0.1081 - val_loss: 0.0509 - val_mean_absolute_error: 0.1731 - val_mean_squared_error: 0.0509
# Epoch 48/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0920 - mean_absolute_error: 0.2383 - mean_squared_error: 0.0920 - val_loss: 0.0538 - val_mean_absolute_error: 0.1728 - val_mean_squared_error: 0.0538
# Epoch 49/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0864 - mean_absolute_error: 0.2229 - mean_squared_error: 0.0864 - val_loss: 0.1046 - val_mean_absolute_error: 0.2850 - val_mean_squared_error: 0.1046
# Epoch 50/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1325 - mean_absolute_error: 0.2936 - mean_squared_error: 0.1325 - val_loss: 0.0683 - val_mean_absolute_error: 0.1993 - val_mean_squared_error: 0.0683
# Epoch 51/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0634 - mean_absolute_error: 0.1930 - mean_squared_error: 0.0634 - val_loss: 0.0713 - val_mean_absolute_error: 0.2008 - val_mean_squared_error: 0.0713
# Epoch 52/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0713 - mean_absolute_error: 0.2133 - mean_squared_error: 0.0713 - val_loss: 0.0711 - val_mean_absolute_error: 0.2191 - val_mean_squared_error: 0.0711
# Epoch 53/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0732 - mean_absolute_error: 0.2222 - mean_squared_error: 0.0732 - val_loss: 0.0478 - val_mean_absolute_error: 0.1777 - val_mean_squared_error: 0.0478
# Epoch 54/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0806 - mean_absolute_error: 0.2473 - mean_squared_error: 0.0806 - val_loss: 0.0501 - val_mean_absolute_error: 0.1648 - val_mean_squared_error: 0.0501
# Epoch 55/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0924 - mean_absolute_error: 0.2219 - mean_squared_error: 0.0924 - val_loss: 0.0381 - val_mean_absolute_error: 0.1411 - val_mean_squared_error: 0.0381
# Epoch 56/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0637 - mean_absolute_error: 0.2060 - mean_squared_error: 0.0637 - val_loss: 0.0396 - val_mean_absolute_error: 0.1505 - val_mean_squared_error: 0.0396
# Epoch 57/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0541 - mean_absolute_error: 0.1810 - mean_squared_error: 0.0541 - val_loss: 0.1213 - val_mean_absolute_error: 0.3033 - val_mean_squared_error: 0.1213
# Epoch 58/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0678 - mean_absolute_error: 0.2155 - mean_squared_error: 0.0678 - val_loss: 0.0314 - val_mean_absolute_error: 0.1346 - val_mean_squared_error: 0.0314
# Epoch 59/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0525 - mean_absolute_error: 0.1818 - mean_squared_error: 0.0525 - val_loss: 0.0589 - val_mean_absolute_error: 0.1761 - val_mean_squared_error: 0.0589
# Epoch 60/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0434 - mean_absolute_error: 0.1603 - mean_squared_error: 0.0434 - val_loss: 0.0572 - val_mean_absolute_error: 0.1966 - val_mean_squared_error: 0.0572
# Epoch 61/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0728 - mean_absolute_error: 0.2000 - mean_squared_error: 0.0728 - val_loss: 0.1510 - val_mean_absolute_error: 0.2815 - val_mean_squared_error: 0.1510
# Epoch 62/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.1276 - mean_absolute_error: 0.2613 - mean_squared_error: 0.1276 - val_loss: 0.1730 - val_mean_absolute_error: 0.3107 - val_mean_squared_error: 0.1730
# Epoch 63/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0759 - mean_absolute_error: 0.1967 - mean_squared_error: 0.0759 - val_loss: 0.0570 - val_mean_absolute_error: 0.1622 - val_mean_squared_error: 0.0570
# Epoch 64/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0639 - mean_absolute_error: 0.1746 - mean_squared_error: 0.0639 - val_loss: 0.0783 - val_mean_absolute_error: 0.1971 - val_mean_squared_error: 0.0783
# Epoch 65/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0819 - mean_absolute_error: 0.2195 - mean_squared_error: 0.0819 - val_loss: 0.0368 - val_mean_absolute_error: 0.1439 - val_mean_squared_error: 0.0368
# Epoch 66/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0457 - mean_absolute_error: 0.1521 - mean_squared_error: 0.0457 - val_loss: 0.0409 - val_mean_absolute_error: 0.1524 - val_mean_squared_error: 0.0409
# Epoch 67/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0459 - mean_absolute_error: 0.1564 - mean_squared_error: 0.0459 - val_loss: 0.0499 - val_mean_absolute_error: 0.1896 - val_mean_squared_error: 0.0499
# Epoch 68/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0411 - mean_absolute_error: 0.1514 - mean_squared_error: 0.0411 - val_loss: 0.0270 - val_mean_absolute_error: 0.1201 - val_mean_squared_error: 0.0270
# Epoch 69/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0345 - mean_absolute_error: 0.1315 - mean_squared_error: 0.0345 - val_loss: 0.0300 - val_mean_absolute_error: 0.1253 - val_mean_squared_error: 0.0300
# Epoch 70/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0304 - mean_absolute_error: 0.1252 - mean_squared_error: 0.0304 - val_loss: 0.0427 - val_mean_absolute_error: 0.1475 - val_mean_squared_error: 0.0427
# Epoch 71/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0428 - mean_absolute_error: 0.1547 - mean_squared_error: 0.0428 - val_loss: 0.0581 - val_mean_absolute_error: 0.1769 - val_mean_squared_error: 0.0581
# Epoch 72/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0518 - mean_absolute_error: 0.1683 - mean_squared_error: 0.0518 - val_loss: 0.0920 - val_mean_absolute_error: 0.2233 - val_mean_squared_error: 0.0920
# Epoch 73/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0516 - mean_absolute_error: 0.1606 - mean_squared_error: 0.0516 - val_loss: 0.0338 - val_mean_absolute_error: 0.1338 - val_mean_squared_error: 0.0338
# Epoch 74/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0449 - mean_absolute_error: 0.1453 - mean_squared_error: 0.0449 - val_loss: 0.0613 - val_mean_absolute_error: 0.2055 - val_mean_squared_error: 0.0613
# Epoch 75/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0466 - mean_absolute_error: 0.1741 - mean_squared_error: 0.0466 - val_loss: 0.0789 - val_mean_absolute_error: 0.2398 - val_mean_squared_error: 0.0789
# Epoch 76/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0587 - mean_absolute_error: 0.1793 - mean_squared_error: 0.0587 - val_loss: 0.0351 - val_mean_absolute_error: 0.1441 - val_mean_squared_error: 0.0351
# Epoch 77/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0530 - mean_absolute_error: 0.1654 - mean_squared_error: 0.0530 - val_loss: 0.0349 - val_mean_absolute_error: 0.1309 - val_mean_squared_error: 0.0349
# Epoch 78/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0366 - mean_absolute_error: 0.1346 - mean_squared_error: 0.0366 - val_loss: 0.0498 - val_mean_absolute_error: 0.1571 - val_mean_squared_error: 0.0498
# Epoch 79/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0524 - mean_absolute_error: 0.1747 - mean_squared_error: 0.0524 - val_loss: 0.0620 - val_mean_absolute_error: 0.1827 - val_mean_squared_error: 0.0620
# Epoch 80/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0497 - mean_absolute_error: 0.1685 - mean_squared_error: 0.0497 - val_loss: 0.0422 - val_mean_absolute_error: 0.1531 - val_mean_squared_error: 0.0422
# Epoch 81/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0445 - mean_absolute_error: 0.1508 - mean_squared_error: 0.0445 - val_loss: 0.1056 - val_mean_absolute_error: 0.2436 - val_mean_squared_error: 0.1056
# Epoch 82/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0605 - mean_absolute_error: 0.1783 - mean_squared_error: 0.0605 - val_loss: 0.0733 - val_mean_absolute_error: 0.1967 - val_mean_squared_error: 0.0733
# Epoch 83/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0385 - mean_absolute_error: 0.1290 - mean_squared_error: 0.0385 - val_loss: 0.1647 - val_mean_absolute_error: 0.2880 - val_mean_squared_error: 0.1647
# Epoch 84/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1651 - mean_absolute_error: 0.2810 - mean_squared_error: 0.1651 - val_loss: 0.0684 - val_mean_absolute_error: 0.1907 - val_mean_squared_error: 0.0684
# Epoch 85/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0446 - mean_absolute_error: 0.1444 - mean_squared_error: 0.0446 - val_loss: 0.0251 - val_mean_absolute_error: 0.1069 - val_mean_squared_error: 0.0251
# Epoch 86/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0357 - mean_absolute_error: 0.1308 - mean_squared_error: 0.0357 - val_loss: 0.0530 - val_mean_absolute_error: 0.1666 - val_mean_squared_error: 0.0530
# Epoch 87/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0404 - mean_absolute_error: 0.1387 - mean_squared_error: 0.0404 - val_loss: 0.0622 - val_mean_absolute_error: 0.1767 - val_mean_squared_error: 0.0622
# Epoch 88/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0534 - mean_absolute_error: 0.1555 - mean_squared_error: 0.0534 - val_loss: 0.0283 - val_mean_absolute_error: 0.1236 - val_mean_squared_error: 0.0283
# Epoch 89/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0277 - mean_absolute_error: 0.1165 - mean_squared_error: 0.0277 - val_loss: 0.0278 - val_mean_absolute_error: 0.1198 - val_mean_squared_error: 0.0278
# Epoch 90/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0273 - mean_absolute_error: 0.1142 - mean_squared_error: 0.0273 - val_loss: 0.0316 - val_mean_absolute_error: 0.1277 - val_mean_squared_error: 0.0316
# Epoch 91/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0523 - mean_absolute_error: 0.1644 - mean_squared_error: 0.0523 - val_loss: 0.0845 - val_mean_absolute_error: 0.2174 - val_mean_squared_error: 0.0845
# Epoch 92/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0732 - mean_absolute_error: 0.1852 - mean_squared_error: 0.0732 - val_loss: 0.0914 - val_mean_absolute_error: 0.2174 - val_mean_squared_error: 0.0914
# Epoch 93/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0526 - mean_absolute_error: 0.1674 - mean_squared_error: 0.0526 - val_loss: 0.0268 - val_mean_absolute_error: 0.1229 - val_mean_squared_error: 0.0268
# Epoch 94/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0269 - mean_absolute_error: 0.1190 - mean_squared_error: 0.0269 - val_loss: 0.0302 - val_mean_absolute_error: 0.1323 - val_mean_squared_error: 0.0302
# Epoch 95/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0262 - mean_absolute_error: 0.1128 - mean_squared_error: 0.0262 - val_loss: 0.0246 - val_mean_absolute_error: 0.1205 - val_mean_squared_error: 0.0246
# Epoch 96/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0273 - mean_absolute_error: 0.1161 - mean_squared_error: 0.0273 - val_loss: 0.0237 - val_mean_absolute_error: 0.1101 - val_mean_squared_error: 0.0237
# Epoch 97/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0273 - mean_absolute_error: 0.1091 - mean_squared_error: 0.0273 - val_loss: 0.0229 - val_mean_absolute_error: 0.1089 - val_mean_squared_error: 0.0229
# Epoch 98/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0249 - mean_absolute_error: 0.1091 - mean_squared_error: 0.0249 - val_loss: 0.0210 - val_mean_absolute_error: 0.1035 - val_mean_squared_error: 0.0210
# Epoch 99/300
# 343/343 [==============================] - 48s 140ms/step - loss: 0.0263 - mean_absolute_error: 0.1103 - mean_squared_error: 0.0263 - val_loss: 0.0241 - val_mean_absolute_error: 0.1125 - val_mean_squared_error: 0.0241
# Epoch 100/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0313 - mean_absolute_error: 0.1199 - mean_squared_error: 0.0313 - val_loss: 0.0275 - val_mean_absolute_error: 0.1125 - val_mean_squared_error: 0.0275
# Epoch 101/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0350 - mean_absolute_error: 0.1219 - mean_squared_error: 0.0350 - val_loss: 0.0251 - val_mean_absolute_error: 0.1160 - val_mean_squared_error: 0.0251
# Epoch 102/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0376 - mean_absolute_error: 0.1342 - mean_squared_error: 0.0376 - val_loss: 0.0348 - val_mean_absolute_error: 0.1309 - val_mean_squared_error: 0.0348
# Epoch 103/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0233 - mean_absolute_error: 0.1054 - mean_squared_error: 0.0233 - val_loss: 0.0225 - val_mean_absolute_error: 0.1129 - val_mean_squared_error: 0.0225
# Epoch 104/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0226 - mean_absolute_error: 0.1055 - mean_squared_error: 0.0226 - val_loss: 0.0342 - val_mean_absolute_error: 0.1363 - val_mean_squared_error: 0.0342
# Epoch 105/300
# 343/343 [==============================] - 1s 1ms/step - loss: 0.0391 - mean_absolute_error: 0.1400 - mean_squared_error: 0.0391 - val_loss: 0.0340 - val_mean_absolute_error: 0.1295 - val_mean_squared_error: 0.0340
# Epoch 106/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0374 - mean_absolute_error: 0.1331 - mean_squared_error: 0.0374 - val_loss: 0.0218 - val_mean_absolute_error: 0.1080 - val_mean_squared_error: 0.0218
# Epoch 107/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0207 - mean_absolute_error: 0.1014 - mean_squared_error: 0.0207 - val_loss: 0.0200 - val_mean_absolute_error: 0.1028 - val_mean_squared_error: 0.0200
# Epoch 108/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0216 - mean_absolute_error: 0.1035 - mean_squared_error: 0.0216 - val_loss: 0.0184 - val_mean_absolute_error: 0.0948 - val_mean_squared_error: 0.0184
# Epoch 109/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0212 - mean_absolute_error: 0.0992 - mean_squared_error: 0.0212 - val_loss: 0.0346 - val_mean_absolute_error: 0.1434 - val_mean_squared_error: 0.0346
# Epoch 110/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0354 - mean_absolute_error: 0.1253 - mean_squared_error: 0.0354 - val_loss: 0.0556 - val_mean_absolute_error: 0.1688 - val_mean_squared_error: 0.0556
# Epoch 111/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0441 - mean_absolute_error: 0.1436 - mean_squared_error: 0.0441 - val_loss: 0.1176 - val_mean_absolute_error: 0.2494 - val_mean_squared_error: 0.1176
# Epoch 112/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0540 - mean_absolute_error: 0.1650 - mean_squared_error: 0.0540 - val_loss: 0.0239 - val_mean_absolute_error: 0.1112 - val_mean_squared_error: 0.0239
# Epoch 113/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0259 - mean_absolute_error: 0.1191 - mean_squared_error: 0.0259 - val_loss: 0.0573 - val_mean_absolute_error: 0.1643 - val_mean_squared_error: 0.0573
# Epoch 114/300
# 343/343 [==============================] - 3s 8ms/step - loss: 0.0340 - mean_absolute_error: 0.1328 - mean_squared_error: 0.0340 - val_loss: 0.0405 - val_mean_absolute_error: 0.1719 - val_mean_squared_error: 0.0405
# Epoch 115/300
# 343/343 [==============================] - 3s 9ms/step - loss: 0.0259 - mean_absolute_error: 0.1242 - mean_squared_error: 0.0259 - val_loss: 0.0258 - val_mean_absolute_error: 0.1185 - val_mean_squared_error: 0.0258
# Epoch 116/300
# 343/343 [==============================] - 3s 9ms/step - loss: 0.0321 - mean_absolute_error: 0.1265 - mean_squared_error: 0.0321 - val_loss: 0.0286 - val_mean_absolute_error: 0.1329 - val_mean_squared_error: 0.0286
# Epoch 117/300
# 343/343 [==============================] - 4s 11ms/step - loss: 0.0617 - mean_absolute_error: 0.1835 - mean_squared_error: 0.0617 - val_loss: 0.0404 - val_mean_absolute_error: 0.1322 - val_mean_squared_error: 0.0404
# Epoch 118/300
# 343/343 [==============================] - 30s 87ms/step - loss: 0.0576 - mean_absolute_error: 0.1769 - mean_squared_error: 0.0576 - val_loss: 0.0856 - val_mean_absolute_error: 0.2201 - val_mean_squared_error: 0.0856
# Epoch 119/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0669 - mean_absolute_error: 0.1901 - mean_squared_error: 0.0669 - val_loss: 0.0268 - val_mean_absolute_error: 0.1332 - val_mean_squared_error: 0.0268
# Epoch 120/300
# 343/343 [==============================] - 1s 1ms/step - loss: 0.0421 - mean_absolute_error: 0.1531 - mean_squared_error: 0.0421 - val_loss: 0.0293 - val_mean_absolute_error: 0.1334 - val_mean_squared_error: 0.0293
# Epoch 121/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0258 - mean_absolute_error: 0.1275 - mean_squared_error: 0.0258 - val_loss: 0.0261 - val_mean_absolute_error: 0.1346 - val_mean_squared_error: 0.0261
# Epoch 122/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0297 - mean_absolute_error: 0.1272 - mean_squared_error: 0.0297 - val_loss: 0.0318 - val_mean_absolute_error: 0.1442 - val_mean_squared_error: 0.0318
# Epoch 123/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0492 - mean_absolute_error: 0.1829 - mean_squared_error: 0.0492 - val_loss: 0.0876 - val_mean_absolute_error: 0.2218 - val_mean_squared_error: 0.0876
# Epoch 124/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0823 - mean_absolute_error: 0.2144 - mean_squared_error: 0.0823 - val_loss: 0.0828 - val_mean_absolute_error: 0.2496 - val_mean_squared_error: 0.0828
# Epoch 125/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1250 - mean_absolute_error: 0.2948 - mean_squared_error: 0.1250 - val_loss: 0.3007 - val_mean_absolute_error: 0.4813 - val_mean_squared_error: 0.3007
# Epoch 126/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.2186 - mean_absolute_error: 0.3790 - mean_squared_error: 0.2186 - val_loss: 0.2260 - val_mean_absolute_error: 0.4264 - val_mean_squared_error: 0.2260
# Epoch 127/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1439 - mean_absolute_error: 0.3046 - mean_squared_error: 0.1439 - val_loss: 0.0732 - val_mean_absolute_error: 0.1973 - val_mean_squared_error: 0.0732
# Epoch 128/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1060 - mean_absolute_error: 0.2804 - mean_squared_error: 0.1060 - val_loss: 0.0303 - val_mean_absolute_error: 0.1370 - val_mean_squared_error: 0.0303
# Epoch 129/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0623 - mean_absolute_error: 0.1957 - mean_squared_error: 0.0623 - val_loss: 0.0667 - val_mean_absolute_error: 0.2171 - val_mean_squared_error: 0.0667
# Epoch 130/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0760 - mean_absolute_error: 0.2239 - mean_squared_error: 0.0760 - val_loss: 0.0678 - val_mean_absolute_error: 0.2033 - val_mean_squared_error: 0.0678
# Epoch 131/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0479 - mean_absolute_error: 0.1691 - mean_squared_error: 0.0479 - val_loss: 0.0910 - val_mean_absolute_error: 0.2391 - val_mean_squared_error: 0.0910
# Epoch 132/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0702 - mean_absolute_error: 0.2030 - mean_squared_error: 0.0702 - val_loss: 0.0289 - val_mean_absolute_error: 0.1259 - val_mean_squared_error: 0.0289
# Epoch 133/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0399 - mean_absolute_error: 0.1438 - mean_squared_error: 0.0399 - val_loss: 0.1090 - val_mean_absolute_error: 0.2502 - val_mean_squared_error: 0.1090
# Epoch 134/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0704 - mean_absolute_error: 0.1959 - mean_squared_error: 0.0704 - val_loss: 0.0449 - val_mean_absolute_error: 0.1694 - val_mean_squared_error: 0.0449
# Epoch 135/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0385 - mean_absolute_error: 0.1521 - mean_squared_error: 0.0385 - val_loss: 0.0348 - val_mean_absolute_error: 0.1292 - val_mean_squared_error: 0.0348
# Epoch 136/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0280 - mean_absolute_error: 0.1253 - mean_squared_error: 0.0280 - val_loss: 0.0461 - val_mean_absolute_error: 0.1512 - val_mean_squared_error: 0.0461
# Epoch 137/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0358 - mean_absolute_error: 0.1386 - mean_squared_error: 0.0358 - val_loss: 0.0274 - val_mean_absolute_error: 0.1078 - val_mean_squared_error: 0.0274
# Epoch 138/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0458 - mean_absolute_error: 0.1462 - mean_squared_error: 0.0458 - val_loss: 0.0242 - val_mean_absolute_error: 0.1098 - val_mean_squared_error: 0.0242
# Epoch 139/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0477 - mean_absolute_error: 0.1537 - mean_squared_error: 0.0477 - val_loss: 0.0649 - val_mean_absolute_error: 0.1774 - val_mean_squared_error: 0.0649
# Epoch 140/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0547 - mean_absolute_error: 0.1736 - mean_squared_error: 0.0547 - val_loss: 0.0324 - val_mean_absolute_error: 0.1351 - val_mean_squared_error: 0.0324
# Epoch 141/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0828 - mean_absolute_error: 0.2089 - mean_squared_error: 0.0828 - val_loss: 0.0253 - val_mean_absolute_error: 0.1309 - val_mean_squared_error: 0.0253
# Epoch 142/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0356 - mean_absolute_error: 0.1392 - mean_squared_error: 0.0356 - val_loss: 0.0327 - val_mean_absolute_error: 0.1321 - val_mean_squared_error: 0.0327
# Epoch 143/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0439 - mean_absolute_error: 0.1424 - mean_squared_error: 0.0439 - val_loss: 0.0394 - val_mean_absolute_error: 0.1453 - val_mean_squared_error: 0.0394
# Epoch 144/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0249 - mean_absolute_error: 0.1233 - mean_squared_error: 0.0249 - val_loss: 0.0228 - val_mean_absolute_error: 0.1217 - val_mean_squared_error: 0.0228
# Epoch 145/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0225 - mean_absolute_error: 0.1170 - mean_squared_error: 0.0225 - val_loss: 0.0196 - val_mean_absolute_error: 0.1011 - val_mean_squared_error: 0.0196
# Epoch 146/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0232 - mean_absolute_error: 0.1136 - mean_squared_error: 0.0232 - val_loss: 0.0185 - val_mean_absolute_error: 0.1016 - val_mean_squared_error: 0.0185
# Epoch 147/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0204 - mean_absolute_error: 0.1037 - mean_squared_error: 0.0204 - val_loss: 0.0358 - val_mean_absolute_error: 0.1321 - val_mean_squared_error: 0.0358
# Epoch 148/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0239 - mean_absolute_error: 0.1169 - mean_squared_error: 0.0239 - val_loss: 0.0203 - val_mean_absolute_error: 0.0971 - val_mean_squared_error: 0.0203
# Epoch 149/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0178 - mean_absolute_error: 0.0971 - mean_squared_error: 0.0178 - val_loss: 0.0255 - val_mean_absolute_error: 0.1234 - val_mean_squared_error: 0.0255
# Epoch 150/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0210 - mean_absolute_error: 0.1139 - mean_squared_error: 0.0210 - val_loss: 0.0400 - val_mean_absolute_error: 0.1478 - val_mean_squared_error: 0.0400
# Epoch 151/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0193 - mean_absolute_error: 0.1079 - mean_squared_error: 0.0193 - val_loss: 0.0207 - val_mean_absolute_error: 0.1035 - val_mean_squared_error: 0.0207
# Epoch 152/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0180 - mean_absolute_error: 0.1042 - mean_squared_error: 0.0180 - val_loss: 0.0183 - val_mean_absolute_error: 0.0982 - val_mean_squared_error: 0.0183
# Epoch 153/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0138 - mean_absolute_error: 0.0877 - mean_squared_error: 0.0138 - val_loss: 0.0185 - val_mean_absolute_error: 0.1010 - val_mean_squared_error: 0.0185
# Epoch 154/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0132 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0132 - val_loss: 0.0220 - val_mean_absolute_error: 0.1189 - val_mean_squared_error: 0.0220
# Epoch 155/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0158 - mean_absolute_error: 0.1002 - mean_squared_error: 0.0158 - val_loss: 0.0175 - val_mean_absolute_error: 0.0941 - val_mean_squared_error: 0.0175
# Epoch 156/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0114 - mean_absolute_error: 0.0791 - mean_squared_error: 0.0114 - val_loss: 0.0162 - val_mean_absolute_error: 0.0901 - val_mean_squared_error: 0.0162
# Epoch 157/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0116 - mean_absolute_error: 0.0839 - mean_squared_error: 0.0116 - val_loss: 0.0179 - val_mean_absolute_error: 0.0942 - val_mean_squared_error: 0.0179
# Epoch 158/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0144 - mean_absolute_error: 0.0884 - mean_squared_error: 0.0144 - val_loss: 0.0220 - val_mean_absolute_error: 0.1189 - val_mean_squared_error: 0.0220
# Epoch 159/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0228 - mean_absolute_error: 0.1205 - mean_squared_error: 0.0228 - val_loss: 0.0283 - val_mean_absolute_error: 0.1364 - val_mean_squared_error: 0.0283
# Epoch 160/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0249 - mean_absolute_error: 0.1161 - mean_squared_error: 0.0249 - val_loss: 0.0268 - val_mean_absolute_error: 0.1168 - val_mean_squared_error: 0.0268
# Epoch 161/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0149 - mean_absolute_error: 0.0931 - mean_squared_error: 0.0149 - val_loss: 0.0190 - val_mean_absolute_error: 0.1049 - val_mean_squared_error: 0.0190
# Epoch 162/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0202 - mean_absolute_error: 0.1152 - mean_squared_error: 0.0202 - val_loss: 0.0193 - val_mean_absolute_error: 0.1060 - val_mean_squared_error: 0.0193
# Epoch 163/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0194 - mean_absolute_error: 0.1023 - mean_squared_error: 0.0194 - val_loss: 0.0246 - val_mean_absolute_error: 0.1065 - val_mean_squared_error: 0.0246
# Epoch 164/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0226 - mean_absolute_error: 0.1091 - mean_squared_error: 0.0226 - val_loss: 0.0218 - val_mean_absolute_error: 0.1047 - val_mean_squared_error: 0.0218
# Epoch 165/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0186 - mean_absolute_error: 0.1008 - mean_squared_error: 0.0186 - val_loss: 0.0175 - val_mean_absolute_error: 0.0938 - val_mean_squared_error: 0.0175
# Epoch 166/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0253 - mean_absolute_error: 0.1151 - mean_squared_error: 0.0253 - val_loss: 0.0502 - val_mean_absolute_error: 0.1753 - val_mean_squared_error: 0.0502
# Epoch 167/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0406 - mean_absolute_error: 0.1487 - mean_squared_error: 0.0406 - val_loss: 0.0329 - val_mean_absolute_error: 0.1403 - val_mean_squared_error: 0.0329
# Epoch 168/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0428 - mean_absolute_error: 0.1443 - mean_squared_error: 0.0428 - val_loss: 0.0873 - val_mean_absolute_error: 0.2193 - val_mean_squared_error: 0.0873
# Epoch 169/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0648 - mean_absolute_error: 0.1893 - mean_squared_error: 0.0648 - val_loss: 0.0337 - val_mean_absolute_error: 0.1335 - val_mean_squared_error: 0.0337
# Epoch 170/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0398 - mean_absolute_error: 0.1518 - mean_squared_error: 0.0398 - val_loss: 0.0741 - val_mean_absolute_error: 0.1841 - val_mean_squared_error: 0.0741
# Epoch 171/300
# 343/343 [==============================] - 1s 1ms/step - loss: 0.0579 - mean_absolute_error: 0.1923 - mean_squared_error: 0.0579 - val_loss: 0.0257 - val_mean_absolute_error: 0.1208 - val_mean_squared_error: 0.0257
# Epoch 172/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0221 - mean_absolute_error: 0.1115 - mean_squared_error: 0.0221 - val_loss: 0.0237 - val_mean_absolute_error: 0.1115 - val_mean_squared_error: 0.0237
# Epoch 173/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0194 - mean_absolute_error: 0.1035 - mean_squared_error: 0.0194 - val_loss: 0.0274 - val_mean_absolute_error: 0.1384 - val_mean_squared_error: 0.0274
# Epoch 174/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0177 - mean_absolute_error: 0.1053 - mean_squared_error: 0.0177 - val_loss: 0.0183 - val_mean_absolute_error: 0.1072 - val_mean_squared_error: 0.0183
# Epoch 175/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0117 - mean_absolute_error: 0.0833 - mean_squared_error: 0.0117 - val_loss: 0.0198 - val_mean_absolute_error: 0.1127 - val_mean_squared_error: 0.0198
# Epoch 176/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0125 - mean_absolute_error: 0.0859 - mean_squared_error: 0.0125 - val_loss: 0.0166 - val_mean_absolute_error: 0.0970 - val_mean_squared_error: 0.0166
# Epoch 177/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0158 - mean_absolute_error: 0.1005 - mean_squared_error: 0.0158 - val_loss: 0.0225 - val_mean_absolute_error: 0.1088 - val_mean_squared_error: 0.0225
# Epoch 178/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0230 - mean_absolute_error: 0.1132 - mean_squared_error: 0.0230 - val_loss: 0.0326 - val_mean_absolute_error: 0.1397 - val_mean_squared_error: 0.0326
# Epoch 179/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0258 - mean_absolute_error: 0.1220 - mean_squared_error: 0.0258 - val_loss: 0.0363 - val_mean_absolute_error: 0.1413 - val_mean_squared_error: 0.0363
# Epoch 180/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0311 - mean_absolute_error: 0.1262 - mean_squared_error: 0.0311 - val_loss: 0.0453 - val_mean_absolute_error: 0.1488 - val_mean_squared_error: 0.0453
# Epoch 181/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0356 - mean_absolute_error: 0.1412 - mean_squared_error: 0.0356 - val_loss: 0.0321 - val_mean_absolute_error: 0.1544 - val_mean_squared_error: 0.0321
# Epoch 182/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0223 - mean_absolute_error: 0.1202 - mean_squared_error: 0.0223 - val_loss: 0.0192 - val_mean_absolute_error: 0.0991 - val_mean_squared_error: 0.0192
# Epoch 183/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0132 - mean_absolute_error: 0.0866 - mean_squared_error: 0.0132 - val_loss: 0.0234 - val_mean_absolute_error: 0.1117 - val_mean_squared_error: 0.0234
# Epoch 184/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0120 - mean_absolute_error: 0.0822 - mean_squared_error: 0.0120 - val_loss: 0.0146 - val_mean_absolute_error: 0.0831 - val_mean_squared_error: 0.0146
# Epoch 185/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0089 - mean_absolute_error: 0.0726 - mean_squared_error: 0.0089 - val_loss: 0.0148 - val_mean_absolute_error: 0.0831 - val_mean_squared_error: 0.0148
# Epoch 186/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0083 - mean_absolute_error: 0.0683 - mean_squared_error: 0.0083 - val_loss: 0.0172 - val_mean_absolute_error: 0.0873 - val_mean_squared_error: 0.0172
# Epoch 187/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0099 - mean_absolute_error: 0.0743 - mean_squared_error: 0.0099 - val_loss: 0.0182 - val_mean_absolute_error: 0.0920 - val_mean_squared_error: 0.0182
# Epoch 188/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0118 - mean_absolute_error: 0.0798 - mean_squared_error: 0.0118 - val_loss: 0.0207 - val_mean_absolute_error: 0.1008 - val_mean_squared_error: 0.0207
# Epoch 189/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0169 - mean_absolute_error: 0.0974 - mean_squared_error: 0.0169 - val_loss: 0.0197 - val_mean_absolute_error: 0.0964 - val_mean_squared_error: 0.0197
# Epoch 190/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0219 - mean_absolute_error: 0.1066 - mean_squared_error: 0.0219 - val_loss: 0.0252 - val_mean_absolute_error: 0.1106 - val_mean_squared_error: 0.0252
# Epoch 191/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0137 - mean_absolute_error: 0.0894 - mean_squared_error: 0.0137 - val_loss: 0.0204 - val_mean_absolute_error: 0.1044 - val_mean_squared_error: 0.0204
# Epoch 192/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0138 - mean_absolute_error: 0.0823 - mean_squared_error: 0.0138 - val_loss: 0.0314 - val_mean_absolute_error: 0.1226 - val_mean_squared_error: 0.0314
# Epoch 193/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0305 - mean_absolute_error: 0.1279 - mean_squared_error: 0.0305 - val_loss: 0.0238 - val_mean_absolute_error: 0.1087 - val_mean_squared_error: 0.0238
# Epoch 194/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0245 - mean_absolute_error: 0.1149 - mean_squared_error: 0.0245 - val_loss: 0.0264 - val_mean_absolute_error: 0.1264 - val_mean_squared_error: 0.0264
# Epoch 195/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0262 - mean_absolute_error: 0.1308 - mean_squared_error: 0.0262 - val_loss: 0.0362 - val_mean_absolute_error: 0.1354 - val_mean_squared_error: 0.0362
# Epoch 196/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0422 - mean_absolute_error: 0.1489 - mean_squared_error: 0.0422 - val_loss: 0.0288 - val_mean_absolute_error: 0.1240 - val_mean_squared_error: 0.0288
# Epoch 197/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0269 - mean_absolute_error: 0.1143 - mean_squared_error: 0.0269 - val_loss: 0.0185 - val_mean_absolute_error: 0.0961 - val_mean_squared_error: 0.0185
# Epoch 198/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0431 - mean_absolute_error: 0.1493 - mean_squared_error: 0.0431 - val_loss: 0.0508 - val_mean_absolute_error: 0.1466 - val_mean_squared_error: 0.0508
# Epoch 199/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1601 - mean_absolute_error: 0.2949 - mean_squared_error: 0.1601 - val_loss: 0.6899 - val_mean_absolute_error: 0.7407 - val_mean_squared_error: 0.6899
# Epoch 200/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.3721 - mean_absolute_error: 0.5023 - mean_squared_error: 0.3721 - val_loss: 0.0797 - val_mean_absolute_error: 0.2267 - val_mean_squared_error: 0.0797
# Epoch 201/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1215 - mean_absolute_error: 0.2701 - mean_squared_error: 0.1215 - val_loss: 0.0577 - val_mean_absolute_error: 0.1864 - val_mean_squared_error: 0.0577
# Epoch 202/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0493 - mean_absolute_error: 0.1681 - mean_squared_error: 0.0493 - val_loss: 0.0578 - val_mean_absolute_error: 0.1750 - val_mean_squared_error: 0.0578
# Epoch 203/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0309 - mean_absolute_error: 0.1291 - mean_squared_error: 0.0309 - val_loss: 0.0250 - val_mean_absolute_error: 0.1149 - val_mean_squared_error: 0.0250
# Epoch 204/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0187 - mean_absolute_error: 0.1035 - mean_squared_error: 0.0187 - val_loss: 0.0231 - val_mean_absolute_error: 0.1065 - val_mean_squared_error: 0.0231
# Epoch 205/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0161 - mean_absolute_error: 0.0930 - mean_squared_error: 0.0161 - val_loss: 0.0401 - val_mean_absolute_error: 0.1379 - val_mean_squared_error: 0.0401
# Epoch 206/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0281 - mean_absolute_error: 0.1201 - mean_squared_error: 0.0281 - val_loss: 0.0203 - val_mean_absolute_error: 0.1081 - val_mean_squared_error: 0.0203
# Epoch 207/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0156 - mean_absolute_error: 0.0924 - mean_squared_error: 0.0156 - val_loss: 0.0370 - val_mean_absolute_error: 0.1345 - val_mean_squared_error: 0.0370
# Epoch 208/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0150 - mean_absolute_error: 0.0911 - mean_squared_error: 0.0150 - val_loss: 0.0173 - val_mean_absolute_error: 0.0905 - val_mean_squared_error: 0.0173
# Epoch 209/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0201 - mean_absolute_error: 0.0973 - mean_squared_error: 0.0201 - val_loss: 0.0366 - val_mean_absolute_error: 0.1355 - val_mean_squared_error: 0.0366
# Epoch 210/300
# ...
# Epoch 232/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0071 - mean_absolute_error: 0.0673 - mean_squared_error: 0.0071 - val_loss: 0.0140 - val_mean_absolute_error: 0.0817 - val_mean_squared_error: 0.0140
# Epoch 233/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0059 - mean_absolute_error: 0.0597 - mean_squared_error: 0.0059 - val_loss: 0.0169 - val_mean_absolute_error: 0.0893 - val_mean_squared_error: 0.0169
# Epoch 234/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0056 - mean_absolute_error: 0.0567 - mean_squared_error: 0.0056 - val_loss: 0.0143 - val_mean_absolute_error: 0.0794 - val_mean_squared_error: 0.0143
# Epoch 235/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0590 - mean_squared_error: 0.0061 - val_loss: 0.0176 - val_mean_absolute_error: 0.0861 - val_mean_squared_error: 0.0176
# Epoch 236/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0117 - mean_absolute_error: 0.0805 - mean_squared_error: 0.0117 - val_loss: 0.0329 - val_mean_absolute_error: 0.1233 - val_mean_squared_error: 0.0329
# Epoch 237/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0196 - mean_absolute_error: 0.1072 - mean_squared_error: 0.0196 - val_loss: 0.0191 - val_mean_absolute_error: 0.0877 - val_mean_squared_error: 0.0191
# Epoch 238/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0381 - mean_absolute_error: 0.1490 - mean_squared_error: 0.0381 - val_loss: 0.0218 - val_mean_absolute_error: 0.1136 - val_mean_squared_error: 0.0218
# Epoch 239/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0511 - mean_absolute_error: 0.1471 - mean_squared_error: 0.0511 - val_loss: 0.0696 - val_mean_absolute_error: 0.2024 - val_mean_squared_error: 0.0696
# Epoch 240/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0384 - mean_absolute_error: 0.1448 - mean_squared_error: 0.0384 - val_loss: 0.0853 - val_mean_absolute_error: 0.2116 - val_mean_squared_error: 0.0853
# Epoch 241/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0661 - mean_absolute_error: 0.1925 - mean_squared_error: 0.0661 - val_loss: 0.0636 - val_mean_absolute_error: 0.1807 - val_mean_squared_error: 0.0636
# Epoch 242/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0550 - mean_absolute_error: 0.1707 - mean_squared_error: 0.0550 - val_loss: 0.0759 - val_mean_absolute_error: 0.2338 - val_mean_squared_error: 0.0759
# Epoch 243/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0317 - mean_absolute_error: 0.1404 - mean_squared_error: 0.0317 - val_loss: 0.0318 - val_mean_absolute_error: 0.1305 - val_mean_squared_error: 0.0318
# Epoch 244/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0166 - mean_absolute_error: 0.1030 - mean_squared_error: 0.0166 - val_loss: 0.0315 - val_mean_absolute_error: 0.1386 - val_mean_squared_error: 0.0315
# Epoch 245/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0170 - mean_absolute_error: 0.1084 - mean_squared_error: 0.0170 - val_loss: 0.0228 - val_mean_absolute_error: 0.0998 - val_mean_squared_error: 0.0228
# Epoch 246/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0122 - mean_absolute_error: 0.0849 - mean_squared_error: 0.0122 - val_loss: 0.0225 - val_mean_absolute_error: 0.1175 - val_mean_squared_error: 0.0225
# Epoch 247/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0143 - mean_absolute_error: 0.0886 - mean_squared_error: 0.0143 - val_loss: 0.0160 - val_mean_absolute_error: 0.0898 - val_mean_squared_error: 0.0160
# Epoch 248/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0090 - mean_absolute_error: 0.0737 - mean_squared_error: 0.0090 - val_loss: 0.0175 - val_mean_absolute_error: 0.1031 - val_mean_squared_error: 0.0175
# Epoch 249/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0095 - mean_absolute_error: 0.0768 - mean_squared_error: 0.0095 - val_loss: 0.0164 - val_mean_absolute_error: 0.0976 - val_mean_squared_error: 0.0164
# Epoch 250/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0079 - mean_absolute_error: 0.0692 - mean_squared_error: 0.0079 - val_loss: 0.0146 - val_mean_absolute_error: 0.0836 - val_mean_squared_error: 0.0146
# Epoch 251/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_absolute_error: 0.0674 - mean_squared_error: 0.0074 - val_loss: 0.0144 - val_mean_absolute_error: 0.0829 - val_mean_squared_error: 0.0144
# Epoch 252/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0086 - mean_absolute_error: 0.0681 - mean_squared_error: 0.0086 - val_loss: 0.0143 - val_mean_absolute_error: 0.0840 - val_mean_squared_error: 0.0143
# Epoch 253/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0066 - mean_absolute_error: 0.0630 - mean_squared_error: 0.0066 - val_loss: 0.0191 - val_mean_absolute_error: 0.0927 - val_mean_squared_error: 0.0191
# Epoch 254/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0060 - mean_absolute_error: 0.0597 - mean_squared_error: 0.0060 - val_loss: 0.0152 - val_mean_absolute_error: 0.0864 - val_mean_squared_error: 0.0152
# Epoch 255/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0056 - mean_absolute_error: 0.0563 - mean_squared_error: 0.0056 - val_loss: 0.0179 - val_mean_absolute_error: 0.0919 - val_mean_squared_error: 0.0179
# Epoch 256/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0612 - mean_squared_error: 0.0062 - val_loss: 0.0141 - val_mean_absolute_error: 0.0838 - val_mean_squared_error: 0.0141
# Epoch 257/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0049 - mean_absolute_error: 0.0552 - mean_squared_error: 0.0049 - val_loss: 0.0135 - val_mean_absolute_error: 0.0813 - val_mean_squared_error: 0.0135
# Epoch 258/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0587 - mean_squared_error: 0.0059 - val_loss: 0.0123 - val_mean_absolute_error: 0.0751 - val_mean_squared_error: 0.0123
# Epoch 259/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0052 - mean_absolute_error: 0.0555 - mean_squared_error: 0.0052 - val_loss: 0.0125 - val_mean_absolute_error: 0.0776 - val_mean_squared_error: 0.0125
# Epoch 260/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0535 - mean_squared_error: 0.0050 - val_loss: 0.0122 - val_mean_absolute_error: 0.0770 - val_mean_squared_error: 0.0122
# Epoch 261/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0045 - mean_absolute_error: 0.0506 - mean_squared_error: 0.0045 - val_loss: 0.0120 - val_mean_absolute_error: 0.0766 - val_mean_squared_error: 0.0120
# Epoch 262/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0054 - mean_absolute_error: 0.0568 - mean_squared_error: 0.0054 - val_loss: 0.0135 - val_mean_absolute_error: 0.0877 - val_mean_squared_error: 0.0135
# Epoch 263/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0049 - mean_absolute_error: 0.0546 - mean_squared_error: 0.0049 - val_loss: 0.0118 - val_mean_absolute_error: 0.0777 - val_mean_squared_error: 0.0118
# Epoch 264/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0044 - mean_absolute_error: 0.0512 - mean_squared_error: 0.0044 - val_loss: 0.0114 - val_mean_absolute_error: 0.0725 - val_mean_squared_error: 0.0114
# Epoch 265/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0506 - mean_squared_error: 0.0044 - val_loss: 0.0120 - val_mean_absolute_error: 0.0745 - val_mean_squared_error: 0.0120
# Epoch 266/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0058 - mean_absolute_error: 0.0580 - mean_squared_error: 0.0058 - val_loss: 0.0143 - val_mean_absolute_error: 0.0901 - val_mean_squared_error: 0.0143
# Epoch 267/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0052 - mean_absolute_error: 0.0575 - mean_squared_error: 0.0052 - val_loss: 0.0133 - val_mean_absolute_error: 0.0845 - val_mean_squared_error: 0.0133
# Epoch 268/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0052 - mean_absolute_error: 0.0560 - mean_squared_error: 0.0052 - val_loss: 0.0164 - val_mean_absolute_error: 0.0966 - val_mean_squared_error: 0.0164
# Epoch 269/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0094 - mean_absolute_error: 0.0781 - mean_squared_error: 0.0094 - val_loss: 0.0167 - val_mean_absolute_error: 0.0957 - val_mean_squared_error: 0.0167
# Epoch 270/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0654 - mean_squared_error: 0.0070 - val_loss: 0.0133 - val_mean_absolute_error: 0.0858 - val_mean_squared_error: 0.0133
# Epoch 271/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0083 - mean_absolute_error: 0.0745 - mean_squared_error: 0.0083 - val_loss: 0.0155 - val_mean_absolute_error: 0.0848 - val_mean_squared_error: 0.0155
# Epoch 272/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0089 - mean_absolute_error: 0.0683 - mean_squared_error: 0.0089 - val_loss: 0.0132 - val_mean_absolute_error: 0.0788 - val_mean_squared_error: 0.0132
# Epoch 273/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0069 - mean_absolute_error: 0.0606 - mean_squared_error: 0.0069 - val_loss: 0.0143 - val_mean_absolute_error: 0.0799 - val_mean_squared_error: 0.0143
# Epoch 274/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0042 - mean_absolute_error: 0.0498 - mean_squared_error: 0.0042 - val_loss: 0.0131 - val_mean_absolute_error: 0.0763 - val_mean_squared_error: 0.0131
# Epoch 275/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0576 - mean_squared_error: 0.0055 - val_loss: 0.0117 - val_mean_absolute_error: 0.0715 - val_mean_squared_error: 0.0117
# Epoch 276/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0046 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0046 - val_loss: 0.0123 - val_mean_absolute_error: 0.0771 - val_mean_squared_error: 0.0123
# Epoch 277/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0046 - mean_absolute_error: 0.0524 - mean_squared_error: 0.0046 - val_loss: 0.0125 - val_mean_absolute_error: 0.0765 - val_mean_squared_error: 0.0125
# Epoch 278/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0081 - mean_absolute_error: 0.0668 - mean_squared_error: 0.0081 - val_loss: 0.0259 - val_mean_absolute_error: 0.1298 - val_mean_squared_error: 0.0259
# Epoch 279/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0171 - mean_absolute_error: 0.1112 - mean_squared_error: 0.0171 - val_loss: 0.0398 - val_mean_absolute_error: 0.1329 - val_mean_squared_error: 0.0398
# Epoch 280/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0277 - mean_absolute_error: 0.1274 - mean_squared_error: 0.0277 - val_loss: 0.3198 - val_mean_absolute_error: 0.4392 - val_mean_squared_error: 0.3198
# Epoch 281/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0987 - mean_absolute_error: 0.2307 - mean_squared_error: 0.0987 - val_loss: 0.0545 - val_mean_absolute_error: 0.1968 - val_mean_squared_error: 0.0545
# Epoch 282/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0542 - mean_absolute_error: 0.1885 - mean_squared_error: 0.0542 - val_loss: 0.1220 - val_mean_absolute_error: 0.2251 - val_mean_squared_error: 0.1220
# Epoch 283/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1002 - mean_absolute_error: 0.2156 - mean_squared_error: 0.1002 - val_loss: 0.0313 - val_mean_absolute_error: 0.1545 - val_mean_squared_error: 0.0313
# Epoch 284/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0482 - mean_absolute_error: 0.1747 - mean_squared_error: 0.0482 - val_loss: 0.0267 - val_mean_absolute_error: 0.1223 - val_mean_squared_error: 0.0267
# Epoch 285/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0732 - mean_absolute_error: 0.1918 - mean_squared_error: 0.0732 - val_loss: 0.0571 - val_mean_absolute_error: 0.1817 - val_mean_squared_error: 0.0571
# Epoch 286/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.1278 - mean_absolute_error: 0.2312 - mean_squared_error: 0.1278 - val_loss: 0.1163 - val_mean_absolute_error: 0.2371 - val_mean_squared_error: 0.1163
# Epoch 287/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.1213 - mean_absolute_error: 0.2501 - mean_squared_error: 0.1213 - val_loss: 0.0942 - val_mean_absolute_error: 0.2361 - val_mean_squared_error: 0.0942
# Epoch 288/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0575 - mean_absolute_error: 0.1986 - mean_squared_error: 0.0575 - val_loss: 0.0496 - val_mean_absolute_error: 0.1786 - val_mean_squared_error: 0.0496
# Epoch 289/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0457 - mean_absolute_error: 0.1634 - mean_squared_error: 0.0457 - val_loss: 0.0545 - val_mean_absolute_error: 0.2025 - val_mean_squared_error: 0.0545
# Epoch 290/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0486 - mean_absolute_error: 0.1788 - mean_squared_error: 0.0486 - val_loss: 0.0788 - val_mean_absolute_error: 0.2458 - val_mean_squared_error: 0.0788
# Epoch 291/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0542 - mean_absolute_error: 0.1781 - mean_squared_error: 0.0542 - val_loss: 0.0309 - val_mean_absolute_error: 0.1489 - val_mean_squared_error: 0.0309
# Epoch 292/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0208 - mean_absolute_error: 0.1131 - mean_squared_error: 0.0208 - val_loss: 0.0381 - val_mean_absolute_error: 0.1572 - val_mean_squared_error: 0.0381
# Epoch 293/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0336 - mean_absolute_error: 0.1518 - mean_squared_error: 0.0336 - val_loss: 0.0782 - val_mean_absolute_error: 0.2133 - val_mean_squared_error: 0.0782
# Epoch 294/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0536 - mean_absolute_error: 0.1706 - mean_squared_error: 0.0536 - val_loss: 0.0432 - val_mean_absolute_error: 0.1642 - val_mean_squared_error: 0.0432
# Epoch 295/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0435 - mean_absolute_error: 0.1539 - mean_squared_error: 0.0435 - val_loss: 0.0166 - val_mean_absolute_error: 0.0896 - val_mean_squared_error: 0.0166
# Epoch 296/300
# 343/343 [==============================] - 1s 2ms/step - loss: 0.0159 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0159 - val_loss: 0.0279 - val_mean_absolute_error: 0.1172 - val_mean_squared_error: 0.0279
# Epoch 297/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0264 - mean_absolute_error: 0.1190 - mean_squared_error: 0.0264 - val_loss: 0.0747 - val_mean_absolute_error: 0.2488 - val_mean_squared_error: 0.0747
# Epoch 298/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0358 - mean_absolute_error: 0.1590 - mean_squared_error: 0.0358 - val_loss: 0.0682 - val_mean_absolute_error: 0.2261 - val_mean_squared_error: 0.0682
# Epoch 299/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0482 - mean_absolute_error: 0.1796 - mean_squared_error: 0.0482 - val_loss: 0.0165 - val_mean_absolute_error: 0.0916 - val_mean_squared_error: 0.0165
# Epoch 300/300
# 343/343 [==============================] - 0s 1ms/step - loss: 0.0856 - mean_absolute_error: 0.1783 - mean_squared_error: 0.0856 - val_loss: 0.0389 - val_mean_absolute_error: 0.1605 - val_mean_squared_error: 0.0389

# %%
hist = pd.DataFrame(history.history)
hist['epoch']= history.epoch
hist.tail()
# Out:
#      val_loss  val_mean_absolute_error  val_mean_squared_error      loss  \
# 295  0.029177                 0.115214                0.029177  0.017802
# 296  0.023944                 0.121841                0.023944  0.023745
# 297  0.030979                 0.125410                0.030979  0.032661
# 298  0.038187                 0.132907                0.038187  0.020232
# 299  0.025964                 0.116361                0.025964  0.018978
#
#      mean_absolute_error  mean_squared_error  epoch
# 295             0.102036            0.017802    295
# 296             0.119257            0.023745    296
# 297             0.138100            0.032661    297
# 298             0.102932            0.020232    298
# 299             0.106840            0.018978    299

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
    
  plt.figure(figsize=(13,9))
  #plt.figure()
  plt.xlabel('Epoch', fontsize= 18)
  plt.ylabel('Mean Abs Error', fontsize= 18)
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  plt.ylim([0,1.2])
  plt.tick_params(labelsize=20)
  plt.legend()
  

  plt.figure(figsize=(13,9))
  #plt.figure()
  plt.xlabel('Epoch', fontsize = 20)
  plt.ylabel('Mean Square Error', fontsize= 20)
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  plt.ylim([0,10])
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# **Save model**

# %%
test_predictions = model.predict([x_RVStrain, x_BPtrain, x_RPtrain])
print(np.shape(test_predictions))
print(np.shape(y_train_stack[:,0]))
print(np.shape(y_train_stack[:,1]))
plt.figure(figsize=(13,9))
plt.scatter((denormalize(y_train_stack[:,0], mean_teff_train, std_teff_train )), denormalize(test_predictions[:,0], mean_teff_train, std_teff_train), label= 'Teff')
#plt.scatter((denormalize(y_train_stack[:,1], mean_logg, std_logg)), denormalize(test_predictions[:,1], mean_logg, std_teff), label= 'Log(g)')
plt.xlabel('True Values [Teff]')
plt.ylabel('Predictions [Teff]')
#plt.axis('equal')
#plt.axis('square')
plt.legend()
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([3000, 30000], [3000, 30000])
plt.show()

#print('test predictions=', test_predictions)
# Out:
# (343, 2)
# (343,)
# (343,)

# %%
plt.figure(figsize=(13,9))
plt.scatter((denormalize(y_train_stack[:,1], mean_logg_train, std_logg_train)), denormalize(test_predictions[:,1], mean_logg_train, std_logg_train), label= 'Log(g)')
plt.xlabel('True Values [Teff]')
plt.ylabel('Predictions [Teff]')
_ = plt.plot([0, 5], [0, 5])
plt.legend()
plt.show()

# %%
#Unnormalizing the labels (teff)
''''
print(np.shape(y_train_stack[:,0]), y_train_stack[:,0])
print(np.shape(y_train_stack[:,1]))





plt.figure(figsize=(13,9))
test_predictions = model.predict([x_RVStrain, x_BPtrain, x_RPtrain])
print('shape of test_predictions:',np.shape(test_predictions))
print('print 10 elements of test_predictions:', test_predictions[0:10])
plt.scatter(denormalize(y_train_stack[:,0]), denormalize(test_predictions[:,0]), s= 4.0, c= 'r', label='Teff' )

print('teff',denormalize(y_train_stack[:,0]))
#plt.scatter(denormalize(y_train_stack[:,1]), denormalize(test_predictions[:,1]), s= 4.0, c= 'b', label='Log(g)' )
plt.xlabel(r"True", fontsize=25)
plt.ylabel(r"Prediction", fontsize=25)
plt.axis('equal')
plt.axis('square')
# increase the x,y tick label size
plt.tick_params(labelsize= 25) 
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-2, 4], [-2, 4], color='green')
plt.legend(fontsize=20)

'''''
# Out:
# '\'\nprint(np.shape(y_train_stack[:,0]), y_train_stack[:,0])\nprint(np.shape(y_train_stack[:,1]))\n\n\n\n\n\nplt.figure(figsize=(13,9))\ntest_predictions = model.predict([x_RVStrain, x_BPtrain, x_RPtrain])\nprint(\'shape of test_predictions:\',np.shape(test_predictions))\nprint(\'print 10 elements of test_predictions:\', test_predictions[0:10])\nplt.scatter(denormalize(y_train_stack[:,0]), denormalize(test_predictions[:,0]), s= 4.0, c= \'r\', label=\'Teff\' )\n\nprint(\'teff\',denormalize(y_train_stack[:,0]))\n#plt.scatter(denormalize(y_train_stack[:,1]), denormalize(test_predictions[:,1]), s= 4.0, c= \'b\', label=\'Log(g)\' )\nplt.xlabel(r"True", fontsize=25)\nplt.ylabel(r"Prediction", fontsize=25)\nplt.axis(\'equal\')\nplt.axis(\'square\')\n# increase the x,y tick label size\nplt.tick_params(labelsize= 25) \n#plt.xlim([0,plt.xlim()[1]])\n#plt.ylim([0,plt.ylim()[1]])\n_ = plt.plot([-2, 4], [-2, 4], color=\'green\')\nplt.legend(fontsize=20)\n\n'

# %%
#Making the histogram of denormalized training set 

plt.figure(figsize=(10,9))
data_teff=np.subtract(denormalize(y_train_stack[:,0], mean_teff_train, std_teff_train), denormalize(test_predictions[:,0], mean_teff_train, std_teff_train)) 
data_logg=np.subtract(denormalize(y_train_stack[:,1], mean_logg_train, std_logg_train), denormalize(test_predictions[:,1], mean_logg_train, std_logg_train)) 

counts_teff, bins_teff = np.histogram(data_teff)
counts_logg, bins_logg = np.histogram(data_logg)

#histogram for LogTeff
plt.hist(bins_teff[:-1], bins_teff, weights=counts_teff, label= r'$\rm T_{\rm eff}$')
plt.tick_params(labelsize=18) 
plt.xlabel(r'[Prediction-True]', fontsize=18)
plt.ylabel('Counts', fontsize=18)
plt.legend(fontsize=20)
plt.show()

#histogram for Log(g)
plt.figure(figsize=(10,9))
plt.hist(bins_logg[:-1], bins_logg, weights=counts_logg, label= 'log(g)', color='red')
plt.tick_params(labelsize=18) 
plt.xlabel(r'[Prediction-True]', fontsize=18)
plt.ylabel('Counts', fontsize=18)
plt.legend(fontsize=20)
plt.show()




#print('standard deviation', len(z))
#print(len(z[teff<5000]))
#print(len(z))

# %% [markdown]
# # Training Data Set

# %%
# getting deviation in Teff bins

teffbin_edges=np.array( [4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000])
nbin = len(teffbin_edges)


# pred vs. true
# unnormalised values
teff_pred = denormalize(test_predictions[:,0], mean_teff_train, std_teff_train)
teff_true = denormalize(y_train_stack[:,0], mean_teff_train, std_teff_train) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
teff_diff = teff_pred-teff_true

# compute mean and std in Teff bins
teff_diff_mean = np.zeros(nbin) 
teff_diff_std = np.zeros(nbin)
teffbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(teff_true<teffbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(teff_true>teffbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((teff_true>teffbin_edges[i-1]) & (teff_true<teffbin_edges[i]))
        #if i=1, teff_true>(teffbin_edges[1-1=0]= 5000) & teff_true<teffbin_edges[1]= 10000, so 5000<teff<10000
        #if i=2, teff_true>(teffbin_edges[2-1=1]=10000) & teff_true<teffbin_edges[2]= 15000, so 10000<teff<15000
        #if i=3, teff_true> (teffbin_edges[3-1=2]= 15000) & teff_true<teffbin_edges[3]= 20000 so 15000<teff<20000
    teffbin_mean[i] = np.mean(teff_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    teff_diff_mean[i] = np.mean(teff_diff[indx]) #calculating the mean values of teff_diff from its index 
    teff_diff_std[i] = np.std(teff_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin teff_true=', teffbin_mean)
print('mean of teff_diff=', teff_diff_mean)
print('std of teff_diff=', teff_diff_std)
print('length of teff_diff=', len(teff_diff))

####################################################################################################################
print('==========================================================================================================')
# getting deviation in Teff bins

loggbin_edges=np.array([  1, 2, 3, 4, 5])
nbin = len(loggbin_edges)

# pred vs. true
# unnormalised values
logg_pred = denormalize(test_predictions[:,1], mean_logg_train, std_logg_train)
logg_true = denormalize(y_train_stack[:,1], mean_logg_train, std_logg_train) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
logg_diff = logg_pred-logg_true

# compute mean and std in Teff bins
logg_diff_mean = np.zeros(nbin) 
logg_diff_std = np.zeros(nbin)
loggbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(logg_true<loggbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(logg_true>loggbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((logg_true>loggbin_edges[i-1]) & (logg_true<loggbin_edges[i]))

    loggbin_mean[i] = np.mean(logg_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    logg_diff_mean[i] = np.mean(logg_diff[indx]) #calculating the mean values of teff_diff from its index 
    logg_diff_std[i] = np.std(logg_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin logg_true=', loggbin_mean)
print('mean of logg_diff=', logg_diff_mean)
print('std of logg_diff=', logg_diff_std)
print('length of logg_diff=', len(logg_diff))
# Out:
# mean of bin teff_true= [ 3588.23529412  4351.35135135  5491.66666667  6526.31578947
#   7500.          8500.          9512.5        10515.625
#  11486.11111111 12500.         13500.         14500.
#  15500.         16500.         21861.11111111]
# mean of teff_diff= [-330.65326287 -600.60276341 -429.99150391 -402.4089227  -393.81933594
#  -310.12089844  -19.03500977  101.90228271  139.30848524  512.18782552
#   289.27597656  -30.53450521 -130.73486328 -317.30214844 -632.9031033 ]
# std of teff_diff= [372.49574366 251.61453103 178.22123783 134.3821498  112.81593822
#  184.11507143 226.47217442 307.10156168 320.07113506  40.02990698
#  240.0302022  262.36701076 227.90432037 319.91587455 260.48371993]
# length of teff_diff= 343
# ==========================================================================================================
# mean of bin logg_true= [0.25       1.5        2.5        3.5        4.75471698]
# mean of logg_diff= [ 0.14103559  0.09368173  0.1014102   0.04954101 -0.05962599]
# std of logg_diff= [0.20321446 0.18176205 0.22859355 0.20744997 0.18452922]
# length of logg_diff= 343

# %%
# plot of teff
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(teff_true, teff_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(teffbin_mean, teff_diff_mean, yerr=teff_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([3250, 11640.76923077])
ylim=np.array([-800, 800])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# set x, y label. 
plt.xlabel(r"$\rm T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$\rm T_{\rm eff,pred}-\rm T_{\rm eff,true}$ (K)", fontsize=18)

# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %%
#Plot log 
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(logg_true, logg_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(loggbin_mean,logg_diff_mean, yerr=logg_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=20) 

# set x, y label. 
#plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=18)
#plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([-0.7, 5.5])
ylim=np.array([-0.9, 0.5])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# draw y=0 line
xline = np.linspace(xlim[0], xlim[1],2 )
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# set x, y label. 
plt.xlabel(r"$\rm log(g)_{\rm true}$", fontsize=22)
plt.ylabel(r"$\rm log(g)_{\rm pred}-\rm log(g)_{\rm true}$", fontsize=22)



# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %% [markdown]
# # Cross Validation Set

# %%
#Test set (x_cv)

test_predictions = model.predict([x_RVScv, x_BPcv, x_RPcv])
print(np.shape(test_predictions))
print(np.shape(y_train_stack[:,0]))
print(np.shape(y_train_stack[:,1]))
plt.figure(figsize=(13,9))
plt.scatter((denormalize(y_cv_stack[:,0], mean_teff_train, std_teff_train )), denormalize(test_predictions[:,0], mean_teff_train, std_teff_train), label= 'Teff')
#plt.scatter((denormalize(y_train_stack[:,1], mean_logg, std_logg)), denormalize(test_predictions[:,1], mean_logg, std_teff), label= 'Log(g)')
plt.xlabel('True Values [Teff]')
plt.ylabel('Predictions [Teff]')
#plt.axis('equal')
#plt.axis('square')
plt.legend()
_ = plt.plot([3000, 30000], [3000, 30000])
plt.show()
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
#_ = plt.plot([1.4, 1.4], [1.4, 1.4])

#print('test predictions=', test_predictions)
# Out:
# (72, 2)
# (343,)
# (343,)

# %%
plt.figure(figsize=(13,9))
plt.scatter((denormalize(y_cv_stack[:,1], mean_logg_train, std_logg_train)), denormalize(test_predictions[:,1], mean_logg_train, std_logg_train), label= 'Log(g)')
plt.xlabel('True Values [Teff]')
plt.ylabel('Predictions [Teff]')
_ = plt.plot([0, 5], [0, 5])
plt.legend()
plt.show()

# %%
# getting deviation in Teff bins
teffbin_edges=np.array( [4000, 5000, 6000,  7000, 8000,  9000,  10000,  12000, 13000])
nbin = len(teffbin_edges)


# pred vs. true
# unnormalised values
teff_pred = denormalize(test_predictions[:,0], mean_teff_train, std_teff_train)
teff_true = denormalize(y_cv_stack[:,0], mean_teff_train, std_teff_train) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
teff_diff = teff_pred-teff_true

print(' Teff diff mean and std for Teff<11000=', np.mean(teff_diff[(teff_true>4000) & (teff_true<11000.0)]), 
      np.std(teff_diff[(teff_true>4000) & (teff_true<11000.0)]),
      len(teff_diff[(teff_true>4000) & (teff_true<11000.0)]))

# compute mean and std in Teff bins
teff_diff_mean = np.zeros(nbin) 
teff_diff_std = np.zeros(nbin)
teffbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(teff_true<teffbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(teff_true>teffbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((teff_true>teffbin_edges[i-1]) & (teff_true<teffbin_edges[i]))
        #if i=1, teff_true>(teffbin_edges[1-1=0]= 5000) & teff_true<teffbin_edges[1]= 10000, so 5000<teff<10000
        #if i=2, teff_true>(teffbin_edges[2-1=1]=10000) & teff_true<teffbin_edges[2]= 15000, so 10000<teff<15000
        #if i=3, teff_true> (teffbin_edges[3-1=2]= 15000) & teff_true<teffbin_edges[3]= 20000 so 15000<teff<20000
    teffbin_mean[i] = np.mean(teff_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    teff_diff_mean[i] = np.mean(teff_diff[indx]) #calculating the mean values of teff_diff from its index 
    teff_diff_std[i] = np.std(teff_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin teff_true=', teffbin_mean)
print('mean of teff_diff=', teff_diff_mean)
print('std of teff_diff=', teff_diff_std)
print('length of teff_diff=', len(teff_diff))

####################################################################################################################
print('==========================================================================================================')
# getting deviation in Teff bins

loggbin_edges=np.array([0, 2, 4, 6 ])
nbin = len(loggbin_edges)

# pred vs. true
# unnormalised values
logg_pred = denormalize(test_predictions[:,1], mean_logg_train, std_logg_train)
logg_true = denormalize(y_cv_stack[:,1], mean_logg_train, std_logg_train) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
logg_diff = logg_pred-logg_true

# compute mean and std in Teff bins
logg_diff_mean = np.zeros(nbin) 
logg_diff_std = np.zeros(nbin)
loggbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(logg_true<loggbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(logg_true>loggbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((logg_true>loggbin_edges[i-1]) & (logg_true<loggbin_edges[i]))

    loggbin_mean[i] = np.mean(logg_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    logg_diff_mean[i] = np.mean(logg_diff[indx]) #calculating the mean values of teff_diff from its index 
    logg_diff_std[i] = np.std(logg_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin logg_true=', loggbin_mean)
print('mean of logg_diff=', logg_diff_mean)
print('std of logg_diff=', logg_diff_std)
print('length of logg_diff=', len(logg_diff))
# Out:
#  Teff diff mean and std for Teff<11000= -403.21935183502904 258.3308374322839 43
# mean of bin teff_true= [ 3750.          4500.          5583.33333333  6437.5
#   7500.          8500.          9250.         10875.
#  17972.22222222]
# mean of teff_diff= [-641.15947266 -772.46254185 -536.44222005 -472.14263916 -348.77478027
#   -97.73535156 -117.96777344  -48.72717285 -154.1890191 ]
# std of teff_diff= [238.90650694 167.14141677 118.39816903 122.87895968  83.83721175
#    0.           0.         206.84671961 518.92745082]
# length of teff_diff= 72
# ==========================================================================================================
# mean of bin logg_true= [       nan 1.22727273 3.11111111 4.71875   ]
# mean of logg_diff= [        nan  0.1225091   0.12691219 -0.1707145 ]
# std of logg_diff= [       nan 0.26978186 0.31154441 0.22288812]
# length of logg_diff= 72

# %%
# plot of logteff
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(teff_true, teff_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(teffbin_mean, teff_diff_mean, yerr=teff_diff_std, fmt='o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([3250,  11725])
ylim=np.array([-1500, 2000])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# set x, y label. 
plt.xlabel(r"$\rm T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$\rm T_{\rm eff,pred}-\rm T_{\rm eff,true}$ (K)", fontsize=18)

# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %%
#Plot log 
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(logg_true, logg_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(loggbin_mean,logg_diff_mean, yerr=logg_diff_std, fmt='o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=20) 

# set x, y label. 
#plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=18)
#plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([-0.5, 5.5])
ylim=np.array([-0.7, 0.8])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# draw y=0 line
xline = np.linspace(xlim[0], xlim[1],2 )
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# set x, y label. 
plt.xlabel(r"$\rm log(g)_{\rm true}$", fontsize=22)
plt.ylabel(r"$\rm log(g)_{\rm pred}-\rm log(g)_{\rm true}$", fontsize=22)



# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %% [raw]
# # Another model
# From TheCNNon, https://github.com/adrn/TheCNNon/blob/master/notebooks/ThisIsCNNON.ipynb

# %%
# Input spectra
input_spec = Input(shape=(num_fluxes,), name='starnet_input_x')

# Reshape spectra for CNN layers
cur_in = Reshape((num_fluxes, 1))(input_spec)

# CNN layers
# First
cur_in = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=128, kernel_size=32)(cur_in) #first CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=32)(cur_in)
# Second CNN layer
cur_in = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=128, kernel_size=16)(cur_in) #2nd CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=16)(cur_in)
# Third CNN layer
cur_in = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=128, kernel_size=8)(cur_in) #2nd CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=8)(cur_in)

# Flatten the current input for the fully-connected layers
cur_in = Flatten()(cur_in)

# Fully-connected layers
cur_in = Dense(units=258, kernel_initializer=initializer, 
               activation=activation)(cur_in)
cur_in = Dense(units=128, kernel_initializer=initializer, 
               activation=activation)(cur_in)

# Output nodes
output_label = Dense(units=num_labels, kernel_regularizer=keras.regularizers.l2(0.01), activation="linear", 
                     input_dim=num_hidden[1])(cur_in)

model = Model(input_spec, output_label)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1658   try:
# -> 1659     c_op = c_api.TF_FinishOperation(op_desc)
#    1660   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Negative dimension size caused by subtracting 8 from 1 for 'max_pooling1d_12/MaxPool' (op: 'MaxPool') with input shapes: [?,1,1,128].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-07ed572f0f80> in <module>
#      20                 padding="same", filters=128, kernel_size=8)(cur_in) #2nd CNN layer
#      21 # Max pooling layer
# ---> 22 cur_in = MaxPooling1D(pool_size=8)(cur_in)
#      23
#      24 # Flatten the current input for the fully-connected layers
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     455             # Actually call the layer,
#     456             # collecting output(s), mask(s), and shape(s).
# --> 457             output = self.call(inputs, **kwargs)
#     458             output_mask = self.compute_mask(inputs, previous_mask)
#     459
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/pooling.py in call(self, inputs)
#      55                                         strides=self.strides + (1,),
#      56                                         padding=self.padding,
# ---> 57                                         data_format=self.data_format)
#      58         return K.squeeze(output, dummy_axis)  # remove dummy last dimension
#      59
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/pooling.py in _pooling_function(self, inputs, pool_size, strides, padding, data_format)
#     111                           padding, data_format):
#     112         output = K.pool2d(inputs, pool_size, strides,
# --> 113                           padding, data_format, pool_mode='max')
#     114         return output
#     115
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in pool2d(x, pool_size, strides, padding, data_format, pool_mode)
#    3976         x = tf.nn.max_pool(x, pool_size, strides,
#    3977                            padding=padding,
# -> 3978                            data_format=tf_data_format)
#    3979     elif pool_mode == 'avg':
#    3980         x = tf.nn.avg_pool(x, pool_size, strides,
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in max_pool(value, ksize, strides, padding, data_format, name)
#    2746         padding=padding,
#    2747         data_format=data_format,
# -> 2748         name=name)
#    2749
#    2750
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in max_pool(input, ksize, strides, padding, data_format, name)
#    5135   _, _, _op = _op_def_lib._apply_op_helper(
#    5136         "MaxPool", input=input, ksize=ksize, strides=strides, padding=padding,
# -> 5137                    data_format=data_format, name=name)
#    5138   _result = _op.outputs[:]
#    5139   _inputs_flat = _op.inputs
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     787                          input_types=input_types, attrs=attr_protos,
# --> 788                          op_def=op_def)
#     789       return output_structure, op_def.is_stateful, op
#     790
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(***failed resolving arguments***)
#    3298           input_types=input_types,
#    3299           original_op=self._default_original_op,
# -> 3300           op_def=op_def)
#    3301       self._create_op_helper(ret, compute_device=compute_device)
#    3302     return ret
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1821           op_def, inputs, node_def.attr)
#    1822       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1823                                 control_input_ops)
#    1824
#    1825     # Initialize self._outputs.
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1660   except errors.InvalidArgumentError as e:
#    1661     # Convert to ValueError for backwards compatibility.
# -> 1662     raise ValueError(str(e))
#    1663
#    1664   return c_op
#
# ValueError: Negative dimension size caused by subtracting 8 from 1 for 'max_pooling1d_12/MaxPool' (op: 'MaxPool') with input shapes: [?,1,1,128].

# %%
optimizer = Adam(lr=0.0005)

# %%
# loss function to minimize
loss_function = 'mean_squared_error'
optimizer = 'adadelta'
# compute mean absolute deviation
metrics = ['mae', 'mse']
#metrics = ['mae']
model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# starnet_input_x (InputLayer) (None, 6758)              0
# _________________________________________________________________
# reshape_10 (Reshape)         (None, 6758, 1)           0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 6758, 128)         4224
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 211, 128)          0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 211, 128)          262272
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 13, 128)           0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 13, 128)           131200
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 1, 128)            0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 258)               33282
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               33152
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 464,259
# Trainable params: 464,259
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, 
          epochs=max_epochs, validation_split = 0.2, verbose=1, shuffle='batch')
# Out:
# Train on 875 samples, validate on 219 samples
# Epoch 1/200
# 875/875 [==============================] - 13s 15ms/step - loss: 5.2174 - mean_absolute_error: 1.4147 - mean_squared_error: 5.1988 - val_loss: 1.5482 - val_mean_absolute_error: 0.9417 - val_mean_squared_error: 1.5305
# Epoch 2/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3955 - mean_absolute_error: 0.5094 - mean_squared_error: 0.3783 - val_loss: 1.8217 - val_mean_absolute_error: 1.0313 - val_mean_squared_error: 1.8050
# Epoch 3/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3606 - mean_absolute_error: 0.4579 - mean_squared_error: 0.3443 - val_loss: 1.9750 - val_mean_absolute_error: 1.0742 - val_mean_squared_error: 1.9589
# Epoch 4/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3806 - mean_absolute_error: 0.4960 - mean_squared_error: 0.3648 - val_loss: 2.0388 - val_mean_absolute_error: 1.0894 - val_mean_squared_error: 2.0232
# Epoch 5/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.4077 - mean_absolute_error: 0.4772 - mean_squared_error: 0.3923 - val_loss: 3.4660 - val_mean_absolute_error: 1.5366 - val_mean_squared_error: 3.4508
# Epoch 6/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.3888 - mean_absolute_error: 0.5023 - mean_squared_error: 0.3738 - val_loss: 3.0916 - val_mean_absolute_error: 1.4193 - val_mean_squared_error: 3.0766
# Epoch 7/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3001 - mean_absolute_error: 0.4360 - mean_squared_error: 0.2852 - val_loss: 3.7524 - val_mean_absolute_error: 1.6397 - val_mean_squared_error: 3.7377
# Epoch 8/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.2883 - mean_absolute_error: 0.4420 - mean_squared_error: 0.2736 - val_loss: 3.6873 - val_mean_absolute_error: 1.6205 - val_mean_squared_error: 3.6728
# Epoch 9/200
# 875/875 [==============================] - 22s 25ms/step - loss: 0.2976 - mean_absolute_error: 0.4493 - mean_squared_error: 0.2833 - val_loss: 3.8704 - val_mean_absolute_error: 1.6722 - val_mean_squared_error: 3.8562
# Epoch 10/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.2398 - mean_absolute_error: 0.3987 - mean_squared_error: 0.2256 - val_loss: 3.9370 - val_mean_absolute_error: 1.6926 - val_mean_squared_error: 3.9230
# Epoch 11/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.2136 - mean_absolute_error: 0.3585 - mean_squared_error: 0.1997 - val_loss: 3.5978 - val_mean_absolute_error: 1.5898 - val_mean_squared_error: 3.5840
# Epoch 12/200
# 875/875 [==============================] - 27s 31ms/step - loss: 0.2410 - mean_absolute_error: 0.3820 - mean_squared_error: 0.2274 - val_loss: 4.0983 - val_mean_absolute_error: 1.7393 - val_mean_squared_error: 4.0850
# Epoch 13/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.1661 - mean_absolute_error: 0.3015 - mean_squared_error: 0.1530 - val_loss: 2.8094 - val_mean_absolute_error: 1.3314 - val_mean_squared_error: 2.7965
# Epoch 14/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1630 - mean_absolute_error: 0.2858 - mean_squared_error: 0.1503 - val_loss: 3.9325 - val_mean_absolute_error: 1.6919 - val_mean_squared_error: 3.9201
# Epoch 15/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.1432 - mean_absolute_error: 0.2689 - mean_squared_error: 0.1311 - val_loss: 3.6180 - val_mean_absolute_error: 1.5971 - val_mean_squared_error: 3.6062
# Epoch 16/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1220 - mean_absolute_error: 0.2405 - mean_squared_error: 0.1106 - val_loss: 3.5919 - val_mean_absolute_error: 1.5885 - val_mean_squared_error: 3.5809
# Epoch 17/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1122 - mean_absolute_error: 0.2418 - mean_squared_error: 0.1015 - val_loss: 3.4441 - val_mean_absolute_error: 1.5411 - val_mean_squared_error: 3.4337
# Epoch 18/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1125 - mean_absolute_error: 0.2457 - mean_squared_error: 0.1025 - val_loss: 3.6328 - val_mean_absolute_error: 1.6010 - val_mean_squared_error: 3.6232
# Epoch 19/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1287 - mean_absolute_error: 0.2610 - mean_squared_error: 0.1194 - val_loss: 3.5788 - val_mean_absolute_error: 1.5843 - val_mean_squared_error: 3.5699
# Epoch 20/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0884 - mean_absolute_error: 0.2150 - mean_squared_error: 0.0797 - val_loss: 2.2024 - val_mean_absolute_error: 1.1457 - val_mean_squared_error: 2.1939
# Epoch 21/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1126 - mean_absolute_error: 0.2483 - mean_squared_error: 0.1043 - val_loss: 3.1658 - val_mean_absolute_error: 1.4498 - val_mean_squared_error: 3.1579
# Epoch 22/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0973 - mean_absolute_error: 0.2238 - mean_squared_error: 0.0895 - val_loss: 3.2924 - val_mean_absolute_error: 1.4950 - val_mean_squared_error: 3.2848
# Epoch 23/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0928 - mean_absolute_error: 0.2209 - mean_squared_error: 0.0853 - val_loss: 2.5891 - val_mean_absolute_error: 1.2693 - val_mean_squared_error: 2.5818
# Epoch 24/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1052 - mean_absolute_error: 0.2388 - mean_squared_error: 0.0981 - val_loss: 2.9058 - val_mean_absolute_error: 1.3614 - val_mean_squared_error: 2.8988
# Epoch 25/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1014 - mean_absolute_error: 0.2394 - mean_squared_error: 0.0945 - val_loss: 2.1955 - val_mean_absolute_error: 1.1433 - val_mean_squared_error: 2.1887
# Epoch 26/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1404 - mean_absolute_error: 0.2719 - mean_squared_error: 0.1338 - val_loss: 3.4146 - val_mean_absolute_error: 1.5348 - val_mean_squared_error: 3.4081
# Epoch 27/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0821 - mean_absolute_error: 0.2071 - mean_squared_error: 0.0757 - val_loss: 2.4974 - val_mean_absolute_error: 1.2405 - val_mean_squared_error: 2.4909
# Epoch 28/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0923 - mean_absolute_error: 0.2196 - mean_squared_error: 0.0859 - val_loss: 2.6382 - val_mean_absolute_error: 1.2849 - val_mean_squared_error: 2.6318
# Epoch 29/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0897 - mean_absolute_error: 0.2259 - mean_squared_error: 0.0834 - val_loss: 2.8831 - val_mean_absolute_error: 1.3586 - val_mean_squared_error: 2.8769
# Epoch 30/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0744 - mean_absolute_error: 0.1986 - mean_squared_error: 0.0682 - val_loss: 1.7850 - val_mean_absolute_error: 1.0208 - val_mean_squared_error: 1.7788
# Epoch 31/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1151 - mean_absolute_error: 0.2334 - mean_squared_error: 0.1090 - val_loss: 2.8941 - val_mean_absolute_error: 1.3617 - val_mean_squared_error: 2.8881
# Epoch 32/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0832 - mean_absolute_error: 0.2128 - mean_squared_error: 0.0773 - val_loss: 2.6767 - val_mean_absolute_error: 1.2974 - val_mean_squared_error: 2.6707
# Epoch 33/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0797 - mean_absolute_error: 0.2058 - mean_squared_error: 0.0738 - val_loss: 3.1776 - val_mean_absolute_error: 1.4555 - val_mean_squared_error: 3.1718
# Epoch 34/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0814 - mean_absolute_error: 0.2059 - mean_squared_error: 0.0757 - val_loss: 2.6626 - val_mean_absolute_error: 1.2925 - val_mean_squared_error: 2.6568
# Epoch 35/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0876 - mean_absolute_error: 0.2151 - mean_squared_error: 0.0819 - val_loss: 2.5699 - val_mean_absolute_error: 1.2623 - val_mean_squared_error: 2.5643
# Epoch 36/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1182 - mean_absolute_error: 0.2553 - mean_squared_error: 0.1126 - val_loss: 2.7674 - val_mean_absolute_error: 1.3285 - val_mean_squared_error: 2.7619
# Epoch 37/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0652 - mean_absolute_error: 0.1795 - mean_squared_error: 0.0597 - val_loss: 3.1619 - val_mean_absolute_error: 1.4543 - val_mean_squared_error: 3.1564
# Epoch 38/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0757 - mean_absolute_error: 0.2025 - mean_squared_error: 0.0703 - val_loss: 2.8025 - val_mean_absolute_error: 1.3408 - val_mean_squared_error: 2.7970
# Epoch 39/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0759 - mean_absolute_error: 0.2020 - mean_squared_error: 0.0705 - val_loss: 2.1523 - val_mean_absolute_error: 1.1254 - val_mean_squared_error: 2.1470
# Epoch 40/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0722 - mean_absolute_error: 0.1941 - mean_squared_error: 0.0669 - val_loss: 2.2233 - val_mean_absolute_error: 1.1493 - val_mean_squared_error: 2.2180
# Epoch 41/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0718 - mean_absolute_error: 0.1899 - mean_squared_error: 0.0666 - val_loss: 2.5742 - val_mean_absolute_error: 1.2647 - val_mean_squared_error: 2.5689
# Epoch 42/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0649 - mean_absolute_error: 0.1807 - mean_squared_error: 0.0597 - val_loss: 2.5939 - val_mean_absolute_error: 1.2684 - val_mean_squared_error: 2.5887
# Epoch 43/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0669 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0618 - val_loss: 2.8934 - val_mean_absolute_error: 1.3602 - val_mean_squared_error: 2.8883
# Epoch 44/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0709 - mean_absolute_error: 0.1983 - mean_squared_error: 0.0659 - val_loss: 2.5505 - val_mean_absolute_error: 1.2618 - val_mean_squared_error: 2.5456
# Epoch 45/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0694 - mean_absolute_error: 0.1891 - mean_squared_error: 0.0645 - val_loss: 2.9804 - val_mean_absolute_error: 1.3956 - val_mean_squared_error: 2.9755
# Epoch 46/200
# 875/875 [==============================] - 24s 28ms/step - loss: 0.0719 - mean_absolute_error: 0.1961 - mean_squared_error: 0.0670 - val_loss: 2.4074 - val_mean_absolute_error: 1.2118 - val_mean_squared_error: 2.4026
# Epoch 47/200
# 875/875 [==============================] - 24s 28ms/step - loss: 0.0618 - mean_absolute_error: 0.1743 - mean_squared_error: 0.0571 - val_loss: 2.2830 - val_mean_absolute_error: 1.1690 - val_mean_squared_error: 2.2782
# Epoch 48/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0676 - mean_absolute_error: 0.1821 - mean_squared_error: 0.0629 - val_loss: 2.6052 - val_mean_absolute_error: 1.2808 - val_mean_squared_error: 2.6005
# Epoch 49/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0630 - mean_absolute_error: 0.1787 - mean_squared_error: 0.0583 - val_loss: 2.4626 - val_mean_absolute_error: 1.2316 - val_mean_squared_error: 2.4579
# Epoch 50/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0601 - mean_absolute_error: 0.1661 - mean_squared_error: 0.0555 - val_loss: 2.7647 - val_mean_absolute_error: 1.3206 - val_mean_squared_error: 2.7601
# Epoch 51/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0643 - mean_absolute_error: 0.1779 - mean_squared_error: 0.0597 - val_loss: 2.5744 - val_mean_absolute_error: 1.2720 - val_mean_squared_error: 2.5698
# Epoch 52/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0919 - mean_absolute_error: 0.2229 - mean_squared_error: 0.0873 - val_loss: 2.5535 - val_mean_absolute_error: 1.2609 - val_mean_squared_error: 2.5490
# Epoch 53/200
# 875/875 [==============================] - 436s 498ms/step - loss: 0.0650 - mean_absolute_error: 0.1887 - mean_squared_error: 0.0605 - val_loss: 2.1651 - val_mean_absolute_error: 1.1289 - val_mean_squared_error: 2.1606
# Epoch 54/200
# 875/875 [==============================] - 116s 133ms/step - loss: 0.1022 - mean_absolute_error: 0.2107 - mean_squared_error: 0.0977 - val_loss: 2.2922 - val_mean_absolute_error: 1.1691 - val_mean_squared_error: 2.2878
# Epoch 55/200
# 875/875 [==============================] - 1980s 2s/step - loss: 0.0704 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0661 - val_loss: 2.6339 - val_mean_absolute_error: 1.2914 - val_mean_squared_error: 2.6296
# Epoch 56/200
# 875/875 [==============================] - 16s 18ms/step - loss: 0.0528 - mean_absolute_error: 0.1586 - mean_squared_error: 0.0485 - val_loss: 1.9749 - val_mean_absolute_error: 1.0711 - val_mean_squared_error: 1.9706
# Epoch 57/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0525 - mean_absolute_error: 0.1568 - mean_squared_error: 0.0482 - val_loss: 2.0850 - val_mean_absolute_error: 1.1014 - val_mean_squared_error: 2.0807
# Epoch 58/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0607 - mean_absolute_error: 0.1662 - mean_squared_error: 0.0565 - val_loss: 2.4774 - val_mean_absolute_error: 1.2292 - val_mean_squared_error: 2.4732
# Epoch 59/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0578 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0536 - val_loss: 2.1773 - val_mean_absolute_error: 1.1350 - val_mean_squared_error: 2.1730
# Epoch 60/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0521 - mean_absolute_error: 0.1542 - mean_squared_error: 0.0479 - val_loss: 2.2251 - val_mean_absolute_error: 1.1478 - val_mean_squared_error: 2.2209
# Epoch 61/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0482 - mean_absolute_error: 0.1538 - mean_squared_error: 0.0441 - val_loss: 2.4825 - val_mean_absolute_error: 1.2420 - val_mean_squared_error: 2.4783
# Epoch 62/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0498 - mean_absolute_error: 0.1520 - mean_squared_error: 0.0457 - val_loss: 2.2666 - val_mean_absolute_error: 1.1597 - val_mean_squared_error: 2.2624
# Epoch 63/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0545 - mean_absolute_error: 0.1639 - mean_squared_error: 0.0504 - val_loss: 2.0965 - val_mean_absolute_error: 1.1046 - val_mean_squared_error: 2.0924
# Epoch 64/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0453 - mean_absolute_error: 0.1479 - mean_squared_error: 0.0412 - val_loss: 2.0962 - val_mean_absolute_error: 1.1012 - val_mean_squared_error: 2.0921
# Epoch 65/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0569 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0528 - val_loss: 2.6018 - val_mean_absolute_error: 1.2822 - val_mean_squared_error: 2.5977
# Epoch 66/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0521 - mean_absolute_error: 0.1593 - mean_squared_error: 0.0481 - val_loss: 2.1614 - val_mean_absolute_error: 1.1230 - val_mean_squared_error: 2.1573
# Epoch 67/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0468 - mean_absolute_error: 0.1503 - mean_squared_error: 0.0427 - val_loss: 1.9528 - val_mean_absolute_error: 1.0605 - val_mean_squared_error: 1.9488
# Epoch 68/200
# 875/875 [==============================] - 14s 15ms/step - loss: 0.0550 - mean_absolute_error: 0.1625 - mean_squared_error: 0.0510 - val_loss: 1.6402 - val_mean_absolute_error: 0.9684 - val_mean_squared_error: 1.6361
# Epoch 69/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0675 - mean_absolute_error: 0.1783 - mean_squared_error: 0.0636 - val_loss: 1.6937 - val_mean_absolute_error: 0.9808 - val_mean_squared_error: 1.6898
# Epoch 70/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0504 - mean_absolute_error: 0.1465 - mean_squared_error: 0.0465 - val_loss: 1.8599 - val_mean_absolute_error: 1.0318 - val_mean_squared_error: 1.8560
# Epoch 71/200
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0540 - mean_absolute_error: 0.1642 - mean_squared_error: 0.0501 - val_loss: 1.9639 - val_mean_absolute_error: 1.0634 - val_mean_squared_error: 1.9600
# Epoch 72/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0399 - mean_absolute_error: 0.1346 - mean_squared_error: 0.0361 - val_loss: 1.6221 - val_mean_absolute_error: 0.9613 - val_mean_squared_error: 1.6183
# Epoch 73/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0413 - mean_absolute_error: 0.1380 - mean_squared_error: 0.0375 - val_loss: 1.5695 - val_mean_absolute_error: 0.9410 - val_mean_squared_error: 1.5657
# Epoch 74/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0508 - mean_absolute_error: 0.1554 - mean_squared_error: 0.0470 - val_loss: 1.6579 - val_mean_absolute_error: 0.9698 - val_mean_squared_error: 1.6541
# Epoch 75/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0419 - mean_absolute_error: 0.1415 - mean_squared_error: 0.0381 - val_loss: 1.9499 - val_mean_absolute_error: 1.0596 - val_mean_squared_error: 1.9461
# Epoch 76/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0503 - mean_absolute_error: 0.1572 - mean_squared_error: 0.0465 - val_loss: 1.8577 - val_mean_absolute_error: 1.0327 - val_mean_squared_error: 1.8540
# Epoch 77/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0476 - mean_absolute_error: 0.1527 - mean_squared_error: 0.0439 - val_loss: 1.7745 - val_mean_absolute_error: 1.0009 - val_mean_squared_error: 1.7708
# Epoch 78/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0451 - mean_absolute_error: 0.1489 - mean_squared_error: 0.0415 - val_loss: 2.0050 - val_mean_absolute_error: 1.0651 - val_mean_squared_error: 2.0014
# Epoch 79/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0440 - mean_absolute_error: 0.1435 - mean_squared_error: 0.0404 - val_loss: 2.0267 - val_mean_absolute_error: 1.0795 - val_mean_squared_error: 2.0231
# Epoch 80/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0364 - mean_absolute_error: 0.1310 - mean_squared_error: 0.0327 - val_loss: 1.8544 - val_mean_absolute_error: 1.0227 - val_mean_squared_error: 1.8507
# Epoch 81/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0374 - mean_absolute_error: 0.1308 - mean_squared_error: 0.0337 - val_loss: 2.1050 - val_mean_absolute_error: 1.0957 - val_mean_squared_error: 2.1014
# Epoch 82/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0405 - mean_absolute_error: 0.1369 - mean_squared_error: 0.0369 - val_loss: 2.0692 - val_mean_absolute_error: 1.0950 - val_mean_squared_error: 2.0656
# Epoch 83/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0377 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0341 - val_loss: 2.1537 - val_mean_absolute_error: 1.1251 - val_mean_squared_error: 2.1501
# Epoch 84/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0437 - mean_absolute_error: 0.1535 - mean_squared_error: 0.0401 - val_loss: 1.9010 - val_mean_absolute_error: 1.0358 - val_mean_squared_error: 1.8974
# Epoch 85/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0372 - mean_absolute_error: 0.1277 - mean_squared_error: 0.0336 - val_loss: 2.2669 - val_mean_absolute_error: 1.1700 - val_mean_squared_error: 2.2633
# Epoch 86/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0398 - mean_absolute_error: 0.1395 - mean_squared_error: 0.0363 - val_loss: 2.4500 - val_mean_absolute_error: 1.2285 - val_mean_squared_error: 2.4464
# Epoch 87/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0461 - mean_absolute_error: 0.1518 - mean_squared_error: 0.0426 - val_loss: 1.7367 - val_mean_absolute_error: 0.9874 - val_mean_squared_error: 1.7331
# Epoch 88/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0332 - mean_absolute_error: 0.1268 - mean_squared_error: 0.0296 - val_loss: 1.9588 - val_mean_absolute_error: 1.0607 - val_mean_squared_error: 1.9552
# Epoch 89/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0321 - mean_absolute_error: 0.1208 - mean_squared_error: 0.0286 - val_loss: 1.7206 - val_mean_absolute_error: 0.9780 - val_mean_squared_error: 1.7171
# Epoch 90/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0419 - mean_absolute_error: 0.1408 - mean_squared_error: 0.0384 - val_loss: 1.8123 - val_mean_absolute_error: 1.0004 - val_mean_squared_error: 1.8087
# Epoch 91/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0369 - mean_absolute_error: 0.1327 - mean_squared_error: 0.0334 - val_loss: 1.9241 - val_mean_absolute_error: 1.0326 - val_mean_squared_error: 1.9206
# Epoch 92/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0409 - mean_absolute_error: 0.1397 - mean_squared_error: 0.0374 - val_loss: 1.9379 - val_mean_absolute_error: 1.0506 - val_mean_squared_error: 1.9345
# Epoch 93/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0382 - mean_absolute_error: 0.1378 - mean_squared_error: 0.0347 - val_loss: 1.7358 - val_mean_absolute_error: 0.9827 - val_mean_squared_error: 1.7323
# Epoch 94/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0326 - mean_absolute_error: 0.1196 - mean_squared_error: 0.0292 - val_loss: 2.3345 - val_mean_absolute_error: 1.1833 - val_mean_squared_error: 2.3311
# Epoch 95/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0323 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0290 - val_loss: 1.7382 - val_mean_absolute_error: 0.9739 - val_mean_squared_error: 1.7348
# Epoch 96/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0350 - mean_absolute_error: 0.1280 - mean_squared_error: 0.0316 - val_loss: 2.1179 - val_mean_absolute_error: 1.1150 - val_mean_squared_error: 2.1145
# Epoch 97/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0421 - mean_absolute_error: 0.1314 - mean_squared_error: 0.0388 - val_loss: 1.6972 - val_mean_absolute_error: 0.9665 - val_mean_squared_error: 1.6939
# Epoch 98/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0352 - mean_absolute_error: 0.1298 - mean_squared_error: 0.0319 - val_loss: 1.6073 - val_mean_absolute_error: 0.9383 - val_mean_squared_error: 1.6039
# Epoch 99/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0366 - mean_absolute_error: 0.1250 - mean_squared_error: 0.0333 - val_loss: 1.6065 - val_mean_absolute_error: 0.9305 - val_mean_squared_error: 1.6031
# Epoch 100/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0383 - mean_absolute_error: 0.1360 - mean_squared_error: 0.0350 - val_loss: 1.5558 - val_mean_absolute_error: 0.9232 - val_mean_squared_error: 1.5524
# Epoch 101/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0360 - mean_absolute_error: 0.1306 - mean_squared_error: 0.0327 - val_loss: 1.7025 - val_mean_absolute_error: 0.9734 - val_mean_squared_error: 1.6992
# Epoch 102/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0343 - mean_absolute_error: 0.1262 - mean_squared_error: 0.0310 - val_loss: 1.6342 - val_mean_absolute_error: 0.9522 - val_mean_squared_error: 1.6309
# Epoch 103/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0292 - mean_absolute_error: 0.1137 - mean_squared_error: 0.0259 - val_loss: 1.6105 - val_mean_absolute_error: 0.9344 - val_mean_squared_error: 1.6073
# Epoch 104/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0303 - mean_absolute_error: 0.1176 - mean_squared_error: 0.0271 - val_loss: 1.7194 - val_mean_absolute_error: 0.9676 - val_mean_squared_error: 1.7162
# Epoch 105/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0335 - mean_absolute_error: 0.1217 - mean_squared_error: 0.0303 - val_loss: 1.9535 - val_mean_absolute_error: 1.0296 - val_mean_squared_error: 1.9503
# Epoch 106/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0304 - mean_absolute_error: 0.1168 - mean_squared_error: 0.0272 - val_loss: 1.7627 - val_mean_absolute_error: 0.9748 - val_mean_squared_error: 1.7595
# Epoch 107/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0285 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0254 - val_loss: 1.5525 - val_mean_absolute_error: 0.9117 - val_mean_squared_error: 1.5493
# Epoch 108/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0284 - mean_absolute_error: 0.1064 - mean_squared_error: 0.0253 - val_loss: 1.9490 - val_mean_absolute_error: 1.0553 - val_mean_squared_error: 1.9458
# Epoch 109/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0288 - mean_absolute_error: 0.1140 - mean_squared_error: 0.0257 - val_loss: 1.6905 - val_mean_absolute_error: 0.9528 - val_mean_squared_error: 1.6874
# Epoch 110/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0305 - mean_absolute_error: 0.1127 - mean_squared_error: 0.0274 - val_loss: 1.9716 - val_mean_absolute_error: 1.0641 - val_mean_squared_error: 1.9685
# Epoch 111/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0478 - mean_absolute_error: 0.1412 - mean_squared_error: 0.0447 - val_loss: 2.3680 - val_mean_absolute_error: 1.1940 - val_mean_squared_error: 2.3649
# Epoch 112/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0319 - mean_absolute_error: 0.1190 - mean_squared_error: 0.0288 - val_loss: 1.5907 - val_mean_absolute_error: 0.9276 - val_mean_squared_error: 1.5876
# Epoch 113/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0406 - mean_absolute_error: 0.1436 - mean_squared_error: 0.0376 - val_loss: 1.6303 - val_mean_absolute_error: 0.9397 - val_mean_squared_error: 1.6273
# Epoch 114/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0279 - mean_absolute_error: 0.1070 - mean_squared_error: 0.0248 - val_loss: 1.6271 - val_mean_absolute_error: 0.9349 - val_mean_squared_error: 1.6241
# Epoch 115/200
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0367 - mean_absolute_error: 0.1284 - mean_squared_error: 0.0337 - val_loss: 1.4954 - val_mean_absolute_error: 0.8941 - val_mean_squared_error: 1.4924
# Epoch 116/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0296 - mean_absolute_error: 0.1059 - mean_squared_error: 0.0267 - val_loss: 1.6060 - val_mean_absolute_error: 0.9296 - val_mean_squared_error: 1.6030
# Epoch 117/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0242 - mean_absolute_error: 0.1044 - mean_squared_error: 0.0212 - val_loss: 1.5665 - val_mean_absolute_error: 0.9125 - val_mean_squared_error: 1.5635
# Epoch 118/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0294 - mean_absolute_error: 0.1080 - mean_squared_error: 0.0264 - val_loss: 1.9528 - val_mean_absolute_error: 1.0536 - val_mean_squared_error: 1.9499
# Epoch 119/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0268 - mean_absolute_error: 0.1112 - mean_squared_error: 0.0238 - val_loss: 1.7776 - val_mean_absolute_error: 0.9920 - val_mean_squared_error: 1.7747
# Epoch 120/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0234 - mean_absolute_error: 0.0991 - mean_squared_error: 0.0204 - val_loss: 1.6669 - val_mean_absolute_error: 0.9537 - val_mean_squared_error: 1.6640
# Epoch 121/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0395 - mean_absolute_error: 0.1368 - mean_squared_error: 0.0366 - val_loss: 1.4784 - val_mean_absolute_error: 0.8891 - val_mean_squared_error: 1.4755
# Epoch 122/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0292 - mean_absolute_error: 0.1148 - mean_squared_error: 0.0263 - val_loss: 1.8647 - val_mean_absolute_error: 1.0212 - val_mean_squared_error: 1.8618
# Epoch 123/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0408 - mean_absolute_error: 0.1294 - mean_squared_error: 0.0379 - val_loss: 1.5569 - val_mean_absolute_error: 0.9142 - val_mean_squared_error: 1.5541
# Epoch 124/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0249 - mean_absolute_error: 0.1057 - mean_squared_error: 0.0221 - val_loss: 1.5006 - val_mean_absolute_error: 0.8936 - val_mean_squared_error: 1.4978
# Epoch 125/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0252 - mean_absolute_error: 0.1017 - mean_squared_error: 0.0223 - val_loss: 1.3502 - val_mean_absolute_error: 0.8432 - val_mean_squared_error: 1.3474
# Epoch 126/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0328 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0300 - val_loss: 1.4099 - val_mean_absolute_error: 0.8643 - val_mean_squared_error: 1.4071
# Epoch 127/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0238 - mean_absolute_error: 0.1068 - mean_squared_error: 0.0210 - val_loss: 1.4231 - val_mean_absolute_error: 0.8624 - val_mean_squared_error: 1.4203
# Epoch 128/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0268 - mean_absolute_error: 0.1065 - mean_squared_error: 0.0240 - val_loss: 1.4367 - val_mean_absolute_error: 0.8706 - val_mean_squared_error: 1.4338
# Epoch 129/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0227 - mean_absolute_error: 0.0965 - mean_squared_error: 0.0199 - val_loss: 1.5391 - val_mean_absolute_error: 0.8931 - val_mean_squared_error: 1.5364
# Epoch 130/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0343 - mean_absolute_error: 0.1239 - mean_squared_error: 0.0315 - val_loss: 1.4705 - val_mean_absolute_error: 0.8828 - val_mean_squared_error: 1.4677
# Epoch 131/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0280 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0253 - val_loss: 1.5932 - val_mean_absolute_error: 0.9133 - val_mean_squared_error: 1.5905
# Epoch 132/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0277 - mean_absolute_error: 0.1139 - mean_squared_error: 0.0250 - val_loss: 1.7935 - val_mean_absolute_error: 0.9983 - val_mean_squared_error: 1.7908
# Epoch 133/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0322 - mean_absolute_error: 0.1160 - mean_squared_error: 0.0295 - val_loss: 1.4766 - val_mean_absolute_error: 0.8801 - val_mean_squared_error: 1.4739
# Epoch 134/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0253 - mean_absolute_error: 0.1060 - mean_squared_error: 0.0226 - val_loss: 1.5339 - val_mean_absolute_error: 0.9065 - val_mean_squared_error: 1.5312
# Epoch 135/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0261 - mean_absolute_error: 0.1125 - mean_squared_error: 0.0234 - val_loss: 1.4380 - val_mean_absolute_error: 0.8710 - val_mean_squared_error: 1.4353
# Epoch 136/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0576 - mean_absolute_error: 0.1493 - mean_squared_error: 0.0549 - val_loss: 1.3447 - val_mean_absolute_error: 0.8465 - val_mean_squared_error: 1.3421
# Epoch 137/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0333 - mean_absolute_error: 0.1154 - mean_squared_error: 0.0307 - val_loss: 1.3273 - val_mean_absolute_error: 0.8353 - val_mean_squared_error: 1.3247
# Epoch 138/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0271 - mean_absolute_error: 0.1111 - mean_squared_error: 0.0245 - val_loss: 1.2775 - val_mean_absolute_error: 0.8230 - val_mean_squared_error: 1.2748
# Epoch 139/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0230 - mean_absolute_error: 0.0956 - mean_squared_error: 0.0204 - val_loss: 1.3633 - val_mean_absolute_error: 0.8381 - val_mean_squared_error: 1.3607
# Epoch 140/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0225 - mean_absolute_error: 0.1048 - mean_squared_error: 0.0199 - val_loss: 1.3127 - val_mean_absolute_error: 0.8349 - val_mean_squared_error: 1.3100
# Epoch 141/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0185 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0159 - val_loss: 1.3691 - val_mean_absolute_error: 0.8287 - val_mean_squared_error: 1.3664
# Epoch 142/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0267 - mean_absolute_error: 0.1066 - mean_squared_error: 0.0241 - val_loss: 1.3541 - val_mean_absolute_error: 0.8321 - val_mean_squared_error: 1.3514
# Epoch 143/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0540 - mean_absolute_error: 0.1430 - mean_squared_error: 0.0514 - val_loss: 1.8749 - val_mean_absolute_error: 1.0292 - val_mean_squared_error: 1.8723
# Epoch 144/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0324 - mean_absolute_error: 0.1221 - mean_squared_error: 0.0298 - val_loss: 1.3159 - val_mean_absolute_error: 0.8185 - val_mean_squared_error: 1.3133
# Epoch 145/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0255 - mean_absolute_error: 0.0968 - mean_squared_error: 0.0230 - val_loss: 1.3150 - val_mean_absolute_error: 0.8193 - val_mean_squared_error: 1.3124
# Epoch 146/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0254 - mean_absolute_error: 0.1047 - mean_squared_error: 0.0229 - val_loss: 1.2388 - val_mean_absolute_error: 0.8109 - val_mean_squared_error: 1.2363
# Epoch 147/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0228 - mean_absolute_error: 0.0953 - mean_squared_error: 0.0203 - val_loss: 1.3844 - val_mean_absolute_error: 0.8388 - val_mean_squared_error: 1.3819
# Epoch 148/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0183 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0158 - val_loss: 1.4506 - val_mean_absolute_error: 0.8512 - val_mean_squared_error: 1.4481
# Epoch 149/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0226 - mean_absolute_error: 0.1001 - mean_squared_error: 0.0201 - val_loss: 1.2548 - val_mean_absolute_error: 0.8096 - val_mean_squared_error: 1.2523
# Epoch 150/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0166 - mean_absolute_error: 0.0821 - mean_squared_error: 0.0141 - val_loss: 1.3095 - val_mean_absolute_error: 0.8080 - val_mean_squared_error: 1.3069
# Epoch 151/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0236 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0211 - val_loss: 1.2904 - val_mean_absolute_error: 0.8212 - val_mean_squared_error: 1.2879
# Epoch 152/200
# 736/875 [========================>.....] - ETA: 1s - loss: 0.0236 - mean_absolute_error: 0.0999 - mean_squared_error: 0.0210

# %%
hist = pd.DataFrame(history.history)
hist['epoch']= history.epoch
hist.tail()
# Out:
#          val_loss  val_mean_absolute_error  val_mean_squared_error  \
# 195  6.650632e+07              6355.818481            6.650632e+07
# 196  6.275853e+07              6161.197162            6.275853e+07
# 197  5.944006e+07              5997.135702            5.944006e+07
# 198  6.229281e+07              6138.579988            6.229281e+07
# 199  6.106594e+07              6076.085226            6.106594e+07
#
#              loss  mean_absolute_error  mean_squared_error  epoch
# 195  1.702399e+06           881.769361        1.702399e+06    195
# 196  1.711892e+06           930.596856        1.711892e+06    196
# 197  1.580298e+06           893.164042        1.580298e+06    197
# 198  1.912179e+06           979.157146        1.912179e+06    198
# 199  1.614590e+06           912.569914        1.614590e+06    199

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  #plt.ylim([0,5])
  plt.legend()
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  #plt.ylim([0,20])
  plt.legend()
  plt.show()


plot_history(history)

# %%
test_predictions = model.predict(norm_flux).flatten()

plt.scatter(normalize(teff), test_predictions)
plt.xlabel('True Values [Teff]')
plt.ylabel('Predictions [Teff]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

print('test predictions=', test_predictions)
# Out:
# test predictions= [ 6836.807   6837.5747  6836.7603 ... 10159.98   12968.633  12631.623 ]
