# %% [markdown]
# # Train the StarNet Model
#
# This notebook takes you through the steps of how to train a StarNet Model
# - Required Python packages: `numpy h5py keras`
# - Required data files: training_data.h5, mean_and_std.npy
#
# Note: We use tensorflow for the keras backend.

# %%
import numpy as np
import h5py
import random
import keras
from keras.models import Model
from keras.layers import Input, Dense, InputLayer, Flatten, Reshape, Concatenate, concatenate
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.optimizers import Adam
import tensorflow as tf
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.utils import HDF5Matrix
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc


#Loading the data

#RVSFlux normalized
pathrvs = 'norm_rvsflux.h5'
readrvs = h5py.File(pathrvs, 'r')
print(readrvs.keys())
rvs = readrvs.get('normrvs')
norm_rvsflux = np.array(rvs)
readrvs.close()

type(rvs)
print('shape of rvsflux:', np.shape(norm_rvsflux))
# Out:
# Using TensorFlow backend.
# <KeysViewHDF5 ['normrvs']>
# shape of rvsflux: (415, 1134)

# %%
#BPFlux
pathbp = 'bpfluxsnr.h5'
readbp = h5py.File(pathbp, 'r')
#print('total number of wave and flux in the folder:'len(readbp.keys()))
bpflux = readbp.get('bpflux0')
bpflux = np.array(bpflux)


norm_bpflux= []

for ii in range(np.shape(norm_rvsflux)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star #',ii)
        fluxlabel = 'bpflux'+str(ii)
        wavelabel = 'bpwave' +str(ii)
        flux = readbp.get(fluxlabel)
        wave= readbp.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_bpflux.append(normflux)


        
norm_bpflux= np.array(norm_bpflux)

print('shape of norm bpflux:', np.shape(norm_bpflux))
#print('shape of norm bpflux:', print(norm_bpflux[0:10]))
# Out:
# shape of norm bpflux: (415, 53)

# %%
#RPFlux
pathrp = 'rpfluxsnr.h5'
readrp = h5py.File(pathrp, 'r')
#print('total number of wave and flux in the folder:'len(readbp.keys()))
rpflux = readrp.get('rpflux0')
rpflux = np.array(rpflux)


norm_rpflux= []

for ii in range(np.shape(norm_rvsflux)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star:',ii)
        fluxlabel = 'rpflux'+str(ii)
        wavelabel = 'rpwave' +str(ii)
        
        flux = readrp.get(fluxlabel)
        wave= readrp.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_rpflux.append(normflux)


        
norm_rpflux= np.array(norm_rpflux)

print('shape of norm_rpflux:', np.shape(norm_rpflux))
#print('output of norm_flux:', print(norm_rpflux[0:10]))

#print('The shapes of features and labels:', np.shape(norm_flux), np.shape(logteff))
# Out:
# shape of norm_rpflux: (415, 49)

# %%
#LogTeff
modparam = 'modparam_feh0.h5' #model parameters includes log g and teff
readfile = h5py.File(modparam, 'r')
print(readfile.keys())
teff = readfile.get('teff')
teff = np.array(teff)
readfile.close()
# Out:
# <KeysViewHDF5 ['logg', 'teff']>

# %%
#features
num_tot = len(teff)
print('total number of input stars =', num_tot)
plim = 0.8
ran_frac = np.random.uniform(0,1,num_tot)
#print('ranfrac=' , ran_frac)




#Input flux data of RVS, BP, RP
x_RVStrain = norm_rvsflux[ran_frac < plim, :]
print('number of RVS training data=', len(x_RVStrain[:,0]))
x_RVScv = norm_rvsflux[ran_frac >= plim, :] #test set we left for the application

x_BPtrain = norm_bpflux[ran_frac < plim, :]
print('number of BP training data=', len(x_BPtrain[:,0]))
x_BPcv = norm_bpflux[ran_frac >= plim, :]

x_RPtrain =norm_rpflux[ran_frac < plim, :]
print('number of RP training data=', len(x_RPtrain[:,0]))
x_RPcv = norm_rpflux[ran_frac >= plim, :]


#print('x_BPtrain', x_BPtrain)

#x_train_combined = np.vstack (x_RVStrain[0,:],x_RPtrain[0,:]) 

#output label which is the logteff
y_train = teff[ran_frac< plim]
y_cv = teff[ran_frac >= plim] #test set


print('The size of CVS for the input flux data')
print('RVS cvs=', np.shape(x_RVScv))
print('BP cvs=', np.shape(x_BPcv))
print('RP cvs=', np.shape(x_RPcv))

print('the size of output label=', np.shape(y_cv) )

id = np.linspace(0, len(x_RVStrain[:, 0])-1, len(x_RVStrain[:, 0]))
plt.plot(id, y_train)
plt.show()
# Out:
# total number of input stars = 415
# number of RVS training data= 339
# number of BP training data= 339
# number of RP training data= 339
# The size of CVS for the input flux data
# RVS cvs= (76, 1134)
# BP cvs= (76, 53)
# RP cvs= (76, 49)
# the size of output label= (76,)

# %% [markdown]
# ** Normalization **
#
# Write a function to normalize the output labels. Each label will be normalized to have approximately have a mean of zero and unit variance.
#
# NOTE: This is necessary to put output labels on a similar scale in order for the model to train properly, this process is reversed in the test stage to give the output labels their proper units

# %%
mean_labels=np.mean(teff)
std_labels=np.std(teff)
print('mean and std teff=', mean_labels, std_labels)
def normalize(labels):
    # Normalize labels
    return (labels-mean_labels) / std_labels
# Out:
# mean and std teff= 10329.518072289156 6040.002374453865

# %%
#normalize the y labels 
#print('y train before norm=', y_train )
y_train= normalize(y_train)
y_cv= normalize(y_cv)
#print('y train after norm=', y_train )

# %% [markdown]
# **Build the StarNet model architecture**
#
# The StarNet architecture is built with:
# - input layer
# - 2 convolutional layers
# - 1 maxpooling layer followed by flattening for the fully connected layer
# - 2 fully connected layers
# - output layer
#
# First, let's define some model variables.

# %%
# activation function used following every layer except for the output layers
activation = 'relu'

# model weight initializer
initializer = 'he_normal'

# number of filters used in the convolutional layers
#num_filters = [4,16]
num_filters = [8,32]
#num_filters = [8,16]

# length of the filters in the convolutional layers
#filter_length = 8
#filter_length = 16
filter_length = 8

# length of the maxpooling window 
pool_length = 4

# number of nodes in each of the hidden fully connected layers
num_hidden = [256,128]
#num_hidden = [24,12]

# number of spectra fed into model at once during training
batch_size = 64

# maximum number of interations for model training
#max_epochs = 200
#max_epochs = 100
#max_epochs = 150 
#max_epochs = 350
#max_epochs = 225
#max_epochs = 180
#max_epochs = 450
#max_epochs = 300
max_epochs = 180


# initial learning rate for optimization algorithm
lr = 0.000003 #handled by Adam
    
# exponential decay rate for the 1st moment estimates for optimization algorithm
beta_1 = 0.9

# exponential decay rate for the 2nd moment estimates for optimization algorithm
beta_2 = 0.999

# a small constant for numerical stability for optimization algorithm
optimizer_epsilon = 1e-08

# %%
num_RVSfluxes=len(x_RVStrain[0,:]) 
print('number of RVS fluxes=', num_RVSfluxes)

num_BPfluxes=len(x_BPtrain[0,:]) 
print('number of BP fluxes=', num_BPfluxes)

num_RPfluxes=len(x_RPtrain[0,:]) 
print('number of RP fluxes=', num_RPfluxes)

num_labels= 1
print('number of training teff=', num_labels)

#ilam = np.linspace(0, num_fluxes-1, num_fluxes)
#plt.plot(ilam, x_train[329, :])
#plt.plot()

#iy = np.linspace(0, len(y_train)-1, len(y_train))
#plt.plot(iy, y_train)
#plt.plot()
# Out:
# number of RVS fluxes= 1134
# number of BP fluxes= 53
# number of RP fluxes= 49
# number of training teff= 1

# %%
first_input = Input(shape=(2, ))
first_dense = Dense(1, )(first_input)

second_input = Input(shape=(2, ))
second_dense = Dense(1, )(second_input)

merge_one = concatenate([first_dense, second_dense])

model = Model(inputs=[first_input, second_input], outputs=merge_one)

# %%
# Input RVS spectra
# print(' num_RVSfluxes=', num_RVSfluxes)
input_RVSspec = Input(shape=(num_RVSfluxes,), name='rvs_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for RVS layers
cur_rvs = Reshape((num_RVSfluxes, 1))(input_RVSspec)

# CNN layers
cur_rvs = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_rvs) #first CNN layer
cur_rvs = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_rvs) #2nd CNN layer

# Max pooling layer
cur_rvs = MaxPooling1D(pool_size=pool_length)(cur_rvs)

# Flatten the current input for the fully-connected layers
cur_rvs = Flatten()(cur_rvs)


##############################################################################################


# Input BP spectra
# print(' num_BPfluxes=', num_BPfluxes)
input_BPspec = Input(shape=(num_BPfluxes,), name='bp_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for BP layers
cur_bp = Reshape((num_BPfluxes, 1))(input_BPspec)

# CNN layers
cur_bp = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_bp) #first CNN layer
cur_bp = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_bp) #2nd CNN layer

# Max pooling layer
cur_bp = MaxPooling1D(pool_size=pool_length)(cur_bp)


# Flatten the current input for the fully-connected layers
cur_bp = Flatten()(cur_bp)


################################################################################################

# Input RP spectra
input_RPspec = Input(shape=(num_RPfluxes,), name='rp_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for CNN layers
cur_rp = Reshape((num_RPfluxes, 1))(input_RPspec)

# CNN layers
cur_rp = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_rp) #first CNN layer
cur_rp = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_rp) #2nd CNN layer

# Max pooling layer
cur_rp = MaxPooling1D(pool_size=pool_length)(cur_rp)

# Flatten the current input for the fully-connected layers
cur_rp = Flatten()(cur_rp)

###############################################################################################

#concatenate RVS/BP/RP and then insert it to dense layer 

cur_comb = concatenate([cur_rvs, cur_bp, cur_rp])

# Fully-connected layers
cur_final = Dense(units=num_hidden[0], kernel_initializer=initializer, 
               activation=activation)(cur_comb)
cur_final = Dense(units=num_hidden[1], kernel_initializer=initializer, 
               activation=activation)(cur_final)

# Output nodes
output_final = Dense(units=num_labels, activation="linear", 
                    input_dim=num_hidden[1], name='output_y')(cur_final)


model = Model(inputs = [input_RVSspec, input_BPspec, input_RPspec], outputs=output_final)
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# **More model techniques**
# * The `Adam` optimizer is the gradient descent algorithm used for minimizing the loss function
# * `EarlyStopping` uses the cross-validation set to test the model following every iteration and stops the training if the cv loss does not decrease by `min_delta` after `patience` iterations
# * `ReduceLROnPlateau` is a form of learning rate decay where the learning rate is decreased by a factor of `factor` if the training loss does not decrease by `epsilon` after `patience` iterations unless the learning rate has reached `min_lr`

# %%
# Default loss function parameters
early_stopping_min_delta = 0.0007
early_stopping_patience = 4
reduce_lr_factor = 0.5
reuce_lr_epsilon = 0.0000009
reduce_lr_patience = 2
reduce_lr_min = 0.00008

# loss function to minimize
loss_function = 'mean_squared_error'

# compute mean absolute deviation
metrics = ['mae', 'mse']
#metrics = ['mae']

# %%
#optimizer = Adam(lr=lr, beta_1=beta_1, beta_2=beta_2, epsilon=optimizer_epsilon, decay=0.0)
optimizer = Adam(lr=0.005 )

early_stopping = EarlyStopping(monitor='val_loss', min_delta=early_stopping_min_delta, 
                                       patience=early_stopping_patience, verbose=2, mode='min')

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, epsilon=reuce_lr_epsilon, 
                                  patience=reduce_lr_patience, min_lr=reduce_lr_min, mode='min', verbose=2)
# Out:
# /anaconda3/lib/python3.6/site-packages/keras/callbacks.py:1065: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '

# %% [markdown]
# **Compile model**

# %%
model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# rvs_input_x (InputLayer)        (None, 1134)         0
# __________________________________________________________________________________________________
# bp_input_x (InputLayer)         (None, 53)           0
# __________________________________________________________________________________________________
# rp_input_x (InputLayer)         (None, 49)           0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1134, 1)      0           rvs_input_x[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 53, 1)        0           bp_input_x[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 49, 1)        0           rp_input_x[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 1134, 8)      72          reshape_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 53, 8)        72          reshape_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 49, 8)        72          reshape_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 1134, 32)     2080        conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 53, 32)       2080        conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 49, 32)       2080        conv1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 283, 32)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 13, 32)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 12, 32)       0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 9056)         0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 416)          0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 384)          0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 9856)         0           flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          2523392     concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          32896       dense_1[0][0]
# __________________________________________________________________________________________________
# output_y (Dense)                (None, 1)            129         dense_2[0][0]
# ==================================================================================================
# Total params: 2,562,873
# Trainable params: 2,562,873
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Train model**

# %%
#history = model.fit(x_train, y_train, validation_data=(x_cv, y_cv),
          #epochs=max_epochs, verbose=1, shuffle='batch',
         #callbacks=[early_stopping, reduce_lr])

history = model.fit([x_RVStrain, x_BPtrain, x_RPtrain], y_train, validation_data=([x_RVScv, x_BPcv, x_RPcv], y_cv),
          epochs=max_epochs, verbose=1, shuffle='batch')
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 339 samples, validate on 76 samples
# Epoch 1/180
# 339/339 [==============================] - 2s 6ms/step - loss: 331.5175 - mean_absolute_error: 9.4097 - mean_squared_error: 331.5175 - val_loss: 7.3719 - val_mean_absolute_error: 2.5384 - val_mean_squared_error: 7.3719
# Epoch 2/180
# 339/339 [==============================] - 0s 1ms/step - loss: 4.7734 - mean_absolute_error: 1.8985 - mean_squared_error: 4.7734 - val_loss: 2.1890 - val_mean_absolute_error: 1.3506 - val_mean_squared_error: 2.1890
# Epoch 3/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.9548 - mean_absolute_error: 0.8326 - mean_squared_error: 0.9548 - val_loss: 3.9288 - val_mean_absolute_error: 1.8564 - val_mean_squared_error: 3.9288
# Epoch 4/180
# 339/339 [==============================] - 1s 2ms/step - loss: 2.0127 - mean_absolute_error: 1.1315 - mean_squared_error: 2.0127 - val_loss: 1.2061 - val_mean_absolute_error: 0.7633 - val_mean_squared_error: 1.2061
# Epoch 5/180
# 339/339 [==============================] - 0s 1ms/step - loss: 1.0950 - mean_absolute_error: 0.8460 - mean_squared_error: 1.0950 - val_loss: 0.5468 - val_mean_absolute_error: 0.5549 - val_mean_squared_error: 0.5468
# Epoch 6/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.6381 - mean_absolute_error: 0.5570 - mean_squared_error: 0.6381 - val_loss: 0.7408 - val_mean_absolute_error: 0.7830 - val_mean_squared_error: 0.7408
# Epoch 7/180
# 339/339 [==============================] - 0s 1ms/step - loss: 1.2041 - mean_absolute_error: 0.9193 - mean_squared_error: 1.2041 - val_loss: 0.2396 - val_mean_absolute_error: 0.2659 - val_mean_squared_error: 0.2396
# Epoch 8/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.7399 - mean_absolute_error: 0.6844 - mean_squared_error: 0.7399 - val_loss: 0.2139 - val_mean_absolute_error: 0.2534 - val_mean_squared_error: 0.2139
# Epoch 9/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.2543 - mean_absolute_error: 0.3571 - mean_squared_error: 0.2543 - val_loss: 0.1199 - val_mean_absolute_error: 0.2288 - val_mean_squared_error: 0.1199
# Epoch 10/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1540 - mean_absolute_error: 0.2965 - mean_squared_error: 0.1540 - val_loss: 0.0951 - val_mean_absolute_error: 0.2487 - val_mean_squared_error: 0.0951
# Epoch 11/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1207 - mean_absolute_error: 0.2733 - mean_squared_error: 0.1207 - val_loss: 0.0888 - val_mean_absolute_error: 0.2508 - val_mean_squared_error: 0.0888
# Epoch 12/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1296 - mean_absolute_error: 0.2673 - mean_squared_error: 0.1296 - val_loss: 0.0534 - val_mean_absolute_error: 0.1776 - val_mean_squared_error: 0.0534
# Epoch 13/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1844 - mean_absolute_error: 0.2996 - mean_squared_error: 0.1844 - val_loss: 0.0427 - val_mean_absolute_error: 0.1665 - val_mean_squared_error: 0.0427
# Epoch 14/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.3539 - mean_absolute_error: 0.4605 - mean_squared_error: 0.3539 - val_loss: 0.0436 - val_mean_absolute_error: 0.1399 - val_mean_squared_error: 0.0436
# Epoch 15/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.3307 - mean_absolute_error: 0.5066 - mean_squared_error: 0.3307 - val_loss: 0.1370 - val_mean_absolute_error: 0.3051 - val_mean_squared_error: 0.1370
# Epoch 16/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1294 - mean_absolute_error: 0.2757 - mean_squared_error: 0.1294 - val_loss: 0.0274 - val_mean_absolute_error: 0.1333 - val_mean_squared_error: 0.0274
# Epoch 17/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1169 - mean_absolute_error: 0.2527 - mean_squared_error: 0.1169 - val_loss: 0.0323 - val_mean_absolute_error: 0.1239 - val_mean_squared_error: 0.0323
# Epoch 18/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1120 - mean_absolute_error: 0.2637 - mean_squared_error: 0.1120 - val_loss: 0.0703 - val_mean_absolute_error: 0.2326 - val_mean_squared_error: 0.0703
# Epoch 19/180
# 339/339 [==============================] - 1s 1ms/step - loss: 0.0745 - mean_absolute_error: 0.2021 - mean_squared_error: 0.0745 - val_loss: 0.0332 - val_mean_absolute_error: 0.1457 - val_mean_squared_error: 0.0332
# Epoch 20/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0338 - mean_absolute_error: 0.1361 - mean_squared_error: 0.0338 - val_loss: 0.0198 - val_mean_absolute_error: 0.1057 - val_mean_squared_error: 0.0198
# Epoch 21/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0426 - mean_absolute_error: 0.1582 - mean_squared_error: 0.0426 - val_loss: 0.0523 - val_mean_absolute_error: 0.2001 - val_mean_squared_error: 0.0523
# Epoch 22/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1088 - mean_absolute_error: 0.2450 - mean_squared_error: 0.1088 - val_loss: 0.0168 - val_mean_absolute_error: 0.1048 - val_mean_squared_error: 0.0168
# Epoch 23/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0778 - mean_absolute_error: 0.2256 - mean_squared_error: 0.0778 - val_loss: 0.0168 - val_mean_absolute_error: 0.1052 - val_mean_squared_error: 0.0168
# Epoch 24/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0436 - mean_absolute_error: 0.1685 - mean_squared_error: 0.0436 - val_loss: 0.0542 - val_mean_absolute_error: 0.2109 - val_mean_squared_error: 0.0542
# Epoch 25/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0859 - mean_absolute_error: 0.2360 - mean_squared_error: 0.0859 - val_loss: 0.0584 - val_mean_absolute_error: 0.2102 - val_mean_squared_error: 0.0584
# Epoch 26/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0256 - mean_absolute_error: 0.1241 - mean_squared_error: 0.0256 - val_loss: 0.0302 - val_mean_absolute_error: 0.1368 - val_mean_squared_error: 0.0302
# Epoch 27/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0300 - mean_absolute_error: 0.1365 - mean_squared_error: 0.0300 - val_loss: 0.0251 - val_mean_absolute_error: 0.1190 - val_mean_squared_error: 0.0251
# Epoch 28/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0442 - mean_absolute_error: 0.1346 - mean_squared_error: 0.0442 - val_loss: 0.0636 - val_mean_absolute_error: 0.2194 - val_mean_squared_error: 0.0636
# Epoch 29/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0724 - mean_absolute_error: 0.2165 - mean_squared_error: 0.0724 - val_loss: 0.0207 - val_mean_absolute_error: 0.1218 - val_mean_squared_error: 0.0207
# Epoch 30/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0425 - mean_absolute_error: 0.1748 - mean_squared_error: 0.0425 - val_loss: 0.0295 - val_mean_absolute_error: 0.1517 - val_mean_squared_error: 0.0295
# Epoch 31/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0458 - mean_absolute_error: 0.1582 - mean_squared_error: 0.0458 - val_loss: 0.0928 - val_mean_absolute_error: 0.2797 - val_mean_squared_error: 0.0928
# Epoch 32/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0859 - mean_absolute_error: 0.2552 - mean_squared_error: 0.0859 - val_loss: 0.0182 - val_mean_absolute_error: 0.1104 - val_mean_squared_error: 0.0182
# Epoch 33/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0397 - mean_absolute_error: 0.1554 - mean_squared_error: 0.0397 - val_loss: 0.0165 - val_mean_absolute_error: 0.1019 - val_mean_squared_error: 0.0165
# Epoch 34/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0234 - mean_absolute_error: 0.1196 - mean_squared_error: 0.0234 - val_loss: 0.0119 - val_mean_absolute_error: 0.0833 - val_mean_squared_error: 0.0119
# Epoch 35/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0265 - mean_absolute_error: 0.1196 - mean_squared_error: 0.0265 - val_loss: 0.0254 - val_mean_absolute_error: 0.1179 - val_mean_squared_error: 0.0254
# Epoch 36/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0207 - mean_absolute_error: 0.1197 - mean_squared_error: 0.0207 - val_loss: 0.0331 - val_mean_absolute_error: 0.1473 - val_mean_squared_error: 0.0331
# Epoch 37/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0292 - mean_absolute_error: 0.1374 - mean_squared_error: 0.0292 - val_loss: 0.0128 - val_mean_absolute_error: 0.0836 - val_mean_squared_error: 0.0128
# Epoch 38/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0154 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0154 - val_loss: 0.0312 - val_mean_absolute_error: 0.1428 - val_mean_squared_error: 0.0312
# Epoch 39/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0203 - mean_absolute_error: 0.1219 - mean_squared_error: 0.0203 - val_loss: 0.0211 - val_mean_absolute_error: 0.1098 - val_mean_squared_error: 0.0211
# Epoch 40/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0118 - mean_absolute_error: 0.0821 - mean_squared_error: 0.0118 - val_loss: 0.0159 - val_mean_absolute_error: 0.0959 - val_mean_squared_error: 0.0159
# Epoch 41/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0151 - mean_absolute_error: 0.0962 - mean_squared_error: 0.0151 - val_loss: 0.0120 - val_mean_absolute_error: 0.0809 - val_mean_squared_error: 0.0120
# Epoch 42/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0133 - mean_absolute_error: 0.0859 - mean_squared_error: 0.0133 - val_loss: 0.0171 - val_mean_absolute_error: 0.1100 - val_mean_squared_error: 0.0171
# Epoch 43/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0153 - mean_absolute_error: 0.0951 - mean_squared_error: 0.0153 - val_loss: 0.0387 - val_mean_absolute_error: 0.1748 - val_mean_squared_error: 0.0387
# Epoch 44/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0256 - mean_absolute_error: 0.1243 - mean_squared_error: 0.0256 - val_loss: 0.0246 - val_mean_absolute_error: 0.1275 - val_mean_squared_error: 0.0246
# Epoch 45/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0312 - mean_absolute_error: 0.1281 - mean_squared_error: 0.0312 - val_loss: 0.0475 - val_mean_absolute_error: 0.1951 - val_mean_squared_error: 0.0475
# Epoch 46/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0369 - mean_absolute_error: 0.1668 - mean_squared_error: 0.0369 - val_loss: 0.0312 - val_mean_absolute_error: 0.1409 - val_mean_squared_error: 0.0312
# Epoch 47/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0154 - mean_absolute_error: 0.1001 - mean_squared_error: 0.0154 - val_loss: 0.0145 - val_mean_absolute_error: 0.0938 - val_mean_squared_error: 0.0145
# Epoch 48/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0138 - mean_absolute_error: 0.0910 - mean_squared_error: 0.0138 - val_loss: 0.0126 - val_mean_absolute_error: 0.0944 - val_mean_squared_error: 0.0126
# Epoch 49/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0095 - mean_absolute_error: 0.0762 - mean_squared_error: 0.0095 - val_loss: 0.0198 - val_mean_absolute_error: 0.1102 - val_mean_squared_error: 0.0198
# Epoch 50/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0129 - mean_absolute_error: 0.0889 - mean_squared_error: 0.0129 - val_loss: 0.0198 - val_mean_absolute_error: 0.1109 - val_mean_squared_error: 0.0198
# Epoch 51/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0198 - mean_absolute_error: 0.1121 - mean_squared_error: 0.0198 - val_loss: 0.0192 - val_mean_absolute_error: 0.1091 - val_mean_squared_error: 0.0192
# Epoch 52/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0334 - mean_absolute_error: 0.1455 - mean_squared_error: 0.0334 - val_loss: 0.0165 - val_mean_absolute_error: 0.1016 - val_mean_squared_error: 0.0165
# Epoch 53/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0299 - mean_absolute_error: 0.1461 - mean_squared_error: 0.0299 - val_loss: 0.0115 - val_mean_absolute_error: 0.0806 - val_mean_squared_error: 0.0115
# Epoch 54/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0149 - mean_absolute_error: 0.1053 - mean_squared_error: 0.0149 - val_loss: 0.0115 - val_mean_absolute_error: 0.0857 - val_mean_squared_error: 0.0115
# Epoch 55/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0174 - mean_absolute_error: 0.1054 - mean_squared_error: 0.0174 - val_loss: 0.0134 - val_mean_absolute_error: 0.0887 - val_mean_squared_error: 0.0134
# Epoch 56/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0172 - mean_absolute_error: 0.1045 - mean_squared_error: 0.0172 - val_loss: 0.0115 - val_mean_absolute_error: 0.0812 - val_mean_squared_error: 0.0115
# Epoch 57/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0136 - mean_absolute_error: 0.0865 - mean_squared_error: 0.0136 - val_loss: 0.0239 - val_mean_absolute_error: 0.1249 - val_mean_squared_error: 0.0239
# Epoch 58/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0185 - mean_absolute_error: 0.1091 - mean_squared_error: 0.0185 - val_loss: 0.0154 - val_mean_absolute_error: 0.0923 - val_mean_squared_error: 0.0154
# Epoch 59/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0089 - mean_absolute_error: 0.0741 - mean_squared_error: 0.0089 - val_loss: 0.0285 - val_mean_absolute_error: 0.1457 - val_mean_squared_error: 0.0285
# Epoch 60/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0149 - mean_absolute_error: 0.0964 - mean_squared_error: 0.0149 - val_loss: 0.0235 - val_mean_absolute_error: 0.1270 - val_mean_squared_error: 0.0235
# Epoch 61/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0308 - mean_absolute_error: 0.1441 - mean_squared_error: 0.0308 - val_loss: 0.0210 - val_mean_absolute_error: 0.1109 - val_mean_squared_error: 0.0210
# Epoch 62/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0619 - mean_absolute_error: 0.1764 - mean_squared_error: 0.0619 - val_loss: 0.0167 - val_mean_absolute_error: 0.1056 - val_mean_squared_error: 0.0167
# Epoch 63/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0977 - mean_absolute_error: 0.2578 - mean_squared_error: 0.0977 - val_loss: 0.2518 - val_mean_absolute_error: 0.4792 - val_mean_squared_error: 0.2518
# Epoch 64/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.2850 - mean_absolute_error: 0.4458 - mean_squared_error: 0.2850 - val_loss: 0.1020 - val_mean_absolute_error: 0.2334 - val_mean_squared_error: 0.1020
# Epoch 65/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0292 - mean_absolute_error: 0.1408 - mean_squared_error: 0.0292 - val_loss: 0.0897 - val_mean_absolute_error: 0.2625 - val_mean_squared_error: 0.0897
# Epoch 66/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0763 - mean_absolute_error: 0.2144 - mean_squared_error: 0.0763 - val_loss: 0.0133 - val_mean_absolute_error: 0.0830 - val_mean_squared_error: 0.0133
# Epoch 67/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0482 - mean_absolute_error: 0.1846 - mean_squared_error: 0.0482 - val_loss: 0.0248 - val_mean_absolute_error: 0.1368 - val_mean_squared_error: 0.0248
# Epoch 68/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0512 - mean_absolute_error: 0.1627 - mean_squared_error: 0.0512 - val_loss: 0.0118 - val_mean_absolute_error: 0.0817 - val_mean_squared_error: 0.0118
# Epoch 69/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0443 - mean_absolute_error: 0.1722 - mean_squared_error: 0.0443 - val_loss: 0.0447 - val_mean_absolute_error: 0.1853 - val_mean_squared_error: 0.0447
# Epoch 70/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0205 - mean_absolute_error: 0.1117 - mean_squared_error: 0.0205 - val_loss: 0.0111 - val_mean_absolute_error: 0.0809 - val_mean_squared_error: 0.0111
# Epoch 71/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0118 - mean_absolute_error: 0.0845 - mean_squared_error: 0.0118 - val_loss: 0.0288 - val_mean_absolute_error: 0.1399 - val_mean_squared_error: 0.0288
# Epoch 72/180
# 339/339 [==============================] - 0s 999us/step - loss: 0.0291 - mean_absolute_error: 0.1288 - mean_squared_error: 0.0291 - val_loss: 0.0633 - val_mean_absolute_error: 0.2277 - val_mean_squared_error: 0.0633
# Epoch 73/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0378 - mean_absolute_error: 0.1672 - mean_squared_error: 0.0378 - val_loss: 0.0165 - val_mean_absolute_error: 0.0949 - val_mean_squared_error: 0.0165
# Epoch 74/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0115 - mean_absolute_error: 0.0834 - mean_squared_error: 0.0115 - val_loss: 0.0142 - val_mean_absolute_error: 0.1031 - val_mean_squared_error: 0.0142
# Epoch 75/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0097 - mean_absolute_error: 0.0752 - mean_squared_error: 0.0097 - val_loss: 0.0087 - val_mean_absolute_error: 0.0734 - val_mean_squared_error: 0.0087
# Epoch 76/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0077 - mean_absolute_error: 0.0684 - mean_squared_error: 0.0077 - val_loss: 0.0092 - val_mean_absolute_error: 0.0793 - val_mean_squared_error: 0.0092
# Epoch 77/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0068 - mean_absolute_error: 0.0637 - mean_squared_error: 0.0068 - val_loss: 0.0102 - val_mean_absolute_error: 0.0730 - val_mean_squared_error: 0.0102
# Epoch 78/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0079 - mean_absolute_error: 0.0681 - mean_squared_error: 0.0079 - val_loss: 0.0189 - val_mean_absolute_error: 0.1142 - val_mean_squared_error: 0.0189
# Epoch 79/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0114 - mean_absolute_error: 0.0823 - mean_squared_error: 0.0114 - val_loss: 0.0116 - val_mean_absolute_error: 0.0883 - val_mean_squared_error: 0.0116
# Epoch 80/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0110 - mean_absolute_error: 0.0817 - mean_squared_error: 0.0110 - val_loss: 0.0097 - val_mean_absolute_error: 0.0813 - val_mean_squared_error: 0.0097
# Epoch 81/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0111 - mean_absolute_error: 0.0825 - mean_squared_error: 0.0111 - val_loss: 0.0177 - val_mean_absolute_error: 0.1192 - val_mean_squared_error: 0.0177
# Epoch 82/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0189 - mean_absolute_error: 0.1142 - mean_squared_error: 0.0189 - val_loss: 0.0068 - val_mean_absolute_error: 0.0653 - val_mean_squared_error: 0.0068
# Epoch 83/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0100 - mean_absolute_error: 0.0801 - mean_squared_error: 0.0100 - val_loss: 0.0102 - val_mean_absolute_error: 0.0753 - val_mean_squared_error: 0.0102
# Epoch 84/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0590 - mean_squared_error: 0.0060 - val_loss: 0.0072 - val_mean_absolute_error: 0.0647 - val_mean_squared_error: 0.0072
# Epoch 85/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0597 - mean_squared_error: 0.0062 - val_loss: 0.0080 - val_mean_absolute_error: 0.0681 - val_mean_squared_error: 0.0080
# Epoch 86/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0585 - mean_squared_error: 0.0059 - val_loss: 0.0068 - val_mean_absolute_error: 0.0636 - val_mean_squared_error: 0.0068
# Epoch 87/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0075 - mean_absolute_error: 0.0661 - mean_squared_error: 0.0075 - val_loss: 0.0085 - val_mean_absolute_error: 0.0762 - val_mean_squared_error: 0.0085
# Epoch 88/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0066 - mean_absolute_error: 0.0603 - mean_squared_error: 0.0066 - val_loss: 0.0081 - val_mean_absolute_error: 0.0720 - val_mean_squared_error: 0.0081
# Epoch 89/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0065 - mean_absolute_error: 0.0631 - mean_squared_error: 0.0065 - val_loss: 0.0073 - val_mean_absolute_error: 0.0679 - val_mean_squared_error: 0.0073
# Epoch 90/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0577 - mean_squared_error: 0.0059 - val_loss: 0.0056 - val_mean_absolute_error: 0.0574 - val_mean_squared_error: 0.0056
# Epoch 91/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0063 - mean_absolute_error: 0.0611 - mean_squared_error: 0.0063 - val_loss: 0.0070 - val_mean_absolute_error: 0.0679 - val_mean_squared_error: 0.0070
# Epoch 92/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0055 - mean_absolute_error: 0.0580 - mean_squared_error: 0.0055 - val_loss: 0.0062 - val_mean_absolute_error: 0.0621 - val_mean_squared_error: 0.0062
# Epoch 93/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0049 - mean_absolute_error: 0.0510 - mean_squared_error: 0.0049 - val_loss: 0.0071 - val_mean_absolute_error: 0.0689 - val_mean_squared_error: 0.0071
# Epoch 94/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0069 - mean_absolute_error: 0.0673 - mean_squared_error: 0.0069 - val_loss: 0.0094 - val_mean_absolute_error: 0.0764 - val_mean_squared_error: 0.0094
# Epoch 95/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0092 - mean_absolute_error: 0.0740 - mean_squared_error: 0.0092 - val_loss: 0.0070 - val_mean_absolute_error: 0.0641 - val_mean_squared_error: 0.0070
# Epoch 96/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0093 - mean_absolute_error: 0.0742 - mean_squared_error: 0.0093 - val_loss: 0.0144 - val_mean_absolute_error: 0.0999 - val_mean_squared_error: 0.0144
# Epoch 97/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0076 - mean_absolute_error: 0.0717 - mean_squared_error: 0.0076 - val_loss: 0.0103 - val_mean_absolute_error: 0.0794 - val_mean_squared_error: 0.0103
# Epoch 98/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0076 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0076 - val_loss: 0.0068 - val_mean_absolute_error: 0.0644 - val_mean_squared_error: 0.0068
# Epoch 99/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0128 - mean_absolute_error: 0.0933 - mean_squared_error: 0.0128 - val_loss: 0.0076 - val_mean_absolute_error: 0.0688 - val_mean_squared_error: 0.0076
# Epoch 100/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0123 - mean_absolute_error: 0.0807 - mean_squared_error: 0.0123 - val_loss: 0.0066 - val_mean_absolute_error: 0.0642 - val_mean_squared_error: 0.0066
# Epoch 101/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0263 - mean_absolute_error: 0.1313 - mean_squared_error: 0.0263 - val_loss: 0.0081 - val_mean_absolute_error: 0.0669 - val_mean_squared_error: 0.0081
# Epoch 102/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0141 - mean_absolute_error: 0.0932 - mean_squared_error: 0.0141 - val_loss: 0.0052 - val_mean_absolute_error: 0.0550 - val_mean_squared_error: 0.0052
# Epoch 103/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0229 - mean_absolute_error: 0.1045 - mean_squared_error: 0.0229 - val_loss: 0.1089 - val_mean_absolute_error: 0.3198 - val_mean_squared_error: 0.1089
# Epoch 104/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1093 - mean_absolute_error: 0.3050 - mean_squared_error: 0.1093 - val_loss: 0.0195 - val_mean_absolute_error: 0.1068 - val_mean_squared_error: 0.0195
# Epoch 105/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0415 - mean_absolute_error: 0.1422 - mean_squared_error: 0.0415 - val_loss: 0.0938 - val_mean_absolute_error: 0.2733 - val_mean_squared_error: 0.0938
# Epoch 106/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1642 - mean_absolute_error: 0.3539 - mean_squared_error: 0.1642 - val_loss: 0.0285 - val_mean_absolute_error: 0.1368 - val_mean_squared_error: 0.0285
# Epoch 107/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0208 - mean_absolute_error: 0.1139 - mean_squared_error: 0.0208 - val_loss: 0.1755 - val_mean_absolute_error: 0.3919 - val_mean_squared_error: 0.1755
# Epoch 108/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0597 - mean_absolute_error: 0.1972 - mean_squared_error: 0.0597 - val_loss: 0.0204 - val_mean_absolute_error: 0.1161 - val_mean_squared_error: 0.0204
# Epoch 109/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0480 - mean_absolute_error: 0.1866 - mean_squared_error: 0.0480 - val_loss: 0.0076 - val_mean_absolute_error: 0.0689 - val_mean_squared_error: 0.0076
# Epoch 110/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0484 - mean_absolute_error: 0.1705 - mean_squared_error: 0.0484 - val_loss: 0.0368 - val_mean_absolute_error: 0.1795 - val_mean_squared_error: 0.0368
# Epoch 111/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0376 - mean_absolute_error: 0.1433 - mean_squared_error: 0.0376 - val_loss: 0.0177 - val_mean_absolute_error: 0.1179 - val_mean_squared_error: 0.0177
# Epoch 112/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0264 - mean_absolute_error: 0.1272 - mean_squared_error: 0.0264 - val_loss: 0.0369 - val_mean_absolute_error: 0.1696 - val_mean_squared_error: 0.0369
# Epoch 113/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0354 - mean_absolute_error: 0.1611 - mean_squared_error: 0.0354 - val_loss: 0.1080 - val_mean_absolute_error: 0.2998 - val_mean_squared_error: 0.1080
# Epoch 114/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0626 - mean_absolute_error: 0.1995 - mean_squared_error: 0.0626 - val_loss: 0.0141 - val_mean_absolute_error: 0.0889 - val_mean_squared_error: 0.0141
# Epoch 115/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0156 - mean_absolute_error: 0.1027 - mean_squared_error: 0.0156 - val_loss: 0.0325 - val_mean_absolute_error: 0.1567 - val_mean_squared_error: 0.0325
# Epoch 116/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0272 - mean_absolute_error: 0.1330 - mean_squared_error: 0.0272 - val_loss: 0.0213 - val_mean_absolute_error: 0.1261 - val_mean_squared_error: 0.0213
# Epoch 117/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0303 - mean_absolute_error: 0.1222 - mean_squared_error: 0.0303 - val_loss: 0.0172 - val_mean_absolute_error: 0.1129 - val_mean_squared_error: 0.0172
# Epoch 118/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0146 - mean_absolute_error: 0.1022 - mean_squared_error: 0.0146 - val_loss: 0.0145 - val_mean_absolute_error: 0.1060 - val_mean_squared_error: 0.0145
# Epoch 119/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0233 - mean_absolute_error: 0.1182 - mean_squared_error: 0.0233 - val_loss: 0.0122 - val_mean_absolute_error: 0.0911 - val_mean_squared_error: 0.0122
# Epoch 120/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0262 - mean_absolute_error: 0.1358 - mean_squared_error: 0.0262 - val_loss: 0.0248 - val_mean_absolute_error: 0.1415 - val_mean_squared_error: 0.0248
# Epoch 121/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0128 - mean_absolute_error: 0.0908 - mean_squared_error: 0.0128 - val_loss: 0.0070 - val_mean_absolute_error: 0.0611 - val_mean_squared_error: 0.0070
# Epoch 122/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0095 - mean_absolute_error: 0.0742 - mean_squared_error: 0.0095 - val_loss: 0.0167 - val_mean_absolute_error: 0.1017 - val_mean_squared_error: 0.0167
# Epoch 123/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0081 - mean_absolute_error: 0.0663 - mean_squared_error: 0.0081 - val_loss: 0.6753 - val_mean_absolute_error: 0.8109 - val_mean_squared_error: 0.6753
# Epoch 124/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1253 - mean_absolute_error: 0.2744 - mean_squared_error: 0.1253 - val_loss: 0.0524 - val_mean_absolute_error: 0.2140 - val_mean_squared_error: 0.0524
# Epoch 125/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0516 - mean_absolute_error: 0.1866 - mean_squared_error: 0.0516 - val_loss: 0.0174 - val_mean_absolute_error: 0.1146 - val_mean_squared_error: 0.0174
# Epoch 126/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0371 - mean_absolute_error: 0.1673 - mean_squared_error: 0.0371 - val_loss: 0.0305 - val_mean_absolute_error: 0.1617 - val_mean_squared_error: 0.0305
# Epoch 127/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0192 - mean_absolute_error: 0.1089 - mean_squared_error: 0.0192 - val_loss: 0.0130 - val_mean_absolute_error: 0.0803 - val_mean_squared_error: 0.0130
# Epoch 128/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0267 - mean_absolute_error: 0.1256 - mean_squared_error: 0.0267 - val_loss: 0.0385 - val_mean_absolute_error: 0.1791 - val_mean_squared_error: 0.0385
# Epoch 129/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0280 - mean_absolute_error: 0.1344 - mean_squared_error: 0.0280 - val_loss: 0.0126 - val_mean_absolute_error: 0.0949 - val_mean_squared_error: 0.0126
# Epoch 130/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0254 - mean_absolute_error: 0.1142 - mean_squared_error: 0.0254 - val_loss: 0.0125 - val_mean_absolute_error: 0.0986 - val_mean_squared_error: 0.0125
# Epoch 131/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0097 - mean_absolute_error: 0.0822 - mean_squared_error: 0.0097 - val_loss: 0.0269 - val_mean_absolute_error: 0.1513 - val_mean_squared_error: 0.0269
# Epoch 132/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0147 - mean_absolute_error: 0.0990 - mean_squared_error: 0.0147 - val_loss: 0.0108 - val_mean_absolute_error: 0.0886 - val_mean_squared_error: 0.0108
# Epoch 133/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0261 - mean_absolute_error: 0.0887 - mean_squared_error: 0.0261 - val_loss: 0.0165 - val_mean_absolute_error: 0.0822 - val_mean_squared_error: 0.0165
# Epoch 134/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1879 - mean_absolute_error: 0.2850 - mean_squared_error: 0.1879 - val_loss: 0.0932 - val_mean_absolute_error: 0.2501 - val_mean_squared_error: 0.0932
# Epoch 135/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0680 - mean_absolute_error: 0.2266 - mean_squared_error: 0.0680 - val_loss: 0.0199 - val_mean_absolute_error: 0.1145 - val_mean_squared_error: 0.0199
# Epoch 136/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0298 - mean_absolute_error: 0.1338 - mean_squared_error: 0.0298 - val_loss: 0.3870 - val_mean_absolute_error: 0.6141 - val_mean_squared_error: 0.3870
# Epoch 137/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0770 - mean_absolute_error: 0.2006 - mean_squared_error: 0.0770 - val_loss: 0.0116 - val_mean_absolute_error: 0.0828 - val_mean_squared_error: 0.0116
# Epoch 138/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0240 - mean_absolute_error: 0.1197 - mean_squared_error: 0.0240 - val_loss: 0.0096 - val_mean_absolute_error: 0.0794 - val_mean_squared_error: 0.0096
# Epoch 139/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0234 - mean_absolute_error: 0.1097 - mean_squared_error: 0.0234 - val_loss: 0.0350 - val_mean_absolute_error: 0.1588 - val_mean_squared_error: 0.0350
# Epoch 140/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0624 - mean_absolute_error: 0.2028 - mean_squared_error: 0.0624 - val_loss: 0.0949 - val_mean_absolute_error: 0.2934 - val_mean_squared_error: 0.0949
# Epoch 141/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1331 - mean_absolute_error: 0.3224 - mean_squared_error: 0.1331 - val_loss: 0.0231 - val_mean_absolute_error: 0.1314 - val_mean_squared_error: 0.0231
# Epoch 142/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0364 - mean_absolute_error: 0.1584 - mean_squared_error: 0.0364 - val_loss: 0.0115 - val_mean_absolute_error: 0.0803 - val_mean_squared_error: 0.0115
# Epoch 143/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0422 - mean_absolute_error: 0.1488 - mean_squared_error: 0.0422 - val_loss: 0.1155 - val_mean_absolute_error: 0.3159 - val_mean_squared_error: 0.1155
# Epoch 144/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0948 - mean_absolute_error: 0.2207 - mean_squared_error: 0.0948 - val_loss: 0.0304 - val_mean_absolute_error: 0.1271 - val_mean_squared_error: 0.0304
# Epoch 145/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.2729 - mean_absolute_error: 0.2867 - mean_squared_error: 0.2729 - val_loss: 0.1470 - val_mean_absolute_error: 0.2799 - val_mean_squared_error: 0.1470
# Epoch 146/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0816 - mean_absolute_error: 0.2106 - mean_squared_error: 0.0816 - val_loss: 0.0734 - val_mean_absolute_error: 0.2327 - val_mean_squared_error: 0.0734
# Epoch 147/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.1955 - mean_absolute_error: 0.3513 - mean_squared_error: 0.1955 - val_loss: 0.0601 - val_mean_absolute_error: 0.1990 - val_mean_squared_error: 0.0601
# Epoch 148/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0312 - mean_absolute_error: 0.1357 - mean_squared_error: 0.0312 - val_loss: 0.0120 - val_mean_absolute_error: 0.0763 - val_mean_squared_error: 0.0120
# Epoch 149/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0106 - mean_absolute_error: 0.0775 - mean_squared_error: 0.0106 - val_loss: 0.0138 - val_mean_absolute_error: 0.0880 - val_mean_squared_error: 0.0138
# Epoch 150/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0128 - mean_absolute_error: 0.0845 - mean_squared_error: 0.0128 - val_loss: 0.0044 - val_mean_absolute_error: 0.0534 - val_mean_squared_error: 0.0044
# Epoch 151/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0132 - mean_absolute_error: 0.0769 - mean_squared_error: 0.0132 - val_loss: 0.0046 - val_mean_absolute_error: 0.0550 - val_mean_squared_error: 0.0046
# Epoch 152/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0433 - mean_absolute_error: 0.1262 - mean_squared_error: 0.0433 - val_loss: 0.0185 - val_mean_absolute_error: 0.1107 - val_mean_squared_error: 0.0185
# Epoch 153/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0403 - mean_absolute_error: 0.1465 - mean_squared_error: 0.0403 - val_loss: 0.0066 - val_mean_absolute_error: 0.0654 - val_mean_squared_error: 0.0066
# Epoch 154/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0171 - mean_absolute_error: 0.1066 - mean_squared_error: 0.0171 - val_loss: 0.0059 - val_mean_absolute_error: 0.0593 - val_mean_squared_error: 0.0059
# Epoch 155/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0186 - mean_absolute_error: 0.1024 - mean_squared_error: 0.0186 - val_loss: 0.0066 - val_mean_absolute_error: 0.0632 - val_mean_squared_error: 0.0066
# Epoch 156/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0182 - mean_absolute_error: 0.0931 - mean_squared_error: 0.0182 - val_loss: 0.0046 - val_mean_absolute_error: 0.0502 - val_mean_squared_error: 0.0046
# Epoch 157/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0139 - mean_absolute_error: 0.0861 - mean_squared_error: 0.0139 - val_loss: 0.0043 - val_mean_absolute_error: 0.0532 - val_mean_squared_error: 0.0043
# Epoch 158/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0052 - mean_absolute_error: 0.0565 - mean_squared_error: 0.0052 - val_loss: 0.0044 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0044
# Epoch 159/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0038 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0038 - val_loss: 0.0037 - val_mean_absolute_error: 0.0459 - val_mean_squared_error: 0.0037
# Epoch 160/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0039 - mean_absolute_error: 0.0478 - mean_squared_error: 0.0039 - val_loss: 0.0041 - val_mean_absolute_error: 0.0466 - val_mean_squared_error: 0.0041
# Epoch 161/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0044 - mean_absolute_error: 0.0512 - mean_squared_error: 0.0044 - val_loss: 0.0040 - val_mean_absolute_error: 0.0465 - val_mean_squared_error: 0.0040
# Epoch 162/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0477 - mean_squared_error: 0.0048 - val_loss: 0.0039 - val_mean_absolute_error: 0.0474 - val_mean_squared_error: 0.0039
# Epoch 163/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0056 - mean_absolute_error: 0.0590 - mean_squared_error: 0.0056 - val_loss: 0.0034 - val_mean_absolute_error: 0.0439 - val_mean_squared_error: 0.0034
# Epoch 164/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0075 - mean_absolute_error: 0.0596 - mean_squared_error: 0.0075 - val_loss: 0.0060 - val_mean_absolute_error: 0.0508 - val_mean_squared_error: 0.0060
# Epoch 165/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0175 - mean_absolute_error: 0.0801 - mean_squared_error: 0.0175 - val_loss: 0.0060 - val_mean_absolute_error: 0.0519 - val_mean_squared_error: 0.0060
# Epoch 166/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0322 - mean_absolute_error: 0.1278 - mean_squared_error: 0.0322 - val_loss: 0.0082 - val_mean_absolute_error: 0.0784 - val_mean_squared_error: 0.0082
# Epoch 167/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0941 - mean_absolute_error: 0.2057 - mean_squared_error: 0.0941 - val_loss: 0.0228 - val_mean_absolute_error: 0.1123 - val_mean_squared_error: 0.0228
# Epoch 168/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.1157 - mean_absolute_error: 0.2542 - mean_squared_error: 0.1157 - val_loss: 0.0118 - val_mean_absolute_error: 0.0808 - val_mean_squared_error: 0.0118
# Epoch 169/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0304 - mean_absolute_error: 0.1272 - mean_squared_error: 0.0304 - val_loss: 0.0048 - val_mean_absolute_error: 0.0483 - val_mean_squared_error: 0.0048
# Epoch 170/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0321 - mean_absolute_error: 0.1188 - mean_squared_error: 0.0321 - val_loss: 0.0124 - val_mean_absolute_error: 0.0697 - val_mean_squared_error: 0.0124
# Epoch 171/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0584 - mean_absolute_error: 0.1504 - mean_squared_error: 0.0584 - val_loss: 0.0275 - val_mean_absolute_error: 0.1082 - val_mean_squared_error: 0.0275
# Epoch 172/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0403 - mean_absolute_error: 0.1609 - mean_squared_error: 0.0403 - val_loss: 0.0164 - val_mean_absolute_error: 0.0985 - val_mean_squared_error: 0.0164
# Epoch 173/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0252 - mean_absolute_error: 0.1148 - mean_squared_error: 0.0252 - val_loss: 0.0075 - val_mean_absolute_error: 0.0658 - val_mean_squared_error: 0.0075
# Epoch 174/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0261 - mean_absolute_error: 0.1099 - mean_squared_error: 0.0261 - val_loss: 0.0228 - val_mean_absolute_error: 0.0970 - val_mean_squared_error: 0.0228
# Epoch 175/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0182 - mean_absolute_error: 0.0884 - mean_squared_error: 0.0182 - val_loss: 0.0068 - val_mean_absolute_error: 0.0623 - val_mean_squared_error: 0.0068
# Epoch 176/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0172 - mean_absolute_error: 0.0809 - mean_squared_error: 0.0172 - val_loss: 0.0118 - val_mean_absolute_error: 0.0722 - val_mean_squared_error: 0.0118
# Epoch 177/180
# 339/339 [==============================] - 1s 2ms/step - loss: 0.0250 - mean_absolute_error: 0.1051 - mean_squared_error: 0.0250 - val_loss: 0.0085 - val_mean_absolute_error: 0.0647 - val_mean_squared_error: 0.0085
# Epoch 178/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0151 - mean_absolute_error: 0.0895 - mean_squared_error: 0.0151 - val_loss: 0.0279 - val_mean_absolute_error: 0.1181 - val_mean_squared_error: 0.0279
# Epoch 179/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0151 - mean_absolute_error: 0.0822 - mean_squared_error: 0.0151 - val_loss: 0.0068 - val_mean_absolute_error: 0.0669 - val_mean_squared_error: 0.0068
# Epoch 180/180
# 339/339 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_absolute_error: 0.0572 - mean_squared_error: 0.0074 - val_loss: 0.0109 - val_mean_absolute_error: 0.0748 - val_mean_squared_error: 0.0109

# %%
hist = pd.DataFrame(history.history)
hist['epoch']= history.epoch
hist.tail()
# Out:
#      val_loss  val_mean_absolute_error  val_mean_squared_error      loss  \
# 175  0.011816                 0.072236                0.011816  0.017195
# 176  0.008465                 0.064719                0.008465  0.025031
# 177  0.027943                 0.118075                0.027943  0.015139
# 178  0.006838                 0.066875                0.006838  0.015066
# 179  0.010886                 0.074788                0.010886  0.007369
#
#      mean_absolute_error  mean_squared_error  epoch
# 175             0.080948            0.017195    175
# 176             0.105118            0.025031    176
# 177             0.089501            0.015139    177
# 178             0.082182            0.015066    178
# 179             0.057217            0.007369    179

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
    
  plt.figure(figsize=(13,9))
  #plt.figure()
  plt.xlabel('Epoch', fontsize= 18)
  plt.ylabel('Mean Abs Error', fontsize= 18)
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  plt.ylim([0,1.2])
  plt.tick_params(labelsize=20)
  plt.legend()
  

  plt.figure(figsize=(13,9))
  #plt.figure()
  plt.xlabel('Epoch', fontsize = 20)
  plt.ylabel('Mean Square Error', fontsize= 20)
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  plt.ylim([0,10])
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# **Save model**

# %%
test_predictions = model.predict([norm_rvsflux, norm_bpflux, norm_rpflux]).flatten()

print(np.shape(test_predictions))

print(np.shape(normalize(teff)))
plt.scatter(normalize(teff), test_predictions)
plt.xlabel('True Values [LogTeff]')
plt.ylabel('Predictions [LogTeff]')
plt.axis('equal')
plt.axis('square')
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
#_ = plt.plot([1.4, 1.4], [1.4, 1.4])
#print('test predictions=', test_predictions)
# Out:
# (415,)
# (415,)
# (-1.3599418736346431, 3.5390270618255384, -1.4492467048020814, 3.4497222306581)

# %%
#Unnormalizing the labels (teff)

def denormalize (labels):
    return (((labels)*(std_labels)) + mean_labels)


test_predictions = model.predict([norm_rvsflux, norm_bpflux, norm_rpflux]).flatten()
plt.scatter(teff, denormalize(test_predictions))
plt.xlabel('True Values [$T_{ eff}$]')
plt.ylabel('Predictions [$T_{ eff}$]')
plt.axis('equal')
plt.axis('square')
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([5.5, 12 ], [5.5, 12])

#print('test predictions=', test_predictions)

# %%
#Unnormalizing the labels (teff)

def denormalize (labels):
    return (((labels)*(std_labels)) + mean_labels)

plt.figure(figsize=(13,9))
test_predictions = model.predict([x_RVStrain, x_BPtrain, x_RPtrain]).flatten()
print('shape of test_predictions:',np.shape(test_predictions))
print('print 10 elements of test_predictions:', test_predictions[0:10])
plt.scatter(denormalize(y_train), denormalize(test_predictions), s= 4.0, c= 'r' )
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=25)
plt.ylabel(r"$T_{\rm eff,pred}$ (K)", fontsize=25)
plt.axis('equal')
plt.axis('square')
# increase the x,y tick label size
plt.tick_params(labelsize= 25) 
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([0, 30000], [0, 30000])
# Out:
# shape of test_predictions: (339,)
# print 10 elements of test_predictions: [-1.1341395 -1.1191207 -1.1297379 -1.1248302 -1.1037533 -1.1159552
#  -1.1120236 -1.049614  -1.0549111 -1.0683703]

# %%
#Making the histogram of denormalized training set 

plt.figure(figsize=(10,9))
z=np.subtract(denormalize(y_train), denormalize(test_predictions)) #difference between the true and predicted values
counts, bins = np.histogram(z)
plt.hist(bins[:-1], bins, weights=counts)

# increase the x,y tick label size
plt.tick_params(labelsize=18) 
plt.title(r'Histogram of $T_{eff}$', fontsize=18)
plt.xlabel(r"$\rm T_{\rm eff,pred}-\rm T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel('Counts', fontsize=18)

print('standard deviation', len(z))
#print(len(z[teff<5000]))
#print(len(z))
# Out:
# standard deviation 339

# %% [markdown]
# # Training Data Set

# %%
# getting deviation in Teff bins
nbin = 6
teffbin_edges=np.array([5000, 10000, 15000, 20000, 25000, 30000 ])

# pred vs. true
# unnormalised values
teff_pred = denormalize(test_predictions)
teff_true = denormalize(y_train) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
teff_diff = teff_pred-teff_true

# compute mean and std in Teff bins
teff_diff_mean = np.zeros(nbin) 
teff_diff_std = np.zeros(nbin)
teffbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(teff_true<teffbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(teff_true>teffbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((teff_true>teffbin_edges[i-1]) & (teff_true<teffbin_edges[i]))
        #if i=1, teff_true>(teffbin_edges[1-1=0]= 5000) & teff_true<teffbin_edges[1]= 10000, so 5000<teff<10000
        #if i=2, teff_true>(teffbin_edges[2-1=1]=10000) & teff_true<teffbin_edges[2]= 15000, so 10000<teff<15000
        #if i=3, teff_true> (teffbin_edges[3-1=2]= 15000) & teff_true<teffbin_edges[3]= 20000 so 15000<teff<20000
    teffbin_mean[i] = np.mean(teff_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    teff_diff_mean[i] = np.mean(teff_diff[indx]) #calculating the mean values of teff_diff from its index 
    teff_diff_std[i] = np.std(teff_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin teff_true=', teffbin_mean)
print('mean of teff_diff=', teff_diff_mean)
print('std of teff_diff=', teff_diff_std)
print('length of teff_diff=', len(teff_diff))
# Out:
# mean of bin teff_true= [ 4089.28571429  7320.89552239 11725.80645161 17565.78947368
#  22500.         28230.76923077]
# mean of teff_diff= [-102.83081055  234.49571479  428.65525769  682.68279708  784.54589844
#   184.7515024 ]
# std of teff_diff= [277.73105383 271.47794023 352.78059282 501.19930238 538.74155128
#  756.35858434]
# length of teff_diff= 339

# %%
# plot
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(teff_true, teff_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(teffbin_mean,teff_diff_mean, yerr=teff_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([2500,32000])
ylim=np.array([-1500, 2500])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# set x, y label. 
plt.xlabel(r"$\rm T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$\rm T_{\rm eff,pred}-\rm T_{\rm eff,true}$ (K)", fontsize=18)

# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %% [markdown]
# # Cross Validation Set

# %%
#Test set (x_cv)

plt.figure(figsize=(13,9))
cv_predictions = model.predict([x_RVScv, x_BPcv, x_RPcv]).flatten()
plt.scatter(denormalize(y_cv), denormalize(cv_predictions), c= 'r', s= 3)
_ = plt.plot([0, 30000], [0, 30000])
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=25)
plt.ylabel(r"$T_{\rm eff,pred}$ (K)", fontsize=25)
plt.axis('equal')
plt.axis('square')
# increase the x,y tick label size
plt.tick_params(labelsize=25) 
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])


#print('test predictions=', test_predictions)

print('len of y_cv=', len(y_cv))
# Out:
# len of y_cv= 76

# %%
# getting deviation in Teff bins
nbin = 5
teffbin_edges=np.array([5000, 10000, 15000, 20000, 30000 ])

# pred vs. true
# unnormalised values
teff_pred = denormalize(cv_predictions)
teff_true = denormalize(y_cv) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
teff_diff = teff_pred-teff_true

# compute mean and std in Teff bins
teff_diff_mean = np.zeros(nbin) 
teff_diff_std = np.zeros(nbin)
teffbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(teff_true<teffbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(teff_true>teffbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((teff_true>teffbin_edges[i-1]) & (teff_true<teffbin_edges[i]))
        #if i=1, teff_true>(teffbin_edges[1-1=0]= 5000) & teff_true<teffbin_edges[1]= 10000, so 5000<teff<10000
        #if i=2, teff_true>(teffbin_edges[2-1=1]=10000) & teff_true<teffbin_edges[2]= 15000, so 10000<teff<15000
        #if i=3, teff_true> (teffbin_edges[3-1=2]= 15000) & teff_true<teffbin_edges[3]= 20000 so 15000<teff<20000
    teffbin_mean[i] = np.mean(teff_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    teff_diff_mean[i] = np.mean(teff_diff[indx]) #calculating the mean values of teff_diff from its index 
    teff_diff_std[i] = np.std(teff_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin teff_true=', teffbin_mean)
print('mean of teff_diff=', teff_diff_mean)
print('std of teff_diff=', teff_diff_std)
print('len of teff_diff=', len(teff_diff))
# Out:
# mean of bin teff_true= [ 4325.          7112.90322581 12289.47368421 17142.85714286
#  25750.        ]
# mean of teff_diff= [-113.12944336  242.34830204  517.19233141  684.03794643  974.60986328]
# std of teff_diff= [179.9888463  291.78245449 345.9429381  259.30490292 498.86947451]
# len of teff_diff= 76

# %%
# plot
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(teff_true, teff_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(teffbin_mean,teff_diff_mean, yerr=teff_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([2500,11500])
ylim=np.array([-1500, 2500])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# set x, y label. 
plt.xlabel(r"$\rm T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$\rm T_{\rm eff,pred}-\rm T_{\rm eff,true}$ (K)", fontsize=18)

# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %%
#Making the histogram of the CV set 

plt.figure(figsize=(13,9))
z=np.subtract(denormalize(y_cv), denormalize(cv_predictions)) #difference between the true and predicted values
counts, bins = np.histogram(z)
plt.hist(bins[:-1], bins, weights=counts)


# increase the x,y tick label size
plt.tick_params(labelsize=18) 

plt.title(r'Histogram of $T_{eff}$', fontsize=18)
plt.xlabel(r"$\rm T_{\rm eff,pred}-\rm T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel('Counts', fontsize=18)
#z[teff<5000].std()
print('standard deviation', len(z))
#print(len(z[teff<5000]))
#print(len(z))
# Out:
# standard deviation 76

# %% [raw]
# # Another model
# From TheCNNon, https://github.com/adrn/TheCNNon/blob/master/notebooks/ThisIsCNNON.ipynb

# %%
# Input spectra
input_spec = Input(shape=(num_fluxes,), name='starnet_input_x')

# Reshape spectra for CNN layers
cur_in = Reshape((num_fluxes, 1))(input_spec)

# CNN layers
# First
cur_in = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=128, kernel_size=32)(cur_in) #first CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=32)(cur_in)
# Second CNN layer
cur_in = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=128, kernel_size=16)(cur_in) #2nd CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=16)(cur_in)
# Third CNN layer
cur_in = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=128, kernel_size=8)(cur_in) #2nd CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=8)(cur_in)

# Flatten the current input for the fully-connected layers
cur_in = Flatten()(cur_in)

# Fully-connected layers
cur_in = Dense(units=258, kernel_initializer=initializer, 
               activation=activation)(cur_in)
cur_in = Dense(units=128, kernel_initializer=initializer, 
               activation=activation)(cur_in)

# Output nodes
output_label = Dense(units=num_labels, kernel_regularizer=keras.regularizers.l2(0.01), activation="linear", 
                     input_dim=num_hidden[1])(cur_in)

model = Model(input_spec, output_label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-07ed572f0f80> in <module>
#       1 # Input spectra
# ----> 2 input_spec = Input(shape=(num_fluxes,), name='starnet_input_x')
#       3
#       4 # Reshape spectra for CNN layers
#       5 cur_in = Reshape((num_fluxes, 1))(input_spec)
#
# NameError: name 'num_fluxes' is not defined

# %%
optimizer = Adam(lr=0.0005)

# %%
# loss function to minimize
loss_function = 'mean_squared_error'
optimizer = 'adadelta'
# compute mean absolute deviation
metrics = ['mae', 'mse']
#metrics = ['mae']
model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# starnet_input_x (InputLayer) (None, 6758)              0
# _________________________________________________________________
# reshape_10 (Reshape)         (None, 6758, 1)           0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 6758, 128)         4224
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 211, 128)          0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 211, 128)          262272
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 13, 128)           0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 13, 128)           131200
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 1, 128)            0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 258)               33282
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               33152
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 464,259
# Trainable params: 464,259
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, 
          epochs=max_epochs, validation_split = 0.2, verbose=1, shuffle='batch')
# Out:
# Train on 875 samples, validate on 219 samples
# Epoch 1/200
# 875/875 [==============================] - 13s 15ms/step - loss: 5.2174 - mean_absolute_error: 1.4147 - mean_squared_error: 5.1988 - val_loss: 1.5482 - val_mean_absolute_error: 0.9417 - val_mean_squared_error: 1.5305
# Epoch 2/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3955 - mean_absolute_error: 0.5094 - mean_squared_error: 0.3783 - val_loss: 1.8217 - val_mean_absolute_error: 1.0313 - val_mean_squared_error: 1.8050
# Epoch 3/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3606 - mean_absolute_error: 0.4579 - mean_squared_error: 0.3443 - val_loss: 1.9750 - val_mean_absolute_error: 1.0742 - val_mean_squared_error: 1.9589
# Epoch 4/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3806 - mean_absolute_error: 0.4960 - mean_squared_error: 0.3648 - val_loss: 2.0388 - val_mean_absolute_error: 1.0894 - val_mean_squared_error: 2.0232
# Epoch 5/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.4077 - mean_absolute_error: 0.4772 - mean_squared_error: 0.3923 - val_loss: 3.4660 - val_mean_absolute_error: 1.5366 - val_mean_squared_error: 3.4508
# Epoch 6/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.3888 - mean_absolute_error: 0.5023 - mean_squared_error: 0.3738 - val_loss: 3.0916 - val_mean_absolute_error: 1.4193 - val_mean_squared_error: 3.0766
# Epoch 7/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3001 - mean_absolute_error: 0.4360 - mean_squared_error: 0.2852 - val_loss: 3.7524 - val_mean_absolute_error: 1.6397 - val_mean_squared_error: 3.7377
# Epoch 8/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.2883 - mean_absolute_error: 0.4420 - mean_squared_error: 0.2736 - val_loss: 3.6873 - val_mean_absolute_error: 1.6205 - val_mean_squared_error: 3.6728
# Epoch 9/200
# 875/875 [==============================] - 22s 25ms/step - loss: 0.2976 - mean_absolute_error: 0.4493 - mean_squared_error: 0.2833 - val_loss: 3.8704 - val_mean_absolute_error: 1.6722 - val_mean_squared_error: 3.8562
# Epoch 10/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.2398 - mean_absolute_error: 0.3987 - mean_squared_error: 0.2256 - val_loss: 3.9370 - val_mean_absolute_error: 1.6926 - val_mean_squared_error: 3.9230
# Epoch 11/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.2136 - mean_absolute_error: 0.3585 - mean_squared_error: 0.1997 - val_loss: 3.5978 - val_mean_absolute_error: 1.5898 - val_mean_squared_error: 3.5840
# Epoch 12/200
# 875/875 [==============================] - 27s 31ms/step - loss: 0.2410 - mean_absolute_error: 0.3820 - mean_squared_error: 0.2274 - val_loss: 4.0983 - val_mean_absolute_error: 1.7393 - val_mean_squared_error: 4.0850
# Epoch 13/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.1661 - mean_absolute_error: 0.3015 - mean_squared_error: 0.1530 - val_loss: 2.8094 - val_mean_absolute_error: 1.3314 - val_mean_squared_error: 2.7965
# Epoch 14/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1630 - mean_absolute_error: 0.2858 - mean_squared_error: 0.1503 - val_loss: 3.9325 - val_mean_absolute_error: 1.6919 - val_mean_squared_error: 3.9201
# Epoch 15/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.1432 - mean_absolute_error: 0.2689 - mean_squared_error: 0.1311 - val_loss: 3.6180 - val_mean_absolute_error: 1.5971 - val_mean_squared_error: 3.6062
# Epoch 16/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1220 - mean_absolute_error: 0.2405 - mean_squared_error: 0.1106 - val_loss: 3.5919 - val_mean_absolute_error: 1.5885 - val_mean_squared_error: 3.5809
# Epoch 17/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1122 - mean_absolute_error: 0.2418 - mean_squared_error: 0.1015 - val_loss: 3.4441 - val_mean_absolute_error: 1.5411 - val_mean_squared_error: 3.4337
# Epoch 18/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1125 - mean_absolute_error: 0.2457 - mean_squared_error: 0.1025 - val_loss: 3.6328 - val_mean_absolute_error: 1.6010 - val_mean_squared_error: 3.6232
# Epoch 19/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1287 - mean_absolute_error: 0.2610 - mean_squared_error: 0.1194 - val_loss: 3.5788 - val_mean_absolute_error: 1.5843 - val_mean_squared_error: 3.5699
# Epoch 20/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0884 - mean_absolute_error: 0.2150 - mean_squared_error: 0.0797 - val_loss: 2.2024 - val_mean_absolute_error: 1.1457 - val_mean_squared_error: 2.1939
# Epoch 21/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1126 - mean_absolute_error: 0.2483 - mean_squared_error: 0.1043 - val_loss: 3.1658 - val_mean_absolute_error: 1.4498 - val_mean_squared_error: 3.1579
# Epoch 22/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0973 - mean_absolute_error: 0.2238 - mean_squared_error: 0.0895 - val_loss: 3.2924 - val_mean_absolute_error: 1.4950 - val_mean_squared_error: 3.2848
# Epoch 23/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0928 - mean_absolute_error: 0.2209 - mean_squared_error: 0.0853 - val_loss: 2.5891 - val_mean_absolute_error: 1.2693 - val_mean_squared_error: 2.5818
# Epoch 24/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1052 - mean_absolute_error: 0.2388 - mean_squared_error: 0.0981 - val_loss: 2.9058 - val_mean_absolute_error: 1.3614 - val_mean_squared_error: 2.8988
# Epoch 25/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1014 - mean_absolute_error: 0.2394 - mean_squared_error: 0.0945 - val_loss: 2.1955 - val_mean_absolute_error: 1.1433 - val_mean_squared_error: 2.1887
# Epoch 26/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1404 - mean_absolute_error: 0.2719 - mean_squared_error: 0.1338 - val_loss: 3.4146 - val_mean_absolute_error: 1.5348 - val_mean_squared_error: 3.4081
# Epoch 27/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0821 - mean_absolute_error: 0.2071 - mean_squared_error: 0.0757 - val_loss: 2.4974 - val_mean_absolute_error: 1.2405 - val_mean_squared_error: 2.4909
# Epoch 28/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0923 - mean_absolute_error: 0.2196 - mean_squared_error: 0.0859 - val_loss: 2.6382 - val_mean_absolute_error: 1.2849 - val_mean_squared_error: 2.6318
# Epoch 29/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0897 - mean_absolute_error: 0.2259 - mean_squared_error: 0.0834 - val_loss: 2.8831 - val_mean_absolute_error: 1.3586 - val_mean_squared_error: 2.8769
# Epoch 30/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0744 - mean_absolute_error: 0.1986 - mean_squared_error: 0.0682 - val_loss: 1.7850 - val_mean_absolute_error: 1.0208 - val_mean_squared_error: 1.7788
# Epoch 31/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1151 - mean_absolute_error: 0.2334 - mean_squared_error: 0.1090 - val_loss: 2.8941 - val_mean_absolute_error: 1.3617 - val_mean_squared_error: 2.8881
# Epoch 32/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0832 - mean_absolute_error: 0.2128 - mean_squared_error: 0.0773 - val_loss: 2.6767 - val_mean_absolute_error: 1.2974 - val_mean_squared_error: 2.6707
# Epoch 33/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0797 - mean_absolute_error: 0.2058 - mean_squared_error: 0.0738 - val_loss: 3.1776 - val_mean_absolute_error: 1.4555 - val_mean_squared_error: 3.1718
# Epoch 34/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0814 - mean_absolute_error: 0.2059 - mean_squared_error: 0.0757 - val_loss: 2.6626 - val_mean_absolute_error: 1.2925 - val_mean_squared_error: 2.6568
# Epoch 35/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0876 - mean_absolute_error: 0.2151 - mean_squared_error: 0.0819 - val_loss: 2.5699 - val_mean_absolute_error: 1.2623 - val_mean_squared_error: 2.5643
# Epoch 36/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1182 - mean_absolute_error: 0.2553 - mean_squared_error: 0.1126 - val_loss: 2.7674 - val_mean_absolute_error: 1.3285 - val_mean_squared_error: 2.7619
# Epoch 37/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0652 - mean_absolute_error: 0.1795 - mean_squared_error: 0.0597 - val_loss: 3.1619 - val_mean_absolute_error: 1.4543 - val_mean_squared_error: 3.1564
# Epoch 38/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0757 - mean_absolute_error: 0.2025 - mean_squared_error: 0.0703 - val_loss: 2.8025 - val_mean_absolute_error: 1.3408 - val_mean_squared_error: 2.7970
# Epoch 39/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0759 - mean_absolute_error: 0.2020 - mean_squared_error: 0.0705 - val_loss: 2.1523 - val_mean_absolute_error: 1.1254 - val_mean_squared_error: 2.1470
# Epoch 40/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0722 - mean_absolute_error: 0.1941 - mean_squared_error: 0.0669 - val_loss: 2.2233 - val_mean_absolute_error: 1.1493 - val_mean_squared_error: 2.2180
# Epoch 41/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0718 - mean_absolute_error: 0.1899 - mean_squared_error: 0.0666 - val_loss: 2.5742 - val_mean_absolute_error: 1.2647 - val_mean_squared_error: 2.5689
# Epoch 42/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0649 - mean_absolute_error: 0.1807 - mean_squared_error: 0.0597 - val_loss: 2.5939 - val_mean_absolute_error: 1.2684 - val_mean_squared_error: 2.5887
# Epoch 43/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0669 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0618 - val_loss: 2.8934 - val_mean_absolute_error: 1.3602 - val_mean_squared_error: 2.8883
# Epoch 44/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0709 - mean_absolute_error: 0.1983 - mean_squared_error: 0.0659 - val_loss: 2.5505 - val_mean_absolute_error: 1.2618 - val_mean_squared_error: 2.5456
# Epoch 45/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0694 - mean_absolute_error: 0.1891 - mean_squared_error: 0.0645 - val_loss: 2.9804 - val_mean_absolute_error: 1.3956 - val_mean_squared_error: 2.9755
# Epoch 46/200
# 875/875 [==============================] - 24s 28ms/step - loss: 0.0719 - mean_absolute_error: 0.1961 - mean_squared_error: 0.0670 - val_loss: 2.4074 - val_mean_absolute_error: 1.2118 - val_mean_squared_error: 2.4026
# Epoch 47/200
# 875/875 [==============================] - 24s 28ms/step - loss: 0.0618 - mean_absolute_error: 0.1743 - mean_squared_error: 0.0571 - val_loss: 2.2830 - val_mean_absolute_error: 1.1690 - val_mean_squared_error: 2.2782
# Epoch 48/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0676 - mean_absolute_error: 0.1821 - mean_squared_error: 0.0629 - val_loss: 2.6052 - val_mean_absolute_error: 1.2808 - val_mean_squared_error: 2.6005
# Epoch 49/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0630 - mean_absolute_error: 0.1787 - mean_squared_error: 0.0583 - val_loss: 2.4626 - val_mean_absolute_error: 1.2316 - val_mean_squared_error: 2.4579
# Epoch 50/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0601 - mean_absolute_error: 0.1661 - mean_squared_error: 0.0555 - val_loss: 2.7647 - val_mean_absolute_error: 1.3206 - val_mean_squared_error: 2.7601
# Epoch 51/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0643 - mean_absolute_error: 0.1779 - mean_squared_error: 0.0597 - val_loss: 2.5744 - val_mean_absolute_error: 1.2720 - val_mean_squared_error: 2.5698
# Epoch 52/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0919 - mean_absolute_error: 0.2229 - mean_squared_error: 0.0873 - val_loss: 2.5535 - val_mean_absolute_error: 1.2609 - val_mean_squared_error: 2.5490
# Epoch 53/200
# 875/875 [==============================] - 436s 498ms/step - loss: 0.0650 - mean_absolute_error: 0.1887 - mean_squared_error: 0.0605 - val_loss: 2.1651 - val_mean_absolute_error: 1.1289 - val_mean_squared_error: 2.1606
# Epoch 54/200
# 875/875 [==============================] - 116s 133ms/step - loss: 0.1022 - mean_absolute_error: 0.2107 - mean_squared_error: 0.0977 - val_loss: 2.2922 - val_mean_absolute_error: 1.1691 - val_mean_squared_error: 2.2878
# Epoch 55/200
# 875/875 [==============================] - 1980s 2s/step - loss: 0.0704 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0661 - val_loss: 2.6339 - val_mean_absolute_error: 1.2914 - val_mean_squared_error: 2.6296
# Epoch 56/200
# 875/875 [==============================] - 16s 18ms/step - loss: 0.0528 - mean_absolute_error: 0.1586 - mean_squared_error: 0.0485 - val_loss: 1.9749 - val_mean_absolute_error: 1.0711 - val_mean_squared_error: 1.9706
# Epoch 57/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0525 - mean_absolute_error: 0.1568 - mean_squared_error: 0.0482 - val_loss: 2.0850 - val_mean_absolute_error: 1.1014 - val_mean_squared_error: 2.0807
# Epoch 58/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0607 - mean_absolute_error: 0.1662 - mean_squared_error: 0.0565 - val_loss: 2.4774 - val_mean_absolute_error: 1.2292 - val_mean_squared_error: 2.4732
# Epoch 59/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0578 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0536 - val_loss: 2.1773 - val_mean_absolute_error: 1.1350 - val_mean_squared_error: 2.1730
# Epoch 60/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0521 - mean_absolute_error: 0.1542 - mean_squared_error: 0.0479 - val_loss: 2.2251 - val_mean_absolute_error: 1.1478 - val_mean_squared_error: 2.2209
# Epoch 61/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0482 - mean_absolute_error: 0.1538 - mean_squared_error: 0.0441 - val_loss: 2.4825 - val_mean_absolute_error: 1.2420 - val_mean_squared_error: 2.4783
# Epoch 62/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0498 - mean_absolute_error: 0.1520 - mean_squared_error: 0.0457 - val_loss: 2.2666 - val_mean_absolute_error: 1.1597 - val_mean_squared_error: 2.2624
# Epoch 63/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0545 - mean_absolute_error: 0.1639 - mean_squared_error: 0.0504 - val_loss: 2.0965 - val_mean_absolute_error: 1.1046 - val_mean_squared_error: 2.0924
# Epoch 64/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0453 - mean_absolute_error: 0.1479 - mean_squared_error: 0.0412 - val_loss: 2.0962 - val_mean_absolute_error: 1.1012 - val_mean_squared_error: 2.0921
# Epoch 65/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0569 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0528 - val_loss: 2.6018 - val_mean_absolute_error: 1.2822 - val_mean_squared_error: 2.5977
# Epoch 66/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0521 - mean_absolute_error: 0.1593 - mean_squared_error: 0.0481 - val_loss: 2.1614 - val_mean_absolute_error: 1.1230 - val_mean_squared_error: 2.1573
# Epoch 67/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0468 - mean_absolute_error: 0.1503 - mean_squared_error: 0.0427 - val_loss: 1.9528 - val_mean_absolute_error: 1.0605 - val_mean_squared_error: 1.9488
# Epoch 68/200
# 875/875 [==============================] - 14s 15ms/step - loss: 0.0550 - mean_absolute_error: 0.1625 - mean_squared_error: 0.0510 - val_loss: 1.6402 - val_mean_absolute_error: 0.9684 - val_mean_squared_error: 1.6361
# Epoch 69/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0675 - mean_absolute_error: 0.1783 - mean_squared_error: 0.0636 - val_loss: 1.6937 - val_mean_absolute_error: 0.9808 - val_mean_squared_error: 1.6898
# Epoch 70/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0504 - mean_absolute_error: 0.1465 - mean_squared_error: 0.0465 - val_loss: 1.8599 - val_mean_absolute_error: 1.0318 - val_mean_squared_error: 1.8560
# Epoch 71/200
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0540 - mean_absolute_error: 0.1642 - mean_squared_error: 0.0501 - val_loss: 1.9639 - val_mean_absolute_error: 1.0634 - val_mean_squared_error: 1.9600
# Epoch 72/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0399 - mean_absolute_error: 0.1346 - mean_squared_error: 0.0361 - val_loss: 1.6221 - val_mean_absolute_error: 0.9613 - val_mean_squared_error: 1.6183
# Epoch 73/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0413 - mean_absolute_error: 0.1380 - mean_squared_error: 0.0375 - val_loss: 1.5695 - val_mean_absolute_error: 0.9410 - val_mean_squared_error: 1.5657
# Epoch 74/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0508 - mean_absolute_error: 0.1554 - mean_squared_error: 0.0470 - val_loss: 1.6579 - val_mean_absolute_error: 0.9698 - val_mean_squared_error: 1.6541
# Epoch 75/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0419 - mean_absolute_error: 0.1415 - mean_squared_error: 0.0381 - val_loss: 1.9499 - val_mean_absolute_error: 1.0596 - val_mean_squared_error: 1.9461
# Epoch 76/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0503 - mean_absolute_error: 0.1572 - mean_squared_error: 0.0465 - val_loss: 1.8577 - val_mean_absolute_error: 1.0327 - val_mean_squared_error: 1.8540
# Epoch 77/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0476 - mean_absolute_error: 0.1527 - mean_squared_error: 0.0439 - val_loss: 1.7745 - val_mean_absolute_error: 1.0009 - val_mean_squared_error: 1.7708
# Epoch 78/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0451 - mean_absolute_error: 0.1489 - mean_squared_error: 0.0415 - val_loss: 2.0050 - val_mean_absolute_error: 1.0651 - val_mean_squared_error: 2.0014
# Epoch 79/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0440 - mean_absolute_error: 0.1435 - mean_squared_error: 0.0404 - val_loss: 2.0267 - val_mean_absolute_error: 1.0795 - val_mean_squared_error: 2.0231
# Epoch 80/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0364 - mean_absolute_error: 0.1310 - mean_squared_error: 0.0327 - val_loss: 1.8544 - val_mean_absolute_error: 1.0227 - val_mean_squared_error: 1.8507
# Epoch 81/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0374 - mean_absolute_error: 0.1308 - mean_squared_error: 0.0337 - val_loss: 2.1050 - val_mean_absolute_error: 1.0957 - val_mean_squared_error: 2.1014
# Epoch 82/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0405 - mean_absolute_error: 0.1369 - mean_squared_error: 0.0369 - val_loss: 2.0692 - val_mean_absolute_error: 1.0950 - val_mean_squared_error: 2.0656
# Epoch 83/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0377 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0341 - val_loss: 2.1537 - val_mean_absolute_error: 1.1251 - val_mean_squared_error: 2.1501
# Epoch 84/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0437 - mean_absolute_error: 0.1535 - mean_squared_error: 0.0401 - val_loss: 1.9010 - val_mean_absolute_error: 1.0358 - val_mean_squared_error: 1.8974
# Epoch 85/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0372 - mean_absolute_error: 0.1277 - mean_squared_error: 0.0336 - val_loss: 2.2669 - val_mean_absolute_error: 1.1700 - val_mean_squared_error: 2.2633
# Epoch 86/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0398 - mean_absolute_error: 0.1395 - mean_squared_error: 0.0363 - val_loss: 2.4500 - val_mean_absolute_error: 1.2285 - val_mean_squared_error: 2.4464
# Epoch 87/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0461 - mean_absolute_error: 0.1518 - mean_squared_error: 0.0426 - val_loss: 1.7367 - val_mean_absolute_error: 0.9874 - val_mean_squared_error: 1.7331
# Epoch 88/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0332 - mean_absolute_error: 0.1268 - mean_squared_error: 0.0296 - val_loss: 1.9588 - val_mean_absolute_error: 1.0607 - val_mean_squared_error: 1.9552
# Epoch 89/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0321 - mean_absolute_error: 0.1208 - mean_squared_error: 0.0286 - val_loss: 1.7206 - val_mean_absolute_error: 0.9780 - val_mean_squared_error: 1.7171
# Epoch 90/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0419 - mean_absolute_error: 0.1408 - mean_squared_error: 0.0384 - val_loss: 1.8123 - val_mean_absolute_error: 1.0004 - val_mean_squared_error: 1.8087
# Epoch 91/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0369 - mean_absolute_error: 0.1327 - mean_squared_error: 0.0334 - val_loss: 1.9241 - val_mean_absolute_error: 1.0326 - val_mean_squared_error: 1.9206
# Epoch 92/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0409 - mean_absolute_error: 0.1397 - mean_squared_error: 0.0374 - val_loss: 1.9379 - val_mean_absolute_error: 1.0506 - val_mean_squared_error: 1.9345
# Epoch 93/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0382 - mean_absolute_error: 0.1378 - mean_squared_error: 0.0347 - val_loss: 1.7358 - val_mean_absolute_error: 0.9827 - val_mean_squared_error: 1.7323
# Epoch 94/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0326 - mean_absolute_error: 0.1196 - mean_squared_error: 0.0292 - val_loss: 2.3345 - val_mean_absolute_error: 1.1833 - val_mean_squared_error: 2.3311
# Epoch 95/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0323 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0290 - val_loss: 1.7382 - val_mean_absolute_error: 0.9739 - val_mean_squared_error: 1.7348
# Epoch 96/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0350 - mean_absolute_error: 0.1280 - mean_squared_error: 0.0316 - val_loss: 2.1179 - val_mean_absolute_error: 1.1150 - val_mean_squared_error: 2.1145
# Epoch 97/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0421 - mean_absolute_error: 0.1314 - mean_squared_error: 0.0388 - val_loss: 1.6972 - val_mean_absolute_error: 0.9665 - val_mean_squared_error: 1.6939
# Epoch 98/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0352 - mean_absolute_error: 0.1298 - mean_squared_error: 0.0319 - val_loss: 1.6073 - val_mean_absolute_error: 0.9383 - val_mean_squared_error: 1.6039
# Epoch 99/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0366 - mean_absolute_error: 0.1250 - mean_squared_error: 0.0333 - val_loss: 1.6065 - val_mean_absolute_error: 0.9305 - val_mean_squared_error: 1.6031
# Epoch 100/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0383 - mean_absolute_error: 0.1360 - mean_squared_error: 0.0350 - val_loss: 1.5558 - val_mean_absolute_error: 0.9232 - val_mean_squared_error: 1.5524
# Epoch 101/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0360 - mean_absolute_error: 0.1306 - mean_squared_error: 0.0327 - val_loss: 1.7025 - val_mean_absolute_error: 0.9734 - val_mean_squared_error: 1.6992
# Epoch 102/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0343 - mean_absolute_error: 0.1262 - mean_squared_error: 0.0310 - val_loss: 1.6342 - val_mean_absolute_error: 0.9522 - val_mean_squared_error: 1.6309
# Epoch 103/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0292 - mean_absolute_error: 0.1137 - mean_squared_error: 0.0259 - val_loss: 1.6105 - val_mean_absolute_error: 0.9344 - val_mean_squared_error: 1.6073
# Epoch 104/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0303 - mean_absolute_error: 0.1176 - mean_squared_error: 0.0271 - val_loss: 1.7194 - val_mean_absolute_error: 0.9676 - val_mean_squared_error: 1.7162
# Epoch 105/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0335 - mean_absolute_error: 0.1217 - mean_squared_error: 0.0303 - val_loss: 1.9535 - val_mean_absolute_error: 1.0296 - val_mean_squared_error: 1.9503
# Epoch 106/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0304 - mean_absolute_error: 0.1168 - mean_squared_error: 0.0272 - val_loss: 1.7627 - val_mean_absolute_error: 0.9748 - val_mean_squared_error: 1.7595
# Epoch 107/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0285 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0254 - val_loss: 1.5525 - val_mean_absolute_error: 0.9117 - val_mean_squared_error: 1.5493
# Epoch 108/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0284 - mean_absolute_error: 0.1064 - mean_squared_error: 0.0253 - val_loss: 1.9490 - val_mean_absolute_error: 1.0553 - val_mean_squared_error: 1.9458
# Epoch 109/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0288 - mean_absolute_error: 0.1140 - mean_squared_error: 0.0257 - val_loss: 1.6905 - val_mean_absolute_error: 0.9528 - val_mean_squared_error: 1.6874
# Epoch 110/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0305 - mean_absolute_error: 0.1127 - mean_squared_error: 0.0274 - val_loss: 1.9716 - val_mean_absolute_error: 1.0641 - val_mean_squared_error: 1.9685
# Epoch 111/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0478 - mean_absolute_error: 0.1412 - mean_squared_error: 0.0447 - val_loss: 2.3680 - val_mean_absolute_error: 1.1940 - val_mean_squared_error: 2.3649
# Epoch 112/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0319 - mean_absolute_error: 0.1190 - mean_squared_error: 0.0288 - val_loss: 1.5907 - val_mean_absolute_error: 0.9276 - val_mean_squared_error: 1.5876
# Epoch 113/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0406 - mean_absolute_error: 0.1436 - mean_squared_error: 0.0376 - val_loss: 1.6303 - val_mean_absolute_error: 0.9397 - val_mean_squared_error: 1.6273
# Epoch 114/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0279 - mean_absolute_error: 0.1070 - mean_squared_error: 0.0248 - val_loss: 1.6271 - val_mean_absolute_error: 0.9349 - val_mean_squared_error: 1.6241
# Epoch 115/200
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0367 - mean_absolute_error: 0.1284 - mean_squared_error: 0.0337 - val_loss: 1.4954 - val_mean_absolute_error: 0.8941 - val_mean_squared_error: 1.4924
# Epoch 116/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0296 - mean_absolute_error: 0.1059 - mean_squared_error: 0.0267 - val_loss: 1.6060 - val_mean_absolute_error: 0.9296 - val_mean_squared_error: 1.6030
# Epoch 117/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0242 - mean_absolute_error: 0.1044 - mean_squared_error: 0.0212 - val_loss: 1.5665 - val_mean_absolute_error: 0.9125 - val_mean_squared_error: 1.5635
# Epoch 118/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0294 - mean_absolute_error: 0.1080 - mean_squared_error: 0.0264 - val_loss: 1.9528 - val_mean_absolute_error: 1.0536 - val_mean_squared_error: 1.9499
# Epoch 119/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0268 - mean_absolute_error: 0.1112 - mean_squared_error: 0.0238 - val_loss: 1.7776 - val_mean_absolute_error: 0.9920 - val_mean_squared_error: 1.7747
# Epoch 120/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0234 - mean_absolute_error: 0.0991 - mean_squared_error: 0.0204 - val_loss: 1.6669 - val_mean_absolute_error: 0.9537 - val_mean_squared_error: 1.6640
# Epoch 121/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0395 - mean_absolute_error: 0.1368 - mean_squared_error: 0.0366 - val_loss: 1.4784 - val_mean_absolute_error: 0.8891 - val_mean_squared_error: 1.4755
# Epoch 122/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0292 - mean_absolute_error: 0.1148 - mean_squared_error: 0.0263 - val_loss: 1.8647 - val_mean_absolute_error: 1.0212 - val_mean_squared_error: 1.8618
# Epoch 123/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0408 - mean_absolute_error: 0.1294 - mean_squared_error: 0.0379 - val_loss: 1.5569 - val_mean_absolute_error: 0.9142 - val_mean_squared_error: 1.5541
# Epoch 124/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0249 - mean_absolute_error: 0.1057 - mean_squared_error: 0.0221 - val_loss: 1.5006 - val_mean_absolute_error: 0.8936 - val_mean_squared_error: 1.4978
# Epoch 125/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0252 - mean_absolute_error: 0.1017 - mean_squared_error: 0.0223 - val_loss: 1.3502 - val_mean_absolute_error: 0.8432 - val_mean_squared_error: 1.3474
# Epoch 126/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0328 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0300 - val_loss: 1.4099 - val_mean_absolute_error: 0.8643 - val_mean_squared_error: 1.4071
# Epoch 127/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0238 - mean_absolute_error: 0.1068 - mean_squared_error: 0.0210 - val_loss: 1.4231 - val_mean_absolute_error: 0.8624 - val_mean_squared_error: 1.4203
# Epoch 128/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0268 - mean_absolute_error: 0.1065 - mean_squared_error: 0.0240 - val_loss: 1.4367 - val_mean_absolute_error: 0.8706 - val_mean_squared_error: 1.4338
# Epoch 129/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0227 - mean_absolute_error: 0.0965 - mean_squared_error: 0.0199 - val_loss: 1.5391 - val_mean_absolute_error: 0.8931 - val_mean_squared_error: 1.5364
# Epoch 130/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0343 - mean_absolute_error: 0.1239 - mean_squared_error: 0.0315 - val_loss: 1.4705 - val_mean_absolute_error: 0.8828 - val_mean_squared_error: 1.4677
# Epoch 131/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0280 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0253 - val_loss: 1.5932 - val_mean_absolute_error: 0.9133 - val_mean_squared_error: 1.5905
# Epoch 132/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0277 - mean_absolute_error: 0.1139 - mean_squared_error: 0.0250 - val_loss: 1.7935 - val_mean_absolute_error: 0.9983 - val_mean_squared_error: 1.7908
# Epoch 133/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0322 - mean_absolute_error: 0.1160 - mean_squared_error: 0.0295 - val_loss: 1.4766 - val_mean_absolute_error: 0.8801 - val_mean_squared_error: 1.4739
# Epoch 134/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0253 - mean_absolute_error: 0.1060 - mean_squared_error: 0.0226 - val_loss: 1.5339 - val_mean_absolute_error: 0.9065 - val_mean_squared_error: 1.5312
# Epoch 135/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0261 - mean_absolute_error: 0.1125 - mean_squared_error: 0.0234 - val_loss: 1.4380 - val_mean_absolute_error: 0.8710 - val_mean_squared_error: 1.4353
# Epoch 136/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0576 - mean_absolute_error: 0.1493 - mean_squared_error: 0.0549 - val_loss: 1.3447 - val_mean_absolute_error: 0.8465 - val_mean_squared_error: 1.3421
# Epoch 137/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0333 - mean_absolute_error: 0.1154 - mean_squared_error: 0.0307 - val_loss: 1.3273 - val_mean_absolute_error: 0.8353 - val_mean_squared_error: 1.3247
# Epoch 138/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0271 - mean_absolute_error: 0.1111 - mean_squared_error: 0.0245 - val_loss: 1.2775 - val_mean_absolute_error: 0.8230 - val_mean_squared_error: 1.2748
# Epoch 139/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0230 - mean_absolute_error: 0.0956 - mean_squared_error: 0.0204 - val_loss: 1.3633 - val_mean_absolute_error: 0.8381 - val_mean_squared_error: 1.3607
# Epoch 140/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0225 - mean_absolute_error: 0.1048 - mean_squared_error: 0.0199 - val_loss: 1.3127 - val_mean_absolute_error: 0.8349 - val_mean_squared_error: 1.3100
# Epoch 141/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0185 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0159 - val_loss: 1.3691 - val_mean_absolute_error: 0.8287 - val_mean_squared_error: 1.3664
# Epoch 142/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0267 - mean_absolute_error: 0.1066 - mean_squared_error: 0.0241 - val_loss: 1.3541 - val_mean_absolute_error: 0.8321 - val_mean_squared_error: 1.3514
# Epoch 143/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0540 - mean_absolute_error: 0.1430 - mean_squared_error: 0.0514 - val_loss: 1.8749 - val_mean_absolute_error: 1.0292 - val_mean_squared_error: 1.8723
# Epoch 144/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0324 - mean_absolute_error: 0.1221 - mean_squared_error: 0.0298 - val_loss: 1.3159 - val_mean_absolute_error: 0.8185 - val_mean_squared_error: 1.3133
# Epoch 145/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0255 - mean_absolute_error: 0.0968 - mean_squared_error: 0.0230 - val_loss: 1.3150 - val_mean_absolute_error: 0.8193 - val_mean_squared_error: 1.3124
# Epoch 146/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0254 - mean_absolute_error: 0.1047 - mean_squared_error: 0.0229 - val_loss: 1.2388 - val_mean_absolute_error: 0.8109 - val_mean_squared_error: 1.2363
# Epoch 147/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0228 - mean_absolute_error: 0.0953 - mean_squared_error: 0.0203 - val_loss: 1.3844 - val_mean_absolute_error: 0.8388 - val_mean_squared_error: 1.3819
# Epoch 148/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0183 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0158 - val_loss: 1.4506 - val_mean_absolute_error: 0.8512 - val_mean_squared_error: 1.4481
# Epoch 149/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0226 - mean_absolute_error: 0.1001 - mean_squared_error: 0.0201 - val_loss: 1.2548 - val_mean_absolute_error: 0.8096 - val_mean_squared_error: 1.2523
# Epoch 150/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0166 - mean_absolute_error: 0.0821 - mean_squared_error: 0.0141 - val_loss: 1.3095 - val_mean_absolute_error: 0.8080 - val_mean_squared_error: 1.3069
# Epoch 151/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0236 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0211 - val_loss: 1.2904 - val_mean_absolute_error: 0.8212 - val_mean_squared_error: 1.2879
# Epoch 152/200
# 736/875 [========================>.....] - ETA: 1s - loss: 0.0236 - mean_absolute_error: 0.0999 - mean_squared_error: 0.0210

# %%
hist = pd.DataFrame(history.history)
hist['epoch']= history.epoch
hist.tail()
# Out:
#          val_loss  val_mean_absolute_error  val_mean_squared_error  \
# 195  6.650632e+07              6355.818481            6.650632e+07
# 196  6.275853e+07              6161.197162            6.275853e+07
# 197  5.944006e+07              5997.135702            5.944006e+07
# 198  6.229281e+07              6138.579988            6.229281e+07
# 199  6.106594e+07              6076.085226            6.106594e+07
#
#              loss  mean_absolute_error  mean_squared_error  epoch
# 195  1.702399e+06           881.769361        1.702399e+06    195
# 196  1.711892e+06           930.596856        1.711892e+06    196
# 197  1.580298e+06           893.164042        1.580298e+06    197
# 198  1.912179e+06           979.157146        1.912179e+06    198
# 199  1.614590e+06           912.569914        1.614590e+06    199

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  #plt.ylim([0,5])
  plt.legend()
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  #plt.ylim([0,20])
  plt.legend()
  plt.show()


plot_history(history)

# %%
test_predictions = model.predict(norm_flux).flatten()

plt.scatter(normalize(teff), test_predictions)
plt.xlabel('True Values [Teff]')
plt.ylabel('Predictions [Teff]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

print('test predictions=', test_predictions)
# Out:
# test predictions= [ 6836.807   6837.5747  6836.7603 ... 10159.98   12968.633  12631.623 ]
