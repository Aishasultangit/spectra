# %% [markdown]
# # Train the StarNet Model
#
# This notebook takes you through the steps of how to train a StarNet Model
# - Required Python packages: `numpy h5py keras`
# - Required data files: training_data.h5, mean_and_std.npy
#
# Note: We use tensorflow for the keras backend.

# %%
import numpy as np
import h5py
import random
import keras
from keras.models import Model
from keras.layers import Input, Dense, InputLayer, Flatten, Reshape, Concatenate, concatenate
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.optimizers import Adam
import tensorflow as tf
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.utils import HDF5Matrix
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc


#Loading the data

#RVSFlux normalized
pathrvs = 'norm_rvsflux.h5'
readrvs = h5py.File(pathrvs, 'r')
print(readrvs.keys())
rvs = readrvs.get('normrvs')
norm_rvsflux = np.array(rvs)
readrvs.close()

type(rvs)
print('shape of rvsflux:', np.shape(norm_rvsflux))
# Out:
# <KeysViewHDF5 ['normrvs']>
# shape of rvsflux: (415, 1134)

# %%
#BPFlux
pathbp = 'bpflux.h5'
readbp = h5py.File(pathbp, 'r')
#print('total number of wave and flux in the folder:'len(readbp.keys()))
bpflux = readbp.get('bpflux0')
bpflux = np.array(bpflux)


norm_bpflux= []

for ii in range(np.shape(norm_rvsflux)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star #',ii)
        fluxlabel = 'bpflux'+str(ii)
        wavelabel = 'bpwave' +str(ii)
        flux = readbp.get(fluxlabel)
        wave= readbp.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_bpflux.append(normflux)


        
norm_bpflux= np.array(norm_bpflux)

print('shape of norm bpflux:', np.shape(norm_bpflux))
#print('shape of norm bpflux:', print(norm_bpflux[0:10]))
# Out:
# shape of norm bpflux: (415, 53)

# %%
#RPFlux
pathrp = 'rpflux.h5'
readrp = h5py.File(pathrp, 'r')
#print('total number of wave and flux in the folder:'len(readbp.keys()))
rpflux = readrp.get('rpflux0')
rpflux = np.array(rpflux)


norm_rpflux= []

for ii in range(np.shape(norm_rvsflux)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star:',ii)
        fluxlabel = 'rpflux'+str(ii)
        wavelabel = 'rpwave' +str(ii)
        
        flux = readrp.get(fluxlabel)
        wave= readrp.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_rpflux.append(normflux)


        
norm_rpflux= np.array(norm_rpflux)

print('shape of norm_rpflux:', np.shape(norm_rpflux))
#print('output of norm_flux:', print(norm_rpflux[0:10]))

#print('The shapes of features and labels:', np.shape(norm_flux), np.shape(logteff))
# Out:
# shape of norm_rpflux: (415, 49)

# %%
#LogTeff
modparam = 'modparam_feh0.h5' #model parameters includes log g and teff
readfile = h5py.File(modparam, 'r')
print(readfile.keys())
logteff = readfile.get('logteff')
logteff = np.array(logteff)
readfile.close()
# Out:
# <KeysViewHDF5 ['logg', 'logteff']>

# %%
#features
num_tot = len(logteff)
print('total number of input stars =', num_tot)
plim = 0.8
ran_frac = np.random.uniform(0,1,num_tot)
#print('ranfrac=' , ran_frac)




#Input flux data of RVS, BP, RP
x_RVStrain = norm_rvsflux[ran_frac < plim, :]
print('number of RVS training data=', len(x_RVStrain[:,0]))
x_RVScv = norm_rvsflux[ran_frac >= plim, :] #test set we left for the application

x_BPtrain = norm_bpflux[ran_frac < plim, :]
print('number of BP training data=', len(x_BPtrain[:,0]))
x_BPcv = norm_bpflux[ran_frac >= plim, :]

x_RPtrain =norm_rpflux[ran_frac < plim, :]
print('number of RP training data=', len(x_RPtrain[:,0]))
x_RPcv = norm_rpflux[ran_frac >= plim, :]


#print('x_BPtrain', x_BPtrain)

#x_train_combined = np.vstack (x_RVStrain[0,:],x_RPtrain[0,:]) 

#output label which is the logteff
y_train = logteff[ran_frac< plim]
y_cv = logteff[ran_frac >= plim] #test set


print('The size of CVS for the input flux data')
print('RVS cvs=', np.shape(x_RVScv))
print('BP cvs=', np.shape(x_BPcv))
print('RP cvs=', np.shape(x_RPcv))

print('the size of output label=', np.shape(y_cv) )

id = np.linspace(0, len(x_RVStrain[:, 0])-1, len(x_RVStrain[:, 0]))
plt.plot(id, y_train)
plt.show()
# Out:
# total number of input stars = 415
# number of RVS training data= 331
# number of BP training data= 331
# number of RP training data= 331
# The size of CVS for the input flux data
# RVS cvs= (84, 1134)
# BP cvs= (84, 53)
# RP cvs= (84, 49)
# the size of output label= (84,)

# %% [markdown]
# ** Normalization **
#
# Write a function to normalize the output labels. Each label will be normalized to have approximately have a mean of zero and unit variance.
#
# NOTE: This is necessary to put output labels on a similar scale in order for the model to train properly, this process is reversed in the test stage to give the output labels their proper units

# %%
mean_labels=np.mean(logteff)
std_labels=np.std(logteff)
print('mean and std teff=', mean_labels, std_labels)
def normalize(labels):
    # Normalize labels
    return (labels-mean_labels) / std_labels
# Out:
# mean and std teff= 3.9478135884985908 0.23697442871023666

# %%
#normalize the y labels 
#print('y train before norm=', y_train )
y_train= normalize(y_train)
y_cv= normalize(y_cv)
#print('y train after norm=', y_train )

# %% [markdown]
# **Build the StarNet model architecture**
#
# The StarNet architecture is built with:
# - input layer
# - 2 convolutional layers
# - 1 maxpooling layer followed by flattening for the fully connected layer
# - 2 fully connected layers
# - output layer
#
# First, let's define some model variables.

# %%
# activation function used following every layer except for the output layers
activation = 'relu'

# model weight initializer
initializer = 'he_normal'

# number of filters used in the convolutional layers
#num_filters = [4,16]
num_filters = [8,32]
#num_filters = [8,16]

# length of the filters in the convolutional layers
#filter_length = 8
#filter_length = 16
filter_length = 8

# length of the maxpooling window 
pool_length = 4

# number of nodes in each of the hidden fully connected layers
num_hidden = [256,128]
#num_hidden = [24,12]

# number of spectra fed into model at once during training
batch_size = 64

# maximum number of interations for model training
#max_epochs = 200
#max_epochs = 100
#max_epochs = 150 
#max_epochs = 350
#max_epochs = 225
#max_epochs = 180
#max_epochs = 450
#max_epochs = 300
max_epochs = 180


# initial learning rate for optimization algorithm
lr = 0.000003 #handled by Adam
    
# exponential decay rate for the 1st moment estimates for optimization algorithm
beta_1 = 0.9

# exponential decay rate for the 2nd moment estimates for optimization algorithm
beta_2 = 0.999

# a small constant for numerical stability for optimization algorithm
optimizer_epsilon = 1e-08

# %%
num_RVSfluxes=len(x_RVStrain[0,:]) 
print('number of RVS fluxes=', num_RVSfluxes)

num_BPfluxes=len(x_BPtrain[0,:]) 
print('number of BP fluxes=', num_BPfluxes)

num_RPfluxes=len(x_RPtrain[0,:]) 
print('number of RP fluxes=', num_RPfluxes)

num_labels= 1
print('number of training teff=', num_labels)

#ilam = np.linspace(0, num_fluxes-1, num_fluxes)
#plt.plot(ilam, x_train[329, :])
#plt.plot()

#iy = np.linspace(0, len(y_train)-1, len(y_train))
#plt.plot(iy, y_train)
#plt.plot()
# Out:
# number of RVS fluxes= 1134
# number of BP fluxes= 53
# number of RP fluxes= 49
# number of training teff= 1

# %%
first_input = Input(shape=(2, ))
first_dense = Dense(1, )(first_input)

second_input = Input(shape=(2, ))
second_dense = Dense(1, )(second_input)

merge_one = concatenate([first_dense, second_dense])

model = Model(inputs=[first_input, second_input], outputs=merge_one)

# %%
# Input RVS spectra
# print(' num_RVSfluxes=', num_RVSfluxes)
input_RVSspec = Input(shape=(num_RVSfluxes,), name='rvs_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for RVS layers
cur_rvs = Reshape((num_RVSfluxes, 1))(input_RVSspec)

# CNN layers
cur_rvs = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_rvs) #first CNN layer
cur_rvs = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_rvs) #2nd CNN layer

# Max pooling layer
cur_rvs = MaxPooling1D(pool_size=pool_length)(cur_rvs)

# Flatten the current input for the fully-connected layers
cur_rvs = Flatten()(cur_rvs)


##############################################################################################


# Input BP spectra
# print(' num_BPfluxes=', num_BPfluxes)
input_BPspec = Input(shape=(num_BPfluxes,), name='bp_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for BP layers
cur_bp = Reshape((num_BPfluxes, 1))(input_BPspec)

# CNN layers
cur_bp = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_bp) #first CNN layer
cur_bp = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_bp) #2nd CNN layer

# Max pooling layer
cur_bp = MaxPooling1D(pool_size=pool_length)(cur_bp)


# Flatten the current input for the fully-connected layers
cur_bp = Flatten()(cur_bp)


################################################################################################

# Input RP spectra
input_RPspec = Input(shape=(num_RPfluxes,), name='rp_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for CNN layers
cur_rp = Reshape((num_RPfluxes, 1))(input_RPspec)

# CNN layers
cur_rp = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_rp) #first CNN layer
cur_rp = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_rp) #2nd CNN layer

# Max pooling layer
cur_rp = MaxPooling1D(pool_size=pool_length)(cur_rp)

# Flatten the current input for the fully-connected layers
cur_rp = Flatten()(cur_rp)

###############################################################################################

#concatenate RVS/BP/RP and then insert it to dense layer 

cur_comb = concatenate([cur_rvs, cur_bp, cur_rp])

# Fully-connected layers
cur_final = Dense(units=num_hidden[0], kernel_initializer=initializer, 
               activation=activation)(cur_comb)
cur_final = Dense(units=num_hidden[1], kernel_initializer=initializer, 
               activation=activation)(cur_final)

# Output nodes
output_final = Dense(units=num_labels, activation="linear", 
                    input_dim=num_hidden[1], name='output_y')(cur_final)


model = Model(inputs = [input_RVSspec, input_BPspec, input_RPspec], outputs=output_final)

# %% [markdown]
# **More model techniques**
# * The `Adam` optimizer is the gradient descent algorithm used for minimizing the loss function
# * `EarlyStopping` uses the cross-validation set to test the model following every iteration and stops the training if the cv loss does not decrease by `min_delta` after `patience` iterations
# * `ReduceLROnPlateau` is a form of learning rate decay where the learning rate is decreased by a factor of `factor` if the training loss does not decrease by `epsilon` after `patience` iterations unless the learning rate has reached `min_lr`

# %%
# Default loss function parameters
early_stopping_min_delta = 0.0007
early_stopping_patience = 4
reduce_lr_factor = 0.5
reuce_lr_epsilon = 0.0000009
reduce_lr_patience = 2
reduce_lr_min = 0.00008

# loss function to minimize
loss_function = 'mean_squared_error'

# compute mean absolute deviation
metrics = ['mae', 'mse']
#metrics = ['mae']

# %%
#optimizer = Adam(lr=lr, beta_1=beta_1, beta_2=beta_2, epsilon=optimizer_epsilon, decay=0.0)
optimizer = Adam(lr=0.005 )

early_stopping = EarlyStopping(monitor='val_loss', min_delta=early_stopping_min_delta, 
                                       patience=early_stopping_patience, verbose=2, mode='min')

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, epsilon=reuce_lr_epsilon, 
                                  patience=reduce_lr_patience, min_lr=reduce_lr_min, mode='min', verbose=2)
# Out:
# /anaconda3/lib/python3.6/site-packages/keras/callbacks.py:1065: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '

# %% [markdown]
# **Compile model**

# %%
model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# rvs_input_x (InputLayer)        (None, 1134)         0
# __________________________________________________________________________________________________
# bp_input_x (InputLayer)         (None, 53)           0
# __________________________________________________________________________________________________
# rp_input_x (InputLayer)         (None, 49)           0
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1134, 1)      0           rvs_input_x[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 53, 1)        0           bp_input_x[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 49, 1)        0           rp_input_x[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 1134, 8)      72          reshape_4[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 53, 8)        72          reshape_5[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 49, 8)        72          reshape_6[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 1134, 32)     2080        conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 53, 32)       2080        conv1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 49, 32)       2080        conv1d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 283, 32)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 13, 32)       0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 12, 32)       0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 9056)         0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 416)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 384)          0           max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 9856)         0           flatten_4[0][0]
#                                                                  flatten_5[0][0]
#                                                                  flatten_6[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          2523392     concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          32896       dense_5[0][0]
# __________________________________________________________________________________________________
# output_y (Dense)                (None, 1)            129         dense_6[0][0]
# ==================================================================================================
# Total params: 2,562,873
# Trainable params: 2,562,873
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Train model**

# %%
#history = model.fit(x_train, y_train, validation_data=(x_cv, y_cv),
          #epochs=max_epochs, verbose=1, shuffle='batch',
         #callbacks=[early_stopping, reduce_lr])

history = model.fit([x_RVStrain, x_BPtrain, x_RPtrain], y_train, validation_data=([x_RVScv, x_BPcv, x_RPcv], y_cv),
          epochs=max_epochs, verbose=1, shuffle='batch')
# Out:
# Train on 331 samples, validate on 84 samples
# Epoch 1/180
# 331/331 [==============================] - 2s 6ms/step - loss: 2991.4372 - mean_absolute_error: 28.4140 - mean_squared_error: 2991.4372 - val_loss: 1.1373 - val_mean_absolute_error: 0.8559 - val_mean_squared_error: 1.1373
# Epoch 2/180
# 331/331 [==============================] - 0s 1ms/step - loss: 22.7231 - mean_absolute_error: 4.1680 - mean_squared_error: 22.7231 - val_loss: 1.2128 - val_mean_absolute_error: 0.8858 - val_mean_squared_error: 1.2128
# Epoch 3/180
# 331/331 [==============================] - 0s 1ms/step - loss: 6.0460 - mean_absolute_error: 2.2772 - mean_squared_error: 6.0460 - val_loss: 2.6131 - val_mean_absolute_error: 1.3850 - val_mean_squared_error: 2.6131
# Epoch 4/180
# 331/331 [==============================] - 1s 2ms/step - loss: 2.9230 - mean_absolute_error: 1.4170 - mean_squared_error: 2.9230 - val_loss: 1.5962 - val_mean_absolute_error: 1.0390 - val_mean_squared_error: 1.5962
# Epoch 5/180
# 331/331 [==============================] - 0s 1ms/step - loss: 1.3131 - mean_absolute_error: 0.9690 - mean_squared_error: 1.3131 - val_loss: 1.4988 - val_mean_absolute_error: 1.0501 - val_mean_squared_error: 1.4988
# Epoch 6/180
# 331/331 [==============================] - 0s 1ms/step - loss: 1.2722 - mean_absolute_error: 0.8496 - mean_squared_error: 1.2722 - val_loss: 0.6090 - val_mean_absolute_error: 0.6313 - val_mean_squared_error: 0.6090
# Epoch 7/180
# 331/331 [==============================] - 0s 1ms/step - loss: 1.5039 - mean_absolute_error: 1.0263 - mean_squared_error: 1.5039 - val_loss: 1.5216 - val_mean_absolute_error: 1.0777 - val_mean_squared_error: 1.5216
# Epoch 8/180
# 331/331 [==============================] - 0s 1ms/step - loss: 2.0057 - mean_absolute_error: 1.1575 - mean_squared_error: 2.0057 - val_loss: 0.6220 - val_mean_absolute_error: 0.6050 - val_mean_squared_error: 0.6220
# Epoch 9/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.8938 - mean_absolute_error: 0.8274 - mean_squared_error: 0.8938 - val_loss: 5.2279 - val_mean_absolute_error: 2.1921 - val_mean_squared_error: 5.2279
# Epoch 10/180
# 331/331 [==============================] - 0s 1ms/step - loss: 1.2594 - mean_absolute_error: 0.9670 - mean_squared_error: 1.2594 - val_loss: 0.5137 - val_mean_absolute_error: 0.5799 - val_mean_squared_error: 0.5137
# Epoch 11/180
# 331/331 [==============================] - 0s 1ms/step - loss: 1.7036 - mean_absolute_error: 0.9721 - mean_squared_error: 1.7036 - val_loss: 0.4038 - val_mean_absolute_error: 0.5029 - val_mean_squared_error: 0.4038
# Epoch 12/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.7249 - mean_absolute_error: 0.6387 - mean_squared_error: 0.7249 - val_loss: 0.3983 - val_mean_absolute_error: 0.4703 - val_mean_squared_error: 0.3983
# Epoch 13/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.7904 - mean_absolute_error: 0.7488 - mean_squared_error: 0.7904 - val_loss: 0.2656 - val_mean_absolute_error: 0.4142 - val_mean_squared_error: 0.2656
# Epoch 14/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.4047 - mean_absolute_error: 0.5025 - mean_squared_error: 0.4047 - val_loss: 0.6653 - val_mean_absolute_error: 0.7554 - val_mean_squared_error: 0.6653
# Epoch 15/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.6632 - mean_absolute_error: 0.7066 - mean_squared_error: 0.6632 - val_loss: 1.0991 - val_mean_absolute_error: 1.0138 - val_mean_squared_error: 1.0991
# Epoch 16/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.5770 - mean_absolute_error: 0.6900 - mean_squared_error: 0.5770 - val_loss: 2.5380 - val_mean_absolute_error: 1.5737 - val_mean_squared_error: 2.5380
# Epoch 17/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.7256 - mean_absolute_error: 0.7621 - mean_squared_error: 0.7256 - val_loss: 1.3196 - val_mean_absolute_error: 1.1238 - val_mean_squared_error: 1.3196
# Epoch 18/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.5004 - mean_absolute_error: 0.5893 - mean_squared_error: 0.5004 - val_loss: 0.5101 - val_mean_absolute_error: 0.6728 - val_mean_squared_error: 0.5101
# Epoch 19/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.2470 - mean_absolute_error: 0.4262 - mean_squared_error: 0.2470 - val_loss: 0.3312 - val_mean_absolute_error: 0.5296 - val_mean_squared_error: 0.3312
# Epoch 20/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.1660 - mean_absolute_error: 0.3121 - mean_squared_error: 0.1660 - val_loss: 0.3723 - val_mean_absolute_error: 0.5683 - val_mean_squared_error: 0.3723
# Epoch 21/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1989 - mean_absolute_error: 0.3734 - mean_squared_error: 0.1989 - val_loss: 0.5391 - val_mean_absolute_error: 0.6968 - val_mean_squared_error: 0.5391
# Epoch 22/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.2043 - mean_absolute_error: 0.3475 - mean_squared_error: 0.2043 - val_loss: 0.1948 - val_mean_absolute_error: 0.4035 - val_mean_squared_error: 0.1948
# Epoch 23/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1137 - mean_absolute_error: 0.2906 - mean_squared_error: 0.1137 - val_loss: 0.1598 - val_mean_absolute_error: 0.3658 - val_mean_squared_error: 0.1598
# Epoch 24/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1071 - mean_absolute_error: 0.2793 - mean_squared_error: 0.1071 - val_loss: 0.0937 - val_mean_absolute_error: 0.2692 - val_mean_squared_error: 0.0937
# Epoch 25/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0981 - mean_absolute_error: 0.2675 - mean_squared_error: 0.0981 - val_loss: 0.1297 - val_mean_absolute_error: 0.3182 - val_mean_squared_error: 0.1297
# Epoch 26/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0664 - mean_absolute_error: 0.2174 - mean_squared_error: 0.0664 - val_loss: 0.1226 - val_mean_absolute_error: 0.3065 - val_mean_squared_error: 0.1226
# Epoch 27/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0951 - mean_absolute_error: 0.2634 - mean_squared_error: 0.0951 - val_loss: 0.1882 - val_mean_absolute_error: 0.4035 - val_mean_squared_error: 0.1882
# Epoch 28/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1544 - mean_absolute_error: 0.3367 - mean_squared_error: 0.1544 - val_loss: 0.3403 - val_mean_absolute_error: 0.5554 - val_mean_squared_error: 0.3403
# Epoch 29/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.2123 - mean_absolute_error: 0.4027 - mean_squared_error: 0.2123 - val_loss: 0.1077 - val_mean_absolute_error: 0.2964 - val_mean_squared_error: 0.1077
# Epoch 30/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1038 - mean_absolute_error: 0.2674 - mean_squared_error: 0.1038 - val_loss: 0.0360 - val_mean_absolute_error: 0.1584 - val_mean_squared_error: 0.0360
# Epoch 31/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0317 - mean_absolute_error: 0.1362 - mean_squared_error: 0.0317 - val_loss: 0.0180 - val_mean_absolute_error: 0.1008 - val_mean_squared_error: 0.0180
# Epoch 32/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0348 - mean_absolute_error: 0.1453 - mean_squared_error: 0.0348 - val_loss: 0.0655 - val_mean_absolute_error: 0.2240 - val_mean_squared_error: 0.0655
# Epoch 33/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0682 - mean_absolute_error: 0.2319 - mean_squared_error: 0.0682 - val_loss: 0.0166 - val_mean_absolute_error: 0.0952 - val_mean_squared_error: 0.0166
# Epoch 34/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0211 - mean_absolute_error: 0.1067 - mean_squared_error: 0.0211 - val_loss: 0.0658 - val_mean_absolute_error: 0.2194 - val_mean_squared_error: 0.0658
# Epoch 35/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0458 - mean_absolute_error: 0.1758 - mean_squared_error: 0.0458 - val_loss: 0.0973 - val_mean_absolute_error: 0.2858 - val_mean_squared_error: 0.0973
# Epoch 36/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0363 - mean_absolute_error: 0.1467 - mean_squared_error: 0.0363 - val_loss: 0.0352 - val_mean_absolute_error: 0.1572 - val_mean_squared_error: 0.0352
# Epoch 37/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0179 - mean_absolute_error: 0.1032 - mean_squared_error: 0.0179 - val_loss: 0.0148 - val_mean_absolute_error: 0.0937 - val_mean_squared_error: 0.0148
# Epoch 38/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0223 - mean_absolute_error: 0.1162 - mean_squared_error: 0.0223 - val_loss: 0.0274 - val_mean_absolute_error: 0.1361 - val_mean_squared_error: 0.0274
# Epoch 39/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0381 - mean_absolute_error: 0.1601 - mean_squared_error: 0.0381 - val_loss: 0.1065 - val_mean_absolute_error: 0.2966 - val_mean_squared_error: 0.1065
# Epoch 40/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0480 - mean_absolute_error: 0.1689 - mean_squared_error: 0.0480 - val_loss: 0.0160 - val_mean_absolute_error: 0.0886 - val_mean_squared_error: 0.0160
# Epoch 41/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0223 - mean_absolute_error: 0.1163 - mean_squared_error: 0.0223 - val_loss: 0.0219 - val_mean_absolute_error: 0.1096 - val_mean_squared_error: 0.0219
# Epoch 42/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0143 - mean_absolute_error: 0.0948 - mean_squared_error: 0.0143 - val_loss: 0.0461 - val_mean_absolute_error: 0.1891 - val_mean_squared_error: 0.0461
# Epoch 43/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0345 - mean_absolute_error: 0.1482 - mean_squared_error: 0.0345 - val_loss: 0.0105 - val_mean_absolute_error: 0.0790 - val_mean_squared_error: 0.0105
# Epoch 44/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0105 - mean_absolute_error: 0.0765 - mean_squared_error: 0.0105 - val_loss: 0.0148 - val_mean_absolute_error: 0.0952 - val_mean_squared_error: 0.0148
# Epoch 45/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0211 - mean_absolute_error: 0.1129 - mean_squared_error: 0.0211 - val_loss: 0.0328 - val_mean_absolute_error: 0.1536 - val_mean_squared_error: 0.0328
# Epoch 46/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0167 - mean_absolute_error: 0.1071 - mean_squared_error: 0.0167 - val_loss: 0.0100 - val_mean_absolute_error: 0.0730 - val_mean_squared_error: 0.0100
# Epoch 47/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0132 - mean_absolute_error: 0.0874 - mean_squared_error: 0.0132 - val_loss: 0.0122 - val_mean_absolute_error: 0.0846 - val_mean_squared_error: 0.0122
# Epoch 48/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0129 - mean_absolute_error: 0.0830 - mean_squared_error: 0.0129 - val_loss: 0.0122 - val_mean_absolute_error: 0.0876 - val_mean_squared_error: 0.0122
# Epoch 49/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0166 - mean_absolute_error: 0.1029 - mean_squared_error: 0.0166 - val_loss: 0.0088 - val_mean_absolute_error: 0.0777 - val_mean_squared_error: 0.0088
# Epoch 50/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0095 - mean_absolute_error: 0.0741 - mean_squared_error: 0.0095 - val_loss: 0.0230 - val_mean_absolute_error: 0.1242 - val_mean_squared_error: 0.0230
# Epoch 51/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0188 - mean_absolute_error: 0.1081 - mean_squared_error: 0.0188 - val_loss: 0.0094 - val_mean_absolute_error: 0.0837 - val_mean_squared_error: 0.0094
# Epoch 52/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0101 - mean_absolute_error: 0.0799 - mean_squared_error: 0.0101 - val_loss: 0.0246 - val_mean_absolute_error: 0.1306 - val_mean_squared_error: 0.0246
# Epoch 53/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0107 - mean_absolute_error: 0.0822 - mean_squared_error: 0.0107 - val_loss: 0.0120 - val_mean_absolute_error: 0.0829 - val_mean_squared_error: 0.0120
# Epoch 54/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0078 - mean_absolute_error: 0.0668 - mean_squared_error: 0.0078 - val_loss: 0.0074 - val_mean_absolute_error: 0.0653 - val_mean_squared_error: 0.0074
# Epoch 55/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0084 - mean_absolute_error: 0.0692 - mean_squared_error: 0.0084 - val_loss: 0.0090 - val_mean_absolute_error: 0.0714 - val_mean_squared_error: 0.0090
# Epoch 56/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0073 - mean_absolute_error: 0.0641 - mean_squared_error: 0.0073 - val_loss: 0.0075 - val_mean_absolute_error: 0.0650 - val_mean_squared_error: 0.0075
# Epoch 57/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0076 - mean_absolute_error: 0.0703 - mean_squared_error: 0.0076 - val_loss: 0.0078 - val_mean_absolute_error: 0.0659 - val_mean_squared_error: 0.0078
# Epoch 58/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0716 - mean_squared_error: 0.0075 - val_loss: 0.0083 - val_mean_absolute_error: 0.0667 - val_mean_squared_error: 0.0083
# Epoch 59/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0069 - mean_absolute_error: 0.0661 - mean_squared_error: 0.0069 - val_loss: 0.0066 - val_mean_absolute_error: 0.0629 - val_mean_squared_error: 0.0066
# Epoch 60/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0078 - mean_absolute_error: 0.0661 - mean_squared_error: 0.0078 - val_loss: 0.0062 - val_mean_absolute_error: 0.0638 - val_mean_squared_error: 0.0062
# Epoch 61/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0607 - mean_squared_error: 0.0061 - val_loss: 0.0061 - val_mean_absolute_error: 0.0597 - val_mean_squared_error: 0.0061
# Epoch 62/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0064 - mean_absolute_error: 0.0630 - mean_squared_error: 0.0064 - val_loss: 0.0086 - val_mean_absolute_error: 0.0709 - val_mean_squared_error: 0.0086
# Epoch 63/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0112 - mean_absolute_error: 0.0880 - mean_squared_error: 0.0112 - val_loss: 0.0081 - val_mean_absolute_error: 0.0674 - val_mean_squared_error: 0.0081
# Epoch 64/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0177 - mean_absolute_error: 0.1117 - mean_squared_error: 0.0177 - val_loss: 0.0069 - val_mean_absolute_error: 0.0665 - val_mean_squared_error: 0.0069
# Epoch 65/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0157 - mean_absolute_error: 0.1075 - mean_squared_error: 0.0157 - val_loss: 0.0072 - val_mean_absolute_error: 0.0658 - val_mean_squared_error: 0.0072
# Epoch 66/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0182 - mean_absolute_error: 0.1148 - mean_squared_error: 0.0182 - val_loss: 0.0146 - val_mean_absolute_error: 0.0887 - val_mean_squared_error: 0.0146
# Epoch 67/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0294 - mean_absolute_error: 0.1405 - mean_squared_error: 0.0294 - val_loss: 0.0171 - val_mean_absolute_error: 0.1148 - val_mean_squared_error: 0.0171
# Epoch 68/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0301 - mean_absolute_error: 0.1522 - mean_squared_error: 0.0301 - val_loss: 0.0072 - val_mean_absolute_error: 0.0643 - val_mean_squared_error: 0.0072
# Epoch 69/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0329 - mean_absolute_error: 0.1522 - mean_squared_error: 0.0329 - val_loss: 0.0571 - val_mean_absolute_error: 0.2250 - val_mean_squared_error: 0.0571
# Epoch 70/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0382 - mean_absolute_error: 0.1641 - mean_squared_error: 0.0382 - val_loss: 0.0079 - val_mean_absolute_error: 0.0739 - val_mean_squared_error: 0.0079
# Epoch 71/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0161 - mean_absolute_error: 0.1070 - mean_squared_error: 0.0161 - val_loss: 0.0221 - val_mean_absolute_error: 0.1038 - val_mean_squared_error: 0.0221
# Epoch 72/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0564 - mean_absolute_error: 0.2018 - mean_squared_error: 0.0564 - val_loss: 0.0280 - val_mean_absolute_error: 0.1497 - val_mean_squared_error: 0.0280
# Epoch 73/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0391 - mean_absolute_error: 0.1763 - mean_squared_error: 0.0391 - val_loss: 0.0138 - val_mean_absolute_error: 0.0950 - val_mean_squared_error: 0.0138
# Epoch 74/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0115 - mean_absolute_error: 0.0885 - mean_squared_error: 0.0115 - val_loss: 0.0074 - val_mean_absolute_error: 0.0658 - val_mean_squared_error: 0.0074
# Epoch 75/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0129 - mean_absolute_error: 0.0855 - mean_squared_error: 0.0129 - val_loss: 0.0068 - val_mean_absolute_error: 0.0592 - val_mean_squared_error: 0.0068
# Epoch 76/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0595 - mean_squared_error: 0.0062 - val_loss: 0.0069 - val_mean_absolute_error: 0.0621 - val_mean_squared_error: 0.0069
# Epoch 77/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0052 - mean_absolute_error: 0.0558 - mean_squared_error: 0.0052 - val_loss: 0.0053 - val_mean_absolute_error: 0.0550 - val_mean_squared_error: 0.0053
# Epoch 78/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0047 - mean_absolute_error: 0.0513 - mean_squared_error: 0.0047 - val_loss: 0.0045 - val_mean_absolute_error: 0.0521 - val_mean_squared_error: 0.0045
# Epoch 79/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0053 - mean_absolute_error: 0.0590 - mean_squared_error: 0.0053 - val_loss: 0.0079 - val_mean_absolute_error: 0.0767 - val_mean_squared_error: 0.0079
# Epoch 80/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0709 - mean_squared_error: 0.0077 - val_loss: 0.0157 - val_mean_absolute_error: 0.1082 - val_mean_squared_error: 0.0157
# Epoch 81/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0188 - mean_absolute_error: 0.1057 - mean_squared_error: 0.0188 - val_loss: 0.0166 - val_mean_absolute_error: 0.1137 - val_mean_squared_error: 0.0166
# Epoch 82/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0422 - mean_absolute_error: 0.1714 - mean_squared_error: 0.0422 - val_loss: 0.0273 - val_mean_absolute_error: 0.1531 - val_mean_squared_error: 0.0273
# Epoch 83/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0468 - mean_absolute_error: 0.1783 - mean_squared_error: 0.0468 - val_loss: 0.0403 - val_mean_absolute_error: 0.1874 - val_mean_squared_error: 0.0403
# Epoch 84/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0207 - mean_absolute_error: 0.1121 - mean_squared_error: 0.0207 - val_loss: 0.0073 - val_mean_absolute_error: 0.0656 - val_mean_squared_error: 0.0073
# Epoch 85/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0103 - mean_absolute_error: 0.0764 - mean_squared_error: 0.0103 - val_loss: 0.0066 - val_mean_absolute_error: 0.0587 - val_mean_squared_error: 0.0066
# Epoch 86/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0150 - mean_absolute_error: 0.1024 - mean_squared_error: 0.0150 - val_loss: 0.0102 - val_mean_absolute_error: 0.0847 - val_mean_squared_error: 0.0102
# Epoch 87/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0159 - mean_absolute_error: 0.0943 - mean_squared_error: 0.0159 - val_loss: 0.0128 - val_mean_absolute_error: 0.0875 - val_mean_squared_error: 0.0128
# Epoch 88/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0197 - mean_absolute_error: 0.1186 - mean_squared_error: 0.0197 - val_loss: 0.0393 - val_mean_absolute_error: 0.1862 - val_mean_squared_error: 0.0393
# Epoch 89/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0205 - mean_absolute_error: 0.1277 - mean_squared_error: 0.0205 - val_loss: 0.0326 - val_mean_absolute_error: 0.1692 - val_mean_squared_error: 0.0326
# Epoch 90/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0218 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0218 - val_loss: 0.0082 - val_mean_absolute_error: 0.0772 - val_mean_squared_error: 0.0082
# Epoch 91/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0094 - mean_absolute_error: 0.0777 - mean_squared_error: 0.0094 - val_loss: 0.0168 - val_mean_absolute_error: 0.1048 - val_mean_squared_error: 0.0168
# Epoch 92/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0232 - mean_absolute_error: 0.1290 - mean_squared_error: 0.0232 - val_loss: 0.0062 - val_mean_absolute_error: 0.0683 - val_mean_squared_error: 0.0062
# Epoch 93/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0157 - mean_absolute_error: 0.1051 - mean_squared_error: 0.0157 - val_loss: 0.0064 - val_mean_absolute_error: 0.0607 - val_mean_squared_error: 0.0064
# Epoch 94/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0048 - mean_absolute_error: 0.0565 - mean_squared_error: 0.0048 - val_loss: 0.0101 - val_mean_absolute_error: 0.0817 - val_mean_squared_error: 0.0101
# Epoch 95/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0344 - mean_absolute_error: 0.1599 - mean_squared_error: 0.0344 - val_loss: 0.0689 - val_mean_absolute_error: 0.2550 - val_mean_squared_error: 0.0689
# Epoch 96/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0347 - mean_absolute_error: 0.1555 - mean_squared_error: 0.0347 - val_loss: 0.0320 - val_mean_absolute_error: 0.1547 - val_mean_squared_error: 0.0320
# Epoch 97/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0389 - mean_absolute_error: 0.1618 - mean_squared_error: 0.0389 - val_loss: 0.0556 - val_mean_absolute_error: 0.2279 - val_mean_squared_error: 0.0556
# Epoch 98/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0394 - mean_absolute_error: 0.1670 - mean_squared_error: 0.0394 - val_loss: 0.0690 - val_mean_absolute_error: 0.2541 - val_mean_squared_error: 0.0690
# Epoch 99/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0320 - mean_absolute_error: 0.1499 - mean_squared_error: 0.0320 - val_loss: 0.0159 - val_mean_absolute_error: 0.1106 - val_mean_squared_error: 0.0159
# Epoch 100/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0433 - mean_absolute_error: 0.1765 - mean_squared_error: 0.0433 - val_loss: 0.0584 - val_mean_absolute_error: 0.2296 - val_mean_squared_error: 0.0584
# Epoch 101/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0617 - mean_absolute_error: 0.2174 - mean_squared_error: 0.0617 - val_loss: 0.0532 - val_mean_absolute_error: 0.1972 - val_mean_squared_error: 0.0532
# Epoch 102/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0525 - mean_absolute_error: 0.1944 - mean_squared_error: 0.0525 - val_loss: 0.0345 - val_mean_absolute_error: 0.1605 - val_mean_squared_error: 0.0345
# Epoch 103/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0228 - mean_absolute_error: 0.1236 - mean_squared_error: 0.0228 - val_loss: 0.0211 - val_mean_absolute_error: 0.1252 - val_mean_squared_error: 0.0211
# Epoch 104/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0233 - mean_absolute_error: 0.1278 - mean_squared_error: 0.0233 - val_loss: 0.0480 - val_mean_absolute_error: 0.2034 - val_mean_squared_error: 0.0480
# Epoch 105/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0636 - mean_absolute_error: 0.1918 - mean_squared_error: 0.0636 - val_loss: 0.0206 - val_mean_absolute_error: 0.1150 - val_mean_squared_error: 0.0206
# Epoch 106/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.1114 - mean_absolute_error: 0.2834 - mean_squared_error: 0.1114 - val_loss: 0.7401 - val_mean_absolute_error: 0.8296 - val_mean_squared_error: 0.7401
# Epoch 107/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1744 - mean_absolute_error: 0.3736 - mean_squared_error: 0.1744 - val_loss: 0.1945 - val_mean_absolute_error: 0.4249 - val_mean_squared_error: 0.1945
# Epoch 108/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.2113 - mean_absolute_error: 0.4164 - mean_squared_error: 0.2113 - val_loss: 0.3491 - val_mean_absolute_error: 0.5802 - val_mean_squared_error: 0.3491
# Epoch 109/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1130 - mean_absolute_error: 0.2638 - mean_squared_error: 0.1130 - val_loss: 0.2245 - val_mean_absolute_error: 0.4499 - val_mean_squared_error: 0.2245
# Epoch 110/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1266 - mean_absolute_error: 0.2792 - mean_squared_error: 0.1266 - val_loss: 0.0638 - val_mean_absolute_error: 0.2022 - val_mean_squared_error: 0.0638
# Epoch 111/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0778 - mean_absolute_error: 0.2187 - mean_squared_error: 0.0778 - val_loss: 0.0775 - val_mean_absolute_error: 0.2583 - val_mean_squared_error: 0.0775
# Epoch 112/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0891 - mean_absolute_error: 0.2450 - mean_squared_error: 0.0891 - val_loss: 0.0124 - val_mean_absolute_error: 0.0998 - val_mean_squared_error: 0.0124
# Epoch 113/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1160 - mean_absolute_error: 0.2784 - mean_squared_error: 0.1160 - val_loss: 0.0910 - val_mean_absolute_error: 0.2890 - val_mean_squared_error: 0.0910
# Epoch 114/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0410 - mean_absolute_error: 0.1782 - mean_squared_error: 0.0410 - val_loss: 0.0090 - val_mean_absolute_error: 0.0759 - val_mean_squared_error: 0.0090
# Epoch 115/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0307 - mean_absolute_error: 0.1474 - mean_squared_error: 0.0307 - val_loss: 0.0058 - val_mean_absolute_error: 0.0612 - val_mean_squared_error: 0.0058
# Epoch 116/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0542 - mean_absolute_error: 0.1648 - mean_squared_error: 0.0542 - val_loss: 0.3590 - val_mean_absolute_error: 0.5869 - val_mean_squared_error: 0.3590
# Epoch 117/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.2637 - mean_absolute_error: 0.4355 - mean_squared_error: 0.2637 - val_loss: 0.1200 - val_mean_absolute_error: 0.3197 - val_mean_squared_error: 0.1200
# Epoch 118/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1255 - mean_absolute_error: 0.2881 - mean_squared_error: 0.1255 - val_loss: 0.0266 - val_mean_absolute_error: 0.1257 - val_mean_squared_error: 0.0266
# Epoch 119/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0614 - mean_absolute_error: 0.2195 - mean_squared_error: 0.0614 - val_loss: 0.0790 - val_mean_absolute_error: 0.2633 - val_mean_squared_error: 0.0790
# Epoch 120/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.1031 - mean_absolute_error: 0.2832 - mean_squared_error: 0.1031 - val_loss: 0.0237 - val_mean_absolute_error: 0.1329 - val_mean_squared_error: 0.0237
# Epoch 121/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0562 - mean_absolute_error: 0.1957 - mean_squared_error: 0.0562 - val_loss: 0.2344 - val_mean_absolute_error: 0.4336 - val_mean_squared_error: 0.2344
# Epoch 122/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1653 - mean_absolute_error: 0.3075 - mean_squared_error: 0.1653 - val_loss: 0.0385 - val_mean_absolute_error: 0.1745 - val_mean_squared_error: 0.0385
# Epoch 123/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1699 - mean_absolute_error: 0.3398 - mean_squared_error: 0.1699 - val_loss: 0.3412 - val_mean_absolute_error: 0.5798 - val_mean_squared_error: 0.3412
# Epoch 124/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1706 - mean_absolute_error: 0.3659 - mean_squared_error: 0.1706 - val_loss: 0.0743 - val_mean_absolute_error: 0.2566 - val_mean_squared_error: 0.0743
# Epoch 125/180
# 331/331 [==============================] - 1s 2ms/step - loss: 1.0098 - mean_absolute_error: 0.7474 - mean_squared_error: 1.0098 - val_loss: 3.2088 - val_mean_absolute_error: 1.7721 - val_mean_squared_error: 3.2088
# Epoch 126/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.8229 - mean_absolute_error: 0.7465 - mean_squared_error: 0.8229 - val_loss: 0.3634 - val_mean_absolute_error: 0.4616 - val_mean_squared_error: 0.3634
# Epoch 127/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.5172 - mean_absolute_error: 0.5266 - mean_squared_error: 0.5172 - val_loss: 0.2394 - val_mean_absolute_error: 0.3761 - val_mean_squared_error: 0.2394
# Epoch 128/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.4981 - mean_absolute_error: 0.5560 - mean_squared_error: 0.4981 - val_loss: 0.5762 - val_mean_absolute_error: 0.6886 - val_mean_squared_error: 0.5762
# Epoch 129/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.3343 - mean_absolute_error: 0.4509 - mean_squared_error: 0.3343 - val_loss: 0.0569 - val_mean_absolute_error: 0.1554 - val_mean_squared_error: 0.0569
# Epoch 130/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.4154 - mean_absolute_error: 0.5522 - mean_squared_error: 0.4154 - val_loss: 0.0311 - val_mean_absolute_error: 0.1374 - val_mean_squared_error: 0.0311
# Epoch 131/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.3815 - mean_absolute_error: 0.5277 - mean_squared_error: 0.3815 - val_loss: 0.1975 - val_mean_absolute_error: 0.3844 - val_mean_squared_error: 0.1975
# Epoch 132/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.2943 - mean_absolute_error: 0.4301 - mean_squared_error: 0.2943 - val_loss: 0.1853 - val_mean_absolute_error: 0.4032 - val_mean_squared_error: 0.1853
# Epoch 133/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.3321 - mean_absolute_error: 0.5067 - mean_squared_error: 0.3321 - val_loss: 0.1210 - val_mean_absolute_error: 0.3218 - val_mean_squared_error: 0.1210
# Epoch 134/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1552 - mean_absolute_error: 0.3236 - mean_squared_error: 0.1552 - val_loss: 0.0173 - val_mean_absolute_error: 0.0906 - val_mean_squared_error: 0.0173
# Epoch 135/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0503 - mean_absolute_error: 0.1927 - mean_squared_error: 0.0503 - val_loss: 0.0306 - val_mean_absolute_error: 0.1259 - val_mean_squared_error: 0.0306
# Epoch 136/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0590 - mean_absolute_error: 0.2113 - mean_squared_error: 0.0590 - val_loss: 0.0877 - val_mean_absolute_error: 0.2796 - val_mean_squared_error: 0.0877
# Epoch 137/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.1085 - mean_absolute_error: 0.2949 - mean_squared_error: 0.1085 - val_loss: 0.0110 - val_mean_absolute_error: 0.0756 - val_mean_squared_error: 0.0110
# Epoch 138/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0915 - mean_absolute_error: 0.2538 - mean_squared_error: 0.0915 - val_loss: 0.0141 - val_mean_absolute_error: 0.0980 - val_mean_squared_error: 0.0141
# Epoch 139/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0148 - mean_absolute_error: 0.0967 - mean_squared_error: 0.0148 - val_loss: 0.0331 - val_mean_absolute_error: 0.1561 - val_mean_squared_error: 0.0331
# Epoch 140/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0164 - mean_absolute_error: 0.1048 - mean_squared_error: 0.0164 - val_loss: 0.0381 - val_mean_absolute_error: 0.1736 - val_mean_squared_error: 0.0381
# Epoch 141/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0225 - mean_absolute_error: 0.1184 - mean_squared_error: 0.0225 - val_loss: 0.0333 - val_mean_absolute_error: 0.1707 - val_mean_squared_error: 0.0333
# Epoch 142/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0368 - mean_absolute_error: 0.1586 - mean_squared_error: 0.0368 - val_loss: 0.0629 - val_mean_absolute_error: 0.2340 - val_mean_squared_error: 0.0629
# Epoch 143/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0321 - mean_absolute_error: 0.1440 - mean_squared_error: 0.0321 - val_loss: 0.0193 - val_mean_absolute_error: 0.0999 - val_mean_squared_error: 0.0193
# Epoch 144/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0414 - mean_absolute_error: 0.1620 - mean_squared_error: 0.0414 - val_loss: 0.0158 - val_mean_absolute_error: 0.1093 - val_mean_squared_error: 0.0158
# Epoch 145/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0197 - mean_absolute_error: 0.1154 - mean_squared_error: 0.0197 - val_loss: 0.0109 - val_mean_absolute_error: 0.0791 - val_mean_squared_error: 0.0109
# Epoch 146/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0188 - mean_absolute_error: 0.1142 - mean_squared_error: 0.0188 - val_loss: 0.0056 - val_mean_absolute_error: 0.0534 - val_mean_squared_error: 0.0056
# Epoch 147/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0095 - mean_absolute_error: 0.0774 - mean_squared_error: 0.0095 - val_loss: 0.0254 - val_mean_absolute_error: 0.1400 - val_mean_squared_error: 0.0254
# Epoch 148/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0313 - mean_absolute_error: 0.1562 - mean_squared_error: 0.0313 - val_loss: 0.0202 - val_mean_absolute_error: 0.1293 - val_mean_squared_error: 0.0202
# Epoch 149/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0169 - mean_absolute_error: 0.1085 - mean_squared_error: 0.0169 - val_loss: 0.0368 - val_mean_absolute_error: 0.1787 - val_mean_squared_error: 0.0368
# Epoch 150/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0139 - mean_absolute_error: 0.0990 - mean_squared_error: 0.0139 - val_loss: 0.0044 - val_mean_absolute_error: 0.0480 - val_mean_squared_error: 0.0044
# Epoch 151/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0503 - mean_squared_error: 0.0048 - val_loss: 0.0045 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0045
# Epoch 152/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0084 - mean_absolute_error: 0.0705 - mean_squared_error: 0.0084 - val_loss: 0.0057 - val_mean_absolute_error: 0.0578 - val_mean_squared_error: 0.0057
# Epoch 153/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0092 - mean_absolute_error: 0.0806 - mean_squared_error: 0.0092 - val_loss: 0.0059 - val_mean_absolute_error: 0.0632 - val_mean_squared_error: 0.0059
# Epoch 154/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0580 - mean_squared_error: 0.0059 - val_loss: 0.0074 - val_mean_absolute_error: 0.0661 - val_mean_squared_error: 0.0074
# Epoch 155/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0043 - mean_absolute_error: 0.0510 - mean_squared_error: 0.0043 - val_loss: 0.0056 - val_mean_absolute_error: 0.0568 - val_mean_squared_error: 0.0056
# Epoch 156/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0558 - mean_squared_error: 0.0049 - val_loss: 0.0052 - val_mean_absolute_error: 0.0570 - val_mean_squared_error: 0.0052
# Epoch 157/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0054 - mean_absolute_error: 0.0582 - mean_squared_error: 0.0054 - val_loss: 0.0066 - val_mean_absolute_error: 0.0643 - val_mean_squared_error: 0.0066
# Epoch 158/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0051 - mean_absolute_error: 0.0523 - mean_squared_error: 0.0051 - val_loss: 0.0045 - val_mean_absolute_error: 0.0514 - val_mean_squared_error: 0.0045
# Epoch 159/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0069 - mean_absolute_error: 0.0628 - mean_squared_error: 0.0069 - val_loss: 0.0040 - val_mean_absolute_error: 0.0485 - val_mean_squared_error: 0.0040
# Epoch 160/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0038 - mean_absolute_error: 0.0485 - mean_squared_error: 0.0038 - val_loss: 0.0048 - val_mean_absolute_error: 0.0541 - val_mean_squared_error: 0.0048
# Epoch 161/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0042 - mean_absolute_error: 0.0508 - mean_squared_error: 0.0042 - val_loss: 0.0039 - val_mean_absolute_error: 0.0477 - val_mean_squared_error: 0.0039
# Epoch 162/180
# 331/331 [==============================] - 0s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0668 - mean_squared_error: 0.0068 - val_loss: 0.0042 - val_mean_absolute_error: 0.0501 - val_mean_squared_error: 0.0042
# Epoch 163/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0036 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0036 - val_loss: 0.0035 - val_mean_absolute_error: 0.0453 - val_mean_squared_error: 0.0035
# Epoch 164/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0034 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0034 - val_loss: 0.0043 - val_mean_absolute_error: 0.0514 - val_mean_squared_error: 0.0043
# Epoch 165/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0035 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0035 - val_loss: 0.0035 - val_mean_absolute_error: 0.0465 - val_mean_squared_error: 0.0035
# Epoch 166/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0033 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0033 - val_loss: 0.0036 - val_mean_absolute_error: 0.0474 - val_mean_squared_error: 0.0036
# Epoch 167/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0031 - val_loss: 0.0035 - val_mean_absolute_error: 0.0452 - val_mean_squared_error: 0.0035
# Epoch 168/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0038 - mean_absolute_error: 0.0483 - mean_squared_error: 0.0038 - val_loss: 0.0045 - val_mean_absolute_error: 0.0534 - val_mean_squared_error: 0.0045
# Epoch 169/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0038 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0038 - val_loss: 0.0034 - val_mean_absolute_error: 0.0460 - val_mean_squared_error: 0.0034
# Epoch 170/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0038 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0038 - val_loss: 0.0050 - val_mean_absolute_error: 0.0556 - val_mean_squared_error: 0.0050
# Epoch 171/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0040 - mean_absolute_error: 0.0513 - mean_squared_error: 0.0040 - val_loss: 0.0034 - val_mean_absolute_error: 0.0443 - val_mean_squared_error: 0.0034
# Epoch 172/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0035 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0035 - val_loss: 0.0049 - val_mean_absolute_error: 0.0573 - val_mean_squared_error: 0.0049
# Epoch 173/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0559 - mean_squared_error: 0.0049 - val_loss: 0.0034 - val_mean_absolute_error: 0.0452 - val_mean_squared_error: 0.0034
# Epoch 174/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0030 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0030 - val_loss: 0.0032 - val_mean_absolute_error: 0.0439 - val_mean_squared_error: 0.0032
# Epoch 175/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0037 - mean_absolute_error: 0.0483 - mean_squared_error: 0.0037 - val_loss: 0.0062 - val_mean_absolute_error: 0.0640 - val_mean_squared_error: 0.0062
# Epoch 176/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0051 - mean_absolute_error: 0.0602 - mean_squared_error: 0.0051 - val_loss: 0.0035 - val_mean_absolute_error: 0.0461 - val_mean_squared_error: 0.0035
# Epoch 177/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0033 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_mean_absolute_error: 0.0435 - val_mean_squared_error: 0.0031
# Epoch 178/180
# 331/331 [==============================] - 1s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0032 - val_loss: 0.0040 - val_mean_absolute_error: 0.0499 - val_mean_squared_error: 0.0040
# Epoch 179/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0037 - mean_absolute_error: 0.0495 - mean_squared_error: 0.0037 - val_loss: 0.0065 - val_mean_absolute_error: 0.0667 - val_mean_squared_error: 0.0065
# Epoch 180/180
# 331/331 [==============================] - 0s 1ms/step - loss: 0.0051 - mean_absolute_error: 0.0602 - mean_squared_error: 0.0051 - val_loss: 0.0056 - val_mean_absolute_error: 0.0613 - val_mean_squared_error: 0.0056

# %%
hist = pd.DataFrame(history.history)
hist['epoch']= history.epoch
hist.tail()
# Out:
#      val_loss  val_mean_absolute_error  val_mean_squared_error      loss  \
# 175  0.003535                 0.046123                0.003535  0.005142
# 176  0.003135                 0.043493                0.003135  0.003259
# 177  0.004028                 0.049872                0.004028  0.003230
# 178  0.006459                 0.066685                0.006459  0.003684
# 179  0.005565                 0.061279                0.005565  0.005118
#
#      mean_absolute_error  mean_squared_error  epoch
# 175             0.060187            0.005142    175
# 176             0.044362            0.003259    176
# 177             0.045019            0.003230    177
# 178             0.049529            0.003684    178
# 179             0.060155            0.005118    179

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
    
  plt.figure(figsize=(13,9))
  #plt.figure()
  plt.xlabel('Epoch', fontsize= 18)
  plt.ylabel('Mean Abs Error', fontsize= 18)
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  plt.ylim([0,1.2])
  plt.tick_params(labelsize=20)
  plt.legend()
  

  plt.figure(figsize=(13,9))
  #plt.figure()
  plt.xlabel('Epoch', fontsize = 20)
  plt.ylabel('Mean Square Error', fontsize= 20)
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  plt.ylim([0,10])
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# **Save model**

# %%
test_predictions = model.predict([norm_rvsflux, norm_bpflux, norm_rpflux]).flatten()

print(np.shape(test_predictions))

print(np.shape(normalize(logteff)))
plt.scatter(normalize(logteff), test_predictions)
plt.xlabel('True Values [LogTeff]')
plt.ylabel('Predictions [LogTeff]')
plt.axis('equal')
plt.axis('square')
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
#_ = plt.plot([1.4, 1.4], [1.4, 1.4])
#print('test predictions=', test_predictions)
# Out:
# (415,)
# (415,)
# (-1.910476065242397, 2.501597583180887, -1.9378848256917451, 2.474188822731539)

# %%
#Unnormalizing the labels (teff)

def denormalize (labels):
    return (((labels)*(std_labels)) + mean_labels)


test_predictions = model.predict([norm_rvsflux, norm_bpflux, norm_rpflux]).flatten()
plt.scatter(logteff, denormalize(test_predictions))
plt.xlabel('True Values [LogTeff]')
plt.ylabel('Predictions [LogTeff]')
plt.axis('equal')
plt.axis('square')
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([5.5, 12 ], [5.5, 12])

#print('test predictions=', test_predictions)

# %%
#Unnormalizing the labels (teff)

def denormalize (labels):
    return (((labels)*(std_labels)) + mean_labels)

plt.figure(figsize=(13,9))
test_predictions = model.predict([x_RVStrain, x_BPtrain, x_RPtrain]).flatten()
print('shape of test_predictions:',np.shape(test_predictions))
print('print 10 elements of test_predictions:', test_predictions[0:10])
plt.scatter(denormalize(y_train), denormalize(test_predictions), s= 4.0, c= 'r' )
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=25)
plt.ylabel(r"$T_{\rm eff,pred}$ (K)", fontsize=25)
_ = plt.plot([3.6, 4.5], [3.6, 4.55])
plt.axis('equal')
plt.axis('square')
# increase the x,y tick label size
plt.tick_params(labelsize= 25) 
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
# Out:
# shape of test_predictions: (331,)
# print 10 elements of test_predictions: [-1.7235391 -1.705467  -1.673053  -1.6359365 -1.594053  -1.5615246
#  -1.5303581 -1.5023024 -1.4639137 -1.4703696]

# %%
#Making the histogram of denormalized training set 

plt.figure(figsize=(10,9))
z=np.subtract(denormalize(y_train), denormalize(test_predictions)) #difference between the true and predicted values
counts, bins = np.histogram(z)
plt.hist(bins[:-1], bins, weights=counts)

# increase the x,y tick label size
plt.tick_params(labelsize=18) 
plt.title(r'Histogram of $T_{eff}$', fontsize=18)
plt.xlabel(r"$\rm logT_{\rm eff,pred}-\rm logT_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel('Counts', fontsize=18)

print('standard deviation', len(z))
#print(len(z[teff<5000]))
#print(len(z))
# Out:
# standard deviation 331

# %% [markdown]
# # Training Data Set

# %%
# getting deviation in Teff bins
nbin = 6
teffbin_edges=np.array([3.6, 3.8, 4.0, 4.2, 4.4])

# pred vs. true
# unnormalised values
teff_pred = denormalize(test_predictions)
teff_true = denormalize(y_train) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
teff_diff = teff_pred-teff_true

# compute mean and std in Teff bins
teff_diff_mean = np.zeros(nbin) 
teff_diff_std = np.zeros(nbin)
teffbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(teff_true<teffbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(teff_true>teffbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((teff_true>teffbin_edges[i-1]) & (teff_true<teffbin_edges[i]))
        #if i=1, teff_true>(teffbin_edges[1-1=0]= 5000) & teff_true<teffbin_edges[1]= 10000, so 5000<teff<10000
        #if i=2, teff_true>(teffbin_edges[2-1=1]=10000) & teff_true<teffbin_edges[2]= 15000, so 10000<teff<15000
        #if i=3, teff_true> (teffbin_edges[3-1=2]= 15000) & teff_true<teffbin_edges[3]= 20000 so 15000<teff<20000
    teffbin_mean[i] = np.mean(teff_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    teff_diff_mean[i] = np.mean(teff_diff[indx]) #calculating the mean values of teff_diff from its index 
    teff_diff_std[i] = np.std(teff_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin teff_true=', teffbin_mean)
print('mean of teff_diff=', teff_diff_mean)
print('std of teff_diff=', teff_diff_std)
print('length of teff_diff=', len(teff_diff))
# Out:
# mean of bin teff_true= [3.55530425 3.70034069 3.90031971 4.08679057 4.28630677 4.44524029]
# mean of teff_diff= [0.02365223 0.010797   0.01188456 0.00819957 0.0116152  0.00849566]
# std of teff_diff= [0.02198716 0.01295057 0.00946311 0.0108929  0.00996364 0.00632103]
# length of teff_diff= 331

# %%
# plot
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(teff_true, teff_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(teffbin_mean,teff_diff_mean, yerr=teff_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([3.5,4.5])
ylim=np.array([-0.25,0.25])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# set x, y label. 
plt.xlabel(r"$\rm logT_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$\rm logT_{\rm eff,pred}-\rm logT_{\rm eff,true}$ (K)", fontsize=18)

# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %% [markdown]
# # Cross Validation Set

# %%
#Test set (x_cv)

plt.figure(figsize=(13,9))
cv_predictions = model.predict([x_RVScv, x_BPcv, x_RPcv]).flatten()
plt.scatter(denormalize(y_cv), denormalize(cv_predictions), c= 'r', s= 3)
_ = plt.plot([3.6, 4.6], [3.6, 4.6])
plt.xlabel(r"$LogT_{\rm eff,true}$ (K)", fontsize=25)
plt.ylabel(r"$LogT_{\rm eff,pred}$ (K)", fontsize=25)
plt.axis('equal')
plt.axis('square')
# increase the x,y tick label size
plt.tick_params(labelsize=25) 
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])


#print('test predictions=', test_predictions)

print('len of y_cv=', len(y_cv))
# Out:
# len of y_cv= 84

# %%
# getting deviation in Teff bins
nbin = 6
teffbin_edges=np.array([3.6, 3.8, 4.0, 4.2, 4.4])

# pred vs. true
# unnormalised values
teff_pred = denormalize(cv_predictions)
teff_true = denormalize(y_cv) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
teff_diff = teff_pred-teff_true

# compute mean and std in Teff bins
teff_diff_mean = np.zeros(nbin) 
teff_diff_std = np.zeros(nbin)
teffbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(teff_true<teffbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(teff_true>teffbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((teff_true>teffbin_edges[i-1]) & (teff_true<teffbin_edges[i]))
        #if i=1, teff_true>(teffbin_edges[1-1=0]= 5000) & teff_true<teffbin_edges[1]= 10000, so 5000<teff<10000
        #if i=2, teff_true>(teffbin_edges[2-1=1]=10000) & teff_true<teffbin_edges[2]= 15000, so 10000<teff<15000
        #if i=3, teff_true> (teffbin_edges[3-1=2]= 15000) & teff_true<teffbin_edges[3]= 20000 so 15000<teff<20000
    teffbin_mean[i] = np.mean(teff_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    teff_diff_mean[i] = np.mean(teff_diff[indx]) #calculating the mean values of teff_diff from its index 
    teff_diff_std[i] = np.std(teff_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin teff_true=', teffbin_mean)
print('mean of teff_diff=', teff_diff_mean)
print('std of teff_diff=', teff_diff_std)
print('len of teff_diff=', len(teff_diff))
# Out:
# mean of bin teff_true= [3.5690374  3.71836336 3.90132377 4.07369433 4.24529725 4.45205325]
# mean of teff_diff= [0.01514618 0.01169577 0.01558343 0.00806603 0.00993341 0.00739604]
# std of teff_diff= [0.02673259 0.0115636  0.00696938 0.01375126 0.01199594 0.00752261]
# len of teff_diff= 84

# %%
# plot
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(teff_true, teff_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(teffbin_mean,teff_diff_mean, yerr=teff_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=25)
plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=25)

# set x, y lim plot range
xlim=np.array([3.5,4.5])
ylim=np.array([-0.11,0.11])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# set x, y label. 
plt.xlabel(r"$\rm logT_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$\rm logT_{\rm eff,pred}-\rm logT_{\rm eff,true}$ (K)", fontsize=18)

# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %%
#Making the histogram of the CV set 

plt.figure(figsize=(13,9))
z=np.subtract(denormalize(y_cv), denormalize(cv_predictions)) #difference between the true and predicted values
counts, bins = np.histogram(z)
plt.hist(bins[:-1], bins, weights=counts)


# increase the x,y tick label size
plt.tick_params(labelsize=18) 

plt.title(r'Histogram of $T_{eff}$', fontsize=18)
plt.xlabel(r"$\rm logT_{\rm eff,pred}-\rm logT_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel('Counts', fontsize=18)
#z[teff<5000].std()
print('standard deviation', len(z))
#print(len(z[teff<5000]))
#print(len(z))
# Out:
# standard deviation 84

# %% [raw]
# # Another model
# From TheCNNon, https://github.com/adrn/TheCNNon/blob/master/notebooks/ThisIsCNNON.ipynb

# %%
# Input spectra
input_spec = Input(shape=(num_fluxes,), name='starnet_input_x')

# Reshape spectra for CNN layers
cur_in = Reshape((num_fluxes, 1))(input_spec)

# CNN layers
# First
cur_in = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=128, kernel_size=32)(cur_in) #first CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=32)(cur_in)
# Second CNN layer
cur_in = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=128, kernel_size=16)(cur_in) #2nd CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=16)(cur_in)
# Third CNN layer
cur_in = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=128, kernel_size=8)(cur_in) #2nd CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=8)(cur_in)

# Flatten the current input for the fully-connected layers
cur_in = Flatten()(cur_in)

# Fully-connected layers
cur_in = Dense(units=258, kernel_initializer=initializer, 
               activation=activation)(cur_in)
cur_in = Dense(units=128, kernel_initializer=initializer, 
               activation=activation)(cur_in)

# Output nodes
output_label = Dense(units=num_labels, kernel_regularizer=keras.regularizers.l2(0.01), activation="linear", 
                     input_dim=num_hidden[1])(cur_in)

model = Model(input_spec, output_label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-07ed572f0f80> in <module>
#       1 # Input spectra
# ----> 2 input_spec = Input(shape=(num_fluxes,), name='starnet_input_x')
#       3
#       4 # Reshape spectra for CNN layers
#       5 cur_in = Reshape((num_fluxes, 1))(input_spec)
#
# NameError: name 'num_fluxes' is not defined

# %%
optimizer = Adam(lr=0.0005)

# %%
# loss function to minimize
loss_function = 'mean_squared_error'
optimizer = 'adadelta'
# compute mean absolute deviation
metrics = ['mae', 'mse']
#metrics = ['mae']
model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# starnet_input_x (InputLayer) (None, 6758)              0
# _________________________________________________________________
# reshape_10 (Reshape)         (None, 6758, 1)           0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 6758, 128)         4224
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 211, 128)          0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 211, 128)          262272
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 13, 128)           0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 13, 128)           131200
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 1, 128)            0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 258)               33282
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               33152
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 464,259
# Trainable params: 464,259
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, 
          epochs=max_epochs, validation_split = 0.2, verbose=1, shuffle='batch')
# Out:
# Train on 875 samples, validate on 219 samples
# Epoch 1/200
# 875/875 [==============================] - 13s 15ms/step - loss: 5.2174 - mean_absolute_error: 1.4147 - mean_squared_error: 5.1988 - val_loss: 1.5482 - val_mean_absolute_error: 0.9417 - val_mean_squared_error: 1.5305
# Epoch 2/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3955 - mean_absolute_error: 0.5094 - mean_squared_error: 0.3783 - val_loss: 1.8217 - val_mean_absolute_error: 1.0313 - val_mean_squared_error: 1.8050
# Epoch 3/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3606 - mean_absolute_error: 0.4579 - mean_squared_error: 0.3443 - val_loss: 1.9750 - val_mean_absolute_error: 1.0742 - val_mean_squared_error: 1.9589
# Epoch 4/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3806 - mean_absolute_error: 0.4960 - mean_squared_error: 0.3648 - val_loss: 2.0388 - val_mean_absolute_error: 1.0894 - val_mean_squared_error: 2.0232
# Epoch 5/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.4077 - mean_absolute_error: 0.4772 - mean_squared_error: 0.3923 - val_loss: 3.4660 - val_mean_absolute_error: 1.5366 - val_mean_squared_error: 3.4508
# Epoch 6/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.3888 - mean_absolute_error: 0.5023 - mean_squared_error: 0.3738 - val_loss: 3.0916 - val_mean_absolute_error: 1.4193 - val_mean_squared_error: 3.0766
# Epoch 7/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3001 - mean_absolute_error: 0.4360 - mean_squared_error: 0.2852 - val_loss: 3.7524 - val_mean_absolute_error: 1.6397 - val_mean_squared_error: 3.7377
# Epoch 8/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.2883 - mean_absolute_error: 0.4420 - mean_squared_error: 0.2736 - val_loss: 3.6873 - val_mean_absolute_error: 1.6205 - val_mean_squared_error: 3.6728
# Epoch 9/200
# 875/875 [==============================] - 22s 25ms/step - loss: 0.2976 - mean_absolute_error: 0.4493 - mean_squared_error: 0.2833 - val_loss: 3.8704 - val_mean_absolute_error: 1.6722 - val_mean_squared_error: 3.8562
# Epoch 10/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.2398 - mean_absolute_error: 0.3987 - mean_squared_error: 0.2256 - val_loss: 3.9370 - val_mean_absolute_error: 1.6926 - val_mean_squared_error: 3.9230
# Epoch 11/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.2136 - mean_absolute_error: 0.3585 - mean_squared_error: 0.1997 - val_loss: 3.5978 - val_mean_absolute_error: 1.5898 - val_mean_squared_error: 3.5840
# Epoch 12/200
# 875/875 [==============================] - 27s 31ms/step - loss: 0.2410 - mean_absolute_error: 0.3820 - mean_squared_error: 0.2274 - val_loss: 4.0983 - val_mean_absolute_error: 1.7393 - val_mean_squared_error: 4.0850
# Epoch 13/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.1661 - mean_absolute_error: 0.3015 - mean_squared_error: 0.1530 - val_loss: 2.8094 - val_mean_absolute_error: 1.3314 - val_mean_squared_error: 2.7965
# Epoch 14/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1630 - mean_absolute_error: 0.2858 - mean_squared_error: 0.1503 - val_loss: 3.9325 - val_mean_absolute_error: 1.6919 - val_mean_squared_error: 3.9201
# Epoch 15/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.1432 - mean_absolute_error: 0.2689 - mean_squared_error: 0.1311 - val_loss: 3.6180 - val_mean_absolute_error: 1.5971 - val_mean_squared_error: 3.6062
# Epoch 16/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1220 - mean_absolute_error: 0.2405 - mean_squared_error: 0.1106 - val_loss: 3.5919 - val_mean_absolute_error: 1.5885 - val_mean_squared_error: 3.5809
# Epoch 17/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1122 - mean_absolute_error: 0.2418 - mean_squared_error: 0.1015 - val_loss: 3.4441 - val_mean_absolute_error: 1.5411 - val_mean_squared_error: 3.4337
# Epoch 18/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1125 - mean_absolute_error: 0.2457 - mean_squared_error: 0.1025 - val_loss: 3.6328 - val_mean_absolute_error: 1.6010 - val_mean_squared_error: 3.6232
# Epoch 19/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1287 - mean_absolute_error: 0.2610 - mean_squared_error: 0.1194 - val_loss: 3.5788 - val_mean_absolute_error: 1.5843 - val_mean_squared_error: 3.5699
# Epoch 20/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0884 - mean_absolute_error: 0.2150 - mean_squared_error: 0.0797 - val_loss: 2.2024 - val_mean_absolute_error: 1.1457 - val_mean_squared_error: 2.1939
# Epoch 21/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1126 - mean_absolute_error: 0.2483 - mean_squared_error: 0.1043 - val_loss: 3.1658 - val_mean_absolute_error: 1.4498 - val_mean_squared_error: 3.1579
# Epoch 22/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0973 - mean_absolute_error: 0.2238 - mean_squared_error: 0.0895 - val_loss: 3.2924 - val_mean_absolute_error: 1.4950 - val_mean_squared_error: 3.2848
# Epoch 23/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0928 - mean_absolute_error: 0.2209 - mean_squared_error: 0.0853 - val_loss: 2.5891 - val_mean_absolute_error: 1.2693 - val_mean_squared_error: 2.5818
# Epoch 24/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1052 - mean_absolute_error: 0.2388 - mean_squared_error: 0.0981 - val_loss: 2.9058 - val_mean_absolute_error: 1.3614 - val_mean_squared_error: 2.8988
# Epoch 25/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1014 - mean_absolute_error: 0.2394 - mean_squared_error: 0.0945 - val_loss: 2.1955 - val_mean_absolute_error: 1.1433 - val_mean_squared_error: 2.1887
# Epoch 26/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1404 - mean_absolute_error: 0.2719 - mean_squared_error: 0.1338 - val_loss: 3.4146 - val_mean_absolute_error: 1.5348 - val_mean_squared_error: 3.4081
# Epoch 27/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0821 - mean_absolute_error: 0.2071 - mean_squared_error: 0.0757 - val_loss: 2.4974 - val_mean_absolute_error: 1.2405 - val_mean_squared_error: 2.4909
# Epoch 28/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0923 - mean_absolute_error: 0.2196 - mean_squared_error: 0.0859 - val_loss: 2.6382 - val_mean_absolute_error: 1.2849 - val_mean_squared_error: 2.6318
# Epoch 29/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0897 - mean_absolute_error: 0.2259 - mean_squared_error: 0.0834 - val_loss: 2.8831 - val_mean_absolute_error: 1.3586 - val_mean_squared_error: 2.8769
# Epoch 30/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0744 - mean_absolute_error: 0.1986 - mean_squared_error: 0.0682 - val_loss: 1.7850 - val_mean_absolute_error: 1.0208 - val_mean_squared_error: 1.7788
# Epoch 31/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1151 - mean_absolute_error: 0.2334 - mean_squared_error: 0.1090 - val_loss: 2.8941 - val_mean_absolute_error: 1.3617 - val_mean_squared_error: 2.8881
# Epoch 32/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0832 - mean_absolute_error: 0.2128 - mean_squared_error: 0.0773 - val_loss: 2.6767 - val_mean_absolute_error: 1.2974 - val_mean_squared_error: 2.6707
# Epoch 33/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0797 - mean_absolute_error: 0.2058 - mean_squared_error: 0.0738 - val_loss: 3.1776 - val_mean_absolute_error: 1.4555 - val_mean_squared_error: 3.1718
# Epoch 34/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0814 - mean_absolute_error: 0.2059 - mean_squared_error: 0.0757 - val_loss: 2.6626 - val_mean_absolute_error: 1.2925 - val_mean_squared_error: 2.6568
# Epoch 35/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0876 - mean_absolute_error: 0.2151 - mean_squared_error: 0.0819 - val_loss: 2.5699 - val_mean_absolute_error: 1.2623 - val_mean_squared_error: 2.5643
# Epoch 36/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1182 - mean_absolute_error: 0.2553 - mean_squared_error: 0.1126 - val_loss: 2.7674 - val_mean_absolute_error: 1.3285 - val_mean_squared_error: 2.7619
# Epoch 37/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0652 - mean_absolute_error: 0.1795 - mean_squared_error: 0.0597 - val_loss: 3.1619 - val_mean_absolute_error: 1.4543 - val_mean_squared_error: 3.1564
# Epoch 38/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0757 - mean_absolute_error: 0.2025 - mean_squared_error: 0.0703 - val_loss: 2.8025 - val_mean_absolute_error: 1.3408 - val_mean_squared_error: 2.7970
# Epoch 39/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0759 - mean_absolute_error: 0.2020 - mean_squared_error: 0.0705 - val_loss: 2.1523 - val_mean_absolute_error: 1.1254 - val_mean_squared_error: 2.1470
# Epoch 40/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0722 - mean_absolute_error: 0.1941 - mean_squared_error: 0.0669 - val_loss: 2.2233 - val_mean_absolute_error: 1.1493 - val_mean_squared_error: 2.2180
# Epoch 41/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0718 - mean_absolute_error: 0.1899 - mean_squared_error: 0.0666 - val_loss: 2.5742 - val_mean_absolute_error: 1.2647 - val_mean_squared_error: 2.5689
# Epoch 42/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0649 - mean_absolute_error: 0.1807 - mean_squared_error: 0.0597 - val_loss: 2.5939 - val_mean_absolute_error: 1.2684 - val_mean_squared_error: 2.5887
# Epoch 43/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0669 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0618 - val_loss: 2.8934 - val_mean_absolute_error: 1.3602 - val_mean_squared_error: 2.8883
# Epoch 44/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0709 - mean_absolute_error: 0.1983 - mean_squared_error: 0.0659 - val_loss: 2.5505 - val_mean_absolute_error: 1.2618 - val_mean_squared_error: 2.5456
# Epoch 45/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0694 - mean_absolute_error: 0.1891 - mean_squared_error: 0.0645 - val_loss: 2.9804 - val_mean_absolute_error: 1.3956 - val_mean_squared_error: 2.9755
# Epoch 46/200
# 875/875 [==============================] - 24s 28ms/step - loss: 0.0719 - mean_absolute_error: 0.1961 - mean_squared_error: 0.0670 - val_loss: 2.4074 - val_mean_absolute_error: 1.2118 - val_mean_squared_error: 2.4026
# Epoch 47/200
# 875/875 [==============================] - 24s 28ms/step - loss: 0.0618 - mean_absolute_error: 0.1743 - mean_squared_error: 0.0571 - val_loss: 2.2830 - val_mean_absolute_error: 1.1690 - val_mean_squared_error: 2.2782
# Epoch 48/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0676 - mean_absolute_error: 0.1821 - mean_squared_error: 0.0629 - val_loss: 2.6052 - val_mean_absolute_error: 1.2808 - val_mean_squared_error: 2.6005
# Epoch 49/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0630 - mean_absolute_error: 0.1787 - mean_squared_error: 0.0583 - val_loss: 2.4626 - val_mean_absolute_error: 1.2316 - val_mean_squared_error: 2.4579
# Epoch 50/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0601 - mean_absolute_error: 0.1661 - mean_squared_error: 0.0555 - val_loss: 2.7647 - val_mean_absolute_error: 1.3206 - val_mean_squared_error: 2.7601
# Epoch 51/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0643 - mean_absolute_error: 0.1779 - mean_squared_error: 0.0597 - val_loss: 2.5744 - val_mean_absolute_error: 1.2720 - val_mean_squared_error: 2.5698
# Epoch 52/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0919 - mean_absolute_error: 0.2229 - mean_squared_error: 0.0873 - val_loss: 2.5535 - val_mean_absolute_error: 1.2609 - val_mean_squared_error: 2.5490
# Epoch 53/200
# 875/875 [==============================] - 436s 498ms/step - loss: 0.0650 - mean_absolute_error: 0.1887 - mean_squared_error: 0.0605 - val_loss: 2.1651 - val_mean_absolute_error: 1.1289 - val_mean_squared_error: 2.1606
# Epoch 54/200
# 875/875 [==============================] - 116s 133ms/step - loss: 0.1022 - mean_absolute_error: 0.2107 - mean_squared_error: 0.0977 - val_loss: 2.2922 - val_mean_absolute_error: 1.1691 - val_mean_squared_error: 2.2878
# Epoch 55/200
# 875/875 [==============================] - 1980s 2s/step - loss: 0.0704 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0661 - val_loss: 2.6339 - val_mean_absolute_error: 1.2914 - val_mean_squared_error: 2.6296
# Epoch 56/200
# 875/875 [==============================] - 16s 18ms/step - loss: 0.0528 - mean_absolute_error: 0.1586 - mean_squared_error: 0.0485 - val_loss: 1.9749 - val_mean_absolute_error: 1.0711 - val_mean_squared_error: 1.9706
# Epoch 57/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0525 - mean_absolute_error: 0.1568 - mean_squared_error: 0.0482 - val_loss: 2.0850 - val_mean_absolute_error: 1.1014 - val_mean_squared_error: 2.0807
# Epoch 58/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0607 - mean_absolute_error: 0.1662 - mean_squared_error: 0.0565 - val_loss: 2.4774 - val_mean_absolute_error: 1.2292 - val_mean_squared_error: 2.4732
# Epoch 59/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0578 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0536 - val_loss: 2.1773 - val_mean_absolute_error: 1.1350 - val_mean_squared_error: 2.1730
# Epoch 60/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0521 - mean_absolute_error: 0.1542 - mean_squared_error: 0.0479 - val_loss: 2.2251 - val_mean_absolute_error: 1.1478 - val_mean_squared_error: 2.2209
# Epoch 61/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0482 - mean_absolute_error: 0.1538 - mean_squared_error: 0.0441 - val_loss: 2.4825 - val_mean_absolute_error: 1.2420 - val_mean_squared_error: 2.4783
# Epoch 62/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0498 - mean_absolute_error: 0.1520 - mean_squared_error: 0.0457 - val_loss: 2.2666 - val_mean_absolute_error: 1.1597 - val_mean_squared_error: 2.2624
# Epoch 63/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0545 - mean_absolute_error: 0.1639 - mean_squared_error: 0.0504 - val_loss: 2.0965 - val_mean_absolute_error: 1.1046 - val_mean_squared_error: 2.0924
# Epoch 64/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0453 - mean_absolute_error: 0.1479 - mean_squared_error: 0.0412 - val_loss: 2.0962 - val_mean_absolute_error: 1.1012 - val_mean_squared_error: 2.0921
# Epoch 65/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0569 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0528 - val_loss: 2.6018 - val_mean_absolute_error: 1.2822 - val_mean_squared_error: 2.5977
# Epoch 66/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0521 - mean_absolute_error: 0.1593 - mean_squared_error: 0.0481 - val_loss: 2.1614 - val_mean_absolute_error: 1.1230 - val_mean_squared_error: 2.1573
# Epoch 67/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0468 - mean_absolute_error: 0.1503 - mean_squared_error: 0.0427 - val_loss: 1.9528 - val_mean_absolute_error: 1.0605 - val_mean_squared_error: 1.9488
# Epoch 68/200
# 875/875 [==============================] - 14s 15ms/step - loss: 0.0550 - mean_absolute_error: 0.1625 - mean_squared_error: 0.0510 - val_loss: 1.6402 - val_mean_absolute_error: 0.9684 - val_mean_squared_error: 1.6361
# Epoch 69/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0675 - mean_absolute_error: 0.1783 - mean_squared_error: 0.0636 - val_loss: 1.6937 - val_mean_absolute_error: 0.9808 - val_mean_squared_error: 1.6898
# Epoch 70/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0504 - mean_absolute_error: 0.1465 - mean_squared_error: 0.0465 - val_loss: 1.8599 - val_mean_absolute_error: 1.0318 - val_mean_squared_error: 1.8560
# Epoch 71/200
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0540 - mean_absolute_error: 0.1642 - mean_squared_error: 0.0501 - val_loss: 1.9639 - val_mean_absolute_error: 1.0634 - val_mean_squared_error: 1.9600
# Epoch 72/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0399 - mean_absolute_error: 0.1346 - mean_squared_error: 0.0361 - val_loss: 1.6221 - val_mean_absolute_error: 0.9613 - val_mean_squared_error: 1.6183
# Epoch 73/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0413 - mean_absolute_error: 0.1380 - mean_squared_error: 0.0375 - val_loss: 1.5695 - val_mean_absolute_error: 0.9410 - val_mean_squared_error: 1.5657
# Epoch 74/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0508 - mean_absolute_error: 0.1554 - mean_squared_error: 0.0470 - val_loss: 1.6579 - val_mean_absolute_error: 0.9698 - val_mean_squared_error: 1.6541
# Epoch 75/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0419 - mean_absolute_error: 0.1415 - mean_squared_error: 0.0381 - val_loss: 1.9499 - val_mean_absolute_error: 1.0596 - val_mean_squared_error: 1.9461
# Epoch 76/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0503 - mean_absolute_error: 0.1572 - mean_squared_error: 0.0465 - val_loss: 1.8577 - val_mean_absolute_error: 1.0327 - val_mean_squared_error: 1.8540
# Epoch 77/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0476 - mean_absolute_error: 0.1527 - mean_squared_error: 0.0439 - val_loss: 1.7745 - val_mean_absolute_error: 1.0009 - val_mean_squared_error: 1.7708
# Epoch 78/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0451 - mean_absolute_error: 0.1489 - mean_squared_error: 0.0415 - val_loss: 2.0050 - val_mean_absolute_error: 1.0651 - val_mean_squared_error: 2.0014
# Epoch 79/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0440 - mean_absolute_error: 0.1435 - mean_squared_error: 0.0404 - val_loss: 2.0267 - val_mean_absolute_error: 1.0795 - val_mean_squared_error: 2.0231
# Epoch 80/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0364 - mean_absolute_error: 0.1310 - mean_squared_error: 0.0327 - val_loss: 1.8544 - val_mean_absolute_error: 1.0227 - val_mean_squared_error: 1.8507
# Epoch 81/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0374 - mean_absolute_error: 0.1308 - mean_squared_error: 0.0337 - val_loss: 2.1050 - val_mean_absolute_error: 1.0957 - val_mean_squared_error: 2.1014
# Epoch 82/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0405 - mean_absolute_error: 0.1369 - mean_squared_error: 0.0369 - val_loss: 2.0692 - val_mean_absolute_error: 1.0950 - val_mean_squared_error: 2.0656
# Epoch 83/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0377 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0341 - val_loss: 2.1537 - val_mean_absolute_error: 1.1251 - val_mean_squared_error: 2.1501
# Epoch 84/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0437 - mean_absolute_error: 0.1535 - mean_squared_error: 0.0401 - val_loss: 1.9010 - val_mean_absolute_error: 1.0358 - val_mean_squared_error: 1.8974
# Epoch 85/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0372 - mean_absolute_error: 0.1277 - mean_squared_error: 0.0336 - val_loss: 2.2669 - val_mean_absolute_error: 1.1700 - val_mean_squared_error: 2.2633
# Epoch 86/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0398 - mean_absolute_error: 0.1395 - mean_squared_error: 0.0363 - val_loss: 2.4500 - val_mean_absolute_error: 1.2285 - val_mean_squared_error: 2.4464
# Epoch 87/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0461 - mean_absolute_error: 0.1518 - mean_squared_error: 0.0426 - val_loss: 1.7367 - val_mean_absolute_error: 0.9874 - val_mean_squared_error: 1.7331
# Epoch 88/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0332 - mean_absolute_error: 0.1268 - mean_squared_error: 0.0296 - val_loss: 1.9588 - val_mean_absolute_error: 1.0607 - val_mean_squared_error: 1.9552
# Epoch 89/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0321 - mean_absolute_error: 0.1208 - mean_squared_error: 0.0286 - val_loss: 1.7206 - val_mean_absolute_error: 0.9780 - val_mean_squared_error: 1.7171
# Epoch 90/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0419 - mean_absolute_error: 0.1408 - mean_squared_error: 0.0384 - val_loss: 1.8123 - val_mean_absolute_error: 1.0004 - val_mean_squared_error: 1.8087
# Epoch 91/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0369 - mean_absolute_error: 0.1327 - mean_squared_error: 0.0334 - val_loss: 1.9241 - val_mean_absolute_error: 1.0326 - val_mean_squared_error: 1.9206
# Epoch 92/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0409 - mean_absolute_error: 0.1397 - mean_squared_error: 0.0374 - val_loss: 1.9379 - val_mean_absolute_error: 1.0506 - val_mean_squared_error: 1.9345
# Epoch 93/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0382 - mean_absolute_error: 0.1378 - mean_squared_error: 0.0347 - val_loss: 1.7358 - val_mean_absolute_error: 0.9827 - val_mean_squared_error: 1.7323
# Epoch 94/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0326 - mean_absolute_error: 0.1196 - mean_squared_error: 0.0292 - val_loss: 2.3345 - val_mean_absolute_error: 1.1833 - val_mean_squared_error: 2.3311
# Epoch 95/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0323 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0290 - val_loss: 1.7382 - val_mean_absolute_error: 0.9739 - val_mean_squared_error: 1.7348
# Epoch 96/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0350 - mean_absolute_error: 0.1280 - mean_squared_error: 0.0316 - val_loss: 2.1179 - val_mean_absolute_error: 1.1150 - val_mean_squared_error: 2.1145
# Epoch 97/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0421 - mean_absolute_error: 0.1314 - mean_squared_error: 0.0388 - val_loss: 1.6972 - val_mean_absolute_error: 0.9665 - val_mean_squared_error: 1.6939
# Epoch 98/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0352 - mean_absolute_error: 0.1298 - mean_squared_error: 0.0319 - val_loss: 1.6073 - val_mean_absolute_error: 0.9383 - val_mean_squared_error: 1.6039
# Epoch 99/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0366 - mean_absolute_error: 0.1250 - mean_squared_error: 0.0333 - val_loss: 1.6065 - val_mean_absolute_error: 0.9305 - val_mean_squared_error: 1.6031
# Epoch 100/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0383 - mean_absolute_error: 0.1360 - mean_squared_error: 0.0350 - val_loss: 1.5558 - val_mean_absolute_error: 0.9232 - val_mean_squared_error: 1.5524
# Epoch 101/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0360 - mean_absolute_error: 0.1306 - mean_squared_error: 0.0327 - val_loss: 1.7025 - val_mean_absolute_error: 0.9734 - val_mean_squared_error: 1.6992
# Epoch 102/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0343 - mean_absolute_error: 0.1262 - mean_squared_error: 0.0310 - val_loss: 1.6342 - val_mean_absolute_error: 0.9522 - val_mean_squared_error: 1.6309
# Epoch 103/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0292 - mean_absolute_error: 0.1137 - mean_squared_error: 0.0259 - val_loss: 1.6105 - val_mean_absolute_error: 0.9344 - val_mean_squared_error: 1.6073
# Epoch 104/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0303 - mean_absolute_error: 0.1176 - mean_squared_error: 0.0271 - val_loss: 1.7194 - val_mean_absolute_error: 0.9676 - val_mean_squared_error: 1.7162
# Epoch 105/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0335 - mean_absolute_error: 0.1217 - mean_squared_error: 0.0303 - val_loss: 1.9535 - val_mean_absolute_error: 1.0296 - val_mean_squared_error: 1.9503
# Epoch 106/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0304 - mean_absolute_error: 0.1168 - mean_squared_error: 0.0272 - val_loss: 1.7627 - val_mean_absolute_error: 0.9748 - val_mean_squared_error: 1.7595
# Epoch 107/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0285 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0254 - val_loss: 1.5525 - val_mean_absolute_error: 0.9117 - val_mean_squared_error: 1.5493
# Epoch 108/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0284 - mean_absolute_error: 0.1064 - mean_squared_error: 0.0253 - val_loss: 1.9490 - val_mean_absolute_error: 1.0553 - val_mean_squared_error: 1.9458
# Epoch 109/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0288 - mean_absolute_error: 0.1140 - mean_squared_error: 0.0257 - val_loss: 1.6905 - val_mean_absolute_error: 0.9528 - val_mean_squared_error: 1.6874
# Epoch 110/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0305 - mean_absolute_error: 0.1127 - mean_squared_error: 0.0274 - val_loss: 1.9716 - val_mean_absolute_error: 1.0641 - val_mean_squared_error: 1.9685
# Epoch 111/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0478 - mean_absolute_error: 0.1412 - mean_squared_error: 0.0447 - val_loss: 2.3680 - val_mean_absolute_error: 1.1940 - val_mean_squared_error: 2.3649
# Epoch 112/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0319 - mean_absolute_error: 0.1190 - mean_squared_error: 0.0288 - val_loss: 1.5907 - val_mean_absolute_error: 0.9276 - val_mean_squared_error: 1.5876
# Epoch 113/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0406 - mean_absolute_error: 0.1436 - mean_squared_error: 0.0376 - val_loss: 1.6303 - val_mean_absolute_error: 0.9397 - val_mean_squared_error: 1.6273
# Epoch 114/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0279 - mean_absolute_error: 0.1070 - mean_squared_error: 0.0248 - val_loss: 1.6271 - val_mean_absolute_error: 0.9349 - val_mean_squared_error: 1.6241
# Epoch 115/200
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0367 - mean_absolute_error: 0.1284 - mean_squared_error: 0.0337 - val_loss: 1.4954 - val_mean_absolute_error: 0.8941 - val_mean_squared_error: 1.4924
# Epoch 116/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0296 - mean_absolute_error: 0.1059 - mean_squared_error: 0.0267 - val_loss: 1.6060 - val_mean_absolute_error: 0.9296 - val_mean_squared_error: 1.6030
# Epoch 117/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0242 - mean_absolute_error: 0.1044 - mean_squared_error: 0.0212 - val_loss: 1.5665 - val_mean_absolute_error: 0.9125 - val_mean_squared_error: 1.5635
# Epoch 118/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0294 - mean_absolute_error: 0.1080 - mean_squared_error: 0.0264 - val_loss: 1.9528 - val_mean_absolute_error: 1.0536 - val_mean_squared_error: 1.9499
# Epoch 119/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0268 - mean_absolute_error: 0.1112 - mean_squared_error: 0.0238 - val_loss: 1.7776 - val_mean_absolute_error: 0.9920 - val_mean_squared_error: 1.7747
# Epoch 120/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0234 - mean_absolute_error: 0.0991 - mean_squared_error: 0.0204 - val_loss: 1.6669 - val_mean_absolute_error: 0.9537 - val_mean_squared_error: 1.6640
# Epoch 121/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0395 - mean_absolute_error: 0.1368 - mean_squared_error: 0.0366 - val_loss: 1.4784 - val_mean_absolute_error: 0.8891 - val_mean_squared_error: 1.4755
# Epoch 122/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0292 - mean_absolute_error: 0.1148 - mean_squared_error: 0.0263 - val_loss: 1.8647 - val_mean_absolute_error: 1.0212 - val_mean_squared_error: 1.8618
# Epoch 123/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0408 - mean_absolute_error: 0.1294 - mean_squared_error: 0.0379 - val_loss: 1.5569 - val_mean_absolute_error: 0.9142 - val_mean_squared_error: 1.5541
# Epoch 124/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0249 - mean_absolute_error: 0.1057 - mean_squared_error: 0.0221 - val_loss: 1.5006 - val_mean_absolute_error: 0.8936 - val_mean_squared_error: 1.4978
# Epoch 125/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0252 - mean_absolute_error: 0.1017 - mean_squared_error: 0.0223 - val_loss: 1.3502 - val_mean_absolute_error: 0.8432 - val_mean_squared_error: 1.3474
# Epoch 126/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0328 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0300 - val_loss: 1.4099 - val_mean_absolute_error: 0.8643 - val_mean_squared_error: 1.4071
# Epoch 127/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0238 - mean_absolute_error: 0.1068 - mean_squared_error: 0.0210 - val_loss: 1.4231 - val_mean_absolute_error: 0.8624 - val_mean_squared_error: 1.4203
# Epoch 128/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0268 - mean_absolute_error: 0.1065 - mean_squared_error: 0.0240 - val_loss: 1.4367 - val_mean_absolute_error: 0.8706 - val_mean_squared_error: 1.4338
# Epoch 129/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0227 - mean_absolute_error: 0.0965 - mean_squared_error: 0.0199 - val_loss: 1.5391 - val_mean_absolute_error: 0.8931 - val_mean_squared_error: 1.5364
# Epoch 130/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0343 - mean_absolute_error: 0.1239 - mean_squared_error: 0.0315 - val_loss: 1.4705 - val_mean_absolute_error: 0.8828 - val_mean_squared_error: 1.4677
# Epoch 131/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0280 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0253 - val_loss: 1.5932 - val_mean_absolute_error: 0.9133 - val_mean_squared_error: 1.5905
# Epoch 132/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0277 - mean_absolute_error: 0.1139 - mean_squared_error: 0.0250 - val_loss: 1.7935 - val_mean_absolute_error: 0.9983 - val_mean_squared_error: 1.7908
# Epoch 133/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0322 - mean_absolute_error: 0.1160 - mean_squared_error: 0.0295 - val_loss: 1.4766 - val_mean_absolute_error: 0.8801 - val_mean_squared_error: 1.4739
# Epoch 134/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0253 - mean_absolute_error: 0.1060 - mean_squared_error: 0.0226 - val_loss: 1.5339 - val_mean_absolute_error: 0.9065 - val_mean_squared_error: 1.5312
# Epoch 135/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0261 - mean_absolute_error: 0.1125 - mean_squared_error: 0.0234 - val_loss: 1.4380 - val_mean_absolute_error: 0.8710 - val_mean_squared_error: 1.4353
# Epoch 136/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0576 - mean_absolute_error: 0.1493 - mean_squared_error: 0.0549 - val_loss: 1.3447 - val_mean_absolute_error: 0.8465 - val_mean_squared_error: 1.3421
# Epoch 137/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0333 - mean_absolute_error: 0.1154 - mean_squared_error: 0.0307 - val_loss: 1.3273 - val_mean_absolute_error: 0.8353 - val_mean_squared_error: 1.3247
# Epoch 138/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0271 - mean_absolute_error: 0.1111 - mean_squared_error: 0.0245 - val_loss: 1.2775 - val_mean_absolute_error: 0.8230 - val_mean_squared_error: 1.2748
# Epoch 139/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0230 - mean_absolute_error: 0.0956 - mean_squared_error: 0.0204 - val_loss: 1.3633 - val_mean_absolute_error: 0.8381 - val_mean_squared_error: 1.3607
# Epoch 140/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0225 - mean_absolute_error: 0.1048 - mean_squared_error: 0.0199 - val_loss: 1.3127 - val_mean_absolute_error: 0.8349 - val_mean_squared_error: 1.3100
# Epoch 141/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0185 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0159 - val_loss: 1.3691 - val_mean_absolute_error: 0.8287 - val_mean_squared_error: 1.3664
# Epoch 142/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0267 - mean_absolute_error: 0.1066 - mean_squared_error: 0.0241 - val_loss: 1.3541 - val_mean_absolute_error: 0.8321 - val_mean_squared_error: 1.3514
# Epoch 143/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0540 - mean_absolute_error: 0.1430 - mean_squared_error: 0.0514 - val_loss: 1.8749 - val_mean_absolute_error: 1.0292 - val_mean_squared_error: 1.8723
# Epoch 144/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0324 - mean_absolute_error: 0.1221 - mean_squared_error: 0.0298 - val_loss: 1.3159 - val_mean_absolute_error: 0.8185 - val_mean_squared_error: 1.3133
# Epoch 145/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0255 - mean_absolute_error: 0.0968 - mean_squared_error: 0.0230 - val_loss: 1.3150 - val_mean_absolute_error: 0.8193 - val_mean_squared_error: 1.3124
# Epoch 146/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0254 - mean_absolute_error: 0.1047 - mean_squared_error: 0.0229 - val_loss: 1.2388 - val_mean_absolute_error: 0.8109 - val_mean_squared_error: 1.2363
# Epoch 147/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0228 - mean_absolute_error: 0.0953 - mean_squared_error: 0.0203 - val_loss: 1.3844 - val_mean_absolute_error: 0.8388 - val_mean_squared_error: 1.3819
# Epoch 148/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0183 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0158 - val_loss: 1.4506 - val_mean_absolute_error: 0.8512 - val_mean_squared_error: 1.4481
# Epoch 149/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0226 - mean_absolute_error: 0.1001 - mean_squared_error: 0.0201 - val_loss: 1.2548 - val_mean_absolute_error: 0.8096 - val_mean_squared_error: 1.2523
# Epoch 150/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0166 - mean_absolute_error: 0.0821 - mean_squared_error: 0.0141 - val_loss: 1.3095 - val_mean_absolute_error: 0.8080 - val_mean_squared_error: 1.3069
# Epoch 151/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0236 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0211 - val_loss: 1.2904 - val_mean_absolute_error: 0.8212 - val_mean_squared_error: 1.2879
# Epoch 152/200
# 736/875 [========================>.....] - ETA: 1s - loss: 0.0236 - mean_absolute_error: 0.0999 - mean_squared_error: 0.0210

# %%
hist = pd.DataFrame(history.history)
hist['epoch']= history.epoch
hist.tail()
# Out:
#          val_loss  val_mean_absolute_error  val_mean_squared_error  \
# 195  6.650632e+07              6355.818481            6.650632e+07
# 196  6.275853e+07              6161.197162            6.275853e+07
# 197  5.944006e+07              5997.135702            5.944006e+07
# 198  6.229281e+07              6138.579988            6.229281e+07
# 199  6.106594e+07              6076.085226            6.106594e+07
#
#              loss  mean_absolute_error  mean_squared_error  epoch
# 195  1.702399e+06           881.769361        1.702399e+06    195
# 196  1.711892e+06           930.596856        1.711892e+06    196
# 197  1.580298e+06           893.164042        1.580298e+06    197
# 198  1.912179e+06           979.157146        1.912179e+06    198
# 199  1.614590e+06           912.569914        1.614590e+06    199

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  #plt.ylim([0,5])
  plt.legend()
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  #plt.ylim([0,20])
  plt.legend()
  plt.show()


plot_history(history)

# %%
test_predictions = model.predict(norm_flux).flatten()

plt.scatter(normalize(teff), test_predictions)
plt.xlabel('True Values [Teff]')
plt.ylabel('Predictions [Teff]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

print('test predictions=', test_predictions)
# Out:
# test predictions= [ 6836.807   6837.5747  6836.7603 ... 10159.98   12968.633  12631.623 ]
