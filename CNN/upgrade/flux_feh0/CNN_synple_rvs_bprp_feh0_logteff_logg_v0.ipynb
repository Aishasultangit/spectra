# %% [markdown]
# # Train the StarNet Model
#
# This notebook takes you through the steps of how to train a StarNet Model
# - Required Python packages: `numpy h5py keras`
# - Required data files: training_data.h5, mean_and_std.npy
#
# Note: We use tensorflow for the keras backend.

# %%
import numpy as np
import h5py
import random
import keras
from keras.models import Model
from keras.layers import Input, Dense, InputLayer, Flatten, Reshape, Concatenate, concatenate
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.optimizers import Adam
import tensorflow as tf
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.utils import HDF5Matrix
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc


#Loading the data

#RVSFlux normalized
pathrvs = 'norm_rvsflux.h5'
readrvs = h5py.File(pathrvs, 'r')
print(readrvs.keys())
rvs = readrvs.get('normrvs')
norm_rvsflux = np.array(rvs)
readrvs.close()

type(rvs)
print('shape of rvsflux:', np.shape(norm_rvsflux))
# Out:
# Using TensorFlow backend.
# <KeysViewHDF5 ['normrvs']>
# shape of rvsflux: (415, 1134)

# %%
#BPFlux
pathbp = 'bpflux.h5'
readbp = h5py.File(pathbp, 'r')
#print('total number of wave and flux in the folder:'len(readbp.keys()))
bpflux = readbp.get('bpflux0')
bpflux = np.array(bpflux)


norm_bpflux= []

for ii in range(np.shape(norm_rvsflux)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star #',ii)
        fluxlabel = 'bpflux'+str(ii)
        wavelabel = 'bpwave' +str(ii)
        flux = readbp.get(fluxlabel)
        wave= readbp.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_bpflux.append(normflux)


        
norm_bpflux= np.array(norm_bpflux)

print('shape of norm bpflux:', np.shape(norm_bpflux))
#print('shape of norm bpflux:', print(norm_bpflux[0:10]))
# Out:
# shape of norm bpflux: (415, 53)

# %%
#RPFlux
pathrp = 'rpflux.h5'
readrp = h5py.File(pathrp, 'r')
#print('total number of wave and flux in the folder:'len(readbp.keys()))
rpflux = readrp.get('rpflux0')
rpflux = np.array(rpflux)


norm_rpflux= []

for ii in range(np.shape(norm_rvsflux)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star:',ii)
        fluxlabel = 'rpflux'+str(ii)
        wavelabel = 'rpwave' +str(ii)
        
        flux = readrp.get(fluxlabel)
        wave= readrp.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_rpflux.append(normflux)


        
norm_rpflux= np.array(norm_rpflux)

print('shape of norm_rpflux:', np.shape(norm_rpflux))
#print('output of norm_flux:', print(norm_rpflux[0:10]))

#print('The shapes of features and labels:', np.shape(norm_flux), np.shape(logteff))
# Out:
# shape of norm_rpflux: (415, 49)

# %%
#LogTeff
modparam = 'modparam_feh0.h5' #model parameters includes log g and teff
readfile = h5py.File(modparam, 'r')
print(readfile.keys())
logteff = readfile.get('logteff')
logteff = np.array(logteff)
logg = readfile.get('logg')
logg = np.array(logg)
readfile.close()

print(np.shape(logteff))
# Out:
# <KeysViewHDF5 ['logg', 'teff']>
# ()

# %%
#features
num_tot = len(logteff)
print('total number of input stars =', num_tot)
plim = 0.8
ran_frac = np.random.uniform(0,1,num_tot)
#print('ranfrac=' , ran_frac)




#Input flux data of RVS, BP, RP
x_RVStrain = norm_rvsflux[ran_frac < plim, :]
print('number of RVS training data=', len(x_RVStrain[:,0]))
x_RVScv = norm_rvsflux[ran_frac >= plim, :] #test set we left for the application

x_BPtrain = norm_bpflux[ran_frac < plim, :]
print('number of BP training data=', len(x_BPtrain[:,0]))
x_BPcv = norm_bpflux[ran_frac >= plim, :]

x_RPtrain =norm_rpflux[ran_frac < plim, :]
print('number of RP training data=', len(x_RPtrain[:,0]))
x_RPcv = norm_rpflux[ran_frac >= plim, :]


#print('x_BPtrain', x_BPtrain)

#x_train_combined = np.vstack (x_RVStrain[0,:],x_RPtrain[0,:]) 

#output label which is the logteff and log g
y_logteff_train = logteff[ran_frac< plim]
y_logteff_cv = logteff[ran_frac >= plim] #test set

y_logg_train = logg[ran_frac< plim]
y_logg_cv = logg[ran_frac >= plim] #test set



print('The size of CVS for the input flux data')
print('RVS cvs=', np.shape(x_RVScv))
print('BP cvs=', np.shape(x_BPcv))
print('RP cvs=', np.shape(x_RPcv))

print('the size of output label=', np.shape(y_logteff_train) )

id = np.linspace(0, len(x_RVStrain[:, 0])-1, len(x_RVStrain[:, 0]))
plt.plot(id, y_logteff_train)
plt.show()
# Out:
# total number of input stars = 415
# number of RVS training data= 334
# number of BP training data= 334
# number of RP training data= 334
# The size of CVS for the input flux data
# RVS cvs= (81, 1134)
# BP cvs= (81, 53)
# RP cvs= (81, 49)
# the size of output label= (334,)

# %% [markdown]
# ** Normalization **
#
# Write a function to normalize the output labels. Each label will be normalized to have approximately have a mean of zero and unit variance.
#
# NOTE: This is necessary to put output labels on a similar scale in order for the model to train properly, this process is reversed in the test stage to give the output labels their proper units

# %%
#mean_labels=np.mean(logteff)
#std_labels=np.std(logteff)
#print('mean and std teff=', mean_labels, std_labels)
def normalize(labels):
    # Normalize labels
    mean_labels=np.mean(labels)
    std_labels=np.std(labels)
    return (labels-mean_labels) / std_labels

# %%
#normalize the y labels, the log teff and log g 

#output label which is the logteff and log g
y_logteff_train = normalize(y_logteff_train)
y_logteff_cv = normalize(y_logteff_cv)

y_logg_train = normalize(y_logg_train)
y_logg_cv = normalize(y_logg_cv)


print('type of data ', type(y_logteff_train),type(y_logteff_cv), type(y_logg_train),type(y_logg_cv) )
# Out:
# type of data  <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %% [markdown]
# **Build the StarNet model architecture**
#
# The StarNet architecture is built with:
# - input layer
# - 2 convolutional layers
# - 1 maxpooling layer followed by flattening for the fully connected layer
# - 2 fully connected layers
# - output layer
#
# First, let's define some model variables.

# %%
# activation function used following every layer except for the output layers
activation = 'relu'
#activation = 'sigmoid'

# model weight initializer
initializer = 'he_normal'

# number of filters used in the convolutional layers
#num_filters = [4,16]
num_filters = [8,32]
#num_filters = [8,16]

# length of the filters in the convolutional layers
#filter_length = 8
#filter_length = 16
filter_length = 8

# length of the maxpooling window 
pool_length = 4

# number of nodes in each of the hidden fully connected layers
num_hidden = [256,128]
#num_hidden = [24,12]

# number of spectra fed into model at once during training
batch_size = 64

# maximum number of interations for model training
#max_epochs = 200
#max_epochs = 100
#max_epochs = 150 
#max_epochs = 350
#max_epochs = 225
#max_epochs = 180
#max_epochs = 450
#max_epochs = 300
max_epochs = 300


# initial learning rate for optimization algorithm
lr = 0.000003 #handled by Adam
    
# exponential decay rate for the 1st moment estimates for optimization algorithm
beta_1 = 0.9

# exponential decay rate for the 2nd moment estimates for optimization algorithm
beta_2 = 0.999

# a small constant for numerical stability for optimization algorithm
optimizer_epsilon = 1e-08

# %%
num_RVSfluxes=len(x_RVStrain[0,:]) 
print('number of RVS fluxes=', num_RVSfluxes)

num_BPfluxes=len(x_BPtrain[0,:]) 
print('number of BP fluxes=', num_BPfluxes)

num_RPfluxes=len(x_RPtrain[0,:]) 
print('number of RP fluxes=', num_RPfluxes)

#num_labels= 1
num_labels= 2
print('number of training labels=', num_labels)

#ilam = np.linspace(0, num_fluxes-1, num_fluxes)
#plt.plot(ilam, x_train[329, :])
#plt.plot()

#iy = np.linspace(0, len(y_train)-1, len(y_train))
#plt.plot(iy, y_train)
#plt.plot()
# Out:
# number of RVS fluxes= 1134
# number of BP fluxes= 53
# number of RP fluxes= 49
# number of training labels= 2

# %%
# Input RVS spectra
# print(' num_RVSfluxes=', num_RVSfluxes)
input_RVSspec = Input(shape=(num_RVSfluxes,), name='rvs_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for RVS layers
cur_rvs = Reshape((num_RVSfluxes, 1))(input_RVSspec)

# CNN layers
cur_rvs = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_rvs) #first CNN layer
cur_rvs = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_rvs) #2nd CNN layer

# Max pooling layer
cur_rvs = MaxPooling1D(pool_size=pool_length)(cur_rvs)

# Flatten the current input for the fully-connected layers
cur_rvs = Flatten()(cur_rvs)


##############################################################################################


# Input BP spectra
# print(' num_BPfluxes=', num_BPfluxes)
input_BPspec = Input(shape=(num_BPfluxes,), name='bp_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for BP layers
cur_bp = Reshape((num_BPfluxes, 1))(input_BPspec)

# CNN layers
cur_bp = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_bp) #first CNN layer
cur_bp = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_bp) #2nd CNN layer

# Max pooling layer
cur_bp = MaxPooling1D(pool_size=pool_length)(cur_bp)


# Flatten the current input for the fully-connected layers
cur_bp = Flatten()(cur_bp)


################################################################################################

# Input RP spectra
input_RPspec = Input(shape=(num_RPfluxes,), name='rp_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for CNN layers
cur_rp = Reshape((num_RPfluxes, 1))(input_RPspec)

# CNN layers
cur_rp = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_rp) #first CNN layer
cur_rp = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_rp) #2nd CNN layer

# Max pooling layer
cur_rp = MaxPooling1D(pool_size=pool_length)(cur_rp)

# Flatten the current input for the fully-connected layers
cur_rp = Flatten()(cur_rp)

###############################################################################################

#concatenate RVS/BP/RP and then insert it to dense layer 

cur_comb = concatenate([cur_rvs, cur_bp, cur_rp])

# Fully-connected layers
cur_final = Dense(units=num_hidden[0], kernel_initializer=initializer, 
               activation=activation)(cur_comb)
cur_final = Dense(units=num_hidden[1], kernel_initializer=initializer, 
               activation=activation)(cur_final)

# Output nodes
output_final = Dense(units=num_labels, activation="linear", 
                    input_dim=num_hidden[1], name='output_y')(cur_final)


model = Model(inputs = [input_RVSspec, input_BPspec, input_RPspec], outputs=output_final)

# %% [markdown]
# **More model techniques**
# * The `Adam` optimizer is the gradient descent algorithm used for minimizing the loss function
# * `EarlyStopping` uses the cross-validation set to test the model following every iteration and stops the training if the cv loss does not decrease by `min_delta` after `patience` iterations
# * `ReduceLROnPlateau` is a form of learning rate decay where the learning rate is decreased by a factor of `factor` if the training loss does not decrease by `epsilon` after `patience` iterations unless the learning rate has reached `min_lr`

# %%
# Default loss function parameters
early_stopping_min_delta = 0.0007
early_stopping_patience = 4
reduce_lr_factor = 0.5
reuce_lr_epsilon = 0.0000009
reduce_lr_patience = 2
reduce_lr_min = 0.00008

# loss function to minimize
loss_function = 'mean_squared_error'

# compute mean absolute deviation
metrics = ['mae', 'mse']
#metrics = ['mae']

# %%
#optimizer = Adam(lr=lr, beta_1=beta_1, beta_2=beta_2, epsilon=optimizer_epsilon, decay=0.0)
optimizer = Adam(lr=0.0005 )

early_stopping = EarlyStopping(monitor='val_loss', min_delta=early_stopping_min_delta, 
                                       patience=early_stopping_patience, verbose=2, mode='min')

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, epsilon=reuce_lr_epsilon, 
                                  patience=reduce_lr_patience, min_lr=reduce_lr_min, mode='min', verbose=2)
# Out:
# /anaconda3/lib/python3.6/site-packages/keras/callbacks.py:1065: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '

# %% [markdown]
# **Compile model**

# %%
model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# rvs_input_x (InputLayer)        (None, 1134)         0
# __________________________________________________________________________________________________
# bp_input_x (InputLayer)         (None, 53)           0
# __________________________________________________________________________________________________
# rp_input_x (InputLayer)         (None, 49)           0
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (None, 1134, 1)      0           rvs_input_x[0][0]
# __________________________________________________________________________________________________
# reshape_20 (Reshape)            (None, 53, 1)        0           bp_input_x[0][0]
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 49, 1)        0           rp_input_x[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 1134, 8)      72          reshape_19[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 53, 8)        72          reshape_20[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 49, 8)        72          reshape_21[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 1134, 32)     2080        conv1d_37[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 53, 32)       2080        conv1d_39[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 49, 32)       2080        conv1d_41[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_19 (MaxPooling1D) (None, 283, 32)      0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_20 (MaxPooling1D) (None, 13, 32)       0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_21 (MaxPooling1D) (None, 12, 32)       0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# flatten_19 (Flatten)            (None, 9056)         0           max_pooling1d_19[0][0]
# __________________________________________________________________________________________________
# flatten_20 (Flatten)            (None, 416)          0           max_pooling1d_20[0][0]
# __________________________________________________________________________________________________
# flatten_21 (Flatten)            (None, 384)          0           max_pooling1d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 9856)         0           flatten_19[0][0]
#                                                                  flatten_20[0][0]
#                                                                  flatten_21[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 256)          2523392     concatenate_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 128)          32896       dense_13[0][0]
# __________________________________________________________________________________________________
# output_y (Dense)                (None, 2)            258         dense_14[0][0]
# ==================================================================================================
# Total params: 2,563,002
# Trainable params: 2,563,002
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Train model**

# %%
#history = model.fit(x_train, y_train, validation_data=(x_cv, y_cv),
          #epochs=max_epochs, verbose=1, shuffle='batch',
         #callbacks=[early_stopping, reduce_lr])
        

y_train_stack = np.column_stack((y_logteff_train, y_logg_train))
y_cv_stack = np.column_stack ((y_logteff_cv, y_logg_cv))

print('shape of the cv logteff and logg=', np.shape(y_cv_stack))
print(' shape of y teff and logg=', np.shape(y_train_stack))
#history = model.fit(x=[x_RVStrain, x_BPtrain, x_RPtrain], y=y_train_stack,
          #validation_split=0.2, epochs=max_epochs, verbose=1, shuffle='batch')
        
history = model.fit(x=[x_RVStrain, x_BPtrain, x_RPtrain], y= y_train_stack, 
                    validation_data=([x_RVScv, x_BPcv, x_RPcv], y_cv_stack),
          epochs=max_epochs, verbose=1, shuffle='batch')
# Out:
# shape of the cv logteff and logg= (81, 2)
#  shape of y teff and logg= (334, 2)
# Train on 334 samples, validate on 81 samples
# Epoch 1/300
# 334/334 [==============================] - 2s 7ms/step - loss: 6.9025 - mean_absolute_error: 2.0405 - mean_squared_error: 6.9025 - val_loss: 3.1611 - val_mean_absolute_error: 1.4858 - val_mean_squared_error: 3.1611
# Epoch 2/300
# 334/334 [==============================] - 0s 1ms/step - loss: 1.8650 - mean_absolute_error: 1.0852 - mean_squared_error: 1.8650 - val_loss: 1.0514 - val_mean_absolute_error: 0.8815 - val_mean_squared_error: 1.0514
# Epoch 3/300
# 334/334 [==============================] - 0s 1ms/step - loss: 1.1968 - mean_absolute_error: 0.8237 - mean_squared_error: 1.1968 - val_loss: 0.8949 - val_mean_absolute_error: 0.7155 - val_mean_squared_error: 0.8949
# Epoch 4/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.8809 - mean_absolute_error: 0.7461 - mean_squared_error: 0.8809 - val_loss: 0.9350 - val_mean_absolute_error: 0.8033 - val_mean_squared_error: 0.9350
# Epoch 5/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.4455 - mean_absolute_error: 0.5436 - mean_squared_error: 0.4455 - val_loss: 0.7970 - val_mean_absolute_error: 0.8012 - val_mean_squared_error: 0.7970
# Epoch 6/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.6360 - mean_absolute_error: 0.6213 - mean_squared_error: 0.6360 - val_loss: 0.5040 - val_mean_absolute_error: 0.5220 - val_mean_squared_error: 0.5040
# Epoch 7/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.6217 - mean_absolute_error: 0.6762 - mean_squared_error: 0.6217 - val_loss: 0.4046 - val_mean_absolute_error: 0.4900 - val_mean_squared_error: 0.4046
# Epoch 8/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5199 - mean_absolute_error: 0.5686 - mean_squared_error: 0.5199 - val_loss: 0.6787 - val_mean_absolute_error: 0.6559 - val_mean_squared_error: 0.6787
# Epoch 9/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.4363 - mean_absolute_error: 0.5013 - mean_squared_error: 0.4363 - val_loss: 0.7108 - val_mean_absolute_error: 0.6835 - val_mean_squared_error: 0.7108
# Epoch 10/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.4502 - mean_absolute_error: 0.5264 - mean_squared_error: 0.4502 - val_loss: 0.4570 - val_mean_absolute_error: 0.5776 - val_mean_squared_error: 0.4570
# Epoch 11/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.4405 - mean_absolute_error: 0.5289 - mean_squared_error: 0.4405 - val_loss: 0.3735 - val_mean_absolute_error: 0.4784 - val_mean_squared_error: 0.3735
# Epoch 12/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.2939 - mean_absolute_error: 0.4343 - mean_squared_error: 0.2939 - val_loss: 0.3444 - val_mean_absolute_error: 0.4627 - val_mean_squared_error: 0.3444
# Epoch 13/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.2411 - mean_absolute_error: 0.3886 - mean_squared_error: 0.2411 - val_loss: 0.2836 - val_mean_absolute_error: 0.3803 - val_mean_squared_error: 0.2836
# Epoch 14/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.2556 - mean_absolute_error: 0.4080 - mean_squared_error: 0.2556 - val_loss: 0.2955 - val_mean_absolute_error: 0.3829 - val_mean_squared_error: 0.2955
# Epoch 15/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.2204 - mean_absolute_error: 0.3802 - mean_squared_error: 0.2204 - val_loss: 0.3274 - val_mean_absolute_error: 0.4342 - val_mean_squared_error: 0.3274
# Epoch 16/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.2452 - mean_absolute_error: 0.4019 - mean_squared_error: 0.2452 - val_loss: 0.3228 - val_mean_absolute_error: 0.4252 - val_mean_squared_error: 0.3228
# Epoch 17/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.2983 - mean_absolute_error: 0.4457 - mean_squared_error: 0.2983 - val_loss: 0.2838 - val_mean_absolute_error: 0.3740 - val_mean_squared_error: 0.2838
# Epoch 18/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.2426 - mean_absolute_error: 0.4074 - mean_squared_error: 0.2426 - val_loss: 0.2076 - val_mean_absolute_error: 0.3605 - val_mean_squared_error: 0.2076
# Epoch 19/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1887 - mean_absolute_error: 0.3355 - mean_squared_error: 0.1887 - val_loss: 0.2754 - val_mean_absolute_error: 0.4616 - val_mean_squared_error: 0.2754
# Epoch 20/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.2130 - mean_absolute_error: 0.4005 - mean_squared_error: 0.2130 - val_loss: 0.4027 - val_mean_absolute_error: 0.5160 - val_mean_squared_error: 0.4027
# Epoch 21/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.2404 - mean_absolute_error: 0.4019 - mean_squared_error: 0.2404 - val_loss: 0.1310 - val_mean_absolute_error: 0.2977 - val_mean_squared_error: 0.1310
# Epoch 22/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.1685 - mean_absolute_error: 0.3278 - mean_squared_error: 0.1685 - val_loss: 0.1289 - val_mean_absolute_error: 0.3008 - val_mean_squared_error: 0.1289
# Epoch 23/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1742 - mean_absolute_error: 0.3365 - mean_squared_error: 0.1742 - val_loss: 0.0994 - val_mean_absolute_error: 0.2264 - val_mean_squared_error: 0.0994
# Epoch 24/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1361 - mean_absolute_error: 0.3023 - mean_squared_error: 0.1361 - val_loss: 0.1981 - val_mean_absolute_error: 0.3238 - val_mean_squared_error: 0.1981
# Epoch 25/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0880 - mean_absolute_error: 0.2319 - mean_squared_error: 0.0880 - val_loss: 0.0988 - val_mean_absolute_error: 0.2284 - val_mean_squared_error: 0.0988
# Epoch 26/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1118 - mean_absolute_error: 0.2541 - mean_squared_error: 0.1118 - val_loss: 0.1188 - val_mean_absolute_error: 0.2508 - val_mean_squared_error: 0.1188
# Epoch 27/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.1072 - mean_absolute_error: 0.2455 - mean_squared_error: 0.1072 - val_loss: 0.1682 - val_mean_absolute_error: 0.3476 - val_mean_squared_error: 0.1682
# Epoch 28/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1743 - mean_absolute_error: 0.3350 - mean_squared_error: 0.1743 - val_loss: 0.4171 - val_mean_absolute_error: 0.5809 - val_mean_squared_error: 0.4171
# Epoch 29/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.2213 - mean_absolute_error: 0.3658 - mean_squared_error: 0.2213 - val_loss: 0.2787 - val_mean_absolute_error: 0.3627 - val_mean_squared_error: 0.2787
# Epoch 30/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.4121 - mean_absolute_error: 0.4925 - mean_squared_error: 0.4121 - val_loss: 0.2745 - val_mean_absolute_error: 0.4080 - val_mean_squared_error: 0.2745
# Epoch 31/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5108 - mean_absolute_error: 0.5424 - mean_squared_error: 0.5108 - val_loss: 0.1551 - val_mean_absolute_error: 0.2953 - val_mean_squared_error: 0.1551
# Epoch 32/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.3812 - mean_absolute_error: 0.4394 - mean_squared_error: 0.3812 - val_loss: 0.1921 - val_mean_absolute_error: 0.3386 - val_mean_squared_error: 0.1921
# Epoch 33/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1765 - mean_absolute_error: 0.3195 - mean_squared_error: 0.1765 - val_loss: 0.2861 - val_mean_absolute_error: 0.3736 - val_mean_squared_error: 0.2861
# Epoch 34/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1497 - mean_absolute_error: 0.2671 - mean_squared_error: 0.1497 - val_loss: 0.1642 - val_mean_absolute_error: 0.3313 - val_mean_squared_error: 0.1642
# Epoch 35/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0985 - mean_absolute_error: 0.2421 - mean_squared_error: 0.0985 - val_loss: 0.1650 - val_mean_absolute_error: 0.3507 - val_mean_squared_error: 0.1650
# Epoch 36/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0767 - mean_absolute_error: 0.1987 - mean_squared_error: 0.0767 - val_loss: 0.1177 - val_mean_absolute_error: 0.2294 - val_mean_squared_error: 0.1177
# Epoch 37/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0682 - mean_absolute_error: 0.1845 - mean_squared_error: 0.0682 - val_loss: 0.0944 - val_mean_absolute_error: 0.2224 - val_mean_squared_error: 0.0944
# Epoch 38/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0721 - mean_absolute_error: 0.1950 - mean_squared_error: 0.0721 - val_loss: 0.0857 - val_mean_absolute_error: 0.1966 - val_mean_squared_error: 0.0857
# Epoch 39/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0687 - mean_absolute_error: 0.1954 - mean_squared_error: 0.0687 - val_loss: 0.1053 - val_mean_absolute_error: 0.2350 - val_mean_squared_error: 0.1053
# Epoch 40/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0883 - mean_absolute_error: 0.2355 - mean_squared_error: 0.0883 - val_loss: 0.2023 - val_mean_absolute_error: 0.3720 - val_mean_squared_error: 0.2023
# Epoch 41/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0898 - mean_absolute_error: 0.2320 - mean_squared_error: 0.0898 - val_loss: 0.2211 - val_mean_absolute_error: 0.4055 - val_mean_squared_error: 0.2211
# Epoch 42/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1097 - mean_absolute_error: 0.2664 - mean_squared_error: 0.1097 - val_loss: 0.1514 - val_mean_absolute_error: 0.3429 - val_mean_squared_error: 0.1514
# Epoch 43/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0889 - mean_absolute_error: 0.2268 - mean_squared_error: 0.0889 - val_loss: 0.2359 - val_mean_absolute_error: 0.3822 - val_mean_squared_error: 0.2359
# Epoch 44/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1131 - mean_absolute_error: 0.2680 - mean_squared_error: 0.1131 - val_loss: 0.1219 - val_mean_absolute_error: 0.2889 - val_mean_squared_error: 0.1219
# Epoch 45/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1085 - mean_absolute_error: 0.2529 - mean_squared_error: 0.1085 - val_loss: 0.1789 - val_mean_absolute_error: 0.3162 - val_mean_squared_error: 0.1789
# Epoch 46/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0864 - mean_absolute_error: 0.2198 - mean_squared_error: 0.0864 - val_loss: 0.1756 - val_mean_absolute_error: 0.3723 - val_mean_squared_error: 0.1756
# Epoch 47/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1258 - mean_absolute_error: 0.2931 - mean_squared_error: 0.1258 - val_loss: 0.1143 - val_mean_absolute_error: 0.2278 - val_mean_squared_error: 0.1143
# Epoch 48/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0838 - mean_absolute_error: 0.2036 - mean_squared_error: 0.0838 - val_loss: 0.0827 - val_mean_absolute_error: 0.1948 - val_mean_squared_error: 0.0827
# Epoch 49/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0660 - mean_absolute_error: 0.1710 - mean_squared_error: 0.0660 - val_loss: 0.0962 - val_mean_absolute_error: 0.2242 - val_mean_squared_error: 0.0962
# Epoch 50/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1181 - mean_absolute_error: 0.2638 - mean_squared_error: 0.1181 - val_loss: 0.1662 - val_mean_absolute_error: 0.2914 - val_mean_squared_error: 0.1662
# Epoch 51/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0737 - mean_absolute_error: 0.2156 - mean_squared_error: 0.0737 - val_loss: 0.0676 - val_mean_absolute_error: 0.1741 - val_mean_squared_error: 0.0676
# Epoch 52/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0557 - mean_absolute_error: 0.1887 - mean_squared_error: 0.0557 - val_loss: 0.0734 - val_mean_absolute_error: 0.1723 - val_mean_squared_error: 0.0734
# Epoch 53/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0592 - mean_absolute_error: 0.1863 - mean_squared_error: 0.0592 - val_loss: 0.0944 - val_mean_absolute_error: 0.2226 - val_mean_squared_error: 0.0944
# Epoch 54/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0566 - mean_absolute_error: 0.1838 - mean_squared_error: 0.0566 - val_loss: 0.0750 - val_mean_absolute_error: 0.2193 - val_mean_squared_error: 0.0750
# Epoch 55/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0433 - mean_absolute_error: 0.1618 - mean_squared_error: 0.0433 - val_loss: 0.0735 - val_mean_absolute_error: 0.2156 - val_mean_squared_error: 0.0735
# Epoch 56/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0367 - mean_absolute_error: 0.1373 - mean_squared_error: 0.0367 - val_loss: 0.0539 - val_mean_absolute_error: 0.1692 - val_mean_squared_error: 0.0539
# Epoch 57/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0384 - mean_absolute_error: 0.1442 - mean_squared_error: 0.0384 - val_loss: 0.0549 - val_mean_absolute_error: 0.1673 - val_mean_squared_error: 0.0549
# Epoch 58/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0509 - mean_absolute_error: 0.1830 - mean_squared_error: 0.0509 - val_loss: 0.0664 - val_mean_absolute_error: 0.1680 - val_mean_squared_error: 0.0664
# Epoch 59/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0617 - mean_absolute_error: 0.2012 - mean_squared_error: 0.0617 - val_loss: 0.0553 - val_mean_absolute_error: 0.1755 - val_mean_squared_error: 0.0553
# Epoch 60/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0549 - mean_absolute_error: 0.1859 - mean_squared_error: 0.0549 - val_loss: 0.0617 - val_mean_absolute_error: 0.1669 - val_mean_squared_error: 0.0617
# Epoch 61/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0514 - mean_absolute_error: 0.1792 - mean_squared_error: 0.0514 - val_loss: 0.0702 - val_mean_absolute_error: 0.2070 - val_mean_squared_error: 0.0702
# Epoch 62/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0542 - mean_absolute_error: 0.1773 - mean_squared_error: 0.0542 - val_loss: 0.0746 - val_mean_absolute_error: 0.2126 - val_mean_squared_error: 0.0746
# Epoch 63/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0392 - mean_absolute_error: 0.1503 - mean_squared_error: 0.0392 - val_loss: 0.0637 - val_mean_absolute_error: 0.2040 - val_mean_squared_error: 0.0637
# Epoch 64/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0406 - mean_absolute_error: 0.1392 - mean_squared_error: 0.0406 - val_loss: 0.0695 - val_mean_absolute_error: 0.1959 - val_mean_squared_error: 0.0695
# Epoch 65/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0314 - mean_absolute_error: 0.1233 - mean_squared_error: 0.0314 - val_loss: 0.0516 - val_mean_absolute_error: 0.1685 - val_mean_squared_error: 0.0516
# Epoch 66/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0320 - mean_absolute_error: 0.1221 - mean_squared_error: 0.0320 - val_loss: 0.0588 - val_mean_absolute_error: 0.1757 - val_mean_squared_error: 0.0588
# Epoch 67/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0295 - mean_absolute_error: 0.1215 - mean_squared_error: 0.0295 - val_loss: 0.0562 - val_mean_absolute_error: 0.1829 - val_mean_squared_error: 0.0562
# Epoch 68/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0312 - mean_absolute_error: 0.1290 - mean_squared_error: 0.0312 - val_loss: 0.0504 - val_mean_absolute_error: 0.1472 - val_mean_squared_error: 0.0504
# Epoch 69/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0350 - mean_absolute_error: 0.1402 - mean_squared_error: 0.0350 - val_loss: 0.0622 - val_mean_absolute_error: 0.1659 - val_mean_squared_error: 0.0622
# Epoch 70/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0361 - mean_absolute_error: 0.1451 - mean_squared_error: 0.0361 - val_loss: 0.0576 - val_mean_absolute_error: 0.1698 - val_mean_squared_error: 0.0576
# Epoch 71/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0383 - mean_absolute_error: 0.1512 - mean_squared_error: 0.0383 - val_loss: 0.0457 - val_mean_absolute_error: 0.1464 - val_mean_squared_error: 0.0457
# Epoch 72/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0379 - mean_absolute_error: 0.1558 - mean_squared_error: 0.0379 - val_loss: 0.0616 - val_mean_absolute_error: 0.1695 - val_mean_squared_error: 0.0616
# Epoch 73/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0428 - mean_absolute_error: 0.1663 - mean_squared_error: 0.0428 - val_loss: 0.0617 - val_mean_absolute_error: 0.2023 - val_mean_squared_error: 0.0617
# Epoch 74/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0352 - mean_absolute_error: 0.1416 - mean_squared_error: 0.0352 - val_loss: 0.0703 - val_mean_absolute_error: 0.2131 - val_mean_squared_error: 0.0703
# Epoch 75/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0303 - mean_absolute_error: 0.1276 - mean_squared_error: 0.0303 - val_loss: 0.0571 - val_mean_absolute_error: 0.1681 - val_mean_squared_error: 0.0571
# Epoch 76/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0270 - mean_absolute_error: 0.1159 - mean_squared_error: 0.0270 - val_loss: 0.0516 - val_mean_absolute_error: 0.1500 - val_mean_squared_error: 0.0516
# Epoch 77/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0315 - mean_absolute_error: 0.1280 - mean_squared_error: 0.0315 - val_loss: 0.0440 - val_mean_absolute_error: 0.1464 - val_mean_squared_error: 0.0440
# Epoch 78/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0309 - mean_absolute_error: 0.1282 - mean_squared_error: 0.0309 - val_loss: 0.0725 - val_mean_absolute_error: 0.1743 - val_mean_squared_error: 0.0725
# Epoch 79/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0318 - mean_absolute_error: 0.1219 - mean_squared_error: 0.0318 - val_loss: 0.0502 - val_mean_absolute_error: 0.1746 - val_mean_squared_error: 0.0502
# Epoch 80/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0328 - mean_absolute_error: 0.1414 - mean_squared_error: 0.0328 - val_loss: 0.0671 - val_mean_absolute_error: 0.1685 - val_mean_squared_error: 0.0671
# Epoch 81/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0338 - mean_absolute_error: 0.1311 - mean_squared_error: 0.0338 - val_loss: 0.0555 - val_mean_absolute_error: 0.1505 - val_mean_squared_error: 0.0555
# Epoch 82/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0293 - mean_absolute_error: 0.1277 - mean_squared_error: 0.0293 - val_loss: 0.0465 - val_mean_absolute_error: 0.1468 - val_mean_squared_error: 0.0465
# Epoch 83/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0299 - mean_absolute_error: 0.1262 - mean_squared_error: 0.0299 - val_loss: 0.0450 - val_mean_absolute_error: 0.1398 - val_mean_squared_error: 0.0450
# Epoch 84/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0352 - mean_absolute_error: 0.1404 - mean_squared_error: 0.0352 - val_loss: 0.0433 - val_mean_absolute_error: 0.1385 - val_mean_squared_error: 0.0433
# Epoch 85/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0325 - mean_absolute_error: 0.1218 - mean_squared_error: 0.0325 - val_loss: 0.0420 - val_mean_absolute_error: 0.1421 - val_mean_squared_error: 0.0420
# Epoch 86/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0274 - mean_absolute_error: 0.1272 - mean_squared_error: 0.0274 - val_loss: 0.0394 - val_mean_absolute_error: 0.1390 - val_mean_squared_error: 0.0394
# Epoch 87/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0288 - mean_absolute_error: 0.1298 - mean_squared_error: 0.0288 - val_loss: 0.0414 - val_mean_absolute_error: 0.1399 - val_mean_squared_error: 0.0414
# Epoch 88/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0286 - mean_absolute_error: 0.1307 - mean_squared_error: 0.0286 - val_loss: 0.0411 - val_mean_absolute_error: 0.1355 - val_mean_squared_error: 0.0411
# Epoch 89/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0281 - mean_absolute_error: 0.1290 - mean_squared_error: 0.0281 - val_loss: 0.0409 - val_mean_absolute_error: 0.1410 - val_mean_squared_error: 0.0409
# Epoch 90/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0304 - mean_absolute_error: 0.1381 - mean_squared_error: 0.0304 - val_loss: 0.0479 - val_mean_absolute_error: 0.1657 - val_mean_squared_error: 0.0479
# Epoch 91/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0338 - mean_absolute_error: 0.1514 - mean_squared_error: 0.0338 - val_loss: 0.0445 - val_mean_absolute_error: 0.1422 - val_mean_squared_error: 0.0445
# Epoch 92/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0494 - mean_absolute_error: 0.1727 - mean_squared_error: 0.0494 - val_loss: 0.0594 - val_mean_absolute_error: 0.1880 - val_mean_squared_error: 0.0594
# Epoch 93/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0637 - mean_absolute_error: 0.1969 - mean_squared_error: 0.0637 - val_loss: 0.0467 - val_mean_absolute_error: 0.1578 - val_mean_squared_error: 0.0467
# Epoch 94/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0456 - mean_absolute_error: 0.1707 - mean_squared_error: 0.0456 - val_loss: 0.0418 - val_mean_absolute_error: 0.1444 - val_mean_squared_error: 0.0418
# Epoch 95/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0446 - mean_absolute_error: 0.1715 - mean_squared_error: 0.0446 - val_loss: 0.0425 - val_mean_absolute_error: 0.1449 - val_mean_squared_error: 0.0425
# Epoch 96/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0573 - mean_absolute_error: 0.1892 - mean_squared_error: 0.0573 - val_loss: 0.1148 - val_mean_absolute_error: 0.2275 - val_mean_squared_error: 0.1148
# Epoch 97/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0611 - mean_absolute_error: 0.2068 - mean_squared_error: 0.0611 - val_loss: 0.0480 - val_mean_absolute_error: 0.1531 - val_mean_squared_error: 0.0480
# Epoch 98/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0661 - mean_absolute_error: 0.1995 - mean_squared_error: 0.0661 - val_loss: 0.0528 - val_mean_absolute_error: 0.1702 - val_mean_squared_error: 0.0528
# Epoch 99/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0756 - mean_absolute_error: 0.1950 - mean_squared_error: 0.0756 - val_loss: 0.0573 - val_mean_absolute_error: 0.1871 - val_mean_squared_error: 0.0573
# Epoch 100/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0663 - mean_absolute_error: 0.1853 - mean_squared_error: 0.0663 - val_loss: 0.0747 - val_mean_absolute_error: 0.2018 - val_mean_squared_error: 0.0747
# Epoch 101/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0867 - mean_absolute_error: 0.2301 - mean_squared_error: 0.0867 - val_loss: 0.1550 - val_mean_absolute_error: 0.2581 - val_mean_squared_error: 0.1550
# Epoch 102/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0586 - mean_absolute_error: 0.1882 - mean_squared_error: 0.0586 - val_loss: 0.0946 - val_mean_absolute_error: 0.1914 - val_mean_squared_error: 0.0946
# Epoch 103/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0609 - mean_absolute_error: 0.1823 - mean_squared_error: 0.0609 - val_loss: 0.0898 - val_mean_absolute_error: 0.2208 - val_mean_squared_error: 0.0898
# Epoch 104/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0772 - mean_absolute_error: 0.2057 - mean_squared_error: 0.0772 - val_loss: 0.0685 - val_mean_absolute_error: 0.1842 - val_mean_squared_error: 0.0685
# Epoch 105/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0386 - mean_absolute_error: 0.1466 - mean_squared_error: 0.0386 - val_loss: 0.0542 - val_mean_absolute_error: 0.1777 - val_mean_squared_error: 0.0542
# Epoch 106/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0316 - mean_absolute_error: 0.1213 - mean_squared_error: 0.0316 - val_loss: 0.0416 - val_mean_absolute_error: 0.1369 - val_mean_squared_error: 0.0416
# Epoch 107/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0238 - mean_absolute_error: 0.1089 - mean_squared_error: 0.0238 - val_loss: 0.0394 - val_mean_absolute_error: 0.1383 - val_mean_squared_error: 0.0394
# Epoch 108/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0214 - mean_absolute_error: 0.1041 - mean_squared_error: 0.0214 - val_loss: 0.0371 - val_mean_absolute_error: 0.1444 - val_mean_squared_error: 0.0371
# Epoch 109/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0242 - mean_absolute_error: 0.1071 - mean_squared_error: 0.0242 - val_loss: 0.0526 - val_mean_absolute_error: 0.1593 - val_mean_squared_error: 0.0526
# Epoch 110/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0220 - mean_absolute_error: 0.1026 - mean_squared_error: 0.0220 - val_loss: 0.0394 - val_mean_absolute_error: 0.1276 - val_mean_squared_error: 0.0394
# Epoch 111/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0227 - mean_absolute_error: 0.1107 - mean_squared_error: 0.0227 - val_loss: 0.0379 - val_mean_absolute_error: 0.1352 - val_mean_squared_error: 0.0379
# Epoch 112/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0239 - mean_absolute_error: 0.1176 - mean_squared_error: 0.0239 - val_loss: 0.0326 - val_mean_absolute_error: 0.1244 - val_mean_squared_error: 0.0326
# Epoch 113/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0229 - mean_absolute_error: 0.1167 - mean_squared_error: 0.0229 - val_loss: 0.0356 - val_mean_absolute_error: 0.1262 - val_mean_squared_error: 0.0356
# Epoch 114/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0224 - mean_absolute_error: 0.1161 - mean_squared_error: 0.0224 - val_loss: 0.1031 - val_mean_absolute_error: 0.2684 - val_mean_squared_error: 0.1031
# Epoch 115/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0482 - mean_absolute_error: 0.1709 - mean_squared_error: 0.0482 - val_loss: 0.0486 - val_mean_absolute_error: 0.1819 - val_mean_squared_error: 0.0486
# Epoch 116/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0440 - mean_absolute_error: 0.1672 - mean_squared_error: 0.0440 - val_loss: 0.1265 - val_mean_absolute_error: 0.3014 - val_mean_squared_error: 0.1265
# Epoch 117/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0382 - mean_absolute_error: 0.1554 - mean_squared_error: 0.0382 - val_loss: 0.0602 - val_mean_absolute_error: 0.2124 - val_mean_squared_error: 0.0602
# Epoch 118/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0319 - mean_absolute_error: 0.1437 - mean_squared_error: 0.0319 - val_loss: 0.0502 - val_mean_absolute_error: 0.1647 - val_mean_squared_error: 0.0502
# Epoch 119/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0270 - mean_absolute_error: 0.1300 - mean_squared_error: 0.0270 - val_loss: 0.0359 - val_mean_absolute_error: 0.1487 - val_mean_squared_error: 0.0359
# Epoch 120/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0256 - mean_absolute_error: 0.1264 - mean_squared_error: 0.0256 - val_loss: 0.0403 - val_mean_absolute_error: 0.1569 - val_mean_squared_error: 0.0403
# Epoch 121/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0304 - mean_absolute_error: 0.1298 - mean_squared_error: 0.0304 - val_loss: 0.0740 - val_mean_absolute_error: 0.1946 - val_mean_squared_error: 0.0740
# Epoch 122/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0241 - mean_absolute_error: 0.1108 - mean_squared_error: 0.0241 - val_loss: 0.0447 - val_mean_absolute_error: 0.1621 - val_mean_squared_error: 0.0447
# Epoch 123/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0503 - mean_absolute_error: 0.1594 - mean_squared_error: 0.0503 - val_loss: 0.1279 - val_mean_absolute_error: 0.2662 - val_mean_squared_error: 0.1279
# Epoch 124/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0451 - mean_absolute_error: 0.1520 - mean_squared_error: 0.0451 - val_loss: 0.0574 - val_mean_absolute_error: 0.1968 - val_mean_squared_error: 0.0574
# Epoch 125/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0282 - mean_absolute_error: 0.1227 - mean_squared_error: 0.0282 - val_loss: 0.0721 - val_mean_absolute_error: 0.2030 - val_mean_squared_error: 0.0721
# Epoch 126/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0282 - mean_absolute_error: 0.1159 - mean_squared_error: 0.0282 - val_loss: 0.0557 - val_mean_absolute_error: 0.1738 - val_mean_squared_error: 0.0557
# Epoch 127/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0256 - mean_absolute_error: 0.1101 - mean_squared_error: 0.0256 - val_loss: 0.0340 - val_mean_absolute_error: 0.1430 - val_mean_squared_error: 0.0340
# Epoch 128/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0290 - mean_absolute_error: 0.1197 - mean_squared_error: 0.0290 - val_loss: 0.0349 - val_mean_absolute_error: 0.1392 - val_mean_squared_error: 0.0349
# Epoch 129/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0295 - mean_absolute_error: 0.1162 - mean_squared_error: 0.0295 - val_loss: 0.0450 - val_mean_absolute_error: 0.1348 - val_mean_squared_error: 0.0450
# Epoch 130/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0248 - mean_absolute_error: 0.1138 - mean_squared_error: 0.0248 - val_loss: 0.0487 - val_mean_absolute_error: 0.1718 - val_mean_squared_error: 0.0487
# Epoch 131/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0289 - mean_absolute_error: 0.1218 - mean_squared_error: 0.0289 - val_loss: 0.0403 - val_mean_absolute_error: 0.1376 - val_mean_squared_error: 0.0403
# Epoch 132/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0148 - mean_absolute_error: 0.0881 - mean_squared_error: 0.0148 - val_loss: 0.0313 - val_mean_absolute_error: 0.1355 - val_mean_squared_error: 0.0313
# Epoch 133/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0160 - mean_absolute_error: 0.0939 - mean_squared_error: 0.0160 - val_loss: 0.0343 - val_mean_absolute_error: 0.1319 - val_mean_squared_error: 0.0343
# Epoch 134/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0194 - mean_absolute_error: 0.1069 - mean_squared_error: 0.0194 - val_loss: 0.0408 - val_mean_absolute_error: 0.1591 - val_mean_squared_error: 0.0408
# Epoch 135/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0282 - mean_absolute_error: 0.1204 - mean_squared_error: 0.0282 - val_loss: 0.0533 - val_mean_absolute_error: 0.1895 - val_mean_squared_error: 0.0533
# Epoch 136/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0304 - mean_absolute_error: 0.1286 - mean_squared_error: 0.0304 - val_loss: 0.1092 - val_mean_absolute_error: 0.2652 - val_mean_squared_error: 0.1092
# Epoch 137/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0424 - mean_absolute_error: 0.1501 - mean_squared_error: 0.0424 - val_loss: 0.0806 - val_mean_absolute_error: 0.2318 - val_mean_squared_error: 0.0806
# Epoch 138/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0600 - mean_absolute_error: 0.1732 - mean_squared_error: 0.0600 - val_loss: 0.0751 - val_mean_absolute_error: 0.1869 - val_mean_squared_error: 0.0751
# Epoch 139/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0566 - mean_absolute_error: 0.1640 - mean_squared_error: 0.0566 - val_loss: 0.0562 - val_mean_absolute_error: 0.1689 - val_mean_squared_error: 0.0562
# Epoch 140/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0264 - mean_absolute_error: 0.1220 - mean_squared_error: 0.0264 - val_loss: 0.0347 - val_mean_absolute_error: 0.1445 - val_mean_squared_error: 0.0347
# Epoch 141/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0212 - mean_absolute_error: 0.1052 - mean_squared_error: 0.0212 - val_loss: 0.0406 - val_mean_absolute_error: 0.1489 - val_mean_squared_error: 0.0406
# Epoch 142/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0205 - mean_absolute_error: 0.1118 - mean_squared_error: 0.0205 - val_loss: 0.0288 - val_mean_absolute_error: 0.1239 - val_mean_squared_error: 0.0288
# Epoch 143/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0168 - mean_absolute_error: 0.0973 - mean_squared_error: 0.0168 - val_loss: 0.0354 - val_mean_absolute_error: 0.1468 - val_mean_squared_error: 0.0354
# Epoch 144/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0215 - mean_absolute_error: 0.1107 - mean_squared_error: 0.0215 - val_loss: 0.0581 - val_mean_absolute_error: 0.1911 - val_mean_squared_error: 0.0581
# Epoch 145/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0174 - mean_absolute_error: 0.1014 - mean_squared_error: 0.0174 - val_loss: 0.0411 - val_mean_absolute_error: 0.1732 - val_mean_squared_error: 0.0411
# Epoch 146/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0182 - mean_absolute_error: 0.1070 - mean_squared_error: 0.0182 - val_loss: 0.0333 - val_mean_absolute_error: 0.1497 - val_mean_squared_error: 0.0333
# Epoch 147/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0177 - mean_absolute_error: 0.0974 - mean_squared_error: 0.0177 - val_loss: 0.0379 - val_mean_absolute_error: 0.1374 - val_mean_squared_error: 0.0379
# Epoch 148/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0161 - mean_absolute_error: 0.0918 - mean_squared_error: 0.0161 - val_loss: 0.0275 - val_mean_absolute_error: 0.1200 - val_mean_squared_error: 0.0275
# Epoch 149/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0192 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0192 - val_loss: 0.0344 - val_mean_absolute_error: 0.1197 - val_mean_squared_error: 0.0344
# Epoch 150/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0425 - mean_absolute_error: 0.1411 - mean_squared_error: 0.0425 - val_loss: 0.0401 - val_mean_absolute_error: 0.1395 - val_mean_squared_error: 0.0401
# Epoch 151/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1440 - mean_absolute_error: 0.2650 - mean_squared_error: 0.1440 - val_loss: 0.0836 - val_mean_absolute_error: 0.1985 - val_mean_squared_error: 0.0836
# Epoch 152/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1248 - mean_absolute_error: 0.2336 - mean_squared_error: 0.1248 - val_loss: 0.3382 - val_mean_absolute_error: 0.3888 - val_mean_squared_error: 0.3382
# Epoch 153/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1749 - mean_absolute_error: 0.2843 - mean_squared_error: 0.1749 - val_loss: 0.1703 - val_mean_absolute_error: 0.2888 - val_mean_squared_error: 0.1703
# Epoch 154/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0745 - mean_absolute_error: 0.1929 - mean_squared_error: 0.0745 - val_loss: 0.0717 - val_mean_absolute_error: 0.2036 - val_mean_squared_error: 0.0717
# Epoch 155/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0339 - mean_absolute_error: 0.1251 - mean_squared_error: 0.0339 - val_loss: 0.0468 - val_mean_absolute_error: 0.1731 - val_mean_squared_error: 0.0468
# Epoch 156/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0280 - mean_absolute_error: 0.1267 - mean_squared_error: 0.0280 - val_loss: 0.0572 - val_mean_absolute_error: 0.2015 - val_mean_squared_error: 0.0572
# Epoch 157/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0231 - mean_absolute_error: 0.1141 - mean_squared_error: 0.0231 - val_loss: 0.0360 - val_mean_absolute_error: 0.1543 - val_mean_squared_error: 0.0360
# Epoch 158/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0171 - mean_absolute_error: 0.0977 - mean_squared_error: 0.0171 - val_loss: 0.0410 - val_mean_absolute_error: 0.1723 - val_mean_squared_error: 0.0410
# Epoch 159/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0187 - mean_absolute_error: 0.1003 - mean_squared_error: 0.0187 - val_loss: 0.0413 - val_mean_absolute_error: 0.1670 - val_mean_squared_error: 0.0413
# Epoch 160/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0178 - mean_absolute_error: 0.1006 - mean_squared_error: 0.0178 - val_loss: 0.0384 - val_mean_absolute_error: 0.1317 - val_mean_squared_error: 0.0384
# Epoch 161/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0148 - mean_absolute_error: 0.0864 - mean_squared_error: 0.0148 - val_loss: 0.0293 - val_mean_absolute_error: 0.1226 - val_mean_squared_error: 0.0293
# Epoch 162/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0184 - mean_absolute_error: 0.1023 - mean_squared_error: 0.0184 - val_loss: 0.0375 - val_mean_absolute_error: 0.1350 - val_mean_squared_error: 0.0375
# Epoch 163/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0141 - mean_absolute_error: 0.0842 - mean_squared_error: 0.0141 - val_loss: 0.0319 - val_mean_absolute_error: 0.1268 - val_mean_squared_error: 0.0319
# Epoch 164/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0137 - mean_absolute_error: 0.0823 - mean_squared_error: 0.0137 - val_loss: 0.0324 - val_mean_absolute_error: 0.1395 - val_mean_squared_error: 0.0324
# Epoch 165/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0158 - mean_absolute_error: 0.0865 - mean_squared_error: 0.0158 - val_loss: 0.0309 - val_mean_absolute_error: 0.1334 - val_mean_squared_error: 0.0309
# Epoch 166/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0171 - mean_absolute_error: 0.0919 - mean_squared_error: 0.0171 - val_loss: 0.0322 - val_mean_absolute_error: 0.1226 - val_mean_squared_error: 0.0322
# Epoch 167/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0124 - mean_absolute_error: 0.0820 - mean_squared_error: 0.0124 - val_loss: 0.0300 - val_mean_absolute_error: 0.1208 - val_mean_squared_error: 0.0300
# Epoch 168/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0137 - mean_absolute_error: 0.0911 - mean_squared_error: 0.0137 - val_loss: 0.0293 - val_mean_absolute_error: 0.1273 - val_mean_squared_error: 0.0293
# Epoch 169/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0131 - mean_absolute_error: 0.0865 - mean_squared_error: 0.0131 - val_loss: 0.0401 - val_mean_absolute_error: 0.1589 - val_mean_squared_error: 0.0401
# Epoch 170/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0156 - mean_absolute_error: 0.0908 - mean_squared_error: 0.0156 - val_loss: 0.0342 - val_mean_absolute_error: 0.1522 - val_mean_squared_error: 0.0342
# Epoch 171/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0192 - mean_absolute_error: 0.1006 - mean_squared_error: 0.0192 - val_loss: 0.0358 - val_mean_absolute_error: 0.1277 - val_mean_squared_error: 0.0358
# Epoch 172/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0185 - mean_absolute_error: 0.0969 - mean_squared_error: 0.0185 - val_loss: 0.0295 - val_mean_absolute_error: 0.1282 - val_mean_squared_error: 0.0295
# Epoch 173/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0207 - mean_absolute_error: 0.1040 - mean_squared_error: 0.0207 - val_loss: 0.0429 - val_mean_absolute_error: 0.1705 - val_mean_squared_error: 0.0429
# Epoch 174/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0191 - mean_absolute_error: 0.1007 - mean_squared_error: 0.0191 - val_loss: 0.0420 - val_mean_absolute_error: 0.1440 - val_mean_squared_error: 0.0420
# Epoch 175/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0272 - mean_absolute_error: 0.1061 - mean_squared_error: 0.0272 - val_loss: 0.0797 - val_mean_absolute_error: 0.2070 - val_mean_squared_error: 0.0797
# Epoch 176/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0344 - mean_absolute_error: 0.1271 - mean_squared_error: 0.0344 - val_loss: 0.0414 - val_mean_absolute_error: 0.1449 - val_mean_squared_error: 0.0414
# Epoch 177/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0306 - mean_absolute_error: 0.1217 - mean_squared_error: 0.0306 - val_loss: 0.0362 - val_mean_absolute_error: 0.1320 - val_mean_squared_error: 0.0362
# Epoch 178/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0183 - mean_absolute_error: 0.0997 - mean_squared_error: 0.0183 - val_loss: 0.0287 - val_mean_absolute_error: 0.1194 - val_mean_squared_error: 0.0287
# Epoch 179/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0191 - mean_absolute_error: 0.1032 - mean_squared_error: 0.0191 - val_loss: 0.0349 - val_mean_absolute_error: 0.1453 - val_mean_squared_error: 0.0349
# Epoch 180/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0365 - mean_absolute_error: 0.1364 - mean_squared_error: 0.0365 - val_loss: 0.0382 - val_mean_absolute_error: 0.1521 - val_mean_squared_error: 0.0382
# Epoch 181/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0173 - mean_absolute_error: 0.0969 - mean_squared_error: 0.0173 - val_loss: 0.0500 - val_mean_absolute_error: 0.1840 - val_mean_squared_error: 0.0500
# Epoch 182/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0195 - mean_absolute_error: 0.0994 - mean_squared_error: 0.0195 - val_loss: 0.0351 - val_mean_absolute_error: 0.1343 - val_mean_squared_error: 0.0351
# Epoch 183/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0163 - mean_absolute_error: 0.0907 - mean_squared_error: 0.0163 - val_loss: 0.0290 - val_mean_absolute_error: 0.1317 - val_mean_squared_error: 0.0290
# Epoch 184/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0159 - mean_absolute_error: 0.0920 - mean_squared_error: 0.0159 - val_loss: 0.0330 - val_mean_absolute_error: 0.1243 - val_mean_squared_error: 0.0330
# Epoch 185/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0121 - mean_absolute_error: 0.0762 - mean_squared_error: 0.0121 - val_loss: 0.0310 - val_mean_absolute_error: 0.1359 - val_mean_squared_error: 0.0310
# Epoch 186/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0164 - mean_absolute_error: 0.0928 - mean_squared_error: 0.0164 - val_loss: 0.0343 - val_mean_absolute_error: 0.1479 - val_mean_squared_error: 0.0343
# Epoch 187/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0147 - mean_absolute_error: 0.0864 - mean_squared_error: 0.0147 - val_loss: 0.0345 - val_mean_absolute_error: 0.1539 - val_mean_squared_error: 0.0345
# Epoch 188/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0122 - mean_absolute_error: 0.0798 - mean_squared_error: 0.0122 - val_loss: 0.0274 - val_mean_absolute_error: 0.1223 - val_mean_squared_error: 0.0274
# Epoch 189/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0119 - mean_absolute_error: 0.0786 - mean_squared_error: 0.0119 - val_loss: 0.0244 - val_mean_absolute_error: 0.1059 - val_mean_squared_error: 0.0244
# Epoch 190/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0175 - mean_absolute_error: 0.0912 - mean_squared_error: 0.0175 - val_loss: 0.0370 - val_mean_absolute_error: 0.1397 - val_mean_squared_error: 0.0370
# Epoch 191/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0220 - mean_absolute_error: 0.1055 - mean_squared_error: 0.0220 - val_loss: 0.0391 - val_mean_absolute_error: 0.1568 - val_mean_squared_error: 0.0391
# Epoch 192/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0212 - mean_absolute_error: 0.1049 - mean_squared_error: 0.0212 - val_loss: 0.0311 - val_mean_absolute_error: 0.1353 - val_mean_squared_error: 0.0311
# Epoch 193/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0148 - mean_absolute_error: 0.0837 - mean_squared_error: 0.0148 - val_loss: 0.0248 - val_mean_absolute_error: 0.1095 - val_mean_squared_error: 0.0248
# Epoch 194/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0146 - mean_absolute_error: 0.0848 - mean_squared_error: 0.0146 - val_loss: 0.0257 - val_mean_absolute_error: 0.1278 - val_mean_squared_error: 0.0257
# Epoch 195/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0107 - mean_absolute_error: 0.0755 - mean_squared_error: 0.0107 - val_loss: 0.0285 - val_mean_absolute_error: 0.1327 - val_mean_squared_error: 0.0285
# Epoch 196/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0114 - mean_absolute_error: 0.0742 - mean_squared_error: 0.0114 - val_loss: 0.0342 - val_mean_absolute_error: 0.1432 - val_mean_squared_error: 0.0342
# Epoch 197/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0112 - mean_absolute_error: 0.0770 - mean_squared_error: 0.0112 - val_loss: 0.0221 - val_mean_absolute_error: 0.1059 - val_mean_squared_error: 0.0221
# Epoch 198/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0177 - mean_absolute_error: 0.0964 - mean_squared_error: 0.0177 - val_loss: 0.0263 - val_mean_absolute_error: 0.1120 - val_mean_squared_error: 0.0263
# Epoch 199/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0117 - mean_absolute_error: 0.0812 - mean_squared_error: 0.0117 - val_loss: 0.0277 - val_mean_absolute_error: 0.1252 - val_mean_squared_error: 0.0277
# Epoch 200/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0109 - mean_absolute_error: 0.0797 - mean_squared_error: 0.0109 - val_loss: 0.0280 - val_mean_absolute_error: 0.1335 - val_mean_squared_error: 0.0280
# Epoch 201/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0185 - mean_absolute_error: 0.1048 - mean_squared_error: 0.0185 - val_loss: 0.0243 - val_mean_absolute_error: 0.1160 - val_mean_squared_error: 0.0243
# Epoch 202/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0096 - mean_absolute_error: 0.0746 - mean_squared_error: 0.0096 - val_loss: 0.0234 - val_mean_absolute_error: 0.1057 - val_mean_squared_error: 0.0234
# Epoch 203/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0109 - mean_absolute_error: 0.0757 - mean_squared_error: 0.0109 - val_loss: 0.0228 - val_mean_absolute_error: 0.1027 - val_mean_squared_error: 0.0228
# Epoch 204/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0115 - mean_absolute_error: 0.0772 - mean_squared_error: 0.0115 - val_loss: 0.0209 - val_mean_absolute_error: 0.1032 - val_mean_squared_error: 0.0209
# Epoch 205/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0096 - mean_absolute_error: 0.0760 - mean_squared_error: 0.0096 - val_loss: 0.0214 - val_mean_absolute_error: 0.1007 - val_mean_squared_error: 0.0214
# Epoch 206/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0090 - mean_absolute_error: 0.0749 - mean_squared_error: 0.0090 - val_loss: 0.0227 - val_mean_absolute_error: 0.1081 - val_mean_squared_error: 0.0227
# Epoch 207/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0087 - mean_absolute_error: 0.0736 - mean_squared_error: 0.0087 - val_loss: 0.0209 - val_mean_absolute_error: 0.1055 - val_mean_squared_error: 0.0209
# Epoch 208/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0101 - mean_absolute_error: 0.0764 - mean_squared_error: 0.0101 - val_loss: 0.0274 - val_mean_absolute_error: 0.1313 - val_mean_squared_error: 0.0274
# Epoch 209/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0073 - mean_absolute_error: 0.0607 - mean_squared_error: 0.0073 - val_loss: 0.0291 - val_mean_absolute_error: 0.1313 - val_mean_squared_error: 0.0291
# Epoch 210/300
# ...
# Epoch 232/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0123 - mean_absolute_error: 0.0811 - mean_squared_error: 0.0123 - val_loss: 0.0365 - val_mean_absolute_error: 0.1300 - val_mean_squared_error: 0.0365
# Epoch 233/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0113 - mean_absolute_error: 0.0788 - mean_squared_error: 0.0113 - val_loss: 0.0245 - val_mean_absolute_error: 0.1082 - val_mean_squared_error: 0.0245
# Epoch 234/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0093 - mean_absolute_error: 0.0748 - mean_squared_error: 0.0093 - val_loss: 0.0253 - val_mean_absolute_error: 0.1264 - val_mean_squared_error: 0.0253
# Epoch 235/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0085 - mean_absolute_error: 0.0705 - mean_squared_error: 0.0085 - val_loss: 0.0216 - val_mean_absolute_error: 0.1031 - val_mean_squared_error: 0.0216
# Epoch 236/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0063 - mean_absolute_error: 0.0621 - mean_squared_error: 0.0063 - val_loss: 0.0214 - val_mean_absolute_error: 0.1128 - val_mean_squared_error: 0.0214
# Epoch 237/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0064 - mean_absolute_error: 0.0606 - mean_squared_error: 0.0064 - val_loss: 0.0203 - val_mean_absolute_error: 0.1111 - val_mean_squared_error: 0.0203
# Epoch 238/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0090 - mean_absolute_error: 0.0712 - mean_squared_error: 0.0090 - val_loss: 0.0354 - val_mean_absolute_error: 0.1412 - val_mean_squared_error: 0.0354
# Epoch 239/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0227 - mean_absolute_error: 0.1129 - mean_squared_error: 0.0227 - val_loss: 0.0574 - val_mean_absolute_error: 0.1945 - val_mean_squared_error: 0.0574
# Epoch 240/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0404 - mean_absolute_error: 0.1413 - mean_squared_error: 0.0404 - val_loss: 0.0873 - val_mean_absolute_error: 0.2321 - val_mean_squared_error: 0.0873
# Epoch 241/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0941 - mean_absolute_error: 0.2164 - mean_squared_error: 0.0941 - val_loss: 0.4133 - val_mean_absolute_error: 0.4420 - val_mean_squared_error: 0.4133
# Epoch 242/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.1278 - mean_absolute_error: 0.2733 - mean_squared_error: 0.1278 - val_loss: 0.0847 - val_mean_absolute_error: 0.2238 - val_mean_squared_error: 0.0847
# Epoch 243/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0330 - mean_absolute_error: 0.1341 - mean_squared_error: 0.0330 - val_loss: 0.0783 - val_mean_absolute_error: 0.2225 - val_mean_squared_error: 0.0783
# Epoch 244/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0655 - mean_absolute_error: 0.1909 - mean_squared_error: 0.0655 - val_loss: 0.0540 - val_mean_absolute_error: 0.1700 - val_mean_squared_error: 0.0540
# Epoch 245/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0247 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0247 - val_loss: 0.0490 - val_mean_absolute_error: 0.1484 - val_mean_squared_error: 0.0490
# Epoch 246/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0152 - mean_absolute_error: 0.0954 - mean_squared_error: 0.0152 - val_loss: 0.0278 - val_mean_absolute_error: 0.1192 - val_mean_squared_error: 0.0278
# Epoch 247/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0120 - mean_absolute_error: 0.0855 - mean_squared_error: 0.0120 - val_loss: 0.0225 - val_mean_absolute_error: 0.1032 - val_mean_squared_error: 0.0225
# Epoch 248/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0131 - mean_absolute_error: 0.0925 - mean_squared_error: 0.0131 - val_loss: 0.0237 - val_mean_absolute_error: 0.1105 - val_mean_squared_error: 0.0237
# Epoch 249/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0118 - mean_absolute_error: 0.0858 - mean_squared_error: 0.0118 - val_loss: 0.0272 - val_mean_absolute_error: 0.1308 - val_mean_squared_error: 0.0272
# Epoch 250/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0660 - mean_squared_error: 0.0078 - val_loss: 0.0235 - val_mean_absolute_error: 0.1151 - val_mean_squared_error: 0.0235
# Epoch 251/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0100 - mean_absolute_error: 0.0756 - mean_squared_error: 0.0100 - val_loss: 0.0266 - val_mean_absolute_error: 0.1342 - val_mean_squared_error: 0.0266
# Epoch 252/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0097 - mean_absolute_error: 0.0766 - mean_squared_error: 0.0097 - val_loss: 0.0341 - val_mean_absolute_error: 0.1471 - val_mean_squared_error: 0.0341
# Epoch 253/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0130 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0130 - val_loss: 0.0278 - val_mean_absolute_error: 0.1304 - val_mean_squared_error: 0.0278
# Epoch 254/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0090 - mean_absolute_error: 0.0734 - mean_squared_error: 0.0090 - val_loss: 0.0209 - val_mean_absolute_error: 0.1020 - val_mean_squared_error: 0.0209
# Epoch 255/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0698 - mean_squared_error: 0.0080 - val_loss: 0.0209 - val_mean_absolute_error: 0.1037 - val_mean_squared_error: 0.0209
# Epoch 256/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0068 - mean_absolute_error: 0.0639 - mean_squared_error: 0.0068 - val_loss: 0.0217 - val_mean_absolute_error: 0.1132 - val_mean_squared_error: 0.0217
# Epoch 257/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0561 - mean_squared_error: 0.0062 - val_loss: 0.0222 - val_mean_absolute_error: 0.1130 - val_mean_squared_error: 0.0222
# Epoch 258/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0593 - mean_squared_error: 0.0061 - val_loss: 0.0195 - val_mean_absolute_error: 0.1011 - val_mean_squared_error: 0.0195
# Epoch 259/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0057 - mean_absolute_error: 0.0552 - mean_squared_error: 0.0057 - val_loss: 0.0221 - val_mean_absolute_error: 0.1097 - val_mean_squared_error: 0.0221
# Epoch 260/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0056 - mean_absolute_error: 0.0537 - mean_squared_error: 0.0056 - val_loss: 0.0244 - val_mean_absolute_error: 0.1223 - val_mean_squared_error: 0.0244
# Epoch 261/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0056 - mean_absolute_error: 0.0543 - mean_squared_error: 0.0056 - val_loss: 0.0226 - val_mean_absolute_error: 0.1113 - val_mean_squared_error: 0.0226
# Epoch 262/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0068 - mean_absolute_error: 0.0588 - mean_squared_error: 0.0068 - val_loss: 0.0263 - val_mean_absolute_error: 0.1215 - val_mean_squared_error: 0.0263
# Epoch 263/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0065 - mean_absolute_error: 0.0586 - mean_squared_error: 0.0065 - val_loss: 0.0285 - val_mean_absolute_error: 0.1166 - val_mean_squared_error: 0.0285
# Epoch 264/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0069 - mean_absolute_error: 0.0589 - mean_squared_error: 0.0069 - val_loss: 0.0218 - val_mean_absolute_error: 0.1163 - val_mean_squared_error: 0.0218
# Epoch 265/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0613 - mean_squared_error: 0.0077 - val_loss: 0.0252 - val_mean_absolute_error: 0.1332 - val_mean_squared_error: 0.0252
# Epoch 266/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0083 - mean_absolute_error: 0.0686 - mean_squared_error: 0.0083 - val_loss: 0.0301 - val_mean_absolute_error: 0.1482 - val_mean_squared_error: 0.0301
# Epoch 267/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0106 - mean_absolute_error: 0.0748 - mean_squared_error: 0.0106 - val_loss: 0.0257 - val_mean_absolute_error: 0.1146 - val_mean_squared_error: 0.0257
# Epoch 268/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0138 - mean_absolute_error: 0.0791 - mean_squared_error: 0.0138 - val_loss: 0.0375 - val_mean_absolute_error: 0.1502 - val_mean_squared_error: 0.0375
# Epoch 269/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0353 - mean_absolute_error: 0.1308 - mean_squared_error: 0.0353 - val_loss: 0.0244 - val_mean_absolute_error: 0.1229 - val_mean_squared_error: 0.0244
# Epoch 270/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0744 - mean_absolute_error: 0.1744 - mean_squared_error: 0.0744 - val_loss: 0.1571 - val_mean_absolute_error: 0.2712 - val_mean_squared_error: 0.1571
# Epoch 271/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0435 - mean_absolute_error: 0.1526 - mean_squared_error: 0.0435 - val_loss: 0.0588 - val_mean_absolute_error: 0.1922 - val_mean_squared_error: 0.0588
# Epoch 272/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0201 - mean_absolute_error: 0.1090 - mean_squared_error: 0.0201 - val_loss: 0.0305 - val_mean_absolute_error: 0.1374 - val_mean_squared_error: 0.0305
# Epoch 273/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0189 - mean_absolute_error: 0.1009 - mean_squared_error: 0.0189 - val_loss: 0.0313 - val_mean_absolute_error: 0.1296 - val_mean_squared_error: 0.0313
# Epoch 274/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0170 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0170 - val_loss: 0.0289 - val_mean_absolute_error: 0.1206 - val_mean_squared_error: 0.0289
# Epoch 275/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0236 - mean_absolute_error: 0.1049 - mean_squared_error: 0.0236 - val_loss: 0.0466 - val_mean_absolute_error: 0.1560 - val_mean_squared_error: 0.0466
# Epoch 276/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0166 - mean_absolute_error: 0.1011 - mean_squared_error: 0.0166 - val_loss: 0.0383 - val_mean_absolute_error: 0.1507 - val_mean_squared_error: 0.0383
# Epoch 277/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0217 - mean_absolute_error: 0.1020 - mean_squared_error: 0.0217 - val_loss: 0.0230 - val_mean_absolute_error: 0.1078 - val_mean_squared_error: 0.0230
# Epoch 278/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0167 - mean_absolute_error: 0.1034 - mean_squared_error: 0.0167 - val_loss: 0.0423 - val_mean_absolute_error: 0.1572 - val_mean_squared_error: 0.0423
# Epoch 279/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0296 - mean_absolute_error: 0.1386 - mean_squared_error: 0.0296 - val_loss: 0.0364 - val_mean_absolute_error: 0.1511 - val_mean_squared_error: 0.0364
# Epoch 280/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0326 - mean_absolute_error: 0.1482 - mean_squared_error: 0.0326 - val_loss: 0.0318 - val_mean_absolute_error: 0.1433 - val_mean_squared_error: 0.0318
# Epoch 281/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0248 - mean_absolute_error: 0.1267 - mean_squared_error: 0.0248 - val_loss: 0.0201 - val_mean_absolute_error: 0.1006 - val_mean_squared_error: 0.0201
# Epoch 282/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0121 - mean_absolute_error: 0.0842 - mean_squared_error: 0.0121 - val_loss: 0.0221 - val_mean_absolute_error: 0.1004 - val_mean_squared_error: 0.0221
# Epoch 283/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0088 - mean_absolute_error: 0.0746 - mean_squared_error: 0.0088 - val_loss: 0.0203 - val_mean_absolute_error: 0.1075 - val_mean_squared_error: 0.0203
# Epoch 284/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0071 - mean_absolute_error: 0.0620 - mean_squared_error: 0.0071 - val_loss: 0.0286 - val_mean_absolute_error: 0.1418 - val_mean_squared_error: 0.0286
# Epoch 285/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0167 - mean_absolute_error: 0.0937 - mean_squared_error: 0.0167 - val_loss: 0.0348 - val_mean_absolute_error: 0.1567 - val_mean_squared_error: 0.0348
# Epoch 286/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0210 - mean_absolute_error: 0.1135 - mean_squared_error: 0.0210 - val_loss: 0.0288 - val_mean_absolute_error: 0.1083 - val_mean_squared_error: 0.0288
# Epoch 287/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0064 - mean_absolute_error: 0.0580 - mean_squared_error: 0.0064 - val_loss: 0.0337 - val_mean_absolute_error: 0.1472 - val_mean_squared_error: 0.0337
# Epoch 288/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0152 - mean_absolute_error: 0.0995 - mean_squared_error: 0.0152 - val_loss: 0.0269 - val_mean_absolute_error: 0.1304 - val_mean_squared_error: 0.0269
# Epoch 289/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0089 - mean_absolute_error: 0.0758 - mean_squared_error: 0.0089 - val_loss: 0.0275 - val_mean_absolute_error: 0.1329 - val_mean_squared_error: 0.0275
# Epoch 290/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0091 - mean_absolute_error: 0.0760 - mean_squared_error: 0.0091 - val_loss: 0.0256 - val_mean_absolute_error: 0.1362 - val_mean_squared_error: 0.0256
# Epoch 291/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0072 - mean_absolute_error: 0.0628 - mean_squared_error: 0.0072 - val_loss: 0.0240 - val_mean_absolute_error: 0.1291 - val_mean_squared_error: 0.0240
# Epoch 292/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0057 - mean_absolute_error: 0.0570 - mean_squared_error: 0.0057 - val_loss: 0.0256 - val_mean_absolute_error: 0.1310 - val_mean_squared_error: 0.0256
# Epoch 293/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0042 - mean_absolute_error: 0.0482 - mean_squared_error: 0.0042 - val_loss: 0.0198 - val_mean_absolute_error: 0.1109 - val_mean_squared_error: 0.0198
# Epoch 294/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0041 - mean_absolute_error: 0.0486 - mean_squared_error: 0.0041 - val_loss: 0.0225 - val_mean_absolute_error: 0.1171 - val_mean_squared_error: 0.0225
# Epoch 295/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0043 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0043 - val_loss: 0.0197 - val_mean_absolute_error: 0.1041 - val_mean_squared_error: 0.0197
# Epoch 296/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0039 - mean_absolute_error: 0.0469 - mean_squared_error: 0.0039 - val_loss: 0.0184 - val_mean_absolute_error: 0.0997 - val_mean_squared_error: 0.0184
# Epoch 297/300
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0455 - mean_squared_error: 0.0038 - val_loss: 0.0181 - val_mean_absolute_error: 0.1009 - val_mean_squared_error: 0.0181
# Epoch 298/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0040 - mean_absolute_error: 0.0476 - mean_squared_error: 0.0040 - val_loss: 0.0199 - val_mean_absolute_error: 0.1126 - val_mean_squared_error: 0.0199
# Epoch 299/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0053 - mean_absolute_error: 0.0545 - mean_squared_error: 0.0053 - val_loss: 0.0202 - val_mean_absolute_error: 0.1102 - val_mean_squared_error: 0.0202
# Epoch 300/300
# 334/334 [==============================] - 0s 1ms/step - loss: 0.0049 - mean_absolute_error: 0.0492 - mean_squared_error: 0.0049 - val_loss: 0.0186 - val_mean_absolute_error: 0.1011 - val_mean_squared_error: 0.0186

# %%
hist = pd.DataFrame(history.history)
hist['epoch']= history.epoch
hist.tail()
# Out:
#      val_loss  val_mean_absolute_error  val_mean_squared_error      loss  \
# 295  0.018355                 0.099695                0.018355  0.003927
# 296  0.018081                 0.100864                0.018081  0.003788
# 297  0.019903                 0.112611                0.019903  0.004048
# 298  0.020218                 0.110249                0.020218  0.005311
# 299  0.018636                 0.101097                0.018636  0.004885
#
#      mean_absolute_error  mean_squared_error  epoch
# 295             0.046894            0.003927    295
# 296             0.045463            0.003788    296
# 297             0.047551            0.004048    297
# 298             0.054456            0.005311    298
# 299             0.049180            0.004885    299

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
    
  plt.figure(figsize=(13,9))
  #plt.figure()
  plt.xlabel('Epoch', fontsize= 18)
  plt.ylabel('Mean Abs Error', fontsize= 18)
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  plt.ylim([0,1.2])
  plt.tick_params(labelsize=20)
  plt.legend()
  

  plt.figure(figsize=(13,9))
  #plt.figure()
  plt.xlabel('Epoch', fontsize = 20)
  plt.ylabel('Mean Square Error', fontsize= 20)
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  plt.ylim([0,10])
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# **Save model**

# %%
test_predictions = model.predict([x_RVStrain, x_BPtrain, x_RPtrain])
print(np.shape(test_predictions))
print(np.shape(y_train_stack[:,0]))
print(np.shape(y_train_stack[:,1]))
plt.scatter(normalize(y_train_stack[:,0]), test_predictions[:,0], label= 'LogTeff')
plt.scatter(normalize(y_train_stack[:,1]), test_predictions[:,1], label= 'Log(g)')
plt.xlabel('True Values [LogTeff]')
plt.ylabel('Predictions [LogTeff]')
plt.axis('equal')
plt.axis('square')
plt.legend()
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
#_ = plt.plot([1.4, 1.4], [1.4, 1.4])
#print('test predictions=', test_predictions)
# Out:
# (334, 2)
# (334,)
# (334,)

# %%
#Unnormalizing the labels (teff)

print(np.shape(y_train_stack[:,0]))
print(np.shape(y_train_stack[:,1]))



def denormalize (labels):
    mean_labels=np.mean(labels)
    std_labels=np.std(labels)
    return (((labels)*(std_labels)) + mean_labels)

plt.figure(figsize=(13,9))
test_predictions = model.predict([x_RVStrain, x_BPtrain, x_RPtrain])
print('shape of test_predictions:',np.shape(test_predictions))
print('print 10 elements of test_predictions:', test_predictions[0:10])
plt.scatter(denormalize(y_train_stack[:,0]), denormalize(test_predictions[:,0]), s= 4.0, c= 'r', label='LogTeff' )
plt.scatter(denormalize(y_train_stack[:,1]), denormalize(test_predictions[:,1]), s= 4.0, c= 'b', label='Log(g)' )
plt.xlabel(r"True", fontsize=25)
plt.ylabel(r"Prediction", fontsize=25)
plt.axis('equal')
plt.axis('square')
# increase the x,y tick label size
plt.tick_params(labelsize= 25) 
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-2, 3], [-2, 3], color='green')
plt.legend(fontsize=20)
# Out:
# (334,)
# (334,)
# shape of test_predictions: (334, 2)
# print 10 elements of test_predictions: [[-1.6500033  -2.3348813 ]
#  [-1.6885345  -1.9405668 ]
#  [-1.6808151  -1.5491525 ]
#  [-1.6886991  -1.2300477 ]
#  [-1.6788524  -0.8190756 ]
#  [-1.6739925  -0.39731073]
#  [-1.6344825   0.23649096]
#  [-1.6078442   0.6693343 ]
#  [-1.5857545   0.8987006 ]
#  [-1.5822867   1.1312923 ]]

# %%
#Making the histogram of denormalized training set 

plt.figure(figsize=(10,9))
data_teff=np.subtract(denormalize(y_train_stack[:,0]), denormalize(test_predictions[:,0])) 
data_logg=np.subtract(denormalize(y_train_stack[:,1]), denormalize(test_predictions[:,1])) 

counts_teff, bins_teff = np.histogram(data_teff)
counts_logg, bins_logg = np.histogram(data_logg)

#histogram for LogTeff
plt.hist(bins_teff[:-1], bins_teff, weights=counts_teff, label= r'$\rm log(\rm T_{\rm eff})$')
plt.tick_params(labelsize=18) 
plt.xlabel(r'[Prediction-True]', fontsize=18)
plt.ylabel('Counts', fontsize=18)
plt.legend(fontsize=20)
plt.show()

#histogram for Log(g)
plt.figure(figsize=(10,9))
plt.hist(bins_logg[:-1], bins_logg, weights=counts_logg, label= 'log(g)', color='red')
plt.tick_params(labelsize=18) 
plt.xlabel(r'[Prediction-True]', fontsize=18)
plt.ylabel('Counts', fontsize=18)
plt.legend(fontsize=20)
plt.show()




#print('standard deviation', len(z))
#print(len(z[teff<5000]))
#print(len(z))

# %% [markdown]
# # Training Data Set

# %%
# getting deviation in Teff bins
nbin = 6
teffbin_edges=np.array([-1.5, -0.5, 0., 0.5, 1.0, 1.5, 2.0])

# pred vs. true
# unnormalised values
teff_pred = denormalize(test_predictions[:,0])
teff_true = denormalize(y_train_stack[:,0]) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
teff_diff = teff_pred-teff_true

# compute mean and std in Teff bins
teff_diff_mean = np.zeros(nbin) 
teff_diff_std = np.zeros(nbin)
teffbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(teff_true<teffbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(teff_true>teffbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((teff_true>teffbin_edges[i-1]) & (teff_true<teffbin_edges[i]))
        #if i=1, teff_true>(teffbin_edges[1-1=0]= 5000) & teff_true<teffbin_edges[1]= 10000, so 5000<teff<10000
        #if i=2, teff_true>(teffbin_edges[2-1=1]=10000) & teff_true<teffbin_edges[2]= 15000, so 10000<teff<15000
        #if i=3, teff_true> (teffbin_edges[3-1=2]= 15000) & teff_true<teffbin_edges[3]= 20000 so 15000<teff<20000
    teffbin_mean[i] = np.mean(teff_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    teff_diff_mean[i] = np.mean(teff_diff[indx]) #calculating the mean values of teff_diff from its index 
    teff_diff_std[i] = np.std(teff_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin teff_true=', teffbin_mean)
print('mean of teff_diff=', teff_diff_mean)
print('std of teff_diff=', teff_diff_std)
print('length of teff_diff=', len(teff_diff))

####################################################################################################################
print('==========================================================================================================')
# getting deviation in Teff bins
nbin = 6
loggbin_edges=np.array([-1.5, -0.5, 0., 0.5, 1.0, 1.5, 2.0])

# pred vs. true
# unnormalised values
logg_pred = denormalize(test_predictions[:,1])
logg_true = denormalize(y_train_stack[:,1]) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
logg_diff = logg_pred-logg_true

# compute mean and std in Teff bins
logg_diff_mean = np.zeros(nbin) 
logg_diff_std = np.zeros(nbin)
loggbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(logg_true<loggbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(logg_true>loggbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((logg_true>loggbin_edges[i-1]) & (logg_true<loggbin_edges[i]))

    loggbin_mean[i] = np.mean(logg_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    logg_diff_mean[i] = np.mean(logg_diff[indx]) #calculating the mean values of teff_diff from its index 
    logg_diff_std[i] = np.std(logg_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin logg_true=', loggbin_mean)
print('mean of logg_diff=', logg_diff_mean)
print('std of logg_diff=', logg_diff_std)
print('length of logg_diff=', len(logg_diff))
# Out:
# mean of bin teff_true= [-1.65901584 -0.96237319 -0.23382359  0.25036779  0.71682921  1.4714568 ]
# mean of teff_diff= [0.04881342 0.02297831 0.02604465 0.03712612 0.01711004 0.04936984]
# std of teff_diff= [0.05068847 0.02918066 0.01882317 0.02286653 0.0305518  0.03087149]
# length of teff_diff= 334
# ==========================================================================================================
# mean of bin logg_true= [-2.01138334 -0.89461146 -0.21563874  0.14996196  0.69836301  1.24676406]
# mean of logg_diff= [ 0.04996689  0.02410144  0.01104043  0.01751499 -0.00228526 -0.10879923]
# std of logg_diff= [0.0687241  0.06448459 0.07808352 0.06671482 0.06199277 0.07697754]
# length of logg_diff= 334

# %%
# plot of logteff
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(teff_true, teff_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(teffbin_mean,teff_diff_mean, yerr=teff_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([-2.4,2.4])
ylim=np.array([-0.07,0.16])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# set x, y label. 
plt.xlabel(r"$\rm logT_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$\rm logT_{\rm eff,pred}-\rm logT_{\rm eff,true}$ (K)", fontsize=18)

# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %%
#Plot log 
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(logg_true, logg_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(loggbin_mean,logg_diff_mean, yerr=logg_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
#plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=18)
#plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([-3,2.5])
ylim=np.array([-0.3,0.3])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])


# set x, y label. 
plt.xlabel(r"$\rm log(g)_{\rm true}$", fontsize=18)
plt.ylabel(r"$\rm log(g)_{\rm pred}-\rm log(g)_{\rm true}$", fontsize=18)



# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %% [markdown]
# # Cross Validation Set

# %%
#Test set (x_cv)

plt.figure(figsize=(13,9))
cv_predictions = model.predict([x_RVScv, x_BPcv, x_RPcv]).flatten()
plt.scatter(denormalize(y_cv), denormalize(cv_predictions), c= 'r', s= 3)
_ = plt.plot([3.6, 4.6], [3.6, 4.6])
plt.xlabel(r"$LogT_{\rm eff,true}$ (K)", fontsize=25)
plt.ylabel(r"$LogT_{\rm eff,pred}$ (K)", fontsize=25)
plt.axis('equal')
plt.axis('square')
# increase the x,y tick label size
plt.tick_params(labelsize=25) 
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])


#print('test predictions=', test_predictions)

print('len of y_cv=', len(y_cv))
# Out:
# len of y_cv= 83

# %%
# getting deviation in Teff bins
nbin = 6
teffbin_edges=np.array([3.6, 3.8, 4.0, 4.2, 4.4])

# pred vs. true
# unnormalised values
teff_pred = denormalize(cv_predictions)
teff_true = denormalize(y_cv) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
teff_diff = teff_pred-teff_true

# compute mean and std in Teff bins
teff_diff_mean = np.zeros(nbin) 
teff_diff_std = np.zeros(nbin)
teffbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(teff_true<teffbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(teff_true>teffbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((teff_true>teffbin_edges[i-1]) & (teff_true<teffbin_edges[i]))
        #if i=1, teff_true>(teffbin_edges[1-1=0]= 5000) & teff_true<teffbin_edges[1]= 10000, so 5000<teff<10000
        #if i=2, teff_true>(teffbin_edges[2-1=1]=10000) & teff_true<teffbin_edges[2]= 15000, so 10000<teff<15000
        #if i=3, teff_true> (teffbin_edges[3-1=2]= 15000) & teff_true<teffbin_edges[3]= 20000 so 15000<teff<20000
    teffbin_mean[i] = np.mean(teff_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    teff_diff_mean[i] = np.mean(teff_diff[indx]) #calculating the mean values of teff_diff from its index 
    teff_diff_std[i] = np.std(teff_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin teff_true=', teffbin_mean)
print('mean of teff_diff=', teff_diff_mean)
print('std of teff_diff=', teff_diff_std)
print('len of teff_diff=', len(teff_diff))
# Out:
# mean of bin teff_true= [3.56279506 3.70254985 3.90483146 4.08967383 4.26159265 4.45188102]
# mean of teff_diff= [ 1.70567472e-02  1.16407104e-02  8.30709750e-05 -5.54377745e-03
#  -2.44710078e-04 -5.07916460e-04]
# std of teff_diff= [0.01541771 0.00509443 0.00533952 0.0040671  0.00837475 0.0038941 ]
# len of teff_diff= 83

# %%
# plot
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(teff_true, teff_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(teffbin_mean,teff_diff_mean, yerr=teff_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=25)
plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=25)

# set x, y lim plot range
xlim=np.array([3.5,4.5])
ylim=np.array([-0.11,0.11])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# set x, y label. 
plt.xlabel(r"$\rm logT_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$\rm logT_{\rm eff,pred}-\rm logT_{\rm eff,true}$ (K)", fontsize=18)

# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %%
#Making the histogram of the CV set 

plt.figure(figsize=(13,9))
z=np.subtract(denormalize(y_cv), denormalize(cv_predictions)) #difference between the true and predicted values
counts, bins = np.histogram(z)
plt.hist(bins[:-1], bins, weights=counts)


# increase the x,y tick label size
plt.tick_params(labelsize=18) 

plt.title(r'Histogram of $T_{eff}$', fontsize=18)
plt.xlabel(r"$\rm logT_{\rm eff,pred}-\rm logT_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel('Counts', fontsize=18)
#z[teff<5000].std()
print('standard deviation', len(z))
#print(len(z[teff<5000]))
#print(len(z))
# Out:
# standard deviation 83

# %% [raw]
# # Another model
# From TheCNNon, https://github.com/adrn/TheCNNon/blob/master/notebooks/ThisIsCNNON.ipynb

# %%
# Input spectra
input_spec = Input(shape=(num_fluxes,), name='starnet_input_x')

# Reshape spectra for CNN layers
cur_in = Reshape((num_fluxes, 1))(input_spec)

# CNN layers
# First
cur_in = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=128, kernel_size=32)(cur_in) #first CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=32)(cur_in)
# Second CNN layer
cur_in = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=128, kernel_size=16)(cur_in) #2nd CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=16)(cur_in)
# Third CNN layer
cur_in = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=128, kernel_size=8)(cur_in) #2nd CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=8)(cur_in)

# Flatten the current input for the fully-connected layers
cur_in = Flatten()(cur_in)

# Fully-connected layers
cur_in = Dense(units=258, kernel_initializer=initializer, 
               activation=activation)(cur_in)
cur_in = Dense(units=128, kernel_initializer=initializer, 
               activation=activation)(cur_in)

# Output nodes
output_label = Dense(units=num_labels, kernel_regularizer=keras.regularizers.l2(0.01), activation="linear", 
                     input_dim=num_hidden[1])(cur_in)

model = Model(input_spec, output_label)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1658   try:
# -> 1659     c_op = c_api.TF_FinishOperation(op_desc)
#    1660   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Negative dimension size caused by subtracting 8 from 1 for 'max_pooling1d_12/MaxPool' (op: 'MaxPool') with input shapes: [?,1,1,128].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-07ed572f0f80> in <module>
#      20                 padding="same", filters=128, kernel_size=8)(cur_in) #2nd CNN layer
#      21 # Max pooling layer
# ---> 22 cur_in = MaxPooling1D(pool_size=8)(cur_in)
#      23
#      24 # Flatten the current input for the fully-connected layers
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     455             # Actually call the layer,
#     456             # collecting output(s), mask(s), and shape(s).
# --> 457             output = self.call(inputs, **kwargs)
#     458             output_mask = self.compute_mask(inputs, previous_mask)
#     459
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/pooling.py in call(self, inputs)
#      55                                         strides=self.strides + (1,),
#      56                                         padding=self.padding,
# ---> 57                                         data_format=self.data_format)
#      58         return K.squeeze(output, dummy_axis)  # remove dummy last dimension
#      59
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/pooling.py in _pooling_function(self, inputs, pool_size, strides, padding, data_format)
#     111                           padding, data_format):
#     112         output = K.pool2d(inputs, pool_size, strides,
# --> 113                           padding, data_format, pool_mode='max')
#     114         return output
#     115
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in pool2d(x, pool_size, strides, padding, data_format, pool_mode)
#    3976         x = tf.nn.max_pool(x, pool_size, strides,
#    3977                            padding=padding,
# -> 3978                            data_format=tf_data_format)
#    3979     elif pool_mode == 'avg':
#    3980         x = tf.nn.avg_pool(x, pool_size, strides,
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in max_pool(value, ksize, strides, padding, data_format, name)
#    2746         padding=padding,
#    2747         data_format=data_format,
# -> 2748         name=name)
#    2749
#    2750
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in max_pool(input, ksize, strides, padding, data_format, name)
#    5135   _, _, _op = _op_def_lib._apply_op_helper(
#    5136         "MaxPool", input=input, ksize=ksize, strides=strides, padding=padding,
# -> 5137                    data_format=data_format, name=name)
#    5138   _result = _op.outputs[:]
#    5139   _inputs_flat = _op.inputs
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     787                          input_types=input_types, attrs=attr_protos,
# --> 788                          op_def=op_def)
#     789       return output_structure, op_def.is_stateful, op
#     790
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(***failed resolving arguments***)
#    3298           input_types=input_types,
#    3299           original_op=self._default_original_op,
# -> 3300           op_def=op_def)
#    3301       self._create_op_helper(ret, compute_device=compute_device)
#    3302     return ret
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1821           op_def, inputs, node_def.attr)
#    1822       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1823                                 control_input_ops)
#    1824
#    1825     # Initialize self._outputs.
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1660   except errors.InvalidArgumentError as e:
#    1661     # Convert to ValueError for backwards compatibility.
# -> 1662     raise ValueError(str(e))
#    1663
#    1664   return c_op
#
# ValueError: Negative dimension size caused by subtracting 8 from 1 for 'max_pooling1d_12/MaxPool' (op: 'MaxPool') with input shapes: [?,1,1,128].

# %%
optimizer = Adam(lr=0.0005)

# %%
# loss function to minimize
loss_function = 'mean_squared_error'
optimizer = 'adadelta'
# compute mean absolute deviation
metrics = ['mae', 'mse']
#metrics = ['mae']
model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# starnet_input_x (InputLayer) (None, 6758)              0
# _________________________________________________________________
# reshape_10 (Reshape)         (None, 6758, 1)           0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 6758, 128)         4224
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 211, 128)          0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 211, 128)          262272
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 13, 128)           0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 13, 128)           131200
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 1, 128)            0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 258)               33282
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               33152
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 464,259
# Trainable params: 464,259
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, 
          epochs=max_epochs, validation_split = 0.2, verbose=1, shuffle='batch')
# Out:
# Train on 875 samples, validate on 219 samples
# Epoch 1/200
# 875/875 [==============================] - 13s 15ms/step - loss: 5.2174 - mean_absolute_error: 1.4147 - mean_squared_error: 5.1988 - val_loss: 1.5482 - val_mean_absolute_error: 0.9417 - val_mean_squared_error: 1.5305
# Epoch 2/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3955 - mean_absolute_error: 0.5094 - mean_squared_error: 0.3783 - val_loss: 1.8217 - val_mean_absolute_error: 1.0313 - val_mean_squared_error: 1.8050
# Epoch 3/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3606 - mean_absolute_error: 0.4579 - mean_squared_error: 0.3443 - val_loss: 1.9750 - val_mean_absolute_error: 1.0742 - val_mean_squared_error: 1.9589
# Epoch 4/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3806 - mean_absolute_error: 0.4960 - mean_squared_error: 0.3648 - val_loss: 2.0388 - val_mean_absolute_error: 1.0894 - val_mean_squared_error: 2.0232
# Epoch 5/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.4077 - mean_absolute_error: 0.4772 - mean_squared_error: 0.3923 - val_loss: 3.4660 - val_mean_absolute_error: 1.5366 - val_mean_squared_error: 3.4508
# Epoch 6/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.3888 - mean_absolute_error: 0.5023 - mean_squared_error: 0.3738 - val_loss: 3.0916 - val_mean_absolute_error: 1.4193 - val_mean_squared_error: 3.0766
# Epoch 7/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3001 - mean_absolute_error: 0.4360 - mean_squared_error: 0.2852 - val_loss: 3.7524 - val_mean_absolute_error: 1.6397 - val_mean_squared_error: 3.7377
# Epoch 8/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.2883 - mean_absolute_error: 0.4420 - mean_squared_error: 0.2736 - val_loss: 3.6873 - val_mean_absolute_error: 1.6205 - val_mean_squared_error: 3.6728
# Epoch 9/200
# 875/875 [==============================] - 22s 25ms/step - loss: 0.2976 - mean_absolute_error: 0.4493 - mean_squared_error: 0.2833 - val_loss: 3.8704 - val_mean_absolute_error: 1.6722 - val_mean_squared_error: 3.8562
# Epoch 10/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.2398 - mean_absolute_error: 0.3987 - mean_squared_error: 0.2256 - val_loss: 3.9370 - val_mean_absolute_error: 1.6926 - val_mean_squared_error: 3.9230
# Epoch 11/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.2136 - mean_absolute_error: 0.3585 - mean_squared_error: 0.1997 - val_loss: 3.5978 - val_mean_absolute_error: 1.5898 - val_mean_squared_error: 3.5840
# Epoch 12/200
# 875/875 [==============================] - 27s 31ms/step - loss: 0.2410 - mean_absolute_error: 0.3820 - mean_squared_error: 0.2274 - val_loss: 4.0983 - val_mean_absolute_error: 1.7393 - val_mean_squared_error: 4.0850
# Epoch 13/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.1661 - mean_absolute_error: 0.3015 - mean_squared_error: 0.1530 - val_loss: 2.8094 - val_mean_absolute_error: 1.3314 - val_mean_squared_error: 2.7965
# Epoch 14/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1630 - mean_absolute_error: 0.2858 - mean_squared_error: 0.1503 - val_loss: 3.9325 - val_mean_absolute_error: 1.6919 - val_mean_squared_error: 3.9201
# Epoch 15/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.1432 - mean_absolute_error: 0.2689 - mean_squared_error: 0.1311 - val_loss: 3.6180 - val_mean_absolute_error: 1.5971 - val_mean_squared_error: 3.6062
# Epoch 16/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1220 - mean_absolute_error: 0.2405 - mean_squared_error: 0.1106 - val_loss: 3.5919 - val_mean_absolute_error: 1.5885 - val_mean_squared_error: 3.5809
# Epoch 17/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1122 - mean_absolute_error: 0.2418 - mean_squared_error: 0.1015 - val_loss: 3.4441 - val_mean_absolute_error: 1.5411 - val_mean_squared_error: 3.4337
# Epoch 18/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1125 - mean_absolute_error: 0.2457 - mean_squared_error: 0.1025 - val_loss: 3.6328 - val_mean_absolute_error: 1.6010 - val_mean_squared_error: 3.6232
# Epoch 19/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1287 - mean_absolute_error: 0.2610 - mean_squared_error: 0.1194 - val_loss: 3.5788 - val_mean_absolute_error: 1.5843 - val_mean_squared_error: 3.5699
# Epoch 20/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0884 - mean_absolute_error: 0.2150 - mean_squared_error: 0.0797 - val_loss: 2.2024 - val_mean_absolute_error: 1.1457 - val_mean_squared_error: 2.1939
# Epoch 21/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1126 - mean_absolute_error: 0.2483 - mean_squared_error: 0.1043 - val_loss: 3.1658 - val_mean_absolute_error: 1.4498 - val_mean_squared_error: 3.1579
# Epoch 22/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0973 - mean_absolute_error: 0.2238 - mean_squared_error: 0.0895 - val_loss: 3.2924 - val_mean_absolute_error: 1.4950 - val_mean_squared_error: 3.2848
# Epoch 23/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0928 - mean_absolute_error: 0.2209 - mean_squared_error: 0.0853 - val_loss: 2.5891 - val_mean_absolute_error: 1.2693 - val_mean_squared_error: 2.5818
# Epoch 24/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1052 - mean_absolute_error: 0.2388 - mean_squared_error: 0.0981 - val_loss: 2.9058 - val_mean_absolute_error: 1.3614 - val_mean_squared_error: 2.8988
# Epoch 25/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1014 - mean_absolute_error: 0.2394 - mean_squared_error: 0.0945 - val_loss: 2.1955 - val_mean_absolute_error: 1.1433 - val_mean_squared_error: 2.1887
# Epoch 26/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1404 - mean_absolute_error: 0.2719 - mean_squared_error: 0.1338 - val_loss: 3.4146 - val_mean_absolute_error: 1.5348 - val_mean_squared_error: 3.4081
# Epoch 27/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0821 - mean_absolute_error: 0.2071 - mean_squared_error: 0.0757 - val_loss: 2.4974 - val_mean_absolute_error: 1.2405 - val_mean_squared_error: 2.4909
# Epoch 28/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0923 - mean_absolute_error: 0.2196 - mean_squared_error: 0.0859 - val_loss: 2.6382 - val_mean_absolute_error: 1.2849 - val_mean_squared_error: 2.6318
# Epoch 29/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0897 - mean_absolute_error: 0.2259 - mean_squared_error: 0.0834 - val_loss: 2.8831 - val_mean_absolute_error: 1.3586 - val_mean_squared_error: 2.8769
# Epoch 30/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0744 - mean_absolute_error: 0.1986 - mean_squared_error: 0.0682 - val_loss: 1.7850 - val_mean_absolute_error: 1.0208 - val_mean_squared_error: 1.7788
# Epoch 31/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1151 - mean_absolute_error: 0.2334 - mean_squared_error: 0.1090 - val_loss: 2.8941 - val_mean_absolute_error: 1.3617 - val_mean_squared_error: 2.8881
# Epoch 32/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0832 - mean_absolute_error: 0.2128 - mean_squared_error: 0.0773 - val_loss: 2.6767 - val_mean_absolute_error: 1.2974 - val_mean_squared_error: 2.6707
# Epoch 33/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0797 - mean_absolute_error: 0.2058 - mean_squared_error: 0.0738 - val_loss: 3.1776 - val_mean_absolute_error: 1.4555 - val_mean_squared_error: 3.1718
# Epoch 34/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0814 - mean_absolute_error: 0.2059 - mean_squared_error: 0.0757 - val_loss: 2.6626 - val_mean_absolute_error: 1.2925 - val_mean_squared_error: 2.6568
# Epoch 35/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0876 - mean_absolute_error: 0.2151 - mean_squared_error: 0.0819 - val_loss: 2.5699 - val_mean_absolute_error: 1.2623 - val_mean_squared_error: 2.5643
# Epoch 36/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1182 - mean_absolute_error: 0.2553 - mean_squared_error: 0.1126 - val_loss: 2.7674 - val_mean_absolute_error: 1.3285 - val_mean_squared_error: 2.7619
# Epoch 37/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0652 - mean_absolute_error: 0.1795 - mean_squared_error: 0.0597 - val_loss: 3.1619 - val_mean_absolute_error: 1.4543 - val_mean_squared_error: 3.1564
# Epoch 38/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0757 - mean_absolute_error: 0.2025 - mean_squared_error: 0.0703 - val_loss: 2.8025 - val_mean_absolute_error: 1.3408 - val_mean_squared_error: 2.7970
# Epoch 39/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0759 - mean_absolute_error: 0.2020 - mean_squared_error: 0.0705 - val_loss: 2.1523 - val_mean_absolute_error: 1.1254 - val_mean_squared_error: 2.1470
# Epoch 40/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0722 - mean_absolute_error: 0.1941 - mean_squared_error: 0.0669 - val_loss: 2.2233 - val_mean_absolute_error: 1.1493 - val_mean_squared_error: 2.2180
# Epoch 41/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0718 - mean_absolute_error: 0.1899 - mean_squared_error: 0.0666 - val_loss: 2.5742 - val_mean_absolute_error: 1.2647 - val_mean_squared_error: 2.5689
# Epoch 42/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0649 - mean_absolute_error: 0.1807 - mean_squared_error: 0.0597 - val_loss: 2.5939 - val_mean_absolute_error: 1.2684 - val_mean_squared_error: 2.5887
# Epoch 43/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0669 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0618 - val_loss: 2.8934 - val_mean_absolute_error: 1.3602 - val_mean_squared_error: 2.8883
# Epoch 44/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0709 - mean_absolute_error: 0.1983 - mean_squared_error: 0.0659 - val_loss: 2.5505 - val_mean_absolute_error: 1.2618 - val_mean_squared_error: 2.5456
# Epoch 45/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0694 - mean_absolute_error: 0.1891 - mean_squared_error: 0.0645 - val_loss: 2.9804 - val_mean_absolute_error: 1.3956 - val_mean_squared_error: 2.9755
# Epoch 46/200
# 875/875 [==============================] - 24s 28ms/step - loss: 0.0719 - mean_absolute_error: 0.1961 - mean_squared_error: 0.0670 - val_loss: 2.4074 - val_mean_absolute_error: 1.2118 - val_mean_squared_error: 2.4026
# Epoch 47/200
# 875/875 [==============================] - 24s 28ms/step - loss: 0.0618 - mean_absolute_error: 0.1743 - mean_squared_error: 0.0571 - val_loss: 2.2830 - val_mean_absolute_error: 1.1690 - val_mean_squared_error: 2.2782
# Epoch 48/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0676 - mean_absolute_error: 0.1821 - mean_squared_error: 0.0629 - val_loss: 2.6052 - val_mean_absolute_error: 1.2808 - val_mean_squared_error: 2.6005
# Epoch 49/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0630 - mean_absolute_error: 0.1787 - mean_squared_error: 0.0583 - val_loss: 2.4626 - val_mean_absolute_error: 1.2316 - val_mean_squared_error: 2.4579
# Epoch 50/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0601 - mean_absolute_error: 0.1661 - mean_squared_error: 0.0555 - val_loss: 2.7647 - val_mean_absolute_error: 1.3206 - val_mean_squared_error: 2.7601
# Epoch 51/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0643 - mean_absolute_error: 0.1779 - mean_squared_error: 0.0597 - val_loss: 2.5744 - val_mean_absolute_error: 1.2720 - val_mean_squared_error: 2.5698
# Epoch 52/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0919 - mean_absolute_error: 0.2229 - mean_squared_error: 0.0873 - val_loss: 2.5535 - val_mean_absolute_error: 1.2609 - val_mean_squared_error: 2.5490
# Epoch 53/200
# 875/875 [==============================] - 436s 498ms/step - loss: 0.0650 - mean_absolute_error: 0.1887 - mean_squared_error: 0.0605 - val_loss: 2.1651 - val_mean_absolute_error: 1.1289 - val_mean_squared_error: 2.1606
# Epoch 54/200
# 875/875 [==============================] - 116s 133ms/step - loss: 0.1022 - mean_absolute_error: 0.2107 - mean_squared_error: 0.0977 - val_loss: 2.2922 - val_mean_absolute_error: 1.1691 - val_mean_squared_error: 2.2878
# Epoch 55/200
# 875/875 [==============================] - 1980s 2s/step - loss: 0.0704 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0661 - val_loss: 2.6339 - val_mean_absolute_error: 1.2914 - val_mean_squared_error: 2.6296
# Epoch 56/200
# 875/875 [==============================] - 16s 18ms/step - loss: 0.0528 - mean_absolute_error: 0.1586 - mean_squared_error: 0.0485 - val_loss: 1.9749 - val_mean_absolute_error: 1.0711 - val_mean_squared_error: 1.9706
# Epoch 57/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0525 - mean_absolute_error: 0.1568 - mean_squared_error: 0.0482 - val_loss: 2.0850 - val_mean_absolute_error: 1.1014 - val_mean_squared_error: 2.0807
# Epoch 58/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0607 - mean_absolute_error: 0.1662 - mean_squared_error: 0.0565 - val_loss: 2.4774 - val_mean_absolute_error: 1.2292 - val_mean_squared_error: 2.4732
# Epoch 59/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0578 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0536 - val_loss: 2.1773 - val_mean_absolute_error: 1.1350 - val_mean_squared_error: 2.1730
# Epoch 60/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0521 - mean_absolute_error: 0.1542 - mean_squared_error: 0.0479 - val_loss: 2.2251 - val_mean_absolute_error: 1.1478 - val_mean_squared_error: 2.2209
# Epoch 61/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0482 - mean_absolute_error: 0.1538 - mean_squared_error: 0.0441 - val_loss: 2.4825 - val_mean_absolute_error: 1.2420 - val_mean_squared_error: 2.4783
# Epoch 62/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0498 - mean_absolute_error: 0.1520 - mean_squared_error: 0.0457 - val_loss: 2.2666 - val_mean_absolute_error: 1.1597 - val_mean_squared_error: 2.2624
# Epoch 63/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0545 - mean_absolute_error: 0.1639 - mean_squared_error: 0.0504 - val_loss: 2.0965 - val_mean_absolute_error: 1.1046 - val_mean_squared_error: 2.0924
# Epoch 64/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0453 - mean_absolute_error: 0.1479 - mean_squared_error: 0.0412 - val_loss: 2.0962 - val_mean_absolute_error: 1.1012 - val_mean_squared_error: 2.0921
# Epoch 65/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0569 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0528 - val_loss: 2.6018 - val_mean_absolute_error: 1.2822 - val_mean_squared_error: 2.5977
# Epoch 66/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0521 - mean_absolute_error: 0.1593 - mean_squared_error: 0.0481 - val_loss: 2.1614 - val_mean_absolute_error: 1.1230 - val_mean_squared_error: 2.1573
# Epoch 67/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0468 - mean_absolute_error: 0.1503 - mean_squared_error: 0.0427 - val_loss: 1.9528 - val_mean_absolute_error: 1.0605 - val_mean_squared_error: 1.9488
# Epoch 68/200
# 875/875 [==============================] - 14s 15ms/step - loss: 0.0550 - mean_absolute_error: 0.1625 - mean_squared_error: 0.0510 - val_loss: 1.6402 - val_mean_absolute_error: 0.9684 - val_mean_squared_error: 1.6361
# Epoch 69/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0675 - mean_absolute_error: 0.1783 - mean_squared_error: 0.0636 - val_loss: 1.6937 - val_mean_absolute_error: 0.9808 - val_mean_squared_error: 1.6898
# Epoch 70/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0504 - mean_absolute_error: 0.1465 - mean_squared_error: 0.0465 - val_loss: 1.8599 - val_mean_absolute_error: 1.0318 - val_mean_squared_error: 1.8560
# Epoch 71/200
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0540 - mean_absolute_error: 0.1642 - mean_squared_error: 0.0501 - val_loss: 1.9639 - val_mean_absolute_error: 1.0634 - val_mean_squared_error: 1.9600
# Epoch 72/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0399 - mean_absolute_error: 0.1346 - mean_squared_error: 0.0361 - val_loss: 1.6221 - val_mean_absolute_error: 0.9613 - val_mean_squared_error: 1.6183
# Epoch 73/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0413 - mean_absolute_error: 0.1380 - mean_squared_error: 0.0375 - val_loss: 1.5695 - val_mean_absolute_error: 0.9410 - val_mean_squared_error: 1.5657
# Epoch 74/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0508 - mean_absolute_error: 0.1554 - mean_squared_error: 0.0470 - val_loss: 1.6579 - val_mean_absolute_error: 0.9698 - val_mean_squared_error: 1.6541
# Epoch 75/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0419 - mean_absolute_error: 0.1415 - mean_squared_error: 0.0381 - val_loss: 1.9499 - val_mean_absolute_error: 1.0596 - val_mean_squared_error: 1.9461
# Epoch 76/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0503 - mean_absolute_error: 0.1572 - mean_squared_error: 0.0465 - val_loss: 1.8577 - val_mean_absolute_error: 1.0327 - val_mean_squared_error: 1.8540
# Epoch 77/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0476 - mean_absolute_error: 0.1527 - mean_squared_error: 0.0439 - val_loss: 1.7745 - val_mean_absolute_error: 1.0009 - val_mean_squared_error: 1.7708
# Epoch 78/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0451 - mean_absolute_error: 0.1489 - mean_squared_error: 0.0415 - val_loss: 2.0050 - val_mean_absolute_error: 1.0651 - val_mean_squared_error: 2.0014
# Epoch 79/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0440 - mean_absolute_error: 0.1435 - mean_squared_error: 0.0404 - val_loss: 2.0267 - val_mean_absolute_error: 1.0795 - val_mean_squared_error: 2.0231
# Epoch 80/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0364 - mean_absolute_error: 0.1310 - mean_squared_error: 0.0327 - val_loss: 1.8544 - val_mean_absolute_error: 1.0227 - val_mean_squared_error: 1.8507
# Epoch 81/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0374 - mean_absolute_error: 0.1308 - mean_squared_error: 0.0337 - val_loss: 2.1050 - val_mean_absolute_error: 1.0957 - val_mean_squared_error: 2.1014
# Epoch 82/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0405 - mean_absolute_error: 0.1369 - mean_squared_error: 0.0369 - val_loss: 2.0692 - val_mean_absolute_error: 1.0950 - val_mean_squared_error: 2.0656
# Epoch 83/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0377 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0341 - val_loss: 2.1537 - val_mean_absolute_error: 1.1251 - val_mean_squared_error: 2.1501
# Epoch 84/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0437 - mean_absolute_error: 0.1535 - mean_squared_error: 0.0401 - val_loss: 1.9010 - val_mean_absolute_error: 1.0358 - val_mean_squared_error: 1.8974
# Epoch 85/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0372 - mean_absolute_error: 0.1277 - mean_squared_error: 0.0336 - val_loss: 2.2669 - val_mean_absolute_error: 1.1700 - val_mean_squared_error: 2.2633
# Epoch 86/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0398 - mean_absolute_error: 0.1395 - mean_squared_error: 0.0363 - val_loss: 2.4500 - val_mean_absolute_error: 1.2285 - val_mean_squared_error: 2.4464
# Epoch 87/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0461 - mean_absolute_error: 0.1518 - mean_squared_error: 0.0426 - val_loss: 1.7367 - val_mean_absolute_error: 0.9874 - val_mean_squared_error: 1.7331
# Epoch 88/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0332 - mean_absolute_error: 0.1268 - mean_squared_error: 0.0296 - val_loss: 1.9588 - val_mean_absolute_error: 1.0607 - val_mean_squared_error: 1.9552
# Epoch 89/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0321 - mean_absolute_error: 0.1208 - mean_squared_error: 0.0286 - val_loss: 1.7206 - val_mean_absolute_error: 0.9780 - val_mean_squared_error: 1.7171
# Epoch 90/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0419 - mean_absolute_error: 0.1408 - mean_squared_error: 0.0384 - val_loss: 1.8123 - val_mean_absolute_error: 1.0004 - val_mean_squared_error: 1.8087
# Epoch 91/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0369 - mean_absolute_error: 0.1327 - mean_squared_error: 0.0334 - val_loss: 1.9241 - val_mean_absolute_error: 1.0326 - val_mean_squared_error: 1.9206
# Epoch 92/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0409 - mean_absolute_error: 0.1397 - mean_squared_error: 0.0374 - val_loss: 1.9379 - val_mean_absolute_error: 1.0506 - val_mean_squared_error: 1.9345
# Epoch 93/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0382 - mean_absolute_error: 0.1378 - mean_squared_error: 0.0347 - val_loss: 1.7358 - val_mean_absolute_error: 0.9827 - val_mean_squared_error: 1.7323
# Epoch 94/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0326 - mean_absolute_error: 0.1196 - mean_squared_error: 0.0292 - val_loss: 2.3345 - val_mean_absolute_error: 1.1833 - val_mean_squared_error: 2.3311
# Epoch 95/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0323 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0290 - val_loss: 1.7382 - val_mean_absolute_error: 0.9739 - val_mean_squared_error: 1.7348
# Epoch 96/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0350 - mean_absolute_error: 0.1280 - mean_squared_error: 0.0316 - val_loss: 2.1179 - val_mean_absolute_error: 1.1150 - val_mean_squared_error: 2.1145
# Epoch 97/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0421 - mean_absolute_error: 0.1314 - mean_squared_error: 0.0388 - val_loss: 1.6972 - val_mean_absolute_error: 0.9665 - val_mean_squared_error: 1.6939
# Epoch 98/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0352 - mean_absolute_error: 0.1298 - mean_squared_error: 0.0319 - val_loss: 1.6073 - val_mean_absolute_error: 0.9383 - val_mean_squared_error: 1.6039
# Epoch 99/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0366 - mean_absolute_error: 0.1250 - mean_squared_error: 0.0333 - val_loss: 1.6065 - val_mean_absolute_error: 0.9305 - val_mean_squared_error: 1.6031
# Epoch 100/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0383 - mean_absolute_error: 0.1360 - mean_squared_error: 0.0350 - val_loss: 1.5558 - val_mean_absolute_error: 0.9232 - val_mean_squared_error: 1.5524
# Epoch 101/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0360 - mean_absolute_error: 0.1306 - mean_squared_error: 0.0327 - val_loss: 1.7025 - val_mean_absolute_error: 0.9734 - val_mean_squared_error: 1.6992
# Epoch 102/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0343 - mean_absolute_error: 0.1262 - mean_squared_error: 0.0310 - val_loss: 1.6342 - val_mean_absolute_error: 0.9522 - val_mean_squared_error: 1.6309
# Epoch 103/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0292 - mean_absolute_error: 0.1137 - mean_squared_error: 0.0259 - val_loss: 1.6105 - val_mean_absolute_error: 0.9344 - val_mean_squared_error: 1.6073
# Epoch 104/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0303 - mean_absolute_error: 0.1176 - mean_squared_error: 0.0271 - val_loss: 1.7194 - val_mean_absolute_error: 0.9676 - val_mean_squared_error: 1.7162
# Epoch 105/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0335 - mean_absolute_error: 0.1217 - mean_squared_error: 0.0303 - val_loss: 1.9535 - val_mean_absolute_error: 1.0296 - val_mean_squared_error: 1.9503
# Epoch 106/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0304 - mean_absolute_error: 0.1168 - mean_squared_error: 0.0272 - val_loss: 1.7627 - val_mean_absolute_error: 0.9748 - val_mean_squared_error: 1.7595
# Epoch 107/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0285 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0254 - val_loss: 1.5525 - val_mean_absolute_error: 0.9117 - val_mean_squared_error: 1.5493
# Epoch 108/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0284 - mean_absolute_error: 0.1064 - mean_squared_error: 0.0253 - val_loss: 1.9490 - val_mean_absolute_error: 1.0553 - val_mean_squared_error: 1.9458
# Epoch 109/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0288 - mean_absolute_error: 0.1140 - mean_squared_error: 0.0257 - val_loss: 1.6905 - val_mean_absolute_error: 0.9528 - val_mean_squared_error: 1.6874
# Epoch 110/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0305 - mean_absolute_error: 0.1127 - mean_squared_error: 0.0274 - val_loss: 1.9716 - val_mean_absolute_error: 1.0641 - val_mean_squared_error: 1.9685
# Epoch 111/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0478 - mean_absolute_error: 0.1412 - mean_squared_error: 0.0447 - val_loss: 2.3680 - val_mean_absolute_error: 1.1940 - val_mean_squared_error: 2.3649
# Epoch 112/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0319 - mean_absolute_error: 0.1190 - mean_squared_error: 0.0288 - val_loss: 1.5907 - val_mean_absolute_error: 0.9276 - val_mean_squared_error: 1.5876
# Epoch 113/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0406 - mean_absolute_error: 0.1436 - mean_squared_error: 0.0376 - val_loss: 1.6303 - val_mean_absolute_error: 0.9397 - val_mean_squared_error: 1.6273
# Epoch 114/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0279 - mean_absolute_error: 0.1070 - mean_squared_error: 0.0248 - val_loss: 1.6271 - val_mean_absolute_error: 0.9349 - val_mean_squared_error: 1.6241
# Epoch 115/200
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0367 - mean_absolute_error: 0.1284 - mean_squared_error: 0.0337 - val_loss: 1.4954 - val_mean_absolute_error: 0.8941 - val_mean_squared_error: 1.4924
# Epoch 116/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0296 - mean_absolute_error: 0.1059 - mean_squared_error: 0.0267 - val_loss: 1.6060 - val_mean_absolute_error: 0.9296 - val_mean_squared_error: 1.6030
# Epoch 117/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0242 - mean_absolute_error: 0.1044 - mean_squared_error: 0.0212 - val_loss: 1.5665 - val_mean_absolute_error: 0.9125 - val_mean_squared_error: 1.5635
# Epoch 118/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0294 - mean_absolute_error: 0.1080 - mean_squared_error: 0.0264 - val_loss: 1.9528 - val_mean_absolute_error: 1.0536 - val_mean_squared_error: 1.9499
# Epoch 119/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0268 - mean_absolute_error: 0.1112 - mean_squared_error: 0.0238 - val_loss: 1.7776 - val_mean_absolute_error: 0.9920 - val_mean_squared_error: 1.7747
# Epoch 120/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0234 - mean_absolute_error: 0.0991 - mean_squared_error: 0.0204 - val_loss: 1.6669 - val_mean_absolute_error: 0.9537 - val_mean_squared_error: 1.6640
# Epoch 121/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0395 - mean_absolute_error: 0.1368 - mean_squared_error: 0.0366 - val_loss: 1.4784 - val_mean_absolute_error: 0.8891 - val_mean_squared_error: 1.4755
# Epoch 122/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0292 - mean_absolute_error: 0.1148 - mean_squared_error: 0.0263 - val_loss: 1.8647 - val_mean_absolute_error: 1.0212 - val_mean_squared_error: 1.8618
# Epoch 123/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0408 - mean_absolute_error: 0.1294 - mean_squared_error: 0.0379 - val_loss: 1.5569 - val_mean_absolute_error: 0.9142 - val_mean_squared_error: 1.5541
# Epoch 124/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0249 - mean_absolute_error: 0.1057 - mean_squared_error: 0.0221 - val_loss: 1.5006 - val_mean_absolute_error: 0.8936 - val_mean_squared_error: 1.4978
# Epoch 125/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0252 - mean_absolute_error: 0.1017 - mean_squared_error: 0.0223 - val_loss: 1.3502 - val_mean_absolute_error: 0.8432 - val_mean_squared_error: 1.3474
# Epoch 126/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0328 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0300 - val_loss: 1.4099 - val_mean_absolute_error: 0.8643 - val_mean_squared_error: 1.4071
# Epoch 127/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0238 - mean_absolute_error: 0.1068 - mean_squared_error: 0.0210 - val_loss: 1.4231 - val_mean_absolute_error: 0.8624 - val_mean_squared_error: 1.4203
# Epoch 128/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0268 - mean_absolute_error: 0.1065 - mean_squared_error: 0.0240 - val_loss: 1.4367 - val_mean_absolute_error: 0.8706 - val_mean_squared_error: 1.4338
# Epoch 129/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0227 - mean_absolute_error: 0.0965 - mean_squared_error: 0.0199 - val_loss: 1.5391 - val_mean_absolute_error: 0.8931 - val_mean_squared_error: 1.5364
# Epoch 130/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0343 - mean_absolute_error: 0.1239 - mean_squared_error: 0.0315 - val_loss: 1.4705 - val_mean_absolute_error: 0.8828 - val_mean_squared_error: 1.4677
# Epoch 131/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0280 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0253 - val_loss: 1.5932 - val_mean_absolute_error: 0.9133 - val_mean_squared_error: 1.5905
# Epoch 132/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0277 - mean_absolute_error: 0.1139 - mean_squared_error: 0.0250 - val_loss: 1.7935 - val_mean_absolute_error: 0.9983 - val_mean_squared_error: 1.7908
# Epoch 133/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0322 - mean_absolute_error: 0.1160 - mean_squared_error: 0.0295 - val_loss: 1.4766 - val_mean_absolute_error: 0.8801 - val_mean_squared_error: 1.4739
# Epoch 134/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0253 - mean_absolute_error: 0.1060 - mean_squared_error: 0.0226 - val_loss: 1.5339 - val_mean_absolute_error: 0.9065 - val_mean_squared_error: 1.5312
# Epoch 135/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0261 - mean_absolute_error: 0.1125 - mean_squared_error: 0.0234 - val_loss: 1.4380 - val_mean_absolute_error: 0.8710 - val_mean_squared_error: 1.4353
# Epoch 136/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0576 - mean_absolute_error: 0.1493 - mean_squared_error: 0.0549 - val_loss: 1.3447 - val_mean_absolute_error: 0.8465 - val_mean_squared_error: 1.3421
# Epoch 137/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0333 - mean_absolute_error: 0.1154 - mean_squared_error: 0.0307 - val_loss: 1.3273 - val_mean_absolute_error: 0.8353 - val_mean_squared_error: 1.3247
# Epoch 138/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0271 - mean_absolute_error: 0.1111 - mean_squared_error: 0.0245 - val_loss: 1.2775 - val_mean_absolute_error: 0.8230 - val_mean_squared_error: 1.2748
# Epoch 139/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0230 - mean_absolute_error: 0.0956 - mean_squared_error: 0.0204 - val_loss: 1.3633 - val_mean_absolute_error: 0.8381 - val_mean_squared_error: 1.3607
# Epoch 140/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0225 - mean_absolute_error: 0.1048 - mean_squared_error: 0.0199 - val_loss: 1.3127 - val_mean_absolute_error: 0.8349 - val_mean_squared_error: 1.3100
# Epoch 141/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0185 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0159 - val_loss: 1.3691 - val_mean_absolute_error: 0.8287 - val_mean_squared_error: 1.3664
# Epoch 142/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0267 - mean_absolute_error: 0.1066 - mean_squared_error: 0.0241 - val_loss: 1.3541 - val_mean_absolute_error: 0.8321 - val_mean_squared_error: 1.3514
# Epoch 143/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0540 - mean_absolute_error: 0.1430 - mean_squared_error: 0.0514 - val_loss: 1.8749 - val_mean_absolute_error: 1.0292 - val_mean_squared_error: 1.8723
# Epoch 144/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0324 - mean_absolute_error: 0.1221 - mean_squared_error: 0.0298 - val_loss: 1.3159 - val_mean_absolute_error: 0.8185 - val_mean_squared_error: 1.3133
# Epoch 145/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0255 - mean_absolute_error: 0.0968 - mean_squared_error: 0.0230 - val_loss: 1.3150 - val_mean_absolute_error: 0.8193 - val_mean_squared_error: 1.3124
# Epoch 146/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0254 - mean_absolute_error: 0.1047 - mean_squared_error: 0.0229 - val_loss: 1.2388 - val_mean_absolute_error: 0.8109 - val_mean_squared_error: 1.2363
# Epoch 147/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0228 - mean_absolute_error: 0.0953 - mean_squared_error: 0.0203 - val_loss: 1.3844 - val_mean_absolute_error: 0.8388 - val_mean_squared_error: 1.3819
# Epoch 148/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0183 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0158 - val_loss: 1.4506 - val_mean_absolute_error: 0.8512 - val_mean_squared_error: 1.4481
# Epoch 149/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0226 - mean_absolute_error: 0.1001 - mean_squared_error: 0.0201 - val_loss: 1.2548 - val_mean_absolute_error: 0.8096 - val_mean_squared_error: 1.2523
# Epoch 150/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0166 - mean_absolute_error: 0.0821 - mean_squared_error: 0.0141 - val_loss: 1.3095 - val_mean_absolute_error: 0.8080 - val_mean_squared_error: 1.3069
# Epoch 151/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0236 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0211 - val_loss: 1.2904 - val_mean_absolute_error: 0.8212 - val_mean_squared_error: 1.2879
# Epoch 152/200
# 736/875 [========================>.....] - ETA: 1s - loss: 0.0236 - mean_absolute_error: 0.0999 - mean_squared_error: 0.0210

# %%
hist = pd.DataFrame(history.history)
hist['epoch']= history.epoch
hist.tail()
# Out:
#          val_loss  val_mean_absolute_error  val_mean_squared_error  \
# 195  6.650632e+07              6355.818481            6.650632e+07
# 196  6.275853e+07              6161.197162            6.275853e+07
# 197  5.944006e+07              5997.135702            5.944006e+07
# 198  6.229281e+07              6138.579988            6.229281e+07
# 199  6.106594e+07              6076.085226            6.106594e+07
#
#              loss  mean_absolute_error  mean_squared_error  epoch
# 195  1.702399e+06           881.769361        1.702399e+06    195
# 196  1.711892e+06           930.596856        1.711892e+06    196
# 197  1.580298e+06           893.164042        1.580298e+06    197
# 198  1.912179e+06           979.157146        1.912179e+06    198
# 199  1.614590e+06           912.569914        1.614590e+06    199

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  #plt.ylim([0,5])
  plt.legend()
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  #plt.ylim([0,20])
  plt.legend()
  plt.show()


plot_history(history)

# %%
test_predictions = model.predict(norm_flux).flatten()

plt.scatter(normalize(teff), test_predictions)
plt.xlabel('True Values [Teff]')
plt.ylabel('Predictions [Teff]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

print('test predictions=', test_predictions)
# Out:
# test predictions= [ 6836.807   6837.5747  6836.7603 ... 10159.98   12968.633  12631.623 ]
