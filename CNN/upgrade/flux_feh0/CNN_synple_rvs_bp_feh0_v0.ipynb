# %% [markdown]
# # Train the StarNet Model
#
# This notebook takes you through the steps of how to train a StarNet Model
# - Required Python packages: `numpy h5py keras`
# - Required data files: training_data.h5, mean_and_std.npy
#
# Note: We use tensorflow for the keras backend.

# %%
import numpy as np
import h5py
import random
import keras
from keras.models import Model
from keras.layers import Input, Dense, InputLayer, Flatten, Reshape
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.optimizers import Adam
import tensorflow as tf
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.utils import HDF5Matrix
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc


#Loading the data

#RVSFlux normalized
pathrvs = 'norm_rvsflux.h5'
readrvs = h5py.File(pathrvs, 'r')
print(readrvs.keys())
rvs = readrvs.get('normrvs')
norm_rvsflux = np.array(rvs)
readrvs.close()

type(rvs)
print('shape of rvsflux:', np.shape(norm_rvsflux))
# Out:
# Using TensorFlow backend.
# <KeysViewHDF5 ['normrvs']>
# shape of rvsflux: (415, 1134)

# %%
''''
#BPFlux
pathbp = 'bpflux.h5'
readbp = h5py.File(pathbp, 'r')
#print('total number of wave and flux in the folder:'len(readbp.keys()))
bpflux = readbp.get('bpflux0')
bpflux = np.array(bpflux)


norm_bpflux= []

for ii in range(np.shape(norm_rvsflux)[0]):
    #if ii%50 == 0: #i=i/100
        #print(ii)
        fluxlabel = 'bpflux'+str(ii)
        wavelabel = 'bpwave' +str(ii)
        
        flux = readbp.get(wavelabel)
        wave= readbp.get(fluxlabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        
        mean_flux=np.mean(flux)
        std_flux=np.std(flux)
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
        #print(fluxbp)
        
        norm_bpflux.append((flux-mean_flux)/std_flux)


        
norm_bpflux= np.array(norm_bpflux)

print('shape of norm bpflux:', np.shape(norm_bpflux))
#print('shape of norm bpflux:', print(norm_bpflux))

#print('The shapes of features and labels:', np.shape(norm_flux), np.shape(logteff))


''''
# Out:
# shape of norm bpflux: (415, 53)

# %%
''''

#RPFlux
pathrp = 'rpflux.h5'
readrp = h5py.File(pathrp, 'r')
#print('total number of wave and flux in the folder:'len(readbp.keys()))
rpflux = readrp.get('rpflux0')
rpflux = np.array(rpflux)


norm_rpflux= []

for ii in range(np.shape(norm_rvsflux)[0]):
    if ii%50 == 0: #i=i/100
        print(ii)
        fluxlabel = 'rpflux'+str(ii)
        wavelabel = 'rpwave' +str(ii)
        
        flux = readrp.get(wavelabel)
        wave= readrp.get(fluxlabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        
        mean_flux=np.mean(flux)
        std_flux=np.std(flux)
        
        plt.plot(wave, flux)
        plt.scatter(wave, flux, color='red')
        plt.show()
        
        
        norm_rpflux.append((flux-mean_flux)/std_flux)


        
norm_rpflux= np.array(norm_rpflux)

print('shape of norm_rpflux:', np.shape(norm_rpflux))
print('output of norm_flux:', print(norm_rpflux[0:10]))

#print('The shapes of features and labels:', np.shape(norm_flux), np.shape(logteff))


''''
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# shape of norm_rpflux: (9, 49)
# [[-1.96245603e+00 -1.75556538e+00 -1.70048721e+00 -1.70888449e+00
#   -1.70046503e+00 -1.64891781e+00 -1.54988812e+00 -1.37328613e+00
#   -1.05896816e+00 -5.77901469e-01  1.22436293e-02  5.90159204e-01
#    1.05142748e+00  1.34838768e+00  1.44778884e+00  1.31672239e+00
#    1.00587466e+00  6.65302533e-01  4.23387099e-01  3.10624593e-01
#    2.89723401e-01  2.78824668e-01  1.72047120e-01 -7.07312443e-02
#   -3.84267306e-01 -6.11652341e-01 -5.90134364e-01 -2.57682346e-01
#    3.15951709e-01  9.75086710e-01  1.52906709e+00  1.82859379e+00
#    1.81975230e+00  1.52158220e+00  1.02197842e+00  4.80361274e-01
#    7.46365666e-02 -1.44091032e-01 -2.44942248e-01 -2.98408479e-01
#   -3.42128146e-01 -4.07919076e-01 -4.73915364e-01 -4.41897246e-01
#   -2.46061981e-01  4.16410634e-02  2.72960192e-01  3.72564742e-01
#    3.83961656e-01]
#  [ 1.79237296e+00  1.71799684e+00  1.61964886e+00  1.50898216e+00
#    1.39659040e+00  1.28997494e+00  1.19700791e+00  1.12395873e+00
#    1.07278805e+00  1.04136626e+00  1.02166493e+00  1.00016393e+00
#    9.65681864e-01  9.14714656e-01  8.44643155e-01  7.48678253e-01
#    6.28406873e-01  5.01218944e-01  3.84942131e-01  2.84651403e-01
#    1.97317568e-01  1.17293531e-01  3.57604520e-02 -5.26884675e-02
#   -1.44859515e-01 -2.28584088e-01 -2.90885565e-01 -3.27194635e-01
#   -3.42889435e-01 -3.49191274e-01 -3.61751174e-01 -3.95981375e-01
#   -4.62017476e-01 -5.63878938e-01 -6.94783789e-01 -8.33385337e-01
#   -9.52437421e-01 -1.04167259e+00 -1.10920512e+00 -1.16410680e+00
#   -1.21074512e+00 -1.25439156e+00 -1.29723578e+00 -1.33332327e+00
#   -1.35634176e+00 -1.37055585e+00 -1.38841275e+00 -1.41865846e+00
#   -1.46064723e+00]
#  [ 2.03306795e+00  1.92736544e+00  1.81530703e+00  1.69918813e+00
#    1.58037120e+00  1.46147443e+00  1.34632711e+00  1.23782679e+00
#    1.13669482e+00  1.04314173e+00  9.56608541e-01  8.73425671e-01
#    7.88577757e-01  7.01097825e-01  6.14385890e-01  5.30872127e-01
#    4.50096064e-01  3.70696709e-01  2.90937863e-01  2.07829247e-01
#    1.18951384e-01  2.66320484e-02 -6.74650340e-02 -1.68282573e-01
#   -2.81086202e-01 -3.91991400e-01 -4.70485138e-01 -4.99479126e-01
#   -4.91618980e-01 -4.76507942e-01 -4.80355026e-01 -5.12428789e-01
#   -5.65423638e-01 -6.27465678e-01 -6.90084578e-01 -7.50978085e-01
#   -8.08211614e-01 -8.61559861e-01 -9.15163676e-01 -9.72911660e-01
#   -1.03341973e+00 -1.09164613e+00 -1.14402626e+00 -1.19153772e+00
#   -1.23797437e+00 -1.28745823e+00 -1.34170913e+00 -1.39860184e+00
#   -1.45300335e+00]
#  [ 2.18459653e+00  2.05604239e+00  1.91922244e+00  1.78027028e+00
#    1.64244186e+00  1.50898706e+00  1.38177581e+00  1.26042687e+00
#    1.14356292e+00  1.03121134e+00  9.24291053e-01  8.21857918e-01
#    7.21088735e-01  6.20729163e-01  5.22337338e-01  4.27766515e-01
#    3.37385802e-01  2.50341198e-01  1.64910874e-01  7.85107948e-02
#   -1.04494631e-02 -9.93920399e-02 -1.83025178e-01 -2.57373050e-01
#   -3.21547675e-01 -3.74049212e-01 -4.11687784e-01 -4.35146655e-01
#   -4.50891076e-01 -4.67745970e-01 -4.93000846e-01 -5.29649793e-01
#   -5.75508260e-01 -6.26145511e-01 -6.79363172e-01 -7.34611212e-01
#   -7.86002656e-01 -8.29821869e-01 -8.75610231e-01 -9.33854084e-01
#   -9.99200647e-01 -1.05540236e+00 -1.09574472e+00 -1.12946808e+00
#   -1.16878587e+00 -1.21988484e+00 -1.28202261e+00 -1.34775171e+00
#   -1.40462030e+00]
#  [ 2.30806618e+00  2.15223376e+00  1.99289667e+00  1.83614700e+00
#    1.68412950e+00  1.53799740e+00  1.39784994e+00  1.26311319e+00
#    1.13308393e+00  1.00764942e+00  8.87167231e-01  7.71322539e-01
#    6.58757378e-01  5.48526446e-01  4.41303455e-01  3.38486912e-01
#    2.40627136e-01  1.46994727e-01  5.59316061e-02 -3.49437252e-02
#   -1.26936868e-01 -2.16553857e-01 -2.94641980e-01 -3.50524606e-01
#   -3.79481859e-01 -3.85948215e-01 -3.80311813e-01 -3.74624214e-01
#   -3.77860449e-01 -3.94214564e-01 -4.24165233e-01 -4.66001207e-01
#   -5.16232750e-01 -5.70990703e-01 -6.29125021e-01 -6.90202867e-01
#   -7.47149485e-01 -7.94754918e-01 -8.42799847e-01 -9.03085465e-01
#   -9.70622159e-01 -1.02832998e+00 -1.06966641e+00 -1.10510339e+00
#   -1.14702288e+00 -1.20046783e+00 -1.26385506e+00 -1.32991583e+00
#   -1.38675122e+00]
#  [ 2.27978583e+00  2.12374567e+00  1.96767105e+00  1.81595457e+00
#    1.66967374e+00  1.52899099e+00  1.39360570e+00  1.26321496e+00
#    1.13750640e+00  1.01627619e+00  8.99503311e-01  7.86923103e-01
#    6.77816140e-01  5.71672407e-01  4.68930985e-01  3.70524508e-01
#    2.76833189e-01  1.87308871e-01  1.00686229e-01  1.52192893e-02
#   -7.01850234e-02 -1.53681575e-01 -2.29720622e-01 -2.91201290e-01
#   -3.34234795e-01 -3.61054047e-01 -3.78561623e-01 -3.95173724e-01
#   -4.17023406e-01 -4.46723438e-01 -4.84249890e-01 -5.28275088e-01
#   -5.76694770e-01 -6.27550361e-01 -6.80781452e-01 -7.36159474e-01
#   -7.88251077e-01 -8.32941873e-01 -8.76969823e-01 -9.28792574e-01
#   -9.85239880e-01 -1.03466213e+00 -1.07268596e+00 -1.10655363e+00
#   -1.14457014e+00 -1.19003376e+00 -1.24194246e+00 -1.29546613e+00
#   -1.34246311e+00]
#  [ 2.26028799e+00  2.10612750e+00  1.95237138e+00  1.80320053e+00
#    1.65975177e+00  1.52217775e+00  1.39002743e+00  1.26284154e+00
#    1.14023456e+00  1.02194947e+00  9.07935616e-01  7.98043670e-01
#    6.91790467e-01  5.88743748e-01  4.89137369e-01  3.93663610e-01
#    3.02684774e-01  2.15823745e-01  1.32080380e-01  5.01677184e-02
#   -3.07715037e-02 -1.10083214e-01 -1.85392002e-01 -2.53347467e-01
#   -3.11275308e-01 -3.58505111e-01 -3.96617541e-01 -4.29397609e-01
#   -4.61075195e-01 -4.94825354e-01 -5.32188678e-01 -5.73430501e-01
#   -6.17700119e-01 -6.63806526e-01 -7.12006567e-01 -7.62244640e-01
#   -8.09686055e-01 -8.50604636e-01 -8.90978610e-01 -9.38343953e-01
#   -9.89763025e-01 -1.03465758e+00 -1.06908882e+00 -1.09963444e+00
#   -1.13386119e+00 -1.17482531e+00 -1.22173292e+00 -1.27025305e+00
#   -1.31294410e+00]
#  [ 2.25292314e+00  2.09668896e+00  1.94211248e+00  1.79189717e+00
#    1.64773722e+00  1.51042010e+00  1.37963360e+00  1.25487291e+00
#    1.13554218e+00  1.02075956e+00  9.09872953e-01  8.02697109e-01
#    6.99165732e-01  5.99105072e-01  5.02584918e-01  4.10020466e-01
#    3.21720792e-01  2.37443116e-01  1.56366166e-01  7.74160798e-02
#   -1.68545312e-04 -7.61542382e-02 -1.49212772e-01 -2.17541042e-01
#   -2.79855658e-01 -3.35929171e-01 -3.86427644e-01 -4.32930724e-01
#   -4.77299081e-01 -5.21026247e-01 -5.64903236e-01 -6.09259675e-01
#   -6.53966806e-01 -6.98632188e-01 -7.43659171e-01 -7.89265543e-01
#   -8.32879821e-01 -8.72496427e-01 -9.11559776e-01 -9.54204814e-01
#   -9.98401874e-01 -1.03791022e+00 -1.07065769e+00 -1.10072166e+00
#   -1.13258512e+00 -1.16803330e+00 -1.20658677e+00 -1.24568723e+00
#   -1.28102329e+00]
#  [ 2.26402766e+00  2.10496814e+00  1.94791469e+00  1.79516339e+00
#    1.64843633e+00  1.50889819e+00  1.37654540e+00  1.25085519e+00
#    1.13103464e+00  1.01606403e+00  9.05287197e-01  7.98591128e-01
#    6.95978055e-01  5.97266187e-01  5.02300378e-01  4.11134202e-01
#    3.23854769e-01  2.40279494e-01  1.59849075e-01  8.18742541e-02
#    5.98470096e-03 -6.75575432e-02 -1.38057057e-01 -2.05009469e-01
#   -2.68426642e-01 -3.28614547e-01 -3.85772765e-01 -4.40134009e-01
#   -4.91896563e-01 -5.41244902e-01 -5.88426960e-01 -6.33877904e-01
#   -6.77857340e-01 -7.20447574e-01 -7.62524091e-01 -8.04662157e-01
#   -8.44755017e-01 -8.81217681e-01 -9.17305689e-01 -9.56752841e-01
#   -9.97430918e-01 -1.03336203e+00 -1.06269161e+00 -1.08948267e+00
#   -1.11814624e+00 -1.15038642e+00 -1.18565030e+00 -1.22135059e+00
#   -1.25326555e+00]]
# output of norm_flux: None

# %%
#BPFlux
pathbp = 'bpflux.h5'
readbp = h5py.File(pathbp, 'r')
#print('total number of wave and flux in the folder:'len(readbp.keys()))
bpflux = readbp.get('bpflux0')
bpflux = np.array(bpflux)


norm_bpflux= []

for ii in range(np.shape(norm_rvsflux)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star #',ii)
        fluxlabel = 'bpflux'+str(ii)
        wavelabel = 'bpwave' +str(ii)
        flux = readbp.get(fluxlabel)
        wave= readbp.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_bpflux.append(normflux)


        
norm_bpflux= np.array(norm_bpflux)

print('shape of norm bpflux:', np.shape(norm_bpflux))
#print('shape of norm bpflux:', print(norm_bpflux[0:10]))
# Out:
# shape of norm bpflux: (415, 53)

# %%
#RPFlux
pathrp = 'rpflux.h5'
readrp = h5py.File(pathrp, 'r')
#print('total number of wave and flux in the folder:'len(readbp.keys()))
rpflux = readrp.get('rpflux0')
rpflux = np.array(rpflux)


norm_rpflux= []

for ii in range(np.shape(norm_rvsflux)[0]):
    #if ii%50 == 0: #i=i/100
        #print('star:',ii)
        fluxlabel = 'rpflux'+str(ii)
        wavelabel = 'rpwave' +str(ii)
        
        flux = readrp.get(fluxlabel)
        wave= readrp.get(wavelabel)
    
        
        flux = np.array(flux)
        wave = np.array(wave)
        #print('flux is:', flux)
        
        max_flux=np.max(flux)
        #print('maxflux:', max_flux)
        normflux = flux/ max_flux
        #print('normflux:',normflux)
        
        
        
        #plt.plot(wave, flux)
        #plt.scatter(wave,flux, color='red')
        #plt.show()
    
        
        norm_rpflux.append(normflux)


        
norm_rpflux= np.array(norm_rpflux)

print('shape of norm_rpflux:', np.shape(norm_rpflux))
#print('output of norm_flux:', print(norm_rpflux[0:10]))

#print('The shapes of features and labels:', np.shape(norm_flux), np.shape(logteff))
# Out:
# shape of norm_rpflux: (415, 49)

# %%
#LogTeff
modparam = 'modparam_feh0.h5' #model parameters includes log g and teff
readfile = h5py.File(modparam, 'r')
print(readfile.keys())
logteff = readfile.get('logteff')
logteff = np.array(logteff)
readfile.close()
# Out:
# <KeysViewHDF5 ['logg', 'logteff']>

# %%
#features
num_tot = len(logteff)
print('total number of input stars =', num_tot)
plim = 0.8
ran_frac = np.random.uniform(0,1,num_tot)
#print('ranfrac=' , ran_frac)




#Input flux data of RVS, BP, RP
x_RVStrain = norm_rvsflux[ran_frac < plim, :]
print('number of RVS training data=', len(x_RVStrain[:,0]))
x_RVScv = norm_rvsflux[ran_frac >= plim, :] #test set we left for the application

x_BPtrain = norm_bpflux[ran_frac < plim, :]
print('number of BP training data=', len(x_BPtrain[:,0]))
x_BPcv = norm_bpflux[ran_frac >= plim, :]

x_RPtrain =norm_rpflux[ran_frac < plim, :]
print('number of RP training data=', len(x_RPtrain[:,0]))
x_RPcv = norm_rpflux[ran_frac >= plim, :]


#print('x_BPtrain', x_BPtrain)

#x_train_combined = np.vstack (x_RVStrain[0,:],x_RPtrain[0,:]) 

#output label which is the logteff
y_train = logteff[ran_frac< plim]
y_cv = logteff[ran_frac >= plim] #test set


print('The size of CVS for the input flux data')
print('RVS cvs=', np.shape(x_RVScv))
print('BP cvs=', np.shape(x_BPcv))
print('RP cvs=', np.shape(x_RPcv))

print('the size of output label=', np.shape(y_cv) )

id = np.linspace(0, len(x_RVStrain[:, 0])-1, len(x_RVStrain[:, 0]))
plt.plot(id, y_train)
plt.show()
# Out:
# total number of input stars = 415
# number of RVS training data= 326
# number of BP training data= 326
# number of RP training data= 326
# The size of CVS for the input flux data
# RVS cvs= (89, 1134)
# BP cvs= (89, 53)
# RP cvs= (89, 49)
# the size of output label= (89,)

# %% [markdown]
# ** Normalization **
#
# Write a function to normalize the output labels. Each label will be normalized to have approximately have a mean of zero and unit variance.
#
# NOTE: This is necessary to put output labels on a similar scale in order for the model to train properly, this process is reversed in the test stage to give the output labels their proper units

# %%
mean_labels=np.mean(logteff)
std_labels=np.std(logteff)
print('mean and std teff=', mean_labels, std_labels)
def normalize(labels):
    # Normalize labels
    return (labels-mean_labels) / std_labels
# Out:
# mean and std teff= 3.9478135884985908 0.23697442871023666

# %%
#normalize the y labels 
#print('y train before norm=', y_train )
y_train= normalize(y_train)
y_cv= normalize(y_cv)
#print('y train after norm=', y_train )

# %% [markdown]
# **Build the StarNet model architecture**
#
# The StarNet architecture is built with:
# - input layer
# - 2 convolutional layers
# - 1 maxpooling layer followed by flattening for the fully connected layer
# - 2 fully connected layers
# - output layer
#
# First, let's define some model variables.

# %%
# activation function used following every layer except for the output layers
activation = 'relu'

# model weight initializer
initializer = 'he_normal'

# number of filters used in the convolutional layers
#num_filters = [4,16]
num_filters = [8,32]
#num_filters = [8,16]

# length of the filters in the convolutional layers
#filter_length = 8
#filter_length = 16
filter_length = 8

# length of the maxpooling window 
pool_length = 4

# number of nodes in each of the hidden fully connected layers
num_hidden = [256,128]
#num_hidden = [24,12]

# number of spectra fed into model at once during training
batch_size = 64

# maximum number of interations for model training
#max_epochs = 200
#max_epochs = 100
#max_epochs = 150 
#max_epochs = 350
#max_epochs = 225
#max_epochs = 180
#max_epochs = 450
#max_epochs = 300
max_epochs = 150


# initial learning rate for optimization algorithm
lr = 0.000003 #handled by Adam
    
# exponential decay rate for the 1st moment estimates for optimization algorithm
beta_1 = 0.9

# exponential decay rate for the 2nd moment estimates for optimization algorithm
beta_2 = 0.999

# a small constant for numerical stability for optimization algorithm
optimizer_epsilon = 1e-08

# %%
num_RVSfluxes=len(x_RVStrain[0,:]) 
print('number of RVS fluxes=', num_RVSfluxes)

num_BPfluxes=len(x_BPtrain[0,:]) 
print('number of BP fluxes=', num_BPfluxes)

num_RPfluxes=len(x_RPtrain[0,:]) 
print('number of RP fluxes=', num_RPfluxes)

num_labels= 1
print('number of training teff=', num_labels)

#ilam = np.linspace(0, num_fluxes-1, num_fluxes)
#plt.plot(ilam, x_train[329, :])
#plt.plot()

#iy = np.linspace(0, len(y_train)-1, len(y_train))
#plt.plot(iy, y_train)
#plt.plot()
# Out:
# number of RVS fluxes= 1134
# number of BP fluxes= 53
# number of RP fluxes= 49
# number of training teff= 1

# %%
# Input RVS spectra
input_RVSspec = Input(shape=(num_RVSfluxes,), name='rvs_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for CNN layers
cur_rvs = Reshape((num_RVSfluxes, 1))(input_RVSspec)

# CNN layers
cur_rvs = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_rvs) #first CNN layer
cur_rvs = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_rvs) #2nd CNN layer

# Max pooling layer
cur_rvs = MaxPooling1D(pool_size=pool_length)(cur_rvs)

# Flatten the current input for the fully-connected layers
cur_rvs = Flatten()(cur_rvs)

# Fully-connected layers
cur_rvs = Dense(units=num_hidden[0], kernel_initializer=initializer, 
               activation=activation)(cur_rvs)
cur_rvs = Dense(units=num_hidden[1], kernel_initializer=initializer, 
               activation=activation)(cur_rvs)


# Output nodes
output_RVSlabel = Dense(units=num_labels, activation="linear", 
                     input_dim=num_hidden[1], name='rvs_output_y')(cur_rvs)
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Input BP spectra
input_BPspec = Input(shape=(num_BPfluxes,), name='bp_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for CNN layers
cur_bp = Reshape((num_BPfluxes, 1))(input_BPspec)

# CNN layers
cur_bp = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_bp) #first CNN layer
cur_bp = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_bp) #2nd CNN layer

# Max pooling layer
cur_bp = MaxPooling1D(pool_size=pool_length)(cur_bp)

# Flatten the current input for the fully-connected layers
cur_bp = Flatten()(cur_bp)

# Fully-connected layers
cur_bp = Dense(units=num_hidden[0], kernel_initializer=initializer, 
               activation=activation)(cur_bp)
cur_bp = Dense(units=num_hidden[1], kernel_initializer=initializer, 
               activation=activation)(cur_bp)



# Output nodes
output_BPlabel = Dense(units=num_labels, activation="linear", 
                     input_dim=num_hidden[1], name='bp_output_y')(cur_bp)

# %%
# Input RP spectra
input_RPspec = Input(shape=(num_RPfluxes,), name='rp_input_x' ) #removed name='starnet_input_x'

# Reshape spectra for CNN layers
cur_rp = Reshape((num_RPfluxes, 1))(input_RPspec)

# CNN layers
cur_rp = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=num_filters[0], kernel_size=filter_length)(cur_rp) #first CNN layer
cur_rp = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=num_filters[1], kernel_size=filter_length)(cur_rp) #2nd CNN layer

# Max pooling layer
cur_rp = MaxPooling1D(pool_size=pool_length)(cur_rp)

# Flatten the current input for the fully-connected layers
cur_rp = Flatten()(cur_rp)

# Fully-connected layers
cur_rp = Dense(units=num_hidden[0], kernel_initializer=initializer, 
               activation=activation)(cur_rp)
cur_rp = Dense(units=num_hidden[1], kernel_initializer=initializer, 
               activation=activation)(cur_rp)



# Output nodes
output_RPlabel = Dense(units=num_labels, activation="linear", 
                     input_dim=num_hidden[1], name='rp_output_y')(cur_rp)


print(output_RPlabel)
# Out:
# Tensor("rp_output_y/BiasAdd:0", shape=(?, 1), dtype=float32)

# %%
#combined = np.concatenate([output_RVSlabel, output_BPlabel, output_RPlabel])
# apply a FC layer and then a regression prediction on the
# combined outputs
#z = Dense(2, activation="relu")(combined)
#z = Dense(1, activation="linear")(z)


model = Model(inputs=[input_RVSspec, input_BPspec, input_RPspec], outputs = [output_RVSlabel, output_BPlabel, output_RPlabel], name='StarNet')

print(model)
# Out:
# <keras.engine.training.Model object at 0xb347f97b8>

# %% [markdown]
# **More model techniques**
# * The `Adam` optimizer is the gradient descent algorithm used for minimizing the loss function
# * `EarlyStopping` uses the cross-validation set to test the model following every iteration and stops the training if the cv loss does not decrease by `min_delta` after `patience` iterations
# * `ReduceLROnPlateau` is a form of learning rate decay where the learning rate is decreased by a factor of `factor` if the training loss does not decrease by `epsilon` after `patience` iterations unless the learning rate has reached `min_lr`

# %%
# Default loss function parameters
early_stopping_min_delta = 0.0007
early_stopping_patience = 4
reduce_lr_factor = 0.5
reuce_lr_epsilon = 0.0000009
reduce_lr_patience = 2
reduce_lr_min = 0.00008

# loss function to minimize
loss_function = 'mean_squared_error'

# compute mean absolute deviation
metrics = ['mae', 'mse']
#metrics = ['mae']

# %%
#optimizer = Adam(lr=lr, beta_1=beta_1, beta_2=beta_2, epsilon=optimizer_epsilon, decay=0.0)
optimizer = Adam(lr=0.005 )

early_stopping = EarlyStopping(monitor='val_loss', min_delta=early_stopping_min_delta, 
                                       patience=early_stopping_patience, verbose=2, mode='min')

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, epsilon=reuce_lr_epsilon, 
                                  patience=reduce_lr_patience, min_lr=reduce_lr_min, mode='min', verbose=2)
# Out:
# /anaconda3/lib/python3.6/site-packages/keras/callbacks.py:1065: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '

# %% [markdown]
# **Compile model**

# %%
model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# rvs_input_x (InputLayer)        (None, 1134)         0
# __________________________________________________________________________________________________
# bp_input_x (InputLayer)         (None, 53)           0
# __________________________________________________________________________________________________
# rp_input_x (InputLayer)         (None, 49)           0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1134, 1)      0           rvs_input_x[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 53, 1)        0           bp_input_x[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 49, 1)        0           rp_input_x[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 1134, 8)      72          reshape_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 53, 8)        72          reshape_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 49, 8)        72          reshape_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 1134, 32)     2080        conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 53, 32)       2080        conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 49, 32)       2080        conv1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 283, 32)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 13, 32)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 12, 32)       0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 9056)         0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 416)          0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 384)          0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          2318592     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          106752      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          98560       flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          32896       dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          32896       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          32896       dense_5[0][0]
# __________________________________________________________________________________________________
# rvs_output_y (Dense)            (None, 1)            129         dense_2[0][0]
# __________________________________________________________________________________________________
# bp_output_y (Dense)             (None, 1)            129         dense_4[0][0]
# __________________________________________________________________________________________________
# rp_output_y (Dense)             (None, 1)            129         dense_6[0][0]
# ==================================================================================================
# Total params: 2,629,435
# Trainable params: 2,629,435
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Train model**

# %%
#history = model.fit(x_train, y_train, validation_data=(x_cv, y_cv),
          #epochs=max_epochs, verbose=1, shuffle='batch',
         #callbacks=[early_stopping, reduce_lr])

history = model.fit(x_train, y_train, validation_data=(x_cv, y_cv),
          epochs=max_epochs, verbose=1, shuffle='batch')
# Out:
# Train on 323 samples, validate on 92 samples
# Epoch 1/150
# 323/323 [==============================] - 3s 10ms/step - loss: 589.3106 - mean_absolute_error: 10.9070 - mean_squared_error: 589.3106 - val_loss: 2.1255 - val_mean_absolute_error: 1.2398 - val_mean_squared_error: 2.1255
# Epoch 2/150
# 323/323 [==============================] - 0s 1ms/step - loss: 9.0941 - mean_absolute_error: 2.4802 - mean_squared_error: 9.0941 - val_loss: 7.7128 - val_mean_absolute_error: 2.6191 - val_mean_squared_error: 7.7128
# Epoch 3/150
# 323/323 [==============================] - 0s 1ms/step - loss: 3.2104 - mean_absolute_error: 1.3776 - mean_squared_error: 3.2104 - val_loss: 0.8417 - val_mean_absolute_error: 0.7472 - val_mean_squared_error: 0.8417
# Epoch 4/150
# 323/323 [==============================] - 0s 1ms/step - loss: 1.2159 - mean_absolute_error: 0.9417 - mean_squared_error: 1.2159 - val_loss: 0.8410 - val_mean_absolute_error: 0.7512 - val_mean_squared_error: 0.8410
# Epoch 5/150
# 323/323 [==============================] - 0s 1ms/step - loss: 1.8080 - mean_absolute_error: 0.9705 - mean_squared_error: 1.8080 - val_loss: 1.3937 - val_mean_absolute_error: 1.0002 - val_mean_squared_error: 1.3937
# Epoch 6/150
# 323/323 [==============================] - 0s 1ms/step - loss: 1.7230 - mean_absolute_error: 1.0612 - mean_squared_error: 1.7230 - val_loss: 3.6359 - val_mean_absolute_error: 1.6630 - val_mean_squared_error: 3.6359
# Epoch 7/150
# 323/323 [==============================] - 0s 995us/step - loss: 2.5890 - mean_absolute_error: 1.3440 - mean_squared_error: 2.5890 - val_loss: 1.0336 - val_mean_absolute_error: 0.8270 - val_mean_squared_error: 1.0336
# Epoch 8/150
# 323/323 [==============================] - 0s 1ms/step - loss: 1.2869 - mean_absolute_error: 0.9238 - mean_squared_error: 1.2869 - val_loss: 0.8597 - val_mean_absolute_error: 0.7572 - val_mean_squared_error: 0.8597
# Epoch 9/150
# 323/323 [==============================] - 0s 1ms/step - loss: 1.1709 - mean_absolute_error: 0.9005 - mean_squared_error: 1.1709 - val_loss: 0.8905 - val_mean_absolute_error: 0.7741 - val_mean_squared_error: 0.8905
# Epoch 10/150
# 323/323 [==============================] - 0s 1ms/step - loss: 1.0898 - mean_absolute_error: 0.8841 - mean_squared_error: 1.0898 - val_loss: 0.8972 - val_mean_absolute_error: 0.7758 - val_mean_squared_error: 0.8972
# Epoch 11/150
# 323/323 [==============================] - 0s 1ms/step - loss: 1.0066 - mean_absolute_error: 0.8354 - mean_squared_error: 1.0066 - val_loss: 0.7270 - val_mean_absolute_error: 0.6861 - val_mean_squared_error: 0.7270
# Epoch 12/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.6690 - mean_absolute_error: 0.6225 - mean_squared_error: 0.6690 - val_loss: 0.1355 - val_mean_absolute_error: 0.2244 - val_mean_squared_error: 0.1355
# Epoch 13/150
# 323/323 [==============================] - 0s 990us/step - loss: 0.3218 - mean_absolute_error: 0.4401 - mean_squared_error: 0.3218 - val_loss: 0.2128 - val_mean_absolute_error: 0.3690 - val_mean_squared_error: 0.2128
# Epoch 14/150
# 323/323 [==============================] - 0s 964us/step - loss: 0.3113 - mean_absolute_error: 0.4550 - mean_squared_error: 0.3113 - val_loss: 0.2587 - val_mean_absolute_error: 0.4429 - val_mean_squared_error: 0.2587
# Epoch 15/150
# 323/323 [==============================] - 0s 991us/step - loss: 0.3603 - mean_absolute_error: 0.5086 - mean_squared_error: 0.3603 - val_loss: 0.2717 - val_mean_absolute_error: 0.4397 - val_mean_squared_error: 0.2717
# Epoch 16/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1618 - mean_absolute_error: 0.3234 - mean_squared_error: 0.1618 - val_loss: 0.2428 - val_mean_absolute_error: 0.4097 - val_mean_squared_error: 0.2428
# Epoch 17/150
# 323/323 [==============================] - 0s 980us/step - loss: 0.2217 - mean_absolute_error: 0.4041 - mean_squared_error: 0.2217 - val_loss: 0.0918 - val_mean_absolute_error: 0.2391 - val_mean_squared_error: 0.0918
# Epoch 18/150
# 323/323 [==============================] - 0s 979us/step - loss: 0.0963 - mean_absolute_error: 0.2468 - mean_squared_error: 0.0963 - val_loss: 0.1884 - val_mean_absolute_error: 0.3605 - val_mean_squared_error: 0.1884
# Epoch 19/150
# 323/323 [==============================] - 0s 973us/step - loss: 0.3620 - mean_absolute_error: 0.5023 - mean_squared_error: 0.3620 - val_loss: 0.1727 - val_mean_absolute_error: 0.3439 - val_mean_squared_error: 0.1727
# Epoch 20/150
# 323/323 [==============================] - 0s 973us/step - loss: 0.2371 - mean_absolute_error: 0.4252 - mean_squared_error: 0.2371 - val_loss: 0.1516 - val_mean_absolute_error: 0.3081 - val_mean_squared_error: 0.1516
# Epoch 21/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1660 - mean_absolute_error: 0.3327 - mean_squared_error: 0.1660 - val_loss: 0.1519 - val_mean_absolute_error: 0.3368 - val_mean_squared_error: 0.1519
# Epoch 22/150
# 323/323 [==============================] - 0s 994us/step - loss: 0.1307 - mean_absolute_error: 0.2987 - mean_squared_error: 0.1307 - val_loss: 0.1419 - val_mean_absolute_error: 0.2821 - val_mean_squared_error: 0.1419
# Epoch 23/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1474 - mean_absolute_error: 0.2971 - mean_squared_error: 0.1474 - val_loss: 0.0892 - val_mean_absolute_error: 0.2637 - val_mean_squared_error: 0.0892
# Epoch 24/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0638 - mean_absolute_error: 0.2110 - mean_squared_error: 0.0638 - val_loss: 0.1582 - val_mean_absolute_error: 0.3387 - val_mean_squared_error: 0.1582
# Epoch 25/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0870 - mean_absolute_error: 0.2295 - mean_squared_error: 0.0870 - val_loss: 0.0790 - val_mean_absolute_error: 0.2330 - val_mean_squared_error: 0.0790
# Epoch 26/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0825 - mean_absolute_error: 0.2135 - mean_squared_error: 0.0825 - val_loss: 0.0734 - val_mean_absolute_error: 0.2259 - val_mean_squared_error: 0.0734
# Epoch 27/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0716 - mean_absolute_error: 0.2118 - mean_squared_error: 0.0716 - val_loss: 0.0396 - val_mean_absolute_error: 0.1610 - val_mean_squared_error: 0.0396
# Epoch 28/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0463 - mean_absolute_error: 0.1678 - mean_squared_error: 0.0463 - val_loss: 0.0358 - val_mean_absolute_error: 0.1365 - val_mean_squared_error: 0.0358
# Epoch 29/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0245 - mean_absolute_error: 0.1212 - mean_squared_error: 0.0245 - val_loss: 0.0259 - val_mean_absolute_error: 0.1213 - val_mean_squared_error: 0.0259
# Epoch 30/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0425 - mean_absolute_error: 0.1573 - mean_squared_error: 0.0425 - val_loss: 0.0441 - val_mean_absolute_error: 0.1402 - val_mean_squared_error: 0.0441
# Epoch 31/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0614 - mean_absolute_error: 0.2099 - mean_squared_error: 0.0614 - val_loss: 0.1129 - val_mean_absolute_error: 0.2649 - val_mean_squared_error: 0.1129
# Epoch 32/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1913 - mean_absolute_error: 0.3744 - mean_squared_error: 0.1913 - val_loss: 0.1148 - val_mean_absolute_error: 0.2974 - val_mean_squared_error: 0.1148
# Epoch 33/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1553 - mean_absolute_error: 0.3184 - mean_squared_error: 0.1553 - val_loss: 0.1446 - val_mean_absolute_error: 0.3052 - val_mean_squared_error: 0.1446
# Epoch 34/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1890 - mean_absolute_error: 0.3589 - mean_squared_error: 0.1890 - val_loss: 0.0684 - val_mean_absolute_error: 0.1923 - val_mean_squared_error: 0.0684
# Epoch 35/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1009 - mean_absolute_error: 0.2616 - mean_squared_error: 0.1009 - val_loss: 0.0510 - val_mean_absolute_error: 0.1788 - val_mean_squared_error: 0.0510
# Epoch 36/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0443 - mean_absolute_error: 0.1525 - mean_squared_error: 0.0443 - val_loss: 0.0584 - val_mean_absolute_error: 0.1736 - val_mean_squared_error: 0.0584
# Epoch 37/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1551 - mean_absolute_error: 0.2905 - mean_squared_error: 0.1551 - val_loss: 0.6093 - val_mean_absolute_error: 0.7408 - val_mean_squared_error: 0.6093
# Epoch 38/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1750 - mean_absolute_error: 0.3311 - mean_squared_error: 0.1750 - val_loss: 0.0643 - val_mean_absolute_error: 0.1869 - val_mean_squared_error: 0.0643
# Epoch 39/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1004 - mean_absolute_error: 0.2573 - mean_squared_error: 0.1004 - val_loss: 0.0816 - val_mean_absolute_error: 0.2632 - val_mean_squared_error: 0.0816
# Epoch 40/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0968 - mean_absolute_error: 0.2342 - mean_squared_error: 0.0968 - val_loss: 0.0459 - val_mean_absolute_error: 0.1476 - val_mean_squared_error: 0.0459
# Epoch 41/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0501 - mean_absolute_error: 0.1531 - mean_squared_error: 0.0501 - val_loss: 0.0993 - val_mean_absolute_error: 0.2769 - val_mean_squared_error: 0.0993
# Epoch 42/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1106 - mean_absolute_error: 0.2709 - mean_squared_error: 0.1106 - val_loss: 0.0428 - val_mean_absolute_error: 0.1519 - val_mean_squared_error: 0.0428
# Epoch 43/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0380 - mean_absolute_error: 0.1626 - mean_squared_error: 0.0380 - val_loss: 0.0503 - val_mean_absolute_error: 0.1841 - val_mean_squared_error: 0.0503
# Epoch 44/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.5252 - mean_absolute_error: 0.6147 - mean_squared_error: 0.5252 - val_loss: 0.4022 - val_mean_absolute_error: 0.5683 - val_mean_squared_error: 0.4022
# Epoch 45/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.3664 - mean_absolute_error: 0.5023 - mean_squared_error: 0.3664 - val_loss: 0.2077 - val_mean_absolute_error: 0.3071 - val_mean_squared_error: 0.2077
# Epoch 46/150
# 323/323 [==============================] - 0s 1000us/step - loss: 0.2709 - mean_absolute_error: 0.4369 - mean_squared_error: 0.2709 - val_loss: 0.2193 - val_mean_absolute_error: 0.3958 - val_mean_squared_error: 0.2193
# Epoch 47/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.2392 - mean_absolute_error: 0.4246 - mean_squared_error: 0.2392 - val_loss: 0.1029 - val_mean_absolute_error: 0.2611 - val_mean_squared_error: 0.1029
# Epoch 48/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0886 - mean_absolute_error: 0.2238 - mean_squared_error: 0.0886 - val_loss: 0.0516 - val_mean_absolute_error: 0.1903 - val_mean_squared_error: 0.0516
# Epoch 49/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0671 - mean_absolute_error: 0.2212 - mean_squared_error: 0.0671 - val_loss: 0.0403 - val_mean_absolute_error: 0.1541 - val_mean_squared_error: 0.0403
# Epoch 50/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1181 - mean_absolute_error: 0.2670 - mean_squared_error: 0.1181 - val_loss: 0.1390 - val_mean_absolute_error: 0.2978 - val_mean_squared_error: 0.1390
# Epoch 51/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1273 - mean_absolute_error: 0.2930 - mean_squared_error: 0.1273 - val_loss: 0.0998 - val_mean_absolute_error: 0.2547 - val_mean_squared_error: 0.0998
# Epoch 52/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0868 - mean_absolute_error: 0.2361 - mean_squared_error: 0.0868 - val_loss: 0.0696 - val_mean_absolute_error: 0.1821 - val_mean_squared_error: 0.0696
# Epoch 53/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0637 - mean_absolute_error: 0.1731 - mean_squared_error: 0.0637 - val_loss: 0.0656 - val_mean_absolute_error: 0.2075 - val_mean_squared_error: 0.0656
# Epoch 54/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0640 - mean_absolute_error: 0.2089 - mean_squared_error: 0.0640 - val_loss: 0.2688 - val_mean_absolute_error: 0.4219 - val_mean_squared_error: 0.2688
# Epoch 55/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1885 - mean_absolute_error: 0.3403 - mean_squared_error: 0.1885 - val_loss: 0.1058 - val_mean_absolute_error: 0.2436 - val_mean_squared_error: 0.1058
# Epoch 56/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1112 - mean_absolute_error: 0.2576 - mean_squared_error: 0.1112 - val_loss: 0.1312 - val_mean_absolute_error: 0.3098 - val_mean_squared_error: 0.1312
# Epoch 57/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.1218 - mean_absolute_error: 0.2978 - mean_squared_error: 0.1218 - val_loss: 0.0958 - val_mean_absolute_error: 0.2670 - val_mean_squared_error: 0.0958
# Epoch 58/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0911 - mean_absolute_error: 0.2392 - mean_squared_error: 0.0911 - val_loss: 0.0636 - val_mean_absolute_error: 0.1859 - val_mean_squared_error: 0.0636
# Epoch 59/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0646 - mean_absolute_error: 0.2039 - mean_squared_error: 0.0646 - val_loss: 0.0517 - val_mean_absolute_error: 0.1953 - val_mean_squared_error: 0.0517
# Epoch 60/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0495 - mean_absolute_error: 0.1740 - mean_squared_error: 0.0495 - val_loss: 0.0349 - val_mean_absolute_error: 0.1484 - val_mean_squared_error: 0.0349
# Epoch 61/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0470 - mean_absolute_error: 0.1774 - mean_squared_error: 0.0470 - val_loss: 0.0607 - val_mean_absolute_error: 0.2124 - val_mean_squared_error: 0.0607
# Epoch 62/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0282 - mean_absolute_error: 0.1345 - mean_squared_error: 0.0282 - val_loss: 0.0237 - val_mean_absolute_error: 0.1211 - val_mean_squared_error: 0.0237
# Epoch 63/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0197 - mean_absolute_error: 0.1128 - mean_squared_error: 0.0197 - val_loss: 0.0219 - val_mean_absolute_error: 0.1109 - val_mean_squared_error: 0.0219
# Epoch 64/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0163 - mean_absolute_error: 0.1018 - mean_squared_error: 0.0163 - val_loss: 0.0172 - val_mean_absolute_error: 0.1007 - val_mean_squared_error: 0.0172
# Epoch 65/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0150 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0150 - val_loss: 0.0236 - val_mean_absolute_error: 0.1299 - val_mean_squared_error: 0.0236
# Epoch 66/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0166 - mean_absolute_error: 0.0964 - mean_squared_error: 0.0166 - val_loss: 0.0156 - val_mean_absolute_error: 0.0986 - val_mean_squared_error: 0.0156
# Epoch 67/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0100 - mean_absolute_error: 0.0719 - mean_squared_error: 0.0100 - val_loss: 0.0151 - val_mean_absolute_error: 0.0932 - val_mean_squared_error: 0.0151
# Epoch 68/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0086 - mean_absolute_error: 0.0682 - mean_squared_error: 0.0086 - val_loss: 0.0132 - val_mean_absolute_error: 0.0848 - val_mean_squared_error: 0.0132
# Epoch 69/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0097 - mean_absolute_error: 0.0696 - mean_squared_error: 0.0097 - val_loss: 0.0137 - val_mean_absolute_error: 0.0837 - val_mean_squared_error: 0.0137
# Epoch 70/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_absolute_error: 0.0595 - mean_squared_error: 0.0074 - val_loss: 0.0119 - val_mean_absolute_error: 0.0798 - val_mean_squared_error: 0.0119
# Epoch 71/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0080 - mean_absolute_error: 0.0665 - mean_squared_error: 0.0080 - val_loss: 0.0122 - val_mean_absolute_error: 0.0807 - val_mean_squared_error: 0.0122
# Epoch 72/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0072 - mean_absolute_error: 0.0602 - mean_squared_error: 0.0072 - val_loss: 0.0115 - val_mean_absolute_error: 0.0796 - val_mean_squared_error: 0.0115
# Epoch 73/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0071 - mean_absolute_error: 0.0610 - mean_squared_error: 0.0071 - val_loss: 0.0124 - val_mean_absolute_error: 0.0801 - val_mean_squared_error: 0.0124
# Epoch 74/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0078 - mean_absolute_error: 0.0619 - mean_squared_error: 0.0078 - val_loss: 0.0114 - val_mean_absolute_error: 0.0784 - val_mean_squared_error: 0.0114
# Epoch 75/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0068 - mean_absolute_error: 0.0590 - mean_squared_error: 0.0068 - val_loss: 0.0124 - val_mean_absolute_error: 0.0805 - val_mean_squared_error: 0.0124
# Epoch 76/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0066 - mean_absolute_error: 0.0566 - mean_squared_error: 0.0066 - val_loss: 0.0109 - val_mean_absolute_error: 0.0755 - val_mean_squared_error: 0.0109
# Epoch 77/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0063 - mean_absolute_error: 0.0567 - mean_squared_error: 0.0063 - val_loss: 0.0111 - val_mean_absolute_error: 0.0761 - val_mean_squared_error: 0.0111
# Epoch 78/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0072 - mean_absolute_error: 0.0619 - mean_squared_error: 0.0072 - val_loss: 0.0125 - val_mean_absolute_error: 0.0785 - val_mean_squared_error: 0.0125
# Epoch 79/150
# 323/323 [==============================] - 0s 999us/step - loss: 0.0063 - mean_absolute_error: 0.0572 - mean_squared_error: 0.0063 - val_loss: 0.0104 - val_mean_absolute_error: 0.0751 - val_mean_squared_error: 0.0104
# Epoch 80/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0549 - mean_squared_error: 0.0060 - val_loss: 0.0116 - val_mean_absolute_error: 0.0748 - val_mean_squared_error: 0.0116
# Epoch 81/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0063 - mean_absolute_error: 0.0564 - mean_squared_error: 0.0063 - val_loss: 0.0112 - val_mean_absolute_error: 0.0754 - val_mean_squared_error: 0.0112
# Epoch 82/150
# 323/323 [==============================] - 0s 998us/step - loss: 0.0067 - mean_absolute_error: 0.0615 - mean_squared_error: 0.0067 - val_loss: 0.0101 - val_mean_absolute_error: 0.0727 - val_mean_squared_error: 0.0101
# Epoch 83/150
# 323/323 [==============================] - 0s 991us/step - loss: 0.0061 - mean_absolute_error: 0.0564 - mean_squared_error: 0.0061 - val_loss: 0.0129 - val_mean_absolute_error: 0.0837 - val_mean_squared_error: 0.0129
# Epoch 84/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0072 - mean_absolute_error: 0.0672 - mean_squared_error: 0.0072 - val_loss: 0.0122 - val_mean_absolute_error: 0.0844 - val_mean_squared_error: 0.0122
# Epoch 85/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0057 - mean_absolute_error: 0.0556 - mean_squared_error: 0.0057 - val_loss: 0.0101 - val_mean_absolute_error: 0.0721 - val_mean_squared_error: 0.0101
# Epoch 86/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0053 - mean_absolute_error: 0.0517 - mean_squared_error: 0.0053 - val_loss: 0.0119 - val_mean_absolute_error: 0.0776 - val_mean_squared_error: 0.0119
# Epoch 87/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0565 - mean_squared_error: 0.0060 - val_loss: 0.0115 - val_mean_absolute_error: 0.0763 - val_mean_squared_error: 0.0115
# Epoch 88/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0054 - mean_absolute_error: 0.0530 - mean_squared_error: 0.0054 - val_loss: 0.0106 - val_mean_absolute_error: 0.0736 - val_mean_squared_error: 0.0106
# Epoch 89/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0055 - mean_absolute_error: 0.0545 - mean_squared_error: 0.0055 - val_loss: 0.0096 - val_mean_absolute_error: 0.0695 - val_mean_squared_error: 0.0096
# Epoch 90/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0055 - mean_absolute_error: 0.0506 - mean_squared_error: 0.0055 - val_loss: 0.0104 - val_mean_absolute_error: 0.0696 - val_mean_squared_error: 0.0104
# Epoch 91/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0053 - mean_absolute_error: 0.0533 - mean_squared_error: 0.0053 - val_loss: 0.0095 - val_mean_absolute_error: 0.0706 - val_mean_squared_error: 0.0095
# Epoch 92/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0054 - mean_absolute_error: 0.0565 - mean_squared_error: 0.0054 - val_loss: 0.0119 - val_mean_absolute_error: 0.0763 - val_mean_squared_error: 0.0119
# Epoch 93/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0054 - mean_absolute_error: 0.0534 - mean_squared_error: 0.0054 - val_loss: 0.0096 - val_mean_absolute_error: 0.0726 - val_mean_squared_error: 0.0096
# Epoch 94/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0052 - mean_absolute_error: 0.0540 - mean_squared_error: 0.0052 - val_loss: 0.0105 - val_mean_absolute_error: 0.0683 - val_mean_squared_error: 0.0105
# Epoch 95/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0047 - mean_absolute_error: 0.0475 - mean_squared_error: 0.0047 - val_loss: 0.0092 - val_mean_absolute_error: 0.0674 - val_mean_squared_error: 0.0092
# Epoch 96/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0047 - mean_absolute_error: 0.0480 - mean_squared_error: 0.0047 - val_loss: 0.0116 - val_mean_absolute_error: 0.0764 - val_mean_squared_error: 0.0116
# Epoch 97/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0049 - mean_absolute_error: 0.0517 - mean_squared_error: 0.0049 - val_loss: 0.0096 - val_mean_absolute_error: 0.0682 - val_mean_squared_error: 0.0096
# Epoch 98/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0052 - mean_absolute_error: 0.0506 - mean_squared_error: 0.0052 - val_loss: 0.0095 - val_mean_absolute_error: 0.0677 - val_mean_squared_error: 0.0095
# Epoch 99/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0052 - mean_absolute_error: 0.0517 - mean_squared_error: 0.0052 - val_loss: 0.0092 - val_mean_absolute_error: 0.0681 - val_mean_squared_error: 0.0092
# Epoch 100/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0044 - mean_absolute_error: 0.0492 - mean_squared_error: 0.0044 - val_loss: 0.0110 - val_mean_absolute_error: 0.0748 - val_mean_squared_error: 0.0110
# Epoch 101/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0057 - mean_absolute_error: 0.0556 - mean_squared_error: 0.0057 - val_loss: 0.0090 - val_mean_absolute_error: 0.0662 - val_mean_squared_error: 0.0090
# Epoch 102/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0058 - mean_absolute_error: 0.0600 - mean_squared_error: 0.0058 - val_loss: 0.0140 - val_mean_absolute_error: 0.0850 - val_mean_squared_error: 0.0140
# Epoch 103/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0067 - mean_absolute_error: 0.0607 - mean_squared_error: 0.0067 - val_loss: 0.0094 - val_mean_absolute_error: 0.0676 - val_mean_squared_error: 0.0094
# Epoch 104/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0050 - mean_absolute_error: 0.0500 - mean_squared_error: 0.0050 - val_loss: 0.0089 - val_mean_absolute_error: 0.0650 - val_mean_squared_error: 0.0089
# Epoch 105/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0058 - mean_absolute_error: 0.0570 - mean_squared_error: 0.0058 - val_loss: 0.0086 - val_mean_absolute_error: 0.0657 - val_mean_squared_error: 0.0086
# Epoch 106/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0056 - mean_absolute_error: 0.0519 - mean_squared_error: 0.0056 - val_loss: 0.0105 - val_mean_absolute_error: 0.0675 - val_mean_squared_error: 0.0105
# Epoch 107/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0054 - mean_absolute_error: 0.0574 - mean_squared_error: 0.0054 - val_loss: 0.0103 - val_mean_absolute_error: 0.0695 - val_mean_squared_error: 0.0103
# Epoch 108/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0040 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0040 - val_loss: 0.0102 - val_mean_absolute_error: 0.0666 - val_mean_squared_error: 0.0102
# Epoch 109/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0044 - mean_absolute_error: 0.0478 - mean_squared_error: 0.0044 - val_loss: 0.0102 - val_mean_absolute_error: 0.0715 - val_mean_squared_error: 0.0102
# Epoch 110/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0046 - mean_absolute_error: 0.0494 - mean_squared_error: 0.0046 - val_loss: 0.0091 - val_mean_absolute_error: 0.0671 - val_mean_squared_error: 0.0091
# Epoch 111/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0044 - mean_absolute_error: 0.0488 - mean_squared_error: 0.0044 - val_loss: 0.0113 - val_mean_absolute_error: 0.0785 - val_mean_squared_error: 0.0113
# Epoch 112/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0045 - mean_absolute_error: 0.0510 - mean_squared_error: 0.0045 - val_loss: 0.0107 - val_mean_absolute_error: 0.0731 - val_mean_squared_error: 0.0107
# Epoch 113/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0043 - mean_absolute_error: 0.0473 - mean_squared_error: 0.0043 - val_loss: 0.0091 - val_mean_absolute_error: 0.0640 - val_mean_squared_error: 0.0091
# Epoch 114/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0037 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0037 - val_loss: 0.0094 - val_mean_absolute_error: 0.0640 - val_mean_squared_error: 0.0094
# Epoch 115/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0036 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0036 - val_loss: 0.0084 - val_mean_absolute_error: 0.0621 - val_mean_squared_error: 0.0084
# Epoch 116/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0035 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0035 - val_loss: 0.0095 - val_mean_absolute_error: 0.0638 - val_mean_squared_error: 0.0095
# Epoch 117/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0033 - mean_absolute_error: 0.0406 - mean_squared_error: 0.0033 - val_loss: 0.0086 - val_mean_absolute_error: 0.0628 - val_mean_squared_error: 0.0086
# Epoch 118/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0037 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0037 - val_loss: 0.0094 - val_mean_absolute_error: 0.0624 - val_mean_squared_error: 0.0094
# Epoch 119/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0035 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0035 - val_loss: 0.0082 - val_mean_absolute_error: 0.0622 - val_mean_squared_error: 0.0082
# Epoch 120/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0036 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0036 - val_loss: 0.0088 - val_mean_absolute_error: 0.0629 - val_mean_squared_error: 0.0088
# Epoch 121/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0038 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0038 - val_loss: 0.0088 - val_mean_absolute_error: 0.0633 - val_mean_squared_error: 0.0088
# Epoch 122/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0037 - mean_absolute_error: 0.0469 - mean_squared_error: 0.0037 - val_loss: 0.0091 - val_mean_absolute_error: 0.0628 - val_mean_squared_error: 0.0091
# Epoch 123/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0035 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0035 - val_loss: 0.0097 - val_mean_absolute_error: 0.0654 - val_mean_squared_error: 0.0097
# Epoch 124/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0036 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0036 - val_loss: 0.0080 - val_mean_absolute_error: 0.0607 - val_mean_squared_error: 0.0080
# Epoch 125/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0032 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0032 - val_loss: 0.0101 - val_mean_absolute_error: 0.0718 - val_mean_squared_error: 0.0101
# Epoch 126/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0052 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0052 - val_loss: 0.0096 - val_mean_absolute_error: 0.0696 - val_mean_squared_error: 0.0096
# Epoch 127/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0046 - mean_absolute_error: 0.0529 - mean_squared_error: 0.0046 - val_loss: 0.0093 - val_mean_absolute_error: 0.0673 - val_mean_squared_error: 0.0093
# Epoch 128/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0038 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0038 - val_loss: 0.0085 - val_mean_absolute_error: 0.0622 - val_mean_squared_error: 0.0085
# Epoch 129/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0036 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0036 - val_loss: 0.0103 - val_mean_absolute_error: 0.0701 - val_mean_squared_error: 0.0103
# Epoch 130/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0038 - mean_absolute_error: 0.0475 - mean_squared_error: 0.0038 - val_loss: 0.0091 - val_mean_absolute_error: 0.0647 - val_mean_squared_error: 0.0091
# Epoch 131/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0034 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0034 - val_loss: 0.0087 - val_mean_absolute_error: 0.0622 - val_mean_squared_error: 0.0087
# Epoch 132/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0032 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0032 - val_loss: 0.0089 - val_mean_absolute_error: 0.0601 - val_mean_squared_error: 0.0089
# Epoch 133/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0030 - mean_absolute_error: 0.0381 - mean_squared_error: 0.0030 - val_loss: 0.0085 - val_mean_absolute_error: 0.0613 - val_mean_squared_error: 0.0085
# Epoch 134/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0033 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0033 - val_loss: 0.0089 - val_mean_absolute_error: 0.0600 - val_mean_squared_error: 0.0089
# Epoch 135/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0031 - mean_absolute_error: 0.0391 - mean_squared_error: 0.0031 - val_loss: 0.0077 - val_mean_absolute_error: 0.0583 - val_mean_squared_error: 0.0077
# Epoch 136/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0034 - mean_absolute_error: 0.0409 - mean_squared_error: 0.0034 - val_loss: 0.0094 - val_mean_absolute_error: 0.0611 - val_mean_squared_error: 0.0094
# Epoch 137/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0033 - mean_absolute_error: 0.0400 - mean_squared_error: 0.0033 - val_loss: 0.0077 - val_mean_absolute_error: 0.0598 - val_mean_squared_error: 0.0077
# Epoch 138/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0034 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0034 - val_loss: 0.0087 - val_mean_absolute_error: 0.0593 - val_mean_squared_error: 0.0087
# Epoch 139/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0027 - mean_absolute_error: 0.0385 - mean_squared_error: 0.0027 - val_loss: 0.0079 - val_mean_absolute_error: 0.0581 - val_mean_squared_error: 0.0079
# Epoch 140/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0027 - mean_absolute_error: 0.0381 - mean_squared_error: 0.0027 - val_loss: 0.0083 - val_mean_absolute_error: 0.0594 - val_mean_squared_error: 0.0083
# Epoch 141/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0026 - mean_absolute_error: 0.0365 - mean_squared_error: 0.0026 - val_loss: 0.0082 - val_mean_absolute_error: 0.0591 - val_mean_squared_error: 0.0082
# Epoch 142/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0031 - mean_absolute_error: 0.0400 - mean_squared_error: 0.0031 - val_loss: 0.0080 - val_mean_absolute_error: 0.0587 - val_mean_squared_error: 0.0080
# Epoch 143/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0032 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0032 - val_loss: 0.0104 - val_mean_absolute_error: 0.0660 - val_mean_squared_error: 0.0104
# Epoch 144/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0028 - mean_absolute_error: 0.0401 - mean_squared_error: 0.0028 - val_loss: 0.0091 - val_mean_absolute_error: 0.0653 - val_mean_squared_error: 0.0091
# Epoch 145/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0030 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0030 - val_loss: 0.0089 - val_mean_absolute_error: 0.0633 - val_mean_squared_error: 0.0089
# Epoch 146/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0027 - mean_absolute_error: 0.0392 - mean_squared_error: 0.0027 - val_loss: 0.0108 - val_mean_absolute_error: 0.0746 - val_mean_squared_error: 0.0108
# Epoch 147/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0052 - mean_absolute_error: 0.0532 - mean_squared_error: 0.0052 - val_loss: 0.0083 - val_mean_absolute_error: 0.0639 - val_mean_squared_error: 0.0083
# Epoch 148/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0039 - mean_absolute_error: 0.0476 - mean_squared_error: 0.0039 - val_loss: 0.0124 - val_mean_absolute_error: 0.0765 - val_mean_squared_error: 0.0124
# Epoch 149/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0051 - mean_absolute_error: 0.0573 - mean_squared_error: 0.0051 - val_loss: 0.0105 - val_mean_absolute_error: 0.0738 - val_mean_squared_error: 0.0105
# Epoch 150/150
# 323/323 [==============================] - 0s 1ms/step - loss: 0.0136 - mean_absolute_error: 0.0817 - mean_squared_error: 0.0136 - val_loss: 0.0200 - val_mean_absolute_error: 0.1115 - val_mean_squared_error: 0.0200

# %%
hist = pd.DataFrame(history.history)
hist['epoch']= history.epoch
hist.tail()
# Out:
#      val_loss  val_mean_absolute_error  val_mean_squared_error      loss  \
# 145  0.010831                 0.074648                0.010831  0.002698
# 146  0.008345                 0.063940                0.008345  0.005223
# 147  0.012420                 0.076537                0.012420  0.003934
# 148  0.010478                 0.073783                0.010478  0.005103
# 149  0.020035                 0.111513                0.020035  0.013632
#
#      mean_absolute_error  mean_squared_error  epoch
# 145             0.039239            0.002698    145
# 146             0.053224            0.005223    146
# 147             0.047579            0.003934    147
# 148             0.057317            0.005103    148
# 149             0.081728            0.013632    149

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
    
  plt.figure(figsize=(13,9))
  #plt.figure()
  plt.xlabel('Epoch', fontsize= 18)
  plt.ylabel('Mean Abs Error', fontsize= 18)
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  plt.ylim([0,1.2])
  plt.tick_params(labelsize=20)
  plt.legend()
  

  plt.figure(figsize=(13,9))
  #plt.figure()
  plt.xlabel('Epoch', fontsize = 20)
  plt.ylabel('Mean Square Error', fontsize= 20)
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  plt.ylim([0,10])
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# **Save model**

# %%
starnet_model = 'starnet_cnn.h5'
model.save(datadir + starnet_model)
print(starnet_model +' saved.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-cbce4fa797c4> in <module>
#       1 starnet_model = 'starnet_cnn.h5'
# ----> 2 model.save(datadir + starnet_model)
#       3 print(starnet_model +' saved.')
#
# NameError: name 'datadir' is not defined

# %%
test_predictions = model.predict(norm_flux).flatten()

plt.scatter(normalize(logteff), test_predictions)
plt.xlabel('True Values [LogTeff]')
plt.ylabel('Predictions [LogTeff]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

#print('test predictions=', test_predictions)

# %%
#Unnormalizing the labels (teff)

def denormalize (labels):
    return (((labels)*(std_labels)) + mean_labels)


test_predictions = model.predict(norm_flux).flatten()
plt.scatter(logteff, denormalize(test_predictions))
plt.xlabel('True Values [LogTeff]')
plt.ylabel('Predictions [LogTeff]')
plt.axis('equal')
plt.axis('square')
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([5.5, 12 ], [5.5, 12])

#print('test predictions=', test_predictions)

# %%
#Unnormalizing the labels (teff)

def denormalize (labels):
    return (((labels)*(std_labels)) + mean_labels)

plt.figure(figsize=(13,9))
test_predictions = model.predict(x_train).flatten()
plt.scatter(denormalize(y_train), denormalize(test_predictions), c= 'r', s= 2.5)
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=25)
plt.ylabel(r"$T_{\rm eff,pred}$ (K)", fontsize=25)
plt.axis('equal')
plt.axis('square')
# increase the x,y tick label size
plt.tick_params(labelsize= 25) 
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([3.4, 4.6], [3.4, 4.6])

#print('test predictions=', test_predictions)

# %%
#Making the histogram 

print(np.shape(logteff))
z=np.subtract(normalize(logteff), test_predictions)
counts, bins = np.histogram(z)
plt.hist(bins[:-1], bins, weights=counts)
plt.title(r'Histogram of $T_{eff}$, dev=0.1568938629689942')
plt.xlabel('Prediction- True')
plt.ylabel('Counts')
z.std()
#print(len(z))

a=np.array(test_predictions)
k=np.count_nonzero(a)
print(k)
# Out:
# (415,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-46a5b62ef131> in <module>
#       2
#       3 print(np.shape(logteff))
# ----> 4 z=np.subtract(normalize(logteff), test_predictions)
#       5 counts, bins = np.histogram(z)
#       6 plt.hist(bins[:-1], bins, weights=counts)
#
# ValueError: operands could not be broadcast together with shapes (415,) (330,)

# %%
#Making the histogram 

z=np.subtract(logteff, denormalize(test_predictions)) #difference between the true and predicted values
counts, bins = np.histogram(z)
plt.hist(bins[:-1], bins, weights=counts)
plt.title(r'Histogram of $T_{eff}$, dev=0.1568938629689942')
plt.xlabel('Prediction- True')
plt.ylabel('Counts')
z[teff<5000].std()
#print(len(z[teff<5000]))
#print(len(z))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-a61acb5c3e8d> in <module>
#       1 #Making the histogram
#       2
# ----> 3 z=np.subtract(logteff, denormalize(test_predictions)) #difference between the true and predicted values
#       4 counts, bins = np.histogram(z)
#       5 plt.hist(bins[:-1], bins, weights=counts)
#
# ValueError: operands could not be broadcast together with shapes (415,) (330,)

# %% [markdown]
# # Training Data Set

# %%
# getting deviation in Teff bins
nbin = 6
teffbin_edges=np.array([3.6, 3.8, 4.0, 4.2, 4.4])

# pred vs. true
# unnormalised values
teff_pred = denormalize(test_predictions)
teff_true = denormalize(y_train) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
teff_diff = teff_pred-teff_true

# compute mean and std in Teff bins
teff_diff_mean = np.zeros(nbin) 
teff_diff_std = np.zeros(nbin)
teffbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(teff_true<teffbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(teff_true>teffbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((teff_true>teffbin_edges[i-1]) & (teff_true<teffbin_edges[i]))
        #if i=1, teff_true>(teffbin_edges[1-1=0]= 5000) & teff_true<teffbin_edges[1]= 10000, so 5000<teff<10000
        #if i=2, teff_true>(teffbin_edges[2-1=1]=10000) & teff_true<teffbin_edges[2]= 15000, so 10000<teff<15000
        #if i=3, teff_true> (teffbin_edges[3-1=2]= 15000) & teff_true<teffbin_edges[3]= 20000 so 15000<teff<20000
    teffbin_mean[i] = np.mean(teff_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    teff_diff_mean[i] = np.mean(teff_diff[indx]) #calculating the mean values of teff_diff from its index 
    teff_diff_std[i] = np.std(teff_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin teff_true=', teffbin_mean)
print('mean of teff_diff=', teff_diff_mean)
print('std of teff_diff=', teff_diff_std)
print('length of teff_diff=', len(teff_diff))
# Out:
# mean of bin teff_true= [3.55816838 3.70205511 3.90009692 4.08363687 4.28228219 4.45081312]
# mean of teff_diff= [ 0.01365563 -0.00730275 -0.02350159 -0.03279644 -0.00157499 -0.03442179]
# std of teff_diff= [0.02564362 0.00952392 0.00648994 0.0133782  0.01578533 0.01527669]
# length of teff_diff= 323

# %%
# plot
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(teff_true, teff_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(teffbin_mean,teff_diff_mean, yerr=teff_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=18)

# set x, y lim plot range
xlim=np.array([3.5,4.5])
ylim=np.array([-0.25,0.25])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# set x, y label. 
plt.xlabel(r"$\rm logT_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$\rm logT_{\rm eff,pred}-\rm logT_{\rm eff,true}$ (K)", fontsize=18)

# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %% [markdown]
# # Cross Validation Set

# %%
#Test set (x_cv)

plt.figure(figsize=(13,9))
cv_predictions = model.predict(x_cv).flatten()
plt.scatter(denormalize(y_cv), denormalize(cv_predictions), c= 'r', s= 3)
plt.xlabel(r"$LogT_{\rm eff,true}$ (K)", fontsize=25)
plt.ylabel(r"$LogT_{\rm eff,pred}$ (K)", fontsize=25)
plt.axis('equal')
plt.axis('square')
# increase the x,y tick label size
plt.tick_params(labelsize=25) 
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([3.4, 4.6], [3.4, 4.6])

#print('test predictions=', test_predictions)

print('len of y_cv=', len(y_cv))
# Out:
# len of y_cv= 92

# %%
# getting deviation in Teff bins
nbin = 6
teffbin_edges=np.array([3.6, 3.8, 4.0, 4.2, 4.4])

# pred vs. true
# unnormalised values
teff_pred = denormalize(cv_predictions)
teff_true = denormalize(y_cv) #teff values are created by read_spectra1_updatedwavelength from the nsc Allende Prieto spectra library
teff_diff = teff_pred-teff_true

# compute mean and std in Teff bins
teff_diff_mean = np.zeros(nbin) 
teff_diff_std = np.zeros(nbin)
teffbin_mean = np.zeros(nbin)

for i in range(nbin): #iterations(0,1,2,3,4)
    if i==0:
        indx = np.where(teff_true<teffbin_edges[i]) #index of teff_true where teff true< 5000 since teff has all values of teff in each library
        #print(indx)
    elif i==nbin-1: #if i= 5-1= 4
        indx = np.where(teff_true>teffbin_edges[i-1]) #index of true_teff>20000
    else: #if i=1,2,3
        indx = np.where((teff_true>teffbin_edges[i-1]) & (teff_true<teffbin_edges[i]))
        #if i=1, teff_true>(teffbin_edges[1-1=0]= 5000) & teff_true<teffbin_edges[1]= 10000, so 5000<teff<10000
        #if i=2, teff_true>(teffbin_edges[2-1=1]=10000) & teff_true<teffbin_edges[2]= 15000, so 10000<teff<15000
        #if i=3, teff_true> (teffbin_edges[3-1=2]= 15000) & teff_true<teffbin_edges[3]= 20000 so 15000<teff<20000
    teffbin_mean[i] = np.mean(teff_true[indx]) #calculating the mean values of teff_true from assigning its index in the for loop
    teff_diff_mean[i] = np.mean(teff_diff[indx]) #calculating the mean values of teff_diff from its index 
    teff_diff_std[i] = np.std(teff_diff[indx]) #calculating the std values of teff-diff from its index
    
print('mean of bin teff_true=', teffbin_mean)
print('mean of teff_diff=', teff_diff_mean)
print('std of teff_diff=', teff_diff_std)
print('len of teff_diff=', len(teff_diff))
# Out:
# mean of bin teff_true= [3.56204598 3.71040251 3.90195078 4.08468111 4.27362202 4.43502472]
# mean of teff_diff= [ 0.01584957 -0.00620399 -0.02169078 -0.04269259  0.01204754 -0.07542882]
# std of teff_diff= [0.02639439 0.0084726  0.00750009 0.01621165 0.01796697 0.03106773]
# len of teff_diff= 92

# %%
# plot
plt.figure(figsize=(13,9))
# plot the difference
plt.scatter(teff_true, teff_diff ,c='k', marker='.')
#plt.plot(teff_true, teff_diff,'o', markersize=1, c='k')

# plot mean (symbol) and scatter with error bars
plt.errorbar(teffbin_mean,teff_diff_mean, yerr=teff_diff_std, fmt='-o', c='r',capsize=3) #plotting the teff bin mean in x-axis and teff_diff in y-axis

# increase the x,y tick label size
plt.tick_params(labelsize=18) 

# set x, y label. 
plt.xlabel(r"$T_{\rm eff,true}$ (K)", fontsize=25)
plt.ylabel(r"$T_{\rm eff,pred}-T_{\rm eff,true}$ (K)", fontsize=25)

# set x, y lim plot range
xlim=np.array([3.5,4.5])
ylim=np.array([-0.25,0.25])
plt.xlim(xlim[0],xlim[1]) #plotting the xlim
plt.ylim(ylim[0],ylim[1])

# set x, y label. 
plt.xlabel(r"$\rm logT_{\rm eff,true}$ (K)", fontsize=18)
plt.ylabel(r"$\rm logT_{\rm eff,pred}-\rm logT_{\rm eff,true}$ (K)", fontsize=18)

# draw y=0 line
xline = np.linspace(xlim[0],xlim[1], 2)
yline = np.zeros_like(xline)
plt.plot(xline,yline,linestyle='--',c='k')

# %% [raw]
# # Another model
# From TheCNNon, https://github.com/adrn/TheCNNon/blob/master/notebooks/ThisIsCNNON.ipynb

# %%
# Input spectra
input_spec = Input(shape=(num_fluxes,), name='starnet_input_x')

# Reshape spectra for CNN layers
cur_in = Reshape((num_fluxes, 1))(input_spec)

# CNN layers
# First
cur_in = Conv1D(kernel_initializer=initializer, activation=activation, 
                padding="same", filters=128, kernel_size=32)(cur_in) #first CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=32)(cur_in)
# Second CNN layer
cur_in = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=128, kernel_size=16)(cur_in) #2nd CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=16)(cur_in)
# Third CNN layer
cur_in = Conv1D(kernel_initializer=initializer, activation=activation,
                padding="same", filters=128, kernel_size=8)(cur_in) #2nd CNN layer
# Max pooling layer
cur_in = MaxPooling1D(pool_size=8)(cur_in)

# Flatten the current input for the fully-connected layers
cur_in = Flatten()(cur_in)

# Fully-connected layers
cur_in = Dense(units=258, kernel_initializer=initializer, 
               activation=activation)(cur_in)
cur_in = Dense(units=128, kernel_initializer=initializer, 
               activation=activation)(cur_in)

# Output nodes
output_label = Dense(units=num_labels, kernel_regularizer=keras.regularizers.l2(0.01), activation="linear", 
                     input_dim=num_hidden[1])(cur_in)

model = Model(input_spec, output_label)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1658   try:
# -> 1659     c_op = c_api.TF_FinishOperation(op_desc)
#    1660   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Negative dimension size caused by subtracting 8 from 1 for 'max_pooling1d_12/MaxPool' (op: 'MaxPool') with input shapes: [?,1,1,128].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-07ed572f0f80> in <module>
#      20                 padding="same", filters=128, kernel_size=8)(cur_in) #2nd CNN layer
#      21 # Max pooling layer
# ---> 22 cur_in = MaxPooling1D(pool_size=8)(cur_in)
#      23
#      24 # Flatten the current input for the fully-connected layers
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     455             # Actually call the layer,
#     456             # collecting output(s), mask(s), and shape(s).
# --> 457             output = self.call(inputs, **kwargs)
#     458             output_mask = self.compute_mask(inputs, previous_mask)
#     459
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/pooling.py in call(self, inputs)
#      55                                         strides=self.strides + (1,),
#      56                                         padding=self.padding,
# ---> 57                                         data_format=self.data_format)
#      58         return K.squeeze(output, dummy_axis)  # remove dummy last dimension
#      59
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/pooling.py in _pooling_function(self, inputs, pool_size, strides, padding, data_format)
#     111                           padding, data_format):
#     112         output = K.pool2d(inputs, pool_size, strides,
# --> 113                           padding, data_format, pool_mode='max')
#     114         return output
#     115
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in pool2d(x, pool_size, strides, padding, data_format, pool_mode)
#    3976         x = tf.nn.max_pool(x, pool_size, strides,
#    3977                            padding=padding,
# -> 3978                            data_format=tf_data_format)
#    3979     elif pool_mode == 'avg':
#    3980         x = tf.nn.avg_pool(x, pool_size, strides,
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in max_pool(value, ksize, strides, padding, data_format, name)
#    2746         padding=padding,
#    2747         data_format=data_format,
# -> 2748         name=name)
#    2749
#    2750
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in max_pool(input, ksize, strides, padding, data_format, name)
#    5135   _, _, _op = _op_def_lib._apply_op_helper(
#    5136         "MaxPool", input=input, ksize=ksize, strides=strides, padding=padding,
# -> 5137                    data_format=data_format, name=name)
#    5138   _result = _op.outputs[:]
#    5139   _inputs_flat = _op.inputs
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     787                          input_types=input_types, attrs=attr_protos,
# --> 788                          op_def=op_def)
#     789       return output_structure, op_def.is_stateful, op
#     790
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(***failed resolving arguments***)
#    3298           input_types=input_types,
#    3299           original_op=self._default_original_op,
# -> 3300           op_def=op_def)
#    3301       self._create_op_helper(ret, compute_device=compute_device)
#    3302     return ret
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1821           op_def, inputs, node_def.attr)
#    1822       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1823                                 control_input_ops)
#    1824
#    1825     # Initialize self._outputs.
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1660   except errors.InvalidArgumentError as e:
#    1661     # Convert to ValueError for backwards compatibility.
# -> 1662     raise ValueError(str(e))
#    1663
#    1664   return c_op
#
# ValueError: Negative dimension size caused by subtracting 8 from 1 for 'max_pooling1d_12/MaxPool' (op: 'MaxPool') with input shapes: [?,1,1,128].

# %%
optimizer = Adam(lr=0.0005)

# %%
# loss function to minimize
loss_function = 'mean_squared_error'
optimizer = 'adadelta'
# compute mean absolute deviation
metrics = ['mae', 'mse']
#metrics = ['mae']
model.compile(optimizer=optimizer, loss=loss_function, metrics=metrics)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# starnet_input_x (InputLayer) (None, 6758)              0
# _________________________________________________________________
# reshape_10 (Reshape)         (None, 6758, 1)           0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 6758, 128)         4224
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 211, 128)          0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 211, 128)          262272
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 13, 128)           0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 13, 128)           131200
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 1, 128)            0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 258)               33282
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               33152
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 464,259
# Trainable params: 464,259
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, 
          epochs=max_epochs, validation_split = 0.2, verbose=1, shuffle='batch')
# Out:
# Train on 875 samples, validate on 219 samples
# Epoch 1/200
# 875/875 [==============================] - 13s 15ms/step - loss: 5.2174 - mean_absolute_error: 1.4147 - mean_squared_error: 5.1988 - val_loss: 1.5482 - val_mean_absolute_error: 0.9417 - val_mean_squared_error: 1.5305
# Epoch 2/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3955 - mean_absolute_error: 0.5094 - mean_squared_error: 0.3783 - val_loss: 1.8217 - val_mean_absolute_error: 1.0313 - val_mean_squared_error: 1.8050
# Epoch 3/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3606 - mean_absolute_error: 0.4579 - mean_squared_error: 0.3443 - val_loss: 1.9750 - val_mean_absolute_error: 1.0742 - val_mean_squared_error: 1.9589
# Epoch 4/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3806 - mean_absolute_error: 0.4960 - mean_squared_error: 0.3648 - val_loss: 2.0388 - val_mean_absolute_error: 1.0894 - val_mean_squared_error: 2.0232
# Epoch 5/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.4077 - mean_absolute_error: 0.4772 - mean_squared_error: 0.3923 - val_loss: 3.4660 - val_mean_absolute_error: 1.5366 - val_mean_squared_error: 3.4508
# Epoch 6/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.3888 - mean_absolute_error: 0.5023 - mean_squared_error: 0.3738 - val_loss: 3.0916 - val_mean_absolute_error: 1.4193 - val_mean_squared_error: 3.0766
# Epoch 7/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.3001 - mean_absolute_error: 0.4360 - mean_squared_error: 0.2852 - val_loss: 3.7524 - val_mean_absolute_error: 1.6397 - val_mean_squared_error: 3.7377
# Epoch 8/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.2883 - mean_absolute_error: 0.4420 - mean_squared_error: 0.2736 - val_loss: 3.6873 - val_mean_absolute_error: 1.6205 - val_mean_squared_error: 3.6728
# Epoch 9/200
# 875/875 [==============================] - 22s 25ms/step - loss: 0.2976 - mean_absolute_error: 0.4493 - mean_squared_error: 0.2833 - val_loss: 3.8704 - val_mean_absolute_error: 1.6722 - val_mean_squared_error: 3.8562
# Epoch 10/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.2398 - mean_absolute_error: 0.3987 - mean_squared_error: 0.2256 - val_loss: 3.9370 - val_mean_absolute_error: 1.6926 - val_mean_squared_error: 3.9230
# Epoch 11/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.2136 - mean_absolute_error: 0.3585 - mean_squared_error: 0.1997 - val_loss: 3.5978 - val_mean_absolute_error: 1.5898 - val_mean_squared_error: 3.5840
# Epoch 12/200
# 875/875 [==============================] - 27s 31ms/step - loss: 0.2410 - mean_absolute_error: 0.3820 - mean_squared_error: 0.2274 - val_loss: 4.0983 - val_mean_absolute_error: 1.7393 - val_mean_squared_error: 4.0850
# Epoch 13/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.1661 - mean_absolute_error: 0.3015 - mean_squared_error: 0.1530 - val_loss: 2.8094 - val_mean_absolute_error: 1.3314 - val_mean_squared_error: 2.7965
# Epoch 14/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1630 - mean_absolute_error: 0.2858 - mean_squared_error: 0.1503 - val_loss: 3.9325 - val_mean_absolute_error: 1.6919 - val_mean_squared_error: 3.9201
# Epoch 15/200
# 875/875 [==============================] - 26s 30ms/step - loss: 0.1432 - mean_absolute_error: 0.2689 - mean_squared_error: 0.1311 - val_loss: 3.6180 - val_mean_absolute_error: 1.5971 - val_mean_squared_error: 3.6062
# Epoch 16/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1220 - mean_absolute_error: 0.2405 - mean_squared_error: 0.1106 - val_loss: 3.5919 - val_mean_absolute_error: 1.5885 - val_mean_squared_error: 3.5809
# Epoch 17/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1122 - mean_absolute_error: 0.2418 - mean_squared_error: 0.1015 - val_loss: 3.4441 - val_mean_absolute_error: 1.5411 - val_mean_squared_error: 3.4337
# Epoch 18/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1125 - mean_absolute_error: 0.2457 - mean_squared_error: 0.1025 - val_loss: 3.6328 - val_mean_absolute_error: 1.6010 - val_mean_squared_error: 3.6232
# Epoch 19/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1287 - mean_absolute_error: 0.2610 - mean_squared_error: 0.1194 - val_loss: 3.5788 - val_mean_absolute_error: 1.5843 - val_mean_squared_error: 3.5699
# Epoch 20/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0884 - mean_absolute_error: 0.2150 - mean_squared_error: 0.0797 - val_loss: 2.2024 - val_mean_absolute_error: 1.1457 - val_mean_squared_error: 2.1939
# Epoch 21/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.1126 - mean_absolute_error: 0.2483 - mean_squared_error: 0.1043 - val_loss: 3.1658 - val_mean_absolute_error: 1.4498 - val_mean_squared_error: 3.1579
# Epoch 22/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0973 - mean_absolute_error: 0.2238 - mean_squared_error: 0.0895 - val_loss: 3.2924 - val_mean_absolute_error: 1.4950 - val_mean_squared_error: 3.2848
# Epoch 23/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0928 - mean_absolute_error: 0.2209 - mean_squared_error: 0.0853 - val_loss: 2.5891 - val_mean_absolute_error: 1.2693 - val_mean_squared_error: 2.5818
# Epoch 24/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1052 - mean_absolute_error: 0.2388 - mean_squared_error: 0.0981 - val_loss: 2.9058 - val_mean_absolute_error: 1.3614 - val_mean_squared_error: 2.8988
# Epoch 25/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1014 - mean_absolute_error: 0.2394 - mean_squared_error: 0.0945 - val_loss: 2.1955 - val_mean_absolute_error: 1.1433 - val_mean_squared_error: 2.1887
# Epoch 26/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1404 - mean_absolute_error: 0.2719 - mean_squared_error: 0.1338 - val_loss: 3.4146 - val_mean_absolute_error: 1.5348 - val_mean_squared_error: 3.4081
# Epoch 27/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0821 - mean_absolute_error: 0.2071 - mean_squared_error: 0.0757 - val_loss: 2.4974 - val_mean_absolute_error: 1.2405 - val_mean_squared_error: 2.4909
# Epoch 28/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0923 - mean_absolute_error: 0.2196 - mean_squared_error: 0.0859 - val_loss: 2.6382 - val_mean_absolute_error: 1.2849 - val_mean_squared_error: 2.6318
# Epoch 29/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0897 - mean_absolute_error: 0.2259 - mean_squared_error: 0.0834 - val_loss: 2.8831 - val_mean_absolute_error: 1.3586 - val_mean_squared_error: 2.8769
# Epoch 30/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0744 - mean_absolute_error: 0.1986 - mean_squared_error: 0.0682 - val_loss: 1.7850 - val_mean_absolute_error: 1.0208 - val_mean_squared_error: 1.7788
# Epoch 31/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1151 - mean_absolute_error: 0.2334 - mean_squared_error: 0.1090 - val_loss: 2.8941 - val_mean_absolute_error: 1.3617 - val_mean_squared_error: 2.8881
# Epoch 32/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0832 - mean_absolute_error: 0.2128 - mean_squared_error: 0.0773 - val_loss: 2.6767 - val_mean_absolute_error: 1.2974 - val_mean_squared_error: 2.6707
# Epoch 33/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0797 - mean_absolute_error: 0.2058 - mean_squared_error: 0.0738 - val_loss: 3.1776 - val_mean_absolute_error: 1.4555 - val_mean_squared_error: 3.1718
# Epoch 34/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0814 - mean_absolute_error: 0.2059 - mean_squared_error: 0.0757 - val_loss: 2.6626 - val_mean_absolute_error: 1.2925 - val_mean_squared_error: 2.6568
# Epoch 35/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0876 - mean_absolute_error: 0.2151 - mean_squared_error: 0.0819 - val_loss: 2.5699 - val_mean_absolute_error: 1.2623 - val_mean_squared_error: 2.5643
# Epoch 36/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.1182 - mean_absolute_error: 0.2553 - mean_squared_error: 0.1126 - val_loss: 2.7674 - val_mean_absolute_error: 1.3285 - val_mean_squared_error: 2.7619
# Epoch 37/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0652 - mean_absolute_error: 0.1795 - mean_squared_error: 0.0597 - val_loss: 3.1619 - val_mean_absolute_error: 1.4543 - val_mean_squared_error: 3.1564
# Epoch 38/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0757 - mean_absolute_error: 0.2025 - mean_squared_error: 0.0703 - val_loss: 2.8025 - val_mean_absolute_error: 1.3408 - val_mean_squared_error: 2.7970
# Epoch 39/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0759 - mean_absolute_error: 0.2020 - mean_squared_error: 0.0705 - val_loss: 2.1523 - val_mean_absolute_error: 1.1254 - val_mean_squared_error: 2.1470
# Epoch 40/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0722 - mean_absolute_error: 0.1941 - mean_squared_error: 0.0669 - val_loss: 2.2233 - val_mean_absolute_error: 1.1493 - val_mean_squared_error: 2.2180
# Epoch 41/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0718 - mean_absolute_error: 0.1899 - mean_squared_error: 0.0666 - val_loss: 2.5742 - val_mean_absolute_error: 1.2647 - val_mean_squared_error: 2.5689
# Epoch 42/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0649 - mean_absolute_error: 0.1807 - mean_squared_error: 0.0597 - val_loss: 2.5939 - val_mean_absolute_error: 1.2684 - val_mean_squared_error: 2.5887
# Epoch 43/200
# 875/875 [==============================] - 26s 29ms/step - loss: 0.0669 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0618 - val_loss: 2.8934 - val_mean_absolute_error: 1.3602 - val_mean_squared_error: 2.8883
# Epoch 44/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0709 - mean_absolute_error: 0.1983 - mean_squared_error: 0.0659 - val_loss: 2.5505 - val_mean_absolute_error: 1.2618 - val_mean_squared_error: 2.5456
# Epoch 45/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0694 - mean_absolute_error: 0.1891 - mean_squared_error: 0.0645 - val_loss: 2.9804 - val_mean_absolute_error: 1.3956 - val_mean_squared_error: 2.9755
# Epoch 46/200
# 875/875 [==============================] - 24s 28ms/step - loss: 0.0719 - mean_absolute_error: 0.1961 - mean_squared_error: 0.0670 - val_loss: 2.4074 - val_mean_absolute_error: 1.2118 - val_mean_squared_error: 2.4026
# Epoch 47/200
# 875/875 [==============================] - 24s 28ms/step - loss: 0.0618 - mean_absolute_error: 0.1743 - mean_squared_error: 0.0571 - val_loss: 2.2830 - val_mean_absolute_error: 1.1690 - val_mean_squared_error: 2.2782
# Epoch 48/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0676 - mean_absolute_error: 0.1821 - mean_squared_error: 0.0629 - val_loss: 2.6052 - val_mean_absolute_error: 1.2808 - val_mean_squared_error: 2.6005
# Epoch 49/200
# 875/875 [==============================] - 25s 28ms/step - loss: 0.0630 - mean_absolute_error: 0.1787 - mean_squared_error: 0.0583 - val_loss: 2.4626 - val_mean_absolute_error: 1.2316 - val_mean_squared_error: 2.4579
# Epoch 50/200
# 875/875 [==============================] - 25s 29ms/step - loss: 0.0601 - mean_absolute_error: 0.1661 - mean_squared_error: 0.0555 - val_loss: 2.7647 - val_mean_absolute_error: 1.3206 - val_mean_squared_error: 2.7601
# Epoch 51/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0643 - mean_absolute_error: 0.1779 - mean_squared_error: 0.0597 - val_loss: 2.5744 - val_mean_absolute_error: 1.2720 - val_mean_squared_error: 2.5698
# Epoch 52/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0919 - mean_absolute_error: 0.2229 - mean_squared_error: 0.0873 - val_loss: 2.5535 - val_mean_absolute_error: 1.2609 - val_mean_squared_error: 2.5490
# Epoch 53/200
# 875/875 [==============================] - 436s 498ms/step - loss: 0.0650 - mean_absolute_error: 0.1887 - mean_squared_error: 0.0605 - val_loss: 2.1651 - val_mean_absolute_error: 1.1289 - val_mean_squared_error: 2.1606
# Epoch 54/200
# 875/875 [==============================] - 116s 133ms/step - loss: 0.1022 - mean_absolute_error: 0.2107 - mean_squared_error: 0.0977 - val_loss: 2.2922 - val_mean_absolute_error: 1.1691 - val_mean_squared_error: 2.2878
# Epoch 55/200
# 875/875 [==============================] - 1980s 2s/step - loss: 0.0704 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0661 - val_loss: 2.6339 - val_mean_absolute_error: 1.2914 - val_mean_squared_error: 2.6296
# Epoch 56/200
# 875/875 [==============================] - 16s 18ms/step - loss: 0.0528 - mean_absolute_error: 0.1586 - mean_squared_error: 0.0485 - val_loss: 1.9749 - val_mean_absolute_error: 1.0711 - val_mean_squared_error: 1.9706
# Epoch 57/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0525 - mean_absolute_error: 0.1568 - mean_squared_error: 0.0482 - val_loss: 2.0850 - val_mean_absolute_error: 1.1014 - val_mean_squared_error: 2.0807
# Epoch 58/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0607 - mean_absolute_error: 0.1662 - mean_squared_error: 0.0565 - val_loss: 2.4774 - val_mean_absolute_error: 1.2292 - val_mean_squared_error: 2.4732
# Epoch 59/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0578 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0536 - val_loss: 2.1773 - val_mean_absolute_error: 1.1350 - val_mean_squared_error: 2.1730
# Epoch 60/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0521 - mean_absolute_error: 0.1542 - mean_squared_error: 0.0479 - val_loss: 2.2251 - val_mean_absolute_error: 1.1478 - val_mean_squared_error: 2.2209
# Epoch 61/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0482 - mean_absolute_error: 0.1538 - mean_squared_error: 0.0441 - val_loss: 2.4825 - val_mean_absolute_error: 1.2420 - val_mean_squared_error: 2.4783
# Epoch 62/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0498 - mean_absolute_error: 0.1520 - mean_squared_error: 0.0457 - val_loss: 2.2666 - val_mean_absolute_error: 1.1597 - val_mean_squared_error: 2.2624
# Epoch 63/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0545 - mean_absolute_error: 0.1639 - mean_squared_error: 0.0504 - val_loss: 2.0965 - val_mean_absolute_error: 1.1046 - val_mean_squared_error: 2.0924
# Epoch 64/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0453 - mean_absolute_error: 0.1479 - mean_squared_error: 0.0412 - val_loss: 2.0962 - val_mean_absolute_error: 1.1012 - val_mean_squared_error: 2.0921
# Epoch 65/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0569 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0528 - val_loss: 2.6018 - val_mean_absolute_error: 1.2822 - val_mean_squared_error: 2.5977
# Epoch 66/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0521 - mean_absolute_error: 0.1593 - mean_squared_error: 0.0481 - val_loss: 2.1614 - val_mean_absolute_error: 1.1230 - val_mean_squared_error: 2.1573
# Epoch 67/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0468 - mean_absolute_error: 0.1503 - mean_squared_error: 0.0427 - val_loss: 1.9528 - val_mean_absolute_error: 1.0605 - val_mean_squared_error: 1.9488
# Epoch 68/200
# 875/875 [==============================] - 14s 15ms/step - loss: 0.0550 - mean_absolute_error: 0.1625 - mean_squared_error: 0.0510 - val_loss: 1.6402 - val_mean_absolute_error: 0.9684 - val_mean_squared_error: 1.6361
# Epoch 69/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0675 - mean_absolute_error: 0.1783 - mean_squared_error: 0.0636 - val_loss: 1.6937 - val_mean_absolute_error: 0.9808 - val_mean_squared_error: 1.6898
# Epoch 70/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0504 - mean_absolute_error: 0.1465 - mean_squared_error: 0.0465 - val_loss: 1.8599 - val_mean_absolute_error: 1.0318 - val_mean_squared_error: 1.8560
# Epoch 71/200
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0540 - mean_absolute_error: 0.1642 - mean_squared_error: 0.0501 - val_loss: 1.9639 - val_mean_absolute_error: 1.0634 - val_mean_squared_error: 1.9600
# Epoch 72/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0399 - mean_absolute_error: 0.1346 - mean_squared_error: 0.0361 - val_loss: 1.6221 - val_mean_absolute_error: 0.9613 - val_mean_squared_error: 1.6183
# Epoch 73/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0413 - mean_absolute_error: 0.1380 - mean_squared_error: 0.0375 - val_loss: 1.5695 - val_mean_absolute_error: 0.9410 - val_mean_squared_error: 1.5657
# Epoch 74/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0508 - mean_absolute_error: 0.1554 - mean_squared_error: 0.0470 - val_loss: 1.6579 - val_mean_absolute_error: 0.9698 - val_mean_squared_error: 1.6541
# Epoch 75/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0419 - mean_absolute_error: 0.1415 - mean_squared_error: 0.0381 - val_loss: 1.9499 - val_mean_absolute_error: 1.0596 - val_mean_squared_error: 1.9461
# Epoch 76/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0503 - mean_absolute_error: 0.1572 - mean_squared_error: 0.0465 - val_loss: 1.8577 - val_mean_absolute_error: 1.0327 - val_mean_squared_error: 1.8540
# Epoch 77/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0476 - mean_absolute_error: 0.1527 - mean_squared_error: 0.0439 - val_loss: 1.7745 - val_mean_absolute_error: 1.0009 - val_mean_squared_error: 1.7708
# Epoch 78/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0451 - mean_absolute_error: 0.1489 - mean_squared_error: 0.0415 - val_loss: 2.0050 - val_mean_absolute_error: 1.0651 - val_mean_squared_error: 2.0014
# Epoch 79/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0440 - mean_absolute_error: 0.1435 - mean_squared_error: 0.0404 - val_loss: 2.0267 - val_mean_absolute_error: 1.0795 - val_mean_squared_error: 2.0231
# Epoch 80/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0364 - mean_absolute_error: 0.1310 - mean_squared_error: 0.0327 - val_loss: 1.8544 - val_mean_absolute_error: 1.0227 - val_mean_squared_error: 1.8507
# Epoch 81/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0374 - mean_absolute_error: 0.1308 - mean_squared_error: 0.0337 - val_loss: 2.1050 - val_mean_absolute_error: 1.0957 - val_mean_squared_error: 2.1014
# Epoch 82/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0405 - mean_absolute_error: 0.1369 - mean_squared_error: 0.0369 - val_loss: 2.0692 - val_mean_absolute_error: 1.0950 - val_mean_squared_error: 2.0656
# Epoch 83/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0377 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0341 - val_loss: 2.1537 - val_mean_absolute_error: 1.1251 - val_mean_squared_error: 2.1501
# Epoch 84/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0437 - mean_absolute_error: 0.1535 - mean_squared_error: 0.0401 - val_loss: 1.9010 - val_mean_absolute_error: 1.0358 - val_mean_squared_error: 1.8974
# Epoch 85/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0372 - mean_absolute_error: 0.1277 - mean_squared_error: 0.0336 - val_loss: 2.2669 - val_mean_absolute_error: 1.1700 - val_mean_squared_error: 2.2633
# Epoch 86/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0398 - mean_absolute_error: 0.1395 - mean_squared_error: 0.0363 - val_loss: 2.4500 - val_mean_absolute_error: 1.2285 - val_mean_squared_error: 2.4464
# Epoch 87/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0461 - mean_absolute_error: 0.1518 - mean_squared_error: 0.0426 - val_loss: 1.7367 - val_mean_absolute_error: 0.9874 - val_mean_squared_error: 1.7331
# Epoch 88/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0332 - mean_absolute_error: 0.1268 - mean_squared_error: 0.0296 - val_loss: 1.9588 - val_mean_absolute_error: 1.0607 - val_mean_squared_error: 1.9552
# Epoch 89/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0321 - mean_absolute_error: 0.1208 - mean_squared_error: 0.0286 - val_loss: 1.7206 - val_mean_absolute_error: 0.9780 - val_mean_squared_error: 1.7171
# Epoch 90/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0419 - mean_absolute_error: 0.1408 - mean_squared_error: 0.0384 - val_loss: 1.8123 - val_mean_absolute_error: 1.0004 - val_mean_squared_error: 1.8087
# Epoch 91/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0369 - mean_absolute_error: 0.1327 - mean_squared_error: 0.0334 - val_loss: 1.9241 - val_mean_absolute_error: 1.0326 - val_mean_squared_error: 1.9206
# Epoch 92/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0409 - mean_absolute_error: 0.1397 - mean_squared_error: 0.0374 - val_loss: 1.9379 - val_mean_absolute_error: 1.0506 - val_mean_squared_error: 1.9345
# Epoch 93/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0382 - mean_absolute_error: 0.1378 - mean_squared_error: 0.0347 - val_loss: 1.7358 - val_mean_absolute_error: 0.9827 - val_mean_squared_error: 1.7323
# Epoch 94/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0326 - mean_absolute_error: 0.1196 - mean_squared_error: 0.0292 - val_loss: 2.3345 - val_mean_absolute_error: 1.1833 - val_mean_squared_error: 2.3311
# Epoch 95/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0323 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0290 - val_loss: 1.7382 - val_mean_absolute_error: 0.9739 - val_mean_squared_error: 1.7348
# Epoch 96/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0350 - mean_absolute_error: 0.1280 - mean_squared_error: 0.0316 - val_loss: 2.1179 - val_mean_absolute_error: 1.1150 - val_mean_squared_error: 2.1145
# Epoch 97/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0421 - mean_absolute_error: 0.1314 - mean_squared_error: 0.0388 - val_loss: 1.6972 - val_mean_absolute_error: 0.9665 - val_mean_squared_error: 1.6939
# Epoch 98/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0352 - mean_absolute_error: 0.1298 - mean_squared_error: 0.0319 - val_loss: 1.6073 - val_mean_absolute_error: 0.9383 - val_mean_squared_error: 1.6039
# Epoch 99/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0366 - mean_absolute_error: 0.1250 - mean_squared_error: 0.0333 - val_loss: 1.6065 - val_mean_absolute_error: 0.9305 - val_mean_squared_error: 1.6031
# Epoch 100/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0383 - mean_absolute_error: 0.1360 - mean_squared_error: 0.0350 - val_loss: 1.5558 - val_mean_absolute_error: 0.9232 - val_mean_squared_error: 1.5524
# Epoch 101/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0360 - mean_absolute_error: 0.1306 - mean_squared_error: 0.0327 - val_loss: 1.7025 - val_mean_absolute_error: 0.9734 - val_mean_squared_error: 1.6992
# Epoch 102/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0343 - mean_absolute_error: 0.1262 - mean_squared_error: 0.0310 - val_loss: 1.6342 - val_mean_absolute_error: 0.9522 - val_mean_squared_error: 1.6309
# Epoch 103/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0292 - mean_absolute_error: 0.1137 - mean_squared_error: 0.0259 - val_loss: 1.6105 - val_mean_absolute_error: 0.9344 - val_mean_squared_error: 1.6073
# Epoch 104/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0303 - mean_absolute_error: 0.1176 - mean_squared_error: 0.0271 - val_loss: 1.7194 - val_mean_absolute_error: 0.9676 - val_mean_squared_error: 1.7162
# Epoch 105/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0335 - mean_absolute_error: 0.1217 - mean_squared_error: 0.0303 - val_loss: 1.9535 - val_mean_absolute_error: 1.0296 - val_mean_squared_error: 1.9503
# Epoch 106/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0304 - mean_absolute_error: 0.1168 - mean_squared_error: 0.0272 - val_loss: 1.7627 - val_mean_absolute_error: 0.9748 - val_mean_squared_error: 1.7595
# Epoch 107/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0285 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0254 - val_loss: 1.5525 - val_mean_absolute_error: 0.9117 - val_mean_squared_error: 1.5493
# Epoch 108/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0284 - mean_absolute_error: 0.1064 - mean_squared_error: 0.0253 - val_loss: 1.9490 - val_mean_absolute_error: 1.0553 - val_mean_squared_error: 1.9458
# Epoch 109/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0288 - mean_absolute_error: 0.1140 - mean_squared_error: 0.0257 - val_loss: 1.6905 - val_mean_absolute_error: 0.9528 - val_mean_squared_error: 1.6874
# Epoch 110/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0305 - mean_absolute_error: 0.1127 - mean_squared_error: 0.0274 - val_loss: 1.9716 - val_mean_absolute_error: 1.0641 - val_mean_squared_error: 1.9685
# Epoch 111/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0478 - mean_absolute_error: 0.1412 - mean_squared_error: 0.0447 - val_loss: 2.3680 - val_mean_absolute_error: 1.1940 - val_mean_squared_error: 2.3649
# Epoch 112/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0319 - mean_absolute_error: 0.1190 - mean_squared_error: 0.0288 - val_loss: 1.5907 - val_mean_absolute_error: 0.9276 - val_mean_squared_error: 1.5876
# Epoch 113/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0406 - mean_absolute_error: 0.1436 - mean_squared_error: 0.0376 - val_loss: 1.6303 - val_mean_absolute_error: 0.9397 - val_mean_squared_error: 1.6273
# Epoch 114/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0279 - mean_absolute_error: 0.1070 - mean_squared_error: 0.0248 - val_loss: 1.6271 - val_mean_absolute_error: 0.9349 - val_mean_squared_error: 1.6241
# Epoch 115/200
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0367 - mean_absolute_error: 0.1284 - mean_squared_error: 0.0337 - val_loss: 1.4954 - val_mean_absolute_error: 0.8941 - val_mean_squared_error: 1.4924
# Epoch 116/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0296 - mean_absolute_error: 0.1059 - mean_squared_error: 0.0267 - val_loss: 1.6060 - val_mean_absolute_error: 0.9296 - val_mean_squared_error: 1.6030
# Epoch 117/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0242 - mean_absolute_error: 0.1044 - mean_squared_error: 0.0212 - val_loss: 1.5665 - val_mean_absolute_error: 0.9125 - val_mean_squared_error: 1.5635
# Epoch 118/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0294 - mean_absolute_error: 0.1080 - mean_squared_error: 0.0264 - val_loss: 1.9528 - val_mean_absolute_error: 1.0536 - val_mean_squared_error: 1.9499
# Epoch 119/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0268 - mean_absolute_error: 0.1112 - mean_squared_error: 0.0238 - val_loss: 1.7776 - val_mean_absolute_error: 0.9920 - val_mean_squared_error: 1.7747
# Epoch 120/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0234 - mean_absolute_error: 0.0991 - mean_squared_error: 0.0204 - val_loss: 1.6669 - val_mean_absolute_error: 0.9537 - val_mean_squared_error: 1.6640
# Epoch 121/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0395 - mean_absolute_error: 0.1368 - mean_squared_error: 0.0366 - val_loss: 1.4784 - val_mean_absolute_error: 0.8891 - val_mean_squared_error: 1.4755
# Epoch 122/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0292 - mean_absolute_error: 0.1148 - mean_squared_error: 0.0263 - val_loss: 1.8647 - val_mean_absolute_error: 1.0212 - val_mean_squared_error: 1.8618
# Epoch 123/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0408 - mean_absolute_error: 0.1294 - mean_squared_error: 0.0379 - val_loss: 1.5569 - val_mean_absolute_error: 0.9142 - val_mean_squared_error: 1.5541
# Epoch 124/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0249 - mean_absolute_error: 0.1057 - mean_squared_error: 0.0221 - val_loss: 1.5006 - val_mean_absolute_error: 0.8936 - val_mean_squared_error: 1.4978
# Epoch 125/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0252 - mean_absolute_error: 0.1017 - mean_squared_error: 0.0223 - val_loss: 1.3502 - val_mean_absolute_error: 0.8432 - val_mean_squared_error: 1.3474
# Epoch 126/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0328 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0300 - val_loss: 1.4099 - val_mean_absolute_error: 0.8643 - val_mean_squared_error: 1.4071
# Epoch 127/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0238 - mean_absolute_error: 0.1068 - mean_squared_error: 0.0210 - val_loss: 1.4231 - val_mean_absolute_error: 0.8624 - val_mean_squared_error: 1.4203
# Epoch 128/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0268 - mean_absolute_error: 0.1065 - mean_squared_error: 0.0240 - val_loss: 1.4367 - val_mean_absolute_error: 0.8706 - val_mean_squared_error: 1.4338
# Epoch 129/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0227 - mean_absolute_error: 0.0965 - mean_squared_error: 0.0199 - val_loss: 1.5391 - val_mean_absolute_error: 0.8931 - val_mean_squared_error: 1.5364
# Epoch 130/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0343 - mean_absolute_error: 0.1239 - mean_squared_error: 0.0315 - val_loss: 1.4705 - val_mean_absolute_error: 0.8828 - val_mean_squared_error: 1.4677
# Epoch 131/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0280 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0253 - val_loss: 1.5932 - val_mean_absolute_error: 0.9133 - val_mean_squared_error: 1.5905
# Epoch 132/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0277 - mean_absolute_error: 0.1139 - mean_squared_error: 0.0250 - val_loss: 1.7935 - val_mean_absolute_error: 0.9983 - val_mean_squared_error: 1.7908
# Epoch 133/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0322 - mean_absolute_error: 0.1160 - mean_squared_error: 0.0295 - val_loss: 1.4766 - val_mean_absolute_error: 0.8801 - val_mean_squared_error: 1.4739
# Epoch 134/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0253 - mean_absolute_error: 0.1060 - mean_squared_error: 0.0226 - val_loss: 1.5339 - val_mean_absolute_error: 0.9065 - val_mean_squared_error: 1.5312
# Epoch 135/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0261 - mean_absolute_error: 0.1125 - mean_squared_error: 0.0234 - val_loss: 1.4380 - val_mean_absolute_error: 0.8710 - val_mean_squared_error: 1.4353
# Epoch 136/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0576 - mean_absolute_error: 0.1493 - mean_squared_error: 0.0549 - val_loss: 1.3447 - val_mean_absolute_error: 0.8465 - val_mean_squared_error: 1.3421
# Epoch 137/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0333 - mean_absolute_error: 0.1154 - mean_squared_error: 0.0307 - val_loss: 1.3273 - val_mean_absolute_error: 0.8353 - val_mean_squared_error: 1.3247
# Epoch 138/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0271 - mean_absolute_error: 0.1111 - mean_squared_error: 0.0245 - val_loss: 1.2775 - val_mean_absolute_error: 0.8230 - val_mean_squared_error: 1.2748
# Epoch 139/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0230 - mean_absolute_error: 0.0956 - mean_squared_error: 0.0204 - val_loss: 1.3633 - val_mean_absolute_error: 0.8381 - val_mean_squared_error: 1.3607
# Epoch 140/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0225 - mean_absolute_error: 0.1048 - mean_squared_error: 0.0199 - val_loss: 1.3127 - val_mean_absolute_error: 0.8349 - val_mean_squared_error: 1.3100
# Epoch 141/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0185 - mean_absolute_error: 0.0875 - mean_squared_error: 0.0159 - val_loss: 1.3691 - val_mean_absolute_error: 0.8287 - val_mean_squared_error: 1.3664
# Epoch 142/200
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0267 - mean_absolute_error: 0.1066 - mean_squared_error: 0.0241 - val_loss: 1.3541 - val_mean_absolute_error: 0.8321 - val_mean_squared_error: 1.3514
# Epoch 143/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0540 - mean_absolute_error: 0.1430 - mean_squared_error: 0.0514 - val_loss: 1.8749 - val_mean_absolute_error: 1.0292 - val_mean_squared_error: 1.8723
# Epoch 144/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0324 - mean_absolute_error: 0.1221 - mean_squared_error: 0.0298 - val_loss: 1.3159 - val_mean_absolute_error: 0.8185 - val_mean_squared_error: 1.3133
# Epoch 145/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0255 - mean_absolute_error: 0.0968 - mean_squared_error: 0.0230 - val_loss: 1.3150 - val_mean_absolute_error: 0.8193 - val_mean_squared_error: 1.3124
# Epoch 146/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0254 - mean_absolute_error: 0.1047 - mean_squared_error: 0.0229 - val_loss: 1.2388 - val_mean_absolute_error: 0.8109 - val_mean_squared_error: 1.2363
# Epoch 147/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0228 - mean_absolute_error: 0.0953 - mean_squared_error: 0.0203 - val_loss: 1.3844 - val_mean_absolute_error: 0.8388 - val_mean_squared_error: 1.3819
# Epoch 148/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0183 - mean_absolute_error: 0.0869 - mean_squared_error: 0.0158 - val_loss: 1.4506 - val_mean_absolute_error: 0.8512 - val_mean_squared_error: 1.4481
# Epoch 149/200
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0226 - mean_absolute_error: 0.1001 - mean_squared_error: 0.0201 - val_loss: 1.2548 - val_mean_absolute_error: 0.8096 - val_mean_squared_error: 1.2523
# Epoch 150/200
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0166 - mean_absolute_error: 0.0821 - mean_squared_error: 0.0141 - val_loss: 1.3095 - val_mean_absolute_error: 0.8080 - val_mean_squared_error: 1.3069
# Epoch 151/200
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0236 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0211 - val_loss: 1.2904 - val_mean_absolute_error: 0.8212 - val_mean_squared_error: 1.2879
# Epoch 152/200
# 736/875 [========================>.....] - ETA: 1s - loss: 0.0236 - mean_absolute_error: 0.0999 - mean_squared_error: 0.0210

# %%
hist = pd.DataFrame(history.history)
hist['epoch']= history.epoch
hist.tail()
# Out:
#          val_loss  val_mean_absolute_error  val_mean_squared_error  \
# 195  6.650632e+07              6355.818481            6.650632e+07
# 196  6.275853e+07              6161.197162            6.275853e+07
# 197  5.944006e+07              5997.135702            5.944006e+07
# 198  6.229281e+07              6138.579988            6.229281e+07
# 199  6.106594e+07              6076.085226            6.106594e+07
#
#              loss  mean_absolute_error  mean_squared_error  epoch
# 195  1.702399e+06           881.769361        1.702399e+06    195
# 196  1.711892e+06           930.596856        1.711892e+06    196
# 197  1.580298e+06           893.164042        1.580298e+06    197
# 198  1.912179e+06           979.157146        1.912179e+06    198
# 199  1.614590e+06           912.569914        1.614590e+06    199

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
  #plt.ylim([0,5])
  plt.legend()
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')
  #plt.ylim([0,20])
  plt.legend()
  plt.show()


plot_history(history)

# %%
test_predictions = model.predict(norm_flux).flatten()

plt.scatter(normalize(teff), test_predictions)
plt.xlabel('True Values [Teff]')
plt.ylabel('Predictions [Teff]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

print('test predictions=', test_predictions)
# Out:
# test predictions= [ 6836.807   6837.5747  6836.7603 ... 10159.98   12968.633  12631.623 ]
